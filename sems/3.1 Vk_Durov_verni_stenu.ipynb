# %% [markdown]
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/vk2.png" height="450" width="450">
#
#
# # <center> Грабёж, разбой и другие незаконные деяния с помощью Python. <br> <br> Наше второе дело. Грабим Вконтакте.   </center>
# ---------

# %% [markdown]
# ## 1. Подготовка
#
# Многие сайты и сервисы хотят упростить жизнь программистам и предоставляют им в пользование уже готорвые куски кода, к которым можно просто обратиться и получить нужную инфомрацию о сервисе. Такие куски кода называются API (Application programming interface). Мы уже пользовались с вами API Google maps, когда качали цены домиков с ЦИАН. Теперь пришло время сделать то же самое с контактом! API это чуть ли не единственный способ добиться чего-либо от него. Ознакомиться с спсобами такого взаимодействия с вконтакте можно [по ссылке, о существовании которой вы даже не догадывались...](https://vk.com/dev/manuals) Да, да, это документация для разработчиков...
#
# Для того, чтобы получить доступ к выгрузке данных из вконтакте, нужно пройти ряд бюрократических процедур. А именно, получить ключ доступа - access token. Для этого:
#
# Создаем свое приложение. Заполняем все поля, загружаем предварительно подготовленные картинки нужного размера. Разрешаем доступ этому приложению к своей старнцие. Сделать это можно по ссылке: http://vk.com/editapp?act=create.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/vk6.png" height="500" width="500">
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/vk_2.png" height="600" width="600">
#
#
# Для работы с частью методов API вконтакте этого вполне достаточно (обычно в заголовке такого метода стоит соответствующая пометка). Для части методов, испульзуемых нами, может понадобиться ключ доступа.
#
# Для того, чтобы получить его необходимо сделать ещё пару странных манипуляций:
#
# Переходим по ссылке вида:
#
# > https://oauth.vk.com/authorize?client_id=**********&scope=friends&redirect_uri=https://oauth.vk.com/blank.html&display=page&v=5.16&response_type=token
#
#
# >https://oauth.vk.com/authorize?client_id=4887677&scope=friends&redirect_uri=https://oauth.vk.com/blank.html&display=page&v=5.16&response_type=token
#
# На месте звездочек должен стоять ID созданного вами приложения.
#
# В итоге по этому запросу будет сформирована ссылка следующего вида:
#
# > https://oauth.vk.com/blank.html#access_token=95b636116ef20e0798fe4dff380511fc13&expires_in=86400&user_id=6045249
#
#
# Первый набор знаков - access token, т.е. маркер доступа. Вторая цифра (expires_in=) время работы маркера доступа в секундах (одни сутки). По истечению суток нужно будет получить новый маркер доступа. Последняя цифра (user_id=) ваш ID Вконтакте. Нам в дальнейшем понадобится маркер доступа и ID.  Для удобства сохраним их.

# %%
token="5f686efffff8f4d7e10e263650bbb57c85773298165fb4669dc3d8d449178fbe761547fb25888016c42e9"
myid ="6045249"

# %% [markdown]
# ## 2. Честный сбор данных.

# %%
# Подгружаем уже знакомую нам библиотеку для запросов
import requests
# Подгружаем библиотеку для работы с матрицами и векторами
import numpy as np

# %% [markdown]
# Подробно узнать о том как задать вопрос Вконтакте можно по этой ссылке: https://new.vk.com/dev/api_requests. Как это можно выяснить по ссылке, любой запрос к Вконтакте должен иметь структуру следующего вида:
#
# > https://api.vk.com/method/METHOD_NAME?PARAMETERS&access_token=ACCESS_TOKEN&v=V
#
# По аналогии с Google maps в ссылку сначала встраивается метод, с помощью которого мы осуществляем запрос и какие-то параметры для этого метода.
#
# Список всех существующих методов и параметров для них можно изучить по ссылке  https://vk.com/dev/methods.
#
# Попробуем узнать своё имя. В списке методов можно узнать, что метод "users.get"  возвращает расширенную информацию о пользователе. Параметр user_ids отвечает за id польователей, о которых информацию нам хотелось бы вытащить.

# %%
url = "https://api.vk.com/method/users.get?user_ids=6045249&access_token="+str(token)

# %%
response = requests.get(url) 
response
# Out:
# <Response [200]>

# %% [markdown]
# Ура! Благославенный 200-ответ! Мы получили его в json формате по аналогии с Google-maps. Посмотрим что у нас тут...

# %%
my_name = response.json()
my_name
# Out:
# {'response': [{'first_name': 'Филипп',
#    'last_name': 'Ульянкин',
#    'uid': 6045249}]}

# %% [markdown]
# О боже! Это же питонячий словарь!

# %%
infa = my_name['response'][0]
infa
# Out:
# {'first_name': 'Филипп', 'last_name': 'Ульянкин', 'uid': 6045249}

# %%
infa['first_name'] + ' ' + infa['last_name']
# Out:
# 'Филипп Ульянкин'

# %% [markdown]
# Для того, чтобы узнать своё имя, нам потребовалась самая малость... Около 10 строк кода... Напишем функцию, которая поможет нам в дальнейшем тащить из вконтакте нужную информацию и перейдём к решению серьёзных проблем.

# %%
def Vk_downloader(method,parameters,token = token):
    url = 'https://api.vk.com/method/'+method+'?'+parameters+'&access_token='+str(token)
    response = requests.get(url) 
    return(response.json())

Vk_downloader('users.get','user_ids=6045249')
# Out:
# {'response': [{'first_name': 'Филипп',
#    'last_name': 'Ульянкин',
#    'uid': 6045249}]}

# %% [markdown]
# ## 3. Как распределены лайки?
#
# ### 3.1 Скачиваем лайки
#
# Вам когда-нибудь было интересно какое распределение у лайков? Пришло время получить ответ на этот вопрос! На самом деле ответ очевиден. Попробуйте угадать...
#
# Для начала выгрузим пару записей со своей стены, чтобы проверить работает ли команда. В качестве ответа на запрос мы получим длинный страшный кусок текста. В этом куске текста будет абсолютно все, что есть у нас на стене. Ссылки на картинки, количество лайков под каждой записью, подробная история того как и откуда был сделан репост записи и так далее. Нас будет интересовать среди всего этого огромного массива данных только одно число - количество лайков под каждой записью, которое будет идити после слова "likes". Вытащим два поста со своей стены и узнаем сколько под ними лайков.

# %%
wall = Vk_downloader('wall.get','user_ids=6045249')
wall
# Out:
# {'response': [128,
#   {'attachment': {'link': {'description': '',
#      'image_big': 'https://pp.userapi.com/c637125/v637125211/4a631/erB8NruZGbM.jpg',
#      'image_src': 'https://pp.userapi.com/c637125/v637125211/4a62f/dd-mIfW5B6s.jpg',
#      'preview_page': '1148727013_1565611111',
#      'preview_url': 'https://m.vk.com/article1148727013_1565611111?api_view=066215601cafa2506cbbc3e2b216da',
#      'target': 'external',
#      'title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#      'url': 'http://varlamov.ru/2359727.html'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c637125/v637125211/4a631/erB8NruZGbM.jpg',
#       'image_src': 'https://pp.userapi.com/c637125/v637125211/4a62f/dd-mIfW5B6s.jpg',
#       'preview_page': '1148727013_1565611111',
#       'preview_url': 'https://m.vk.com/article1148727013_1565611111?api_view=066215601cafa2506cbbc3e2b216da',
#       'target': 'external',
#       'title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#       'url': 'http://varlamov.ru/2359727.html'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 24},
#    'date': 1493975247,
#    'from_id': 6045249,
#    'id': 7159,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 14, 'user_likes': 0},
#    'media': {'share_title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#     'share_url': 'http://varlamov.ru/2359727.html',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 24,
#    'reposts': {'count': 1, 'user_reposted': 0},
#    'text': 'Немного о пятиэтажках... В моём районе довольно много пятиэтажек... Судя по всему скоро он превратится из пригодного для жизни места в огромную стройку, а после в огромный массив путинских муравейников... :(',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': 'Microsoft ограничила возможность выбора браузера и поисковой системы по умолчанию в своей новой системе Windows 10 S, следует из информации на сайте компании.',
#      'image_big': 'https://pp.userapi.com/c638323/v638323329/441d0/gBVMIXb1zNY.jpg',
#      'image_src': 'https://pp.userapi.com/c638323/v638323329/441ce/2tSPp6O7i8s.jpg',
#      'target': 'external',
#      'title': 'Microsoft запретила менять браузер и поисковик по умолчанию в новой Windows 10 S',
#      'url': 'https://vc.ru/n/windows-10s-default-browser'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': 'Microsoft ограничила возможность выбора браузера и поисковой системы по умолчанию в своей новой системе Windows 10 S, следует из информации на сайте компании.',
#       'image_big': 'https://pp.userapi.com/c638323/v638323329/441d0/gBVMIXb1zNY.jpg',
#       'image_src': 'https://pp.userapi.com/c638323/v638323329/441ce/2tSPp6O7i8s.jpg',
#       'target': 'external',
#       'title': 'Microsoft запретила менять браузер и поисковик по умолчанию в новой Windows 10 S',
#       'url': 'https://vc.ru/n/windows-10s-default-browser'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 5},
#    'copy_owner_id': -33393308,
#    'copy_post_date': 1493817317,
#    'copy_post_id': 455945,
#    'copy_post_type': 'post',
#    'copy_text': 'Кто бы мог подумать... Я просто оставлю вот эту вот ссылку вот здесь. Всем свободного софта! ;) <br>http://ubuntu.ru/',
#    'date': 1493818683,
#    'from_id': 6045249,
#    'id': 7153,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 4, 'user_likes': 0},
#    'media': {'share_title': 'Microsoft запретила менять браузер и поисковик по умолчанию в новой Windows 10 S',
#     'share_url': 'https://vc.ru/n/windows-10s-default-browser',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 5,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Оказывается, в новой Windows 10 нельзя менять браузер и поиск по умолчанию — система всегда будет использовать Microsoft Edge и Bing.<br><br>Ограничение можно снять, обновившись до Windows 10 Pro. До конца года это можно сделать бесплатно, затем — за дополнительные $50<br><br>https://vc.ru/n/windows-10s-default-browser',
#    'to_id': 6045249},
#   {'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': 91857120,
#    'copy_post_date': 1493073344,
#    'copy_post_id': 1929,
#    'copy_post_type': 'post',
#    'copy_text': 'wow',
#    'date': 1493073840,
#    'from_id': 6045249,
#    'id': 7152,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 12, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Захабрился :)<br><br>Оригинал: https://vk.com/wall-20629724_1008902',
#    'to_id': 6045249},
#   {'attachment': {'photo': {'access_key': '3bc882fa96da982bd1',
#      'aid': -7,
#      'created': 1491829729,
#      'height': 471,
#      'owner_id': -84793390,
#      'pid': 456239248,
#      'post_id': 2154,
#      'src': 'https://pp.userapi.com/c636418/v636418231/56778/Fw5Z0PaeJzQ.jpg',
#      'src_big': 'https://pp.userapi.com/c636418/v636418231/56779/T33fMexK25U.jpg',
#      'src_small': 'https://pp.userapi.com/c636418/v636418231/56777/om-Fuqq0Udk.jpg',
#      'src_xbig': 'https://pp.userapi.com/c636418/v636418231/5677a/rN_ZsyAnETQ.jpg',
#      'text': '',
#      'user_id': 100,
#      'width': 800},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '3bc882fa96da982bd1',
#       'aid': -7,
#       'created': 1491829729,
#       'height': 471,
#       'owner_id': -84793390,
#       'pid': 456239248,
#       'post_id': 2154,
#       'src': 'https://pp.userapi.com/c636418/v636418231/56778/Fw5Z0PaeJzQ.jpg',
#       'src_big': 'https://pp.userapi.com/c636418/v636418231/56779/T33fMexK25U.jpg',
#       'src_small': 'https://pp.userapi.com/c636418/v636418231/56777/om-Fuqq0Udk.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636418/v636418231/5677a/rN_ZsyAnETQ.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 800},
#      'type': 'photo'},
#     {'link': {'description': 'Яндекс.Алгоритм — это открытый чемпионат по спортивному программированию с оригинальными правилами, сложными алгоритмическими задачами и денежными призами. Уже несколько лет чемпионат проходит в несколько этапов — разминочный, квалификационный, отборочный и финальный. Разминочный раунд начнётся 22 апреля в 16:00 (UTC+3) &lt;http://timeanddate.com/worldclock…',
#       'target': 'external',
#       'title': 'Регистрация открыта! — Алгоритм 2017',
#       'url': 'https://contest.yandex.ru/algorithm2017/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': -84793390,
#    'copy_post_date': 1491829726,
#    'copy_post_id': 2154,
#    'copy_post_type': 'post',
#    'date': 1491939376,
#    'from_id': 6045249,
#    'id': 7151,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 2, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Мы начали приём заявок на чемпионат по спортивному программированию Яндекс.Алгоритм. В этом году он пройдет уже в шестой раз — https://contest.yandex.ru/algorithm2017/.<br><br>У Алгоритма есть несколько особенностей. Во-первых, он проходит в интернете, на платформе Яндекс.Контест — присоединиться можно из любой точки мира. Во-вторых, это индивидуальное состязание — каждый сам за себя. Наконец, участвовать может любой желающий — образование и род занятий не имеют значения. Разминочный раунд начнется 22 апреля в 16:00 и продлится 100 минут. Регистрация уже открыта — не пропустите!<br><br>Что нового ожидает участников в этом году, расписание, призы и прочие подробности читайте в блоге Яндекса — https://yandex.ru/blog/company/yandeks-algoritm-2017',
#    'to_id': 6045249},
#   {'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 10},
#    'date': 1491322806,
#    'from_id': 6045249,
#    'id': 7135,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 11, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 10,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Если меня когда-нибудь спросят: "Филипп, а где работают самые некомпетентные кретины?" Я не задумываясь отвечу: "Росстат".',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': 'A visual introduction to probability and statistics.',
#      'image_big': 'https://pp.userapi.com/c638119/v638119573/345d8/xFvOPkO00S8.jpg',
#      'image_src': 'https://pp.userapi.com/c638119/v638119573/345d6/oa_5C7h_KDo.jpg',
#      'target': 'external',
#      'title': 'Seeing Theory',
#      'url': 'http://students.brown.edu/seeing-theory/index.html'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': 'A visual introduction to probability and statistics.',
#       'image_big': 'https://pp.userapi.com/c638119/v638119573/345d8/xFvOPkO00S8.jpg',
#       'image_src': 'https://pp.userapi.com/c638119/v638119573/345d6/oa_5C7h_KDo.jpg',
#       'target': 'external',
#       'title': 'Seeing Theory',
#       'url': 'http://students.brown.edu/seeing-theory/index.html'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 2},
#    'date': 1490783566,
#    'from_id': 6045249,
#    'id': 7126,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 12, 'user_likes': 0},
#    'media': {'share_title': 'Seeing Theory',
#     'share_url': 'http://students.brown.edu/seeing-theory/index.html',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 2,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'И в вашу ленту только что попала очередная богоподобная визуализация! На этот раз она связана с тервером и матстатом... Сложные вещи - наглядно. <br><br>http://students.brown.edu/seeing-theory/index.html',
#    'to_id': 6045249},
#   {'attachment': {'photo': {'access_key': 'c46344a88af0091717',
#      'aid': -7,
#      'created': 1489926249,
#      'height': 768,
#      'owner_id': 6045249,
#      'pid': 456240079,
#      'src': 'https://pp.userapi.com/c638931/v638931249/2ba57/wWU5ZwG2D5E.jpg',
#      'src_big': 'https://pp.userapi.com/c638931/v638931249/2ba58/8rhnsvzrb9Q.jpg',
#      'src_small': 'https://pp.userapi.com/c638931/v638931249/2ba56/epFQoUjDaYA.jpg',
#      'src_xbig': 'https://pp.userapi.com/c638931/v638931249/2ba59/gTqzzbVvxeo.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c638931/v638931249/2ba5a/SmKuipmJdo8.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c638931/v638931249/2ba51/tGAC1QSgwUo.jpg',
#      'text': '',
#      'width': 1366},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'c46344a88af0091717',
#       'aid': -7,
#       'created': 1489926249,
#       'height': 768,
#       'owner_id': 6045249,
#       'pid': 456240079,
#       'src': 'https://pp.userapi.com/c638931/v638931249/2ba57/wWU5ZwG2D5E.jpg',
#       'src_big': 'https://pp.userapi.com/c638931/v638931249/2ba58/8rhnsvzrb9Q.jpg',
#       'src_small': 'https://pp.userapi.com/c638931/v638931249/2ba56/epFQoUjDaYA.jpg',
#       'src_xbig': 'https://pp.userapi.com/c638931/v638931249/2ba59/gTqzzbVvxeo.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c638931/v638931249/2ba5a/SmKuipmJdo8.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c638931/v638931249/2ba51/tGAC1QSgwUo.jpg',
#       'text': '',
#       'width': 1366},
#      'type': 'photo'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 1},
#    'date': 1489925418,
#    'from_id': 6045249,
#    'id': 7116,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 7, 'user_likes': 0},
#    'media': {'item_id': 456240079,
#     'owner_id': 6045249,
#     'thumb_src': 'https://pp.userapi.com/c638931/v638931249/2ba57/wWU5ZwG2D5E.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 1,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Немного богоподобной визуализации всем в ленту!<br><br>http://stuffin.space/?intldes=1965-108M - разные объект, которые вращаются вокруг Земли! От спутников до космического мусора...<br><br>http://flowingdata.com/2016/01/19/how-you-will-die/ - визуализция того как мы все умрём и во сколько лет...<br><br>http://names.mercator.ru/ - можно узнать насколько популярным было ваше имя в Москве в предыдущие эпохи и насколько оно популярно сейчас.',
#    'to_id': 6045249},
#   {'attachment': {'photo': {'access_key': '0b3c539a07f972e12a',
#      'aid': -7,
#      'created': 1489675420,
#      'height': 1280,
#      'owner_id': 6045249,
#      'pid': 456240072,
#      'post_id': 7107,
#      'src': 'https://pp.userapi.com/c626124/v626124249/54a90/PGERFc9zeE8.jpg',
#      'src_big': 'https://pp.userapi.com/c626124/v626124249/54a91/QD6hvimPGZo.jpg',
#      'src_small': 'https://pp.userapi.com/c626124/v626124249/54a8f/Rib-5lStjUQ.jpg',
#      'src_xbig': 'https://pp.userapi.com/c626124/v626124249/54a92/fWn6pnH26ac.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c626124/v626124249/54a93/kTsmKU5IMOQ.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c626124/v626124249/54a94/BmcjJ4Z3XSg.jpg',
#      'text': '',
#      'width': 960},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '0b3c539a07f972e12a',
#       'aid': -7,
#       'created': 1489675420,
#       'height': 1280,
#       'owner_id': 6045249,
#       'pid': 456240072,
#       'post_id': 7107,
#       'src': 'https://pp.userapi.com/c626124/v626124249/54a90/PGERFc9zeE8.jpg',
#       'src_big': 'https://pp.userapi.com/c626124/v626124249/54a91/QD6hvimPGZo.jpg',
#       'src_small': 'https://pp.userapi.com/c626124/v626124249/54a8f/Rib-5lStjUQ.jpg',
#       'src_xbig': 'https://pp.userapi.com/c626124/v626124249/54a92/fWn6pnH26ac.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c626124/v626124249/54a93/kTsmKU5IMOQ.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c626124/v626124249/54a94/BmcjJ4Z3XSg.jpg',
#       'text': '',
#       'width': 960},
#      'type': 'photo'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 5},
#    'date': 1489675533,
#    'from_id': 6045249,
#    'id': 7107,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 27, 'user_likes': 0},
#    'media': {'item_id': 456240072,
#     'owner_id': 6045249,
#     'thumb_src': 'https://pp.userapi.com/c626124/v626124249/54a90/PGERFc9zeE8.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 5,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'То самое чувство, когда за LaTeX люди продают тебе душу :D',
#    'to_id': 6045249},
#   {'attachment': {'doc': {'access_key': 'f2f6413d88b45c6963',
#      'date': 1488808945,
#      'did': 442883528,
#      'ext': 'gif',
#      'owner_id': 6822132,
#      'size': 523233,
#      'thumb': 'https://pp.userapi.com/c810220/u423277263/-3/m_4973f7caff.jpg',
#      'thumb_s': 'https://pp.userapi.com/c810220/u423277263/-3/s_4973f7caff.jpg',
#      'title': 'sc2smwcggkjy.gif',
#      'url': 'https://vk.com/doc6822132_442883528?hash=804caa04985d1bfbd3&dl=GYYDINJSGQ4Q:1494431905:d74dc89a1c35aa083b&api=1&no_preview=1'},
#     'type': 'doc'},
#    'attachments': [{'doc': {'access_key': 'f2f6413d88b45c6963',
#       'date': 1488808945,
#       'did': 442883528,
#       'ext': 'gif',
#       'owner_id': 6822132,
#       'size': 523233,
#       'thumb': 'https://pp.userapi.com/c810220/u423277263/-3/m_4973f7caff.jpg',
#       'thumb_s': 'https://pp.userapi.com/c810220/u423277263/-3/s_4973f7caff.jpg',
#       'title': 'sc2smwcggkjy.gif',
#       'url': 'https://vk.com/doc6822132_442883528?hash=804caa04985d1bfbd3&dl=GYYDINJSGQ4Q:1494431905:d74dc89a1c35aa083b&api=1&no_preview=1'},
#      'type': 'doc'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 2},
#    'copy_owner_id': -33393308,
#    'copy_post_date': 1488808954,
#    'copy_post_id': 439403,
#    'copy_post_type': 'post',
#    'date': 1488809033,
#    'from_id': 6045249,
#    'id': 7102,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 7, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 2,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Инструкция при появлении машины Google Maps: «Не теряйтесь, действуйте» <br> <br>via https://www.reddit.com/user/Jerken',
#    'to_id': 6045249},
#   {'attachment': {'photo': {'access_key': 'b2714aa8e66bea733b',
#      'aid': -7,
#      'created': 1488473399,
#      'height': 720,
#      'owner_id': 6045249,
#      'pid': 456239951,
#      'post_id': 7097,
#      'src': 'https://pp.userapi.com/c626124/v626124249/51984/lCfngimmYs0.jpg',
#      'src_big': 'https://pp.userapi.com/c626124/v626124249/51985/TfqtKry3qtw.jpg',
#      'src_small': 'https://pp.userapi.com/c626124/v626124249/51983/4Cdpd3t_b00.jpg',
#      'src_xbig': 'https://pp.userapi.com/c626124/v626124249/51986/LDZsZ_m4uj0.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c626124/v626124249/51987/gqk5cQ8iGJA.jpg',
#      'text': '',
#      'width': 1280},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'b2714aa8e66bea733b',
#       'aid': -7,
#       'created': 1488473399,
#       'height': 720,
#       'owner_id': 6045249,
#       'pid': 456239951,
#       'post_id': 7097,
#       'src': 'https://pp.userapi.com/c626124/v626124249/51984/lCfngimmYs0.jpg',
#       'src_big': 'https://pp.userapi.com/c626124/v626124249/51985/TfqtKry3qtw.jpg',
#       'src_small': 'https://pp.userapi.com/c626124/v626124249/51983/4Cdpd3t_b00.jpg',
#       'src_xbig': 'https://pp.userapi.com/c626124/v626124249/51986/LDZsZ_m4uj0.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c626124/v626124249/51987/gqk5cQ8iGJA.jpg',
#       'text': '',
#       'width': 1280},
#      'type': 'photo'},
#     {'audio': {'aid': 456240377,
#       'artist': 'The Coral',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 2,
#       'lyrics_id': 3120961,
#       'owner_id': 2000313358,
#       'performer': 'The Coral',
#       'title': 'Dreaming Of You'},
#      'type': 'audio'},
#     {'audio': {'aid': 456239981,
#       'artist': 'The Shins',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 2,
#       'owner_id': 2000315166,
#       'performer': 'The Shins',
#       'title': 'New Slang'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240326,
#       'artist': 'Joseph Arthur',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 18,
#       'lyrics_id': 3103222,
#       'owner_id': 2000313613,
#       'performer': 'Joseph Arthur',
#       'title': 'In the Sun'},
#      'type': 'audio'},
#     {'audio': {'aid': 456239945,
#       'artist': 'Jeremy Kay',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 2,
#       'owner_id': 2000315437,
#       'performer': 'Jeremy Kay',
#       'title': 'Have It All'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240281,
#       'artist': 'Colin Hay',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 2,
#       'lyrics_id': 10327823,
#       'owner_id': 2000313596,
#       'performer': 'Colin Hay',
#       'title': 'Overkill'},
#      'type': 'audio'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 4},
#    'date': 1488473491,
#    'from_id': 6045249,
#    'id': 7097,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 12, 'user_likes': 0},
#    'media': {'item_id': 456240281, 'owner_id': 2000313596, 'type': 'audio'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 4,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Omg i am so indy',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': 'История создания фильма «Прибытие» (без спойлеров), рассказанная научным консультантом фильма, Стивеном Вольфрамом Связываемся с Голливудом «Интересный...',
#      'image_big': 'https://pp.userapi.com/c636731/v636731186/51078/OE2nu__ZCdg.jpg',
#      'image_src': 'https://pp.userapi.com/c636731/v636731186/51076/gYYHYr_jJwk.jpg',
#      'preview_page': '1114962946_805811514',
#      'preview_url': 'https://m.vk.com/article1114962946_805811514?api_view=59748c11808281859cbbc28b250e42',
#      'target': 'external',
#      'title': 'Как мог бы работать инопланетный космический корабль?         перевод',
#      'url': 'https://geektimes.ru/post/282786/'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': 'История создания фильма «Прибытие» (без спойлеров), рассказанная научным консультантом фильма, Стивеном Вольфрамом Связываемся с Голливудом «Интересный...',
#       'image_big': 'https://pp.userapi.com/c636731/v636731186/51078/OE2nu__ZCdg.jpg',
#       'image_src': 'https://pp.userapi.com/c636731/v636731186/51076/gYYHYr_jJwk.jpg',
#       'preview_page': '1114962946_805811514',
#       'preview_url': 'https://m.vk.com/article1114962946_805811514?api_view=59748c11808281859cbbc28b250e42',
#       'target': 'external',
#       'title': 'Как мог бы работать инопланетный космический корабль?         перевод',
#       'url': 'https://geektimes.ru/post/282786/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'date': 1487773558,
#    'from_id': 1634318,
#    'id': 7094,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 2, 'user_likes': 0},
#    'media': {'share_title': 'Как мог бы работать инопланетный космический корабль?         перевод',
#     'share_url': 'https://geektimes.ru/post/282786/',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Для чего еще нужен Wolfram Mathematica :)<br>https://geektimes.ru/post/282786/',
#    'to_id': 6045249},
#   {'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': -24086381,
#    'copy_post_date': 1487344190,
#    'copy_post_id': 51704,
#    'copy_post_type': 'post',
#    'date': 1487348527,
#    'from_id': 6045249,
#    'id': 7092,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 14, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'platform': 'iphone', 'type': 'api'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': '- сколько вам нужно времени для решения этой задачи?<br>- сделаю за час в течение недели до конца этого месяца',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': '',
#      'image_src': 'https://pp.userapi.com/c837222/v837222249/25ac9/_19KwjwD4dE.jpg',
#      'target': 'external',
#      'title': 'My Galaxies',
#      'url': 'http://mygalaxies.co.uk/'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': '',
#       'image_src': 'https://pp.userapi.com/c837222/v837222249/25ac9/_19KwjwD4dE.jpg',
#       'target': 'external',
#       'title': 'My Galaxies',
#       'url': 'http://mygalaxies.co.uk/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 2},
#    'date': 1486893375,
#    'from_id': 6045249,
#    'id': 7088,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 1, 'user_likes': 0},
#    'media': {'share_title': 'My Galaxies',
#     'share_url': 'http://mygalaxies.co.uk/',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 2,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Есть возможность написать любое слово из реально существующих на небе галактик...',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': '',
#      'image_big': 'https://pp.userapi.com/c837533/v837533036/1be3b/Fw6f9rw-FcY.jpg',
#      'image_src': 'https://pp.userapi.com/c837533/v837533036/1be39/JlBl47rpM0U.jpg',
#      'target': 'external',
#      'title': 'SSC: Blue Eyes Blue',
#      'url': 'http://yagudin.tilda.ws/blue-eyes-blue'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c837533/v837533036/1be3b/Fw6f9rw-FcY.jpg',
#       'image_src': 'https://pp.userapi.com/c837533/v837533036/1be39/JlBl47rpM0U.jpg',
#       'target': 'external',
#       'title': 'SSC: Blue Eyes Blue',
#       'url': 'http://yagudin.tilda.ws/blue-eyes-blue'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': 94844036,
#    'copy_post_date': 1483813495,
#    'copy_post_id': 278,
#    'copy_post_type': 'post',
#    'copy_text': 'Воля бога Вулкана и есть истина!',
#    'date': 1486233447,
#    'from_id': 6045249,
#    'id': 7080,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 5, 'user_likes': 0},
#    'media': {'share_title': 'SSC: Blue Eyes Blue',
#     'share_url': 'http://yagudin.tilda.ws/blue-eyes-blue',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'IT WAS YOU WHO MADE MY BLUE EYES BLUE<br>yagudin.tilda.ws/blue-eyes-blue<br><br>Перевёл замечательный рассказ Скотта Александера. Завязка — эпистемическая головоломка Литтлвуда про всеобщее знание (common knowledge), которую я первый раз услышал на математическом кружке в следующей формулировке:<br><br>Едут в вагоне поезда N мудрецов. За окнами прелестный пейзаж. Поезд то и дело ныряет в туннели. Дух захватывает. Собрались все мудрецы в коридоре вагона, в открытые окна глядят, не наглядятся. Вдруг в одном туннеле грохот, дым, пыль! Грязь какая-то в окна посыпалась. Проехали туннель — входит проводник. «Тут кое-кто испачкался, — говорит. — В поезде, к сожалению, воды нет. Но сейчас подряд большие остановки пойдут, так что можно будет выйти из поезда и помыться».<br>Надобно вас теперь предупредить — мудрецы в вагоне собрались как на подбор: столь же умные, сколь ленивые. Никто, скажем, зря мыться не пойдет (если не знает наверняка, что испачкался). И у соседей не спросит, чистое у него лицо или грязное — зачем напрасно людей тревожить и самому беспокоиться? — проще сообразить.<br>Что же сделают мудрецы после объявления проводника?<br><br>Оригинал: slatestarcodex.com/2015/10/15/it-was-you-who-made-my-blue-eyes-blue/<br>Больше переводов статей и рассказов (рекомендую «Размышления о Молохе»): vk.com/slatestarcodex<br><br>Статья в «Кванте» с решением: problems.ru/articles/215.php<br>Хороший текст про common knowledge: scottaaronson.com/blog/?p=2410',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': '',
#      'image_big': 'https://pp.userapi.com/c626617/v626617209/453a1/IO8hbvpQ7tE.jpg',
#      'image_src': 'https://pp.userapi.com/c626617/v626617209/4539f/nGZ__YH0CB8.jpg',
#      'target': 'external',
#      'title': 'ФИС «На Дальний Восток»',
#      'url': 'https://надальнийвосток.рф/'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': '',
#       'image_big': 'https://pp.userapi.com/c626617/v626617209/453a1/IO8hbvpQ7tE.jpg',
#       'image_src': 'https://pp.userapi.com/c626617/v626617209/4539f/nGZ__YH0CB8.jpg',
#       'target': 'external',
#       'title': 'ФИС «На Дальний Восток»',
#       'url': 'https://надальнийвосток.рф/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 13},
#    'date': 1485984200,
#    'from_id': 6045249,
#    'id': 7068,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 8, 'user_likes': 0},
#    'media': {'share_title': 'ФИС «На Дальний Восток»',
#     'share_url': 'https://надальнийвосток.рф/',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 13,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Ребята! Если кто-то берёт себе землю на Дальнем Востоке, то давайте брать её по соседству! Хочу хороших соседей :)',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': 'Двухдневная Data Science конференция',
#      'image_src': 'https://pp.userapi.com/c837639/v837639249/215a1/NW8ezX8xnVs.jpg',
#      'target': 'external',
#      'title': 'Data Fest⁴ 11-12 Февраля',
#      'url': 'http://datafest.ru/'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': 'Двухдневная Data Science конференция',
#       'image_src': 'https://pp.userapi.com/c837639/v837639249/215a1/NW8ezX8xnVs.jpg',
#       'target': 'external',
#       'title': 'Data Fest⁴ 11-12 Февраля',
#       'url': 'http://datafest.ru/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'date': 1485261569,
#    'from_id': 6045249,
#    'id': 7066,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 4, 'user_likes': 0},
#    'media': {'share_title': 'Data Fest⁴ 11-12 Февраля',
#     'share_url': 'http://datafest.ru/',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': '😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍',
#    'to_id': 6045249},
#   {'attachment': {'type': 'video',
#     'video': {'access_key': '971501d94387e0786c',
#      'date': 1458724733,
#      'description': 'MitchiriNeko March LINE Sticker has appeared !<br>http://line.me/S/sticker/1094344<br><br>「みっちりねこマーチ」のLINEスタンプ発売中！<br><br>「みっちりねこ」のWEBコミック最新号はマンガボックスで！A cute cat cartoon characters in a marching band! - The latest episode of its web comics is available at Manga Box! English editions are coming soon.<br>https://www.mangabox.me/<br>https://www.mangabox.me/reader/23829/<br><br>この動画の曲「みっちりねこマーチ」発売中です！<br>This video\'s music "MitchiriNeko March" is now on sale!<br>https://itunes.apple.com/jp/album/mitchiri-neko-',
#      'duration': 181,
#      'image': 'https://pp.userapi.com/c628621/u19371535/video/l_dccd125b.jpg',
#      'image_big': 'https://pp.userapi.com/c628621/u19371535/video/l_dccd125b.jpg',
#      'image_small': 'https://pp.userapi.com/c628621/u19371535/video/s_dad4ae32.jpg',
#      'image_xbig': 'https://pp.userapi.com/c628621/u19371535/video/y_9de6d68a.jpg',
#      'owner_id': -28903348,
#      'platform': 'YouTube',
#      'title': 'みっちりねこマーチ - MitchiriNeko March',
#      'vid': 456239023,
#      'views': 62311}},
#    'attachments': [{'type': 'video',
#      'video': {'access_key': '971501d94387e0786c',
#       'date': 1458724733,
#       'description': 'MitchiriNeko March LINE Sticker has appeared !<br>http://line.me/S/sticker/1094344<br><br>「みっちりねこマーチ」のLINEスタンプ発売中！<br><br>「みっちりねこ」のWEBコミック最新号はマンガボックスで！A cute cat cartoon characters in a marching band! - The latest episode of its web comics is available at Manga Box! English editions are coming soon.<br>https://www.mangabox.me/<br>https://www.mangabox.me/reader/23829/<br><br>この動画の曲「みっちりねこマーチ」発売中です！<br>This video\'s music "MitchiriNeko March" is now on sale!<br>https://itunes.apple.com/jp/album/mitchiri-neko-',
#       'duration': 181,
#       'image': 'https://pp.userapi.com/c628621/u19371535/video/l_dccd125b.jpg',
#       'image_big': 'https://pp.userapi.com/c628621/u19371535/video/l_dccd125b.jpg',
#       'image_small': 'https://pp.userapi.com/c628621/u19371535/video/s_dad4ae32.jpg',
#       'image_xbig': 'https://pp.userapi.com/c628621/u19371535/video/y_9de6d68a.jpg',
#       'owner_id': -28903348,
#       'platform': 'YouTube',
#       'title': 'みっちりねこマーチ - MitchiriNeko March',
#       'vid': 456239023,
#       'views': 62311}}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'date': 1485127446,
#    'from_id': 6045249,
#    'id': 7065,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 19, 'user_likes': 0},
#    'media': {'item_id': 456239023, 'owner_id': -28903348, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Когда спустя неделю твой код заработал.',
#    'to_id': 6045249},
#   {'attachment': {'photo': {'access_key': '4f275c7de2432324b8',
#      'aid': -7,
#      'created': 1484560209,
#      'height': 650,
#      'owner_id': -63337812,
#      'pid': 456240479,
#      'post_id': 316654,
#      'src': 'https://pp.userapi.com/c836127/v836127790/1f5ac/bMdL5gulM5M.jpg',
#      'src_big': 'https://pp.userapi.com/c836127/v836127790/1f5ad/I0vZeZ_9FbY.jpg',
#      'src_small': 'https://pp.userapi.com/c836127/v836127790/1f5ab/B5Ej-dwr-WQ.jpg',
#      'src_xbig': 'https://pp.userapi.com/c836127/v836127790/1f5ae/RFfYL379sxo.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c836127/v836127790/1f5af/jKyOIiEvs58.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c836127/v836127790/1f5b0/JTOOZhnjHoE.jpg',
#      'text': '',
#      'user_id': 100,
#      'width': 1300},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '4f275c7de2432324b8',
#       'aid': -7,
#       'created': 1484560209,
#       'height': 650,
#       'owner_id': -63337812,
#       'pid': 456240479,
#       'post_id': 316654,
#       'src': 'https://pp.userapi.com/c836127/v836127790/1f5ac/bMdL5gulM5M.jpg',
#       'src_big': 'https://pp.userapi.com/c836127/v836127790/1f5ad/I0vZeZ_9FbY.jpg',
#       'src_small': 'https://pp.userapi.com/c836127/v836127790/1f5ab/B5Ej-dwr-WQ.jpg',
#       'src_xbig': 'https://pp.userapi.com/c836127/v836127790/1f5ae/RFfYL379sxo.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c836127/v836127790/1f5af/jKyOIiEvs58.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c836127/v836127790/1f5b0/JTOOZhnjHoE.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 1300},
#      'type': 'photo'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': -63337812,
#    'copy_post_date': 1484910604,
#    'copy_post_id': 316654,
#    'copy_post_type': 'post',
#    'copy_text': '- Тук тук<br>- Кто там?<br>- Будущее',
#    'date': 1484910730,
#    'from_id': 6045249,
#    'id': 7064,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 7, 'user_likes': 0},
#    'media': {'item_id': 456240479,
#     'owner_id': -63337812,
#     'thumb_src': 'https://pp.userapi.com/c836127/v836127790/1f5ac/bMdL5gulM5M.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'В Нормандии открылась первая в мире дорога из солнечных батарей<br><br>На северо-западе Франции состоялось открытие участка первой в мире автодороги Wattway, покрытие которой изготовлено из специальных панелей с солнечными батареями. Экспериментальный участок дороги, протяженностью около одного километра, расположен в Нормандии в районе города Турувр.<br><br>Общая площадь вмонтированных в покрытие солнечных батарей составляет 28 квадратных километров. Батареи в свою очередь покрыты резиной и подключены к местной электросети. <br> <br>В среднем по дороге в Турувре проезжают две тысячи автомобилей каждый день. При оптимальных условиях "солнечная" дорога сможет генерировать 280 кВт энергии в час. Это обеспечит городок с населением пять тысяч жителей уличным освещением на протяжении целого года. <br> <br>Как сообщает ТАСС, в церемонии открытия автодороги приняла участие министр экологии, устойчивого развития и энергетики страны Сеголен Руаяль, которая отметила, что "использование поверхности автодорог для размещения панно, превращающих энергию солнечного света в электричество, позволяет сэкономить земли, пригодные для ведения сельского хозяйства". Она также объявила о четырехлетнем плане по строительству "солнечных" магистралей в Бретани и Марселе.<br><br>Отметим, что впервые солнечные батареи в качестве дорожного покрытия были применены два года назад на велодорожке в Нидерландах. На начальной фазе эксперимент показал, что происходит весьма быстрый износ поверхности солнечных батарей, особенно в зимнее время. В дальнейшем голландские инженеры сумели решить эту проблему. <br> <br>Другим недостатком подобных дорог является то, что солнечные батареи работают более эффективно, находясь под углом к солнцу, как правило, на пологих крышах домов, а не на горизонтальной поверхности. Кроме того, каждый киловатт-пик (единица измерения солнечных систем) Wattway в настоящее время стоит 17 евро, а киловатт-пик подобной установки на крыше обходится в 1,30 евро.',
#    'to_id': 6045249},
#   {'attachment': {'link': {'description': 'В Москве прошел первый хакатон стриптиз-индустрии. Поскольку никто не смог доказать обратного, можно с уверенностью сказать, что впервые в мире соревнование программистов проходило в окружении оголенных девушек и с перерывом на приватные танцы.',
#      'image_big': 'https://pp.userapi.com/c604617/v604617249/29adf/zfy9tIkUN2A.jpg',
#      'image_src': 'https://pp.userapi.com/c604617/v604617249/29add/2QDBpb884Lg.jpg',
#      'target': 'external',
#      'title': 'Хакатон на раздевание',
#      'url': 'http://www.content-review.com/articles/38121/'},
#     'type': 'link'},
#    'attachments': [{'link': {'description': 'В Москве прошел первый хакатон стриптиз-индустрии. Поскольку никто не смог доказать обратного, можно с уверенностью сказать, что впервые в мире соревнование программистов проходило в окружении оголенных девушек и с перерывом на приватные танцы.',
#       'image_big': 'https://pp.userapi.com/c604617/v604617249/29adf/zfy9tIkUN2A.jpg',
#       'image_src': 'https://pp.userapi.com/c604617/v604617249/29add/2QDBpb884Lg.jpg',
#       'target': 'external',
#       'title': 'Хакатон на раздевание',
#       'url': 'http://www.content-review.com/articles/38121/'},
#      'type': 'link'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 1},
#    'date': 1484434220,
#    'from_id': 6045249,
#    'id': 7062,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 10, 'user_likes': 0},
#    'media': {'share_title': 'Хакатон на раздевание',
#     'share_url': 'http://www.content-review.com/articles/38121/',
#     'type': 'share'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 1,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'text': 'Алло, да. Я на хакатоне. Программирую. Данные? Да, данные очень большие. Нет, нет. Нейронка обучается довольно таки быстро...',
#    'to_id': 6045249},
#   {'attachment': {'doc': {'access_key': 'c402e6dd5f483c3507',
#      'date': 1484095178,
#      'did': 440910268,
#      'ext': 'pdf',
#      'owner_id': 6356042,
#      'size': 531564,
#      'title': 'ml_problems_kantor.pdf',
#      'url': 'https://vk.com/doc6356042_440910268?hash=d0a08f2e236553442b&dl=GYYDINJSGQ4Q:1494431905:bbf8c651f4f3e1e7e3&api=1&no_preview=1'},
#     'type': 'doc'},
#    'attachments': [{'doc': {'access_key': 'c402e6dd5f483c3507',
#       'date': 1484095178,
#       'did': 440910268,
#       'ext': 'pdf',
#       'owner_id': 6356042,
#       'size': 531564,
#       'title': 'ml_problems_kantor.pdf',
#       'url': 'https://vk.com/doc6356042_440910268?hash=d0a08f2e236553442b&dl=GYYDINJSGQ4Q:1494431905:bbf8c651f4f3e1e7e3&api=1&no_preview=1'},
#      'type': 'doc'}],
#    'can_delete': 1,
#    'can_pin': 1,
#    'comments': {'can_post': 1, 'count': 0},
#    'copy_owner_id': -78553823,
#    'copy_post_date': 1484095260,
#    'copy_post_id': 758,
#    'copy_post_type': 'post',
#    'date': 1484252994,
#    'from_id': 6045249,
#    'id': 7059,
#    'likes': {'can_like': 1, 'can_publish': 0, 'count': 2, 'user_likes': 0},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 0,
#    'reposts': {'count': 0, 'user_reposted': 0},
#    'signer_id': 6356042,
#    'text': 'Пока на нашем курсе перерыв между семестрами, предлагаю посмотреть на примеры теоретических задач по машинному обучению (с решениями). Ровно год назад я собрал какое-то количество таких задач в сборник, который прикрепляю сейчас к этому посту. <br><br>До сих пор мы практически не разбирали подобного на DMIA, но если кому-то это покажется интересным - можем уделить этому немного времени во втором семестре. И, разумеется, в любом случае задачи из сборника могут оказаться полезными, чтобы лучше разобраться в теории :)',
#    'to_id': 6045249}]}

# %%
len(wall['response'])
# Out:
# 21

# %% [markdown]
# Скачалось целых 20 записей. Первая запись - число постов на стене. Посмотрим на парочку.

# %%
wall['response'][1]
# Out:
# {'attachment': {'link': {'description': '',
#    'image_big': 'https://pp.userapi.com/c637125/v637125211/4a631/erB8NruZGbM.jpg',
#    'image_src': 'https://pp.userapi.com/c637125/v637125211/4a62f/dd-mIfW5B6s.jpg',
#    'preview_page': '1148727013_1565611111',
#    'preview_url': 'https://m.vk.com/article1148727013_1565611111?api_view=066215601cafa2506cbbc3e2b216da',
#    'target': 'external',
#    'title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#    'url': 'http://varlamov.ru/2359727.html'},
#   'type': 'link'},
#  'attachments': [{'link': {'description': '',
#     'image_big': 'https://pp.userapi.com/c637125/v637125211/4a631/erB8NruZGbM.jpg',
#     'image_src': 'https://pp.userapi.com/c637125/v637125211/4a62f/dd-mIfW5B6s.jpg',
#     'preview_page': '1148727013_1565611111',
#     'preview_url': 'https://m.vk.com/article1148727013_1565611111?api_view=066215601cafa2506cbbc3e2b216da',
#     'target': 'external',
#     'title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#     'url': 'http://varlamov.ru/2359727.html'},
#    'type': 'link'}],
#  'can_delete': 1,
#  'can_pin': 1,
#  'comments': {'can_post': 1, 'count': 24},
#  'date': 1493975247,
#  'from_id': 6045249,
#  'id': 7159,
#  'likes': {'can_like': 1, 'can_publish': 0, 'count': 14, 'user_likes': 0},
#  'media': {'share_title': 'Что делают с пятиэтажками в Европе: реконструкция вместо реновации',
#   'share_url': 'http://varlamov.ru/2359727.html',
#   'type': 'share'},
#  'online': 0,
#  'post_source': {'type': 'vk'},
#  'post_type': 'post',
#  'reply_count': 24,
#  'reposts': {'count': 1, 'user_reposted': 0},
#  'text': 'Немного о пятиэтажках... В моём районе довольно много пятиэтажек... Судя по всему скоро он превратится из пригодного для жизни места в огромную стройку, а после в огромный массив путинских муравейников... :(',
#  'to_id': 6045249}

# %%
wall['response'][1]['likes']
# Out:
# {'can_like': 1, 'can_publish': 0, 'count': 14, 'user_likes': 0}

# %%
wall['response'][1]['likes']['count']
# Out:
# 14

# %%
[item['likes']['count'] for item in wall['response'][1:]]
# Out:
# [14, 4, 12, 2, 11, 12, 7, 27, 7, 12, 2, 14, 1, 5, 8, 4, 19, 7, 10, 2]

# %% [markdown]
# Все лайки со стены в наших руках! Можно творить с ними что угодно... Попробуем провернуть аналогичный трюк с лайками из какой-нибудь группы. Например, лентача. Отметим, что при этом есть одна тонкость, которая прописана в описании метода "wall.get". Если мы хотим вытащить записи из группы, то ее id должен быть записан со знаком минус.

# %%
wall = Vk_downloader('wall.get','owner_id=-29534144')
wall
# Out:
# {'response': [20969,
#   {'attachment': {'photo': {'access_key': 'fc1f5d1e287f6c1122',
#      'aid': -7,
#      'created': 1494428411,
#      'height': 359,
#      'owner_id': -29534144,
#      'pid': 456377343,
#      'post_id': 6271865,
#      'src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002865/30e7c/qDpqL1dXNbY.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002865/30e7a/NDsL3t1RFpc.jpg',
#      'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp',
#      'user_id': 100,
#      'width': 502},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'fc1f5d1e287f6c1122',
#       'aid': -7,
#       'created': 1494428411,
#       'height': 359,
#       'owner_id': -29534144,
#       'pid': 456377343,
#       'post_id': 6271865,
#       'src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002865/30e7c/qDpqL1dXNbY.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002865/30e7a/NDsL3t1RFpc.jpg',
#       'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp',
#       'user_id': 100,
#       'width': 502},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 112},
#    'date': 1494428411,
#    'from_id': -29534144,
#    'id': 6271865,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 3388, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377343,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 112,
#    'reposts': {'count': 119, 'user_reposted': 0},
#    'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp',
#    'to_id': -29534144},
#   {'attachment': {'type': 'video',
#     'video': {'access_key': 'c477ba800ed8242ddd',
#      'date': 1494423746,
#      'description': 'В Ноябрьске дети играли на льду на пустыре между двумя новостройками. Здесь посл...',
#      'duration': 46,
#      'image': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg',
#      'image_big': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg',
#      'image_small': 'https://pp.userapi.com/c604627/u8821158/video/s_446a44ef.jpg',
#      'owner_id': -132147085,
#      'platform': 'YouTube',
#      'title': 'На Ямале дети застряли на льдине в луже посреди двора. Пришлось вызывать спасате...',
#      'vid': 456240919,
#      'views': 8928}},
#    'attachments': [{'type': 'video',
#      'video': {'access_key': 'c477ba800ed8242ddd',
#       'date': 1494423746,
#       'description': 'В Ноябрьске дети играли на льду на пустыре между двумя новостройками. Здесь посл...',
#       'duration': 46,
#       'image': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg',
#       'image_big': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg',
#       'image_small': 'https://pp.userapi.com/c604627/u8821158/video/s_446a44ef.jpg',
#       'owner_id': -132147085,
#       'platform': 'YouTube',
#       'title': 'На Ямале дети застряли на льдине в луже посреди двора. Пришлось вызывать спасате...',
#       'vid': 456240919,
#       'views': 8928}}],
#    'comments': {'can_post': 1, 'count': 47},
#    'copy_owner_id': -132147085,
#    'copy_post_date': 1494424270,
#    'copy_post_id': 48721,
#    'copy_post_type': 'post',
#    'date': 1494426457,
#    'from_id': -29534144,
#    'id': 6271697,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 620, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456240919, 'owner_id': -132147085, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 47,
#    'reposts': {'count': 27, 'user_reposted': 0},
#    'text': 'В Ноябрьске дети застряли на льдине посреди огромной лужи во дворе. <br><br>Жителям пришлось вызывать спасателей, чтобы благополучно переправить ребят на берег',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '9078acae01822ac749',
#      'aid': -7,
#      'created': 1494423207,
#      'height': 1080,
#      'owner_id': -29534144,
#      'pid': 456377260,
#      'post_id': 6271266,
#      'src': 'https://pp.userapi.com/c7002/v7002428/30d80/IFigSkRfN1A.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002428/30d81/pvM8DylJ2k0.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002428/30d7f/Zzl-1o9_A4U.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002428/30d82/Pq906Iui9HM.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002428/30d83/L7DXLUOnwT0.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c7002/v7002428/30d84/Mor9qbFrnSM.jpg',
#      'text': 'Путин поручил приравнять медовуху в сельхозпродукции.<br><br>Это значит, что акцизы на нее снизят<br><br>http://news.lenta.ch/tuKx',
#      'user_id': 100,
#      'width': 1920},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '9078acae01822ac749',
#       'aid': -7,
#       'created': 1494423207,
#       'height': 1080,
#       'owner_id': -29534144,
#       'pid': 456377260,
#       'post_id': 6271266,
#       'src': 'https://pp.userapi.com/c7002/v7002428/30d80/IFigSkRfN1A.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002428/30d81/pvM8DylJ2k0.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002428/30d7f/Zzl-1o9_A4U.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002428/30d82/Pq906Iui9HM.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002428/30d83/L7DXLUOnwT0.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c7002/v7002428/30d84/Mor9qbFrnSM.jpg',
#       'text': 'Путин поручил приравнять медовуху в сельхозпродукции.<br><br>Это значит, что акцизы на нее снизят<br><br>http://news.lenta.ch/tuKx',
#       'user_id': 100,
#       'width': 1920},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 144},
#    'date': 1494423207,
#    'from_id': -29534144,
#    'id': 6271266,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 4968, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377260,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002428/30d80/IFigSkRfN1A.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 144,
#    'reposts': {'count': 130, 'user_reposted': 0},
#    'text': 'Путин поручил приравнять медовуху к сельхозпродукции.<br><br>Это значит, что акцизы на нее снизят<br><br>http://news.lenta.ch/tuKx',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '858520b313a406f65d',
#      'aid': -7,
#      'created': 1494418300,
#      'height': 582,
#      'owner_id': -29534144,
#      'pid': 456377208,
#      'post_id': 6270608,
#      'src': 'https://pp.userapi.com/c7002/v7002752/313a2/PqqhGIj8jSE.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002752/313a3/GDv7IEMQ87Q.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002752/313a1/-BNCQBo_eDk.jpg',
#      'text': 'Путин подписал указ об усилении мер безопасности во время проведения Кубка конфедераций в 2017 году и чемпионата мира по футболу 2018 года.<br><br>Все митинги должны будут проводиться только в тех местах и в то время, которое определят местные власти и ФСБ<br><br>http://news.lenta.ch/tuqo',
#      'user_id': 100,
#      'width': 580},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '858520b313a406f65d',
#       'aid': -7,
#       'created': 1494418300,
#       'height': 582,
#       'owner_id': -29534144,
#       'pid': 456377208,
#       'post_id': 6270608,
#       'src': 'https://pp.userapi.com/c7002/v7002752/313a2/PqqhGIj8jSE.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002752/313a3/GDv7IEMQ87Q.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002752/313a1/-BNCQBo_eDk.jpg',
#       'text': 'Путин подписал указ об усилении мер безопасности во время проведения Кубка конфедераций в 2017 году и чемпионата мира по футболу 2018 года.<br><br>Все митинги должны будут проводиться только в тех местах и в то время, которое определят местные власти и ФСБ<br><br>http://news.lenta.ch/tuqo',
#       'user_id': 100,
#       'width': 580},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 183},
#    'date': 1494418300,
#    'from_id': -29534144,
#    'id': 6270608,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 5441, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377208,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002752/313a2/PqqhGIj8jSE.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 183,
#    'reposts': {'count': 216, 'user_reposted': 0},
#    'text': 'Путин подписал указ об усилении мер безопасности во время проведения Кубка конфедераций в 2017 году и чемпионата мира по футболу 2018 года.<br><br>Все митинги должны будут проводиться только в тех местах и в то время, которое определят местные власти и ФСБ<br><br>http://news.lenta.ch/tuqo',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '3964d73100a8f8e80e',
#      'aid': -7,
#      'created': 1494413302,
#      'height': 400,
#      'owner_id': -29534144,
#      'pid': 456377147,
#      'post_id': 6269589,
#      'src': 'https://pp.userapi.com/c7002/v7002346/31181/8jFeI09zynM.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002346/31182/DSwrVuhqfN8.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002346/31180/IzztAIRjUiw.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002346/31183/G_Ff20yddE4.jpg',
#      'text': 'На 9 мая жительница Омска убила своего сожителя, ударив его ножом. Ровно семь лет назад, на 9 мая, она сделала тоже самое, но с другим сожителем<br><br>http://news.lenta.ch/tudB',
#      'user_id': 100,
#      'width': 700},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '3964d73100a8f8e80e',
#       'aid': -7,
#       'created': 1494413302,
#       'height': 400,
#       'owner_id': -29534144,
#       'pid': 456377147,
#       'post_id': 6269589,
#       'src': 'https://pp.userapi.com/c7002/v7002346/31181/8jFeI09zynM.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002346/31182/DSwrVuhqfN8.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002346/31180/IzztAIRjUiw.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002346/31183/G_Ff20yddE4.jpg',
#       'text': 'На 9 мая жительница Омска убила своего сожителя, ударив его ножом. Ровно семь лет назад, на 9 мая, она сделала тоже самое, но с другим сожителем<br><br>http://news.lenta.ch/tudB',
#       'user_id': 100,
#       'width': 700},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 227},
#    'date': 1494413302,
#    'from_id': -29534144,
#    'id': 6269589,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 9841, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377147,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002346/31181/8jFeI09zynM.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 227,
#    'reposts': {'count': 182, 'user_reposted': 0},
#    'text': 'На 9 мая жительница Омска убила своего сожителя, ударив его ножом. Ровно семь лет назад, на 9 мая, она сделала тоже самое, но с другим сожителем<br><br>http://news.lenta.ch/tudB',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': 'e78bfad0dc195914ed',
#      'aid': -7,
#      'created': 1494410711,
#      'height': 2048,
#      'owner_id': -29534144,
#      'pid': 456377109,
#      'post_id': 6269024,
#      'src': 'https://pp.userapi.com/c7002/v7002678/30ce6/XdG4hPcq23w.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002678/30ce7/30FBcEy-zxo.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002678/30ce5/PnusGgcfu0A.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002678/30ce8/YBygshqYZ38.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002678/30ce9/tk4avuHpE-o.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c7002/v7002678/30cea/drzygw0tpCw.jpg',
#      'text': 'Депутат Лариса Уотерс стала первой в истории австралийского парламента женщиной, принесшей на заседание своего грудного ребенка. Как сообщается, интимный процесс кормления никак не помешал работе парламента. <br><br>Своим поступком Лариса призывает власти внимательнее отнестись к проблеме работающих родителей. До 2016 года в Австралии существовал закон, который запрещал входить в парламент с малолетними детьми и кормить их там.',
#      'user_id': 100,
#      'width': 1362},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'e78bfad0dc195914ed',
#       'aid': -7,
#       'created': 1494410711,
#       'height': 2048,
#       'owner_id': -29534144,
#       'pid': 456377109,
#       'post_id': 6269024,
#       'src': 'https://pp.userapi.com/c7002/v7002678/30ce6/XdG4hPcq23w.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002678/30ce7/30FBcEy-zxo.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002678/30ce5/PnusGgcfu0A.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002678/30ce8/YBygshqYZ38.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002678/30ce9/tk4avuHpE-o.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c7002/v7002678/30cea/drzygw0tpCw.jpg',
#       'text': 'Депутат Лариса Уотерс стала первой в истории австралийского парламента женщиной, принесшей на заседание своего грудного ребенка. Как сообщается, интимный процесс кормления никак не помешал работе парламента. <br><br>Своим поступком Лариса призывает власти внимательнее отнестись к проблеме работающих родителей. До 2016 года в Австралии существовал закон, который запрещал входить в парламент с малолетними детьми и кормить их там.',
#       'user_id': 100,
#       'width': 1362},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 747},
#    'date': 1494410711,
#    'from_id': -29534144,
#    'id': 6269024,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 2938, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377109,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002678/30ce6/XdG4hPcq23w.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 747,
#    'reposts': {'count': 46, 'user_reposted': 0},
#    'text': 'Депутат Лариса Уотерс стала первой в истории австралийского парламента женщиной, принесшей на заседание своего грудного ребенка. Как сообщается, интимный процесс кормления никак не помешал работе парламента. Своим поступком Лариса призывает власти внимательнее отнестись к проблеме работающих родителей. <br><br>До 2016 года в Австралии существовал закон, который запрещал входить в парламент с малолетними детьми и кормить их там.',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '276e402a10e1674e8d',
#      'aid': -7,
#      'created': 1494408009,
#      'height': 453,
#      'owner_id': -29534144,
#      'pid': 456377087,
#      'post_id': 6268649,
#      'src': 'https://pp.userapi.com/c7002/v7002873/30c44/eme0qoFgUbo.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002873/30c45/DYXIvnybSA8.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002873/30c43/KpU8EAOuQlw.jpg',
#      'text': 'Пару месяцев назад на сайте парламента Тувы вышла заметка о приключениях четырёхлетней девочки из отдаленного селения, которая обнаружив, что у неё умерла бабушка, пошла через сугробы и темень восемь километров, чтобы рассказать о трагедии ближайшим соседям. <br><br>Как оказалось, история была сильно «приукрашена» пресс-секретарём парламента и на деле всё было по-другому. Но тем не менее, на основании этой заметки против матери девочки возбудили два уголовных дела — оставление в опасности и неисполнение обязанностей по воспитанию несовершеннолетнего. Сама мать в тот момент находилась в райцентре. <br><br>http://news.lenta.ch/tuP1',
#      'user_id': 100,
#      'width': 604},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '276e402a10e1674e8d',
#       'aid': -7,
#       'created': 1494408009,
#       'height': 453,
#       'owner_id': -29534144,
#       'pid': 456377087,
#       'post_id': 6268649,
#       'src': 'https://pp.userapi.com/c7002/v7002873/30c44/eme0qoFgUbo.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002873/30c45/DYXIvnybSA8.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002873/30c43/KpU8EAOuQlw.jpg',
#       'text': 'Пару месяцев назад на сайте парламента Тувы вышла заметка о приключениях четырёхлетней девочки из отдаленного селения, которая обнаружив, что у неё умерла бабушка, пошла через сугробы и темень восемь километров, чтобы рассказать о трагедии ближайшим соседям. <br><br>Как оказалось, история была сильно «приукрашена» пресс-секретарём парламента и на деле всё было по-другому. Но тем не менее, на основании этой заметки против матери девочки возбудили два уголовных дела — оставление в опасности и неисполнение обязанностей по воспитанию несовершеннолетнего. Сама мать в тот момент находилась в райцентре. <br><br>http://news.lenta.ch/tuP1',
#       'user_id': 100,
#       'width': 604},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 89},
#    'date': 1494408009,
#    'from_id': -29534144,
#    'id': 6268649,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 2028, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377087,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002873/30c44/eme0qoFgUbo.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 89,
#    'reposts': {'count': 32, 'user_reposted': 0},
#    'text': 'Пару месяцев назад на сайте парламента Тувы вышла заметка о приключениях четырёхлетней девочки из отдаленного селения, которая обнаружив, что у неё умерла бабушка, пошла через сугробы и темень восемь километров, чтобы рассказать о трагедии ближайшим соседям. <br><br>Как оказалось, история была сильно «приукрашена» пресс-секретарём парламента и на деле всё было по-другому. Но тем не менее, на основании этой заметки против матери девочки возбудили два уголовных дела — оставление в опасности и неисполнение обязанностей по воспитанию несовершеннолетнего. Сама мать в тот момент находилась в райцентре. <br><br>http://news.lenta.ch/tuP1',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '3eb8fe85c99692dcc2',
#      'aid': -7,
#      'created': 1494411541,
#      'height': 765,
#      'owner_id': -29534144,
#      'pid': 456377126,
#      'src': 'https://pp.userapi.com/c638921/v638921830/3a811/W98ad7zYrI4.jpg',
#      'src_big': 'https://pp.userapi.com/c638921/v638921830/3a812/jt_k2fnbm7I.jpg',
#      'src_small': 'https://pp.userapi.com/c638921/v638921830/3a810/wVpmmliGc30.jpg',
#      'src_xbig': 'https://pp.userapi.com/c638921/v638921830/3a813/6yfcWW5_VFo.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c638921/v638921830/3a814/maubV33D-qQ.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c638921/v638921830/3a815/ecMeD3_cN3k.jpg',
#      'text': '',
#      'user_id': 100,
#      'width': 1297},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '3eb8fe85c99692dcc2',
#       'aid': -7,
#       'created': 1494411541,
#       'height': 765,
#       'owner_id': -29534144,
#       'pid': 456377126,
#       'src': 'https://pp.userapi.com/c638921/v638921830/3a811/W98ad7zYrI4.jpg',
#       'src_big': 'https://pp.userapi.com/c638921/v638921830/3a812/jt_k2fnbm7I.jpg',
#       'src_small': 'https://pp.userapi.com/c638921/v638921830/3a810/wVpmmliGc30.jpg',
#       'src_xbig': 'https://pp.userapi.com/c638921/v638921830/3a813/6yfcWW5_VFo.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c638921/v638921830/3a814/maubV33D-qQ.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c638921/v638921830/3a815/ecMeD3_cN3k.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 1297},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 960},
#    'date': 1494404781,
#    'from_id': -29534144,
#    'id': 6268161,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 5414, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456377126,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c638921/v638921830/3a811/W98ad7zYrI4.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 960,
#    'reposts': {'count': 139, 'user_reposted': 0},
#    'text': 'Во время шествия «Бессмертного полка» в Москве и Петербурге из-за флагов Нагорного Карабаха подрались армяне и азербайджанцы<br><br>http://news.lenta.ch/tufi',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '725dce1fae6f20b48a',
#      'aid': -7,
#      'created': 1494400605,
#      'height': 762,
#      'owner_id': -29534144,
#      'pid': 456376995,
#      'post_id': 6267359,
#      'src': 'https://pp.userapi.com/c7002/v7002880/313c4/Tu5m5dczCJs.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002880/313c5/GjdnmZVbQis.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002880/313c3/BUMjtx99RXk.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002880/313c6/s6Af06REJAE.jpg',
#      'text': 'Для решения проблемы с демографией Путину предложили обложить налогом бездетные семьи и те, где всего лишь один ребёнок <br><br>http://news.lenta.ch/tuB8',
#      'user_id': 100,
#      'width': 785},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '725dce1fae6f20b48a',
#       'aid': -7,
#       'created': 1494400605,
#       'height': 762,
#       'owner_id': -29534144,
#       'pid': 456376995,
#       'post_id': 6267359,
#       'src': 'https://pp.userapi.com/c7002/v7002880/313c4/Tu5m5dczCJs.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002880/313c5/GjdnmZVbQis.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002880/313c3/BUMjtx99RXk.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002880/313c6/s6Af06REJAE.jpg',
#       'text': 'Для решения проблемы с демографией Путину предложили обложить налогом бездетные семьи и те, где всего лишь один ребёнок <br><br>http://news.lenta.ch/tuB8',
#       'user_id': 100,
#       'width': 785},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 927},
#    'date': 1494400605,
#    'from_id': -29534144,
#    'id': 6267359,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 8449, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376995,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002880/313c4/Tu5m5dczCJs.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 927,
#    'reposts': {'count': 504, 'user_reposted': 0},
#    'text': 'Для решения проблемы с демографией Путину предложили обложить налогом бездетные семьи и те, где всего лишь один ребёнок <br><br>http://news.lenta.ch/tuB8<br><br>upd. Мизулина назвала этот налог провокацией https://vk.cc/6CBAqj',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '1b177bcece05626f31',
#      'aid': -7,
#      'created': 1494396079,
#      'height': 799,
#      'owner_id': -29534144,
#      'pid': 456376946,
#      'post_id': 6267074,
#      'src': 'https://pp.userapi.com/c7002/v7002247/316fd/J4X4H9_AaUU.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002247/316fe/PudfboybVZw.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002247/316fc/NwlJR46uc4g.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002247/316ff/IiZw8Io4VsU.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002247/31700/im_q0kjV0mk.jpg',
#      'text': 'Китайские ученые научились декодировать образы букв в мозгу человека<br><br>http://news.lenta.ch/tuY3',
#      'user_id': 100,
#      'width': 1200},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '1b177bcece05626f31',
#       'aid': -7,
#       'created': 1494396079,
#       'height': 799,
#       'owner_id': -29534144,
#       'pid': 456376946,
#       'post_id': 6267074,
#       'src': 'https://pp.userapi.com/c7002/v7002247/316fd/J4X4H9_AaUU.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002247/316fe/PudfboybVZw.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002247/316fc/NwlJR46uc4g.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002247/316ff/IiZw8Io4VsU.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002247/31700/im_q0kjV0mk.jpg',
#       'text': 'Китайские ученые научились декодировать образы букв в мозгу человека<br><br>http://news.lenta.ch/tuY3',
#       'user_id': 100,
#       'width': 1200},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 84},
#    'date': 1494396079,
#    'from_id': -29534144,
#    'id': 6267074,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 4872, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376946,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002247/316fd/J4X4H9_AaUU.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 84,
#    'reposts': {'count': 80, 'user_reposted': 0},
#    'text': 'Китайские ученые научились декодировать образы букв в мозгу человека<br><br>http://news.lenta.ch/tuY3',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': 'ddea4df5df89e47745',
#      'aid': -7,
#      'created': 1494392485,
#      'height': 468,
#      'owner_id': -29534144,
#      'pid': 456376920,
#      'post_id': 6266877,
#      'src': 'https://pp.userapi.com/c7002/v7002364/30940/5mDg0RV_bGc.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002364/30941/hzFelEk8UeQ.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002364/3093f/XuneOwBwyh4.jpg',
#      'text': 'Трамп уволил директора ФБР <br><br>http://news.lenta.ch/tuTS',
#      'user_id': 100,
#      'width': 512},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'ddea4df5df89e47745',
#       'aid': -7,
#       'created': 1494392485,
#       'height': 468,
#       'owner_id': -29534144,
#       'pid': 456376920,
#       'post_id': 6266877,
#       'src': 'https://pp.userapi.com/c7002/v7002364/30940/5mDg0RV_bGc.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002364/30941/hzFelEk8UeQ.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002364/3093f/XuneOwBwyh4.jpg',
#       'text': 'Трамп уволил директора ФБР <br><br>http://news.lenta.ch/tuTS',
#       'user_id': 100,
#       'width': 512},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 149},
#    'date': 1494392485,
#    'from_id': -29534144,
#    'id': 6266877,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 9468, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376920,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002364/30940/5mDg0RV_bGc.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 149,
#    'reposts': {'count': 161, 'user_reposted': 0},
#    'text': 'Трамп уволил директора ФБР <br><br>http://news.lenta.ch/tuTS',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': 'b514f7632be86a6d07',
#      'aid': -7,
#      'created': 1494368961,
#      'height': 447,
#      'owner_id': -29534144,
#      'pid': 456376844,
#      'src': 'https://pp.userapi.com/c636826/v636826498/5d546/Hr2afRN9Y_Y.jpg',
#      'src_big': 'https://pp.userapi.com/c636826/v636826498/5d547/8psC6HX5OuY.jpg',
#      'src_small': 'https://pp.userapi.com/c636826/v636826498/5d545/WbKaFF-e9Kg.jpg',
#      'text': '',
#      'user_id': 100,
#      'width': 447},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'b514f7632be86a6d07',
#       'aid': -7,
#       'created': 1494368961,
#       'height': 447,
#       'owner_id': -29534144,
#       'pid': 456376844,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d546/Hr2afRN9Y_Y.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d547/8psC6HX5OuY.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d545/WbKaFF-e9Kg.jpg',
#       'text': '',
#       'user_id': 100,
#       'width': 447},
#      'type': 'photo'},
#     {'audio': {'aid': 456240224,
#       'album': 2,
#       'artist': 'Black Eyed Peas',
#       'duration': 25,
#       'genre': 3,
#       'owner_id': 2000451401,
#       'performer': 'Black Eyed Peas',
#       'title': 'Where Is The Love? ',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240772,
#       'album': 2,
#       'artist': 'Борис Гребенщиков',
#       'duration': 25,
#       'genre': 1001,
#       'lyrics_id': 155529987,
#       'owner_id': 2000448974,
#       'performer': 'Борис Гребенщиков',
#       'title': 'Любовь во время войны',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240114,
#       'album': 2,
#       'artist': 'The Cranberries',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 18,
#       'lyrics_id': 190637661,
#       'owner_id': 2000451881,
#       'performer': 'The Cranberries',
#       'title': 'Zombie'},
#      'type': 'audio'},
#     {'audio': {'aid': 456239962,
#       'album': 2,
#       'artist': 'Pink Floyd',
#       'duration': 25,
#       'genre': 18,
#       'owner_id': 2000452356,
#       'performer': 'Pink Floyd',
#       'title': 'Another Brick In The Wall',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240227,
#       'album': 2,
#       'artist': 'ДДТ',
#       'duration': 25,
#       'genre': 18,
#       'lyrics_id': 10799787,
#       'owner_id': 2000451639,
#       'performer': 'ДДТ',
#       'title': 'Не стреляй',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240502,
#       'album': 2,
#       'artist': 'Metallica',
#       'content_restricted': 1,
#       'duration': 25,
#       'genre': 18,
#       'owner_id': 2000450291,
#       'performer': 'Metallica',
#       'title': 'One'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240404,
#       'album': 2,
#       'artist': 'John Lennon',
#       'duration': 25,
#       'genre': 1,
#       'lyrics_id': 4121633,
#       'owner_id': 2000450428,
#       'performer': 'John Lennon',
#       'title': 'Imagine',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240644,
#       'album': 2,
#       'artist': 'Александр Вертинский',
#       'duration': 25,
#       'genre': 2,
#       'lyrics_id': 251256951,
#       'owner_id': 2000449771,
#       'performer': 'Александр Вертинский',
#       'title': 'То, что я должен сказать',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'},
#     {'audio': {'aid': 456240617,
#       'album': 2,
#       'artist': 'Joan Baez',
#       'duration': 25,
#       'genre': 18,
#       'lyrics_id': 9753700,
#       'owner_id': 2000449836,
#       'performer': 'Joan Baez',
#       'title': 'Where Have All The Flowers Gone',
#       'url': 'https://vk.com/mp3/audio_api_unavailable.mp3'},
#      'type': 'audio'}],
#    'comments': {'can_post': 1, 'count': 328},
#    'date': 1494367866,
#    'from_id': -29534144,
#    'id': 6266141,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 8958, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456240617, 'owner_id': 2000449836, 'type': 'audio'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 328,
#    'reposts': {'count': 578, 'user_reposted': 0},
#    'text': 'Помните, война — это плохо<br><br>#радиолентач',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '0a190b3faf87baf781',
#      'aid': -7,
#      'created': 1494360558,
#      'height': 667,
#      'owner_id': -29534144,
#      'pid': 456376688,
#      'src': 'https://pp.userapi.com/c636826/v636826498/5d509/O-PjXoXNp6A.jpg',
#      'src_big': 'https://pp.userapi.com/c636826/v636826498/5d50a/YmN1cm0z_d8.jpg',
#      'src_small': 'https://pp.userapi.com/c636826/v636826498/5d508/T9LkITs3MZo.jpg',
#      'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d50b/JQDyA-PXb1Y.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d50c/E4fCRxNsAZ0.jpg',
#      'text': 'Москва.<br>Фото: Сергей Савостьянов',
#      'user_id': 100,
#      'width': 1000},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '0a190b3faf87baf781',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376688,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d509/O-PjXoXNp6A.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d50a/YmN1cm0z_d8.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d508/T9LkITs3MZo.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d50b/JQDyA-PXb1Y.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d50c/E4fCRxNsAZ0.jpg',
#       'text': 'Москва.<br>Фото: Сергей Савостьянов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '9ccde323931ce86751',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376689,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4ca/MT96ktUA1lA.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4cb/i9gZg3_9CKs.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4c9/8-0flXlab5Y.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4cc/qbeNPMuRvyU.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4cd/9pdbCqpJXYI.jpg',
#       'text': 'Москва.<br>Фото: Сергей Савостьянов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '90ce81a4ab222abcf5',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376690,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4d3/sqbjz4-aSpw.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4d4/YHHVSm4NrBs.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4d2/0Ve_jW1zSBk.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4d5/n6kub-FeN9M.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4d6/JFGokVKQIj8.jpg',
#       'text': 'Владивосток<br>Фото: Виталий Аньков',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '182a7ffa78a7b7af0b',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376691,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4c1/zqBxer3JAS8.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4c2/GQe4CYojO_I.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4c0/yjPuTlJH9P8.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4c3/MP4S4R2Yh38.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4c4/BgZHPNGiaLQ.jpg',
#       'text': 'Москва.<br>Фото: Сергей Савостьянов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': 'dee7218132b5484dcc',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376692,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4dc/bEtONyK7Zok.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4dd/UZ_GKDiaeYs.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4db/kNY8x6ZVHA0.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4de/x3Xljq-9Y1I.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4df/vAttJgOYANk.jpg',
#       'text': 'Омск.<br>Фото: Дмитрий Феоктистов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '0ba9d61da997a66dc6',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376693,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4e5/fnZieksF4u8.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4e6/jCt15cu8AnM.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4e4/TaJOac7c6IY.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4e7/e1bnnVjr5RI.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4e8/6JecvxMgF6M.jpg',
#       'text': 'Санкт-Петербург.<br>Фото: Петр Ковалев',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': 'ca6631616fd1c1f412',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376694,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4ee/TGpU1RUO7g8.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4ef/US9Ur617o48.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4ed/t9sXkZ1OhyI.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4f0/r9vfXXAsCTU.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4f1/ew2XXg5zlXQ.jpg',
#       'text': 'Южно-Сахалинск.<br>Фото: Сергей Красноухов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '37dff823e490972817',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376695,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d4f7/IOWyQj2vPr0.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d4f8/ZJZuin9pRMM.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4f6/XqXu_YIc0lo.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d4f9/kCc0pQbKF-g.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d4fa/ODceuPErj_8.jpg',
#       'text': 'Москва.<br>Фото: Владимир Астапкович',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '2d0e40248d17d60d46',
#       'aid': -7,
#       'created': 1494360558,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376696,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d500/E7HoyiD8yUY.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d501/PbWJuIFpshA.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d4ff/eCbM3t6Wl9A.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d502/VyIf2BbZY1c.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d503/BRyWKUMb1lo.jpg',
#       'text': 'Владивосток<br>Фото: Виталий Аньков',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 323},
#    'date': 1494360882,
#    'from_id': -29534144,
#    'id': 6265520,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 7324, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376696,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c636826/v636826498/5d500/E7HoyiD8yUY.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 323,
#    'reposts': {'count': 224, 'user_reposted': 0},
#    'text': 'А вот и фотографии праздничного салюта в разных городах подъехали.<br><br>Лепота',
#    'to_id': -29534144},
#   {'attachment': {'type': 'video',
#     'video': {'access_key': 'c24e05af263d89fec5',
#      'date': 1494344575,
#      'description': 'К 9 мая президенты постсоветских стран выступили с речами: повод был один, но речи получились разными',
#      'duration': 110,
#      'first_frame_130': 'https://pp.userapi.com/c636729/v636729229/6dc66/kXEDf1jfCjw.jpg',
#      'first_frame_160': 'https://pp.userapi.com/c636729/v636729229/6dc65/YLg94NraNk8.jpg',
#      'first_frame_320': 'https://pp.userapi.com/c636729/v636729229/6dc64/4tmGqwvoGrQ.jpg',
#      'first_frame_800': 'https://pp.userapi.com/c636729/v636729229/6dc63/CJv93rP8iPs.jpg',
#      'image': 'https://pp.userapi.com/c604817/v604817229/4c6cb/lHsY4kjHI90.jpg',
#      'image_big': 'https://pp.userapi.com/c604817/v604817229/4c6cb/lHsY4kjHI90.jpg',
#      'image_small': 'https://pp.userapi.com/c604817/v604817229/4c6cd/VrXlN0lls_g.jpg',
#      'owner_id': -78242229,
#      'title': 'Речи президентов экс-СССР к 9 мая',
#      'vid': 456240445,
#      'views': 361501}},
#    'attachments': [{'type': 'video',
#      'video': {'access_key': 'c24e05af263d89fec5',
#       'date': 1494344575,
#       'description': 'К 9 мая президенты постсоветских стран выступили с речами: повод был один, но речи получились разными',
#       'duration': 110,
#       'first_frame_130': 'https://pp.userapi.com/c636729/v636729229/6dc66/kXEDf1jfCjw.jpg',
#       'first_frame_160': 'https://pp.userapi.com/c636729/v636729229/6dc65/YLg94NraNk8.jpg',
#       'first_frame_320': 'https://pp.userapi.com/c636729/v636729229/6dc64/4tmGqwvoGrQ.jpg',
#       'first_frame_800': 'https://pp.userapi.com/c636729/v636729229/6dc63/CJv93rP8iPs.jpg',
#       'image': 'https://pp.userapi.com/c604817/v604817229/4c6cb/lHsY4kjHI90.jpg',
#       'image_big': 'https://pp.userapi.com/c604817/v604817229/4c6cb/lHsY4kjHI90.jpg',
#       'image_small': 'https://pp.userapi.com/c604817/v604817229/4c6cd/VrXlN0lls_g.jpg',
#       'owner_id': -78242229,
#       'title': 'Речи президентов экс-СССР к 9 мая',
#       'vid': 456240445,
#       'views': 361501}}],
#    'comments': {'can_post': 1, 'count': 509},
#    'date': 1494354992,
#    'from_id': -29534144,
#    'id': 6264890,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 5923, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456240445, 'owner_id': -78242229, 'type': 'video'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 509,
#    'reposts': {'count': 338, 'user_reposted': 0},
#    'text': 'К 9 мая президенты постсоветских стран выступили с речами: повод был один, но речи получились разными',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '7cebce2d0f734d5a7f',
#      'aid': -7,
#      'created': 1494350423,
#      'height': 869,
#      'owner_id': -29534144,
#      'pid': 456376559,
#      'post_id': 6264195,
#      'src': 'https://pp.userapi.com/c7002/v7002834/30776/ZdTmck310Vw.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002834/30777/8YMSFlWyAJs.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002834/30775/Mk-OC9u5vTU.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002834/30778/-KM08cBV3xE.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002834/30779/l-MHpVwh6s4.jpg',
#      'text': 'Лентач, ловите актуальный тест про оборонные расходы разных стран.<br><br>И не забудьте обсудить результаты<br><br>http://news.lenta.ch/tDLK',
#      'user_id': 100,
#      'width': 1280},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '7cebce2d0f734d5a7f',
#       'aid': -7,
#       'created': 1494350423,
#       'height': 869,
#       'owner_id': -29534144,
#       'pid': 456376559,
#       'post_id': 6264195,
#       'src': 'https://pp.userapi.com/c7002/v7002834/30776/ZdTmck310Vw.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002834/30777/8YMSFlWyAJs.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002834/30775/Mk-OC9u5vTU.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002834/30778/-KM08cBV3xE.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002834/30779/l-MHpVwh6s4.jpg',
#       'text': 'Лентач, ловите актуальный тест про оборонные расходы разных стран.<br><br>И не забудьте обсудить результаты<br><br>http://news.lenta.ch/tDLK',
#       'user_id': 100,
#       'width': 1280},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 176},
#    'date': 1494350423,
#    'from_id': -29534144,
#    'id': 6264195,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 3884, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376559,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002834/30776/ZdTmck310Vw.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 176,
#    'reposts': {'count': 43, 'user_reposted': 0},
#    'text': 'Лентач, ловите актуальный тест про оборонные расходы разных стран.<br><br>И не забудьте обсудить результаты<br><br>http://news.lenta.ch/tDLK',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '72d8ac25159cc2e071',
#      'aid': -7,
#      'created': 1494346531,
#      'height': 466,
#      'owner_id': -29534144,
#      'pid': 456376442,
#      'src': 'https://pp.userapi.com/c636826/v636826498/5d34c/VjeWZwi41_Q.jpg',
#      'src_big': 'https://pp.userapi.com/c636826/v636826498/5d34d/MkR6IHao5kg.jpg',
#      'src_small': 'https://pp.userapi.com/c636826/v636826498/5d34b/FAt2fLeGU9k.jpg',
#      'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d34e/o_2Rjs-Grag.jpg',
#      'text': 'Омск.<br>Фото: Александр Румянцев',
#      'user_id': 100,
#      'width': 685},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '72d8ac25159cc2e071',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 466,
#       'owner_id': -29534144,
#       'pid': 456376442,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d34c/VjeWZwi41_Q.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d34d/MkR6IHao5kg.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d34b/FAt2fLeGU9k.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d34e/o_2Rjs-Grag.jpg',
#       'text': 'Омск.<br>Фото: Александр Румянцев',
#       'user_id': 100,
#       'width': 685},
#      'type': 'photo'},
#     {'photo': {'access_key': 'fad7205bc32edfd143',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 667,
#       'owner_id': -29534144,
#       'pid': 456376443,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d354/0-SpunrhsrM.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d355/JCanqKCWuQk.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d353/_dFawtg1lws.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d356/edo-1BW0QyI.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d357/jsl6tHGGwkw.jpg',
#       'text': 'Краснодар.<br>Фото: Владимир Аносов',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'},
#     {'photo': {'access_key': '89256399712b5d06e5',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 837,
#       'owner_id': -29534144,
#       'pid': 456376444,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d35d/Lj1C9ZVMAcA.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d35e/Domd4WXhP54.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d35c/GNZB5CHelec.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d35f/VbZRkTsL4fg.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d360/Lwu0yZplR90.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c636826/v636826498/5d361/JY9TWxZEesM.jpg',
#       'text': 'Москва.<br>Фото: Артем Сизов',
#       'user_id': 100,
#       'width': 1500},
#      'type': 'photo'},
#     {'photo': {'access_key': '13625fb872da94f736',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 960,
#       'owner_id': -29534144,
#       'pid': 456376445,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d37d/mDvVkfZXT10.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d37e/avI8mr56AsY.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d37c/BoKCZ3zMIKc.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d37f/Floem0sl8k8.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c636826/v636826498/5d380/jA07oIpUmHM.jpg',
#       'text': 'Казань.<br>Фото: портал ProKazan',
#       'user_id': 100,
#       'width': 1280},
#      'type': 'photo'},
#     {'photo': {'access_key': '7b05d04c246d6517ba',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 478,
#       'owner_id': -29534144,
#       'pid': 456376446,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d386/DpSeA-Zag6A.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d387/D9WBlbH7uzU.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d385/qZxPf9vX2Y4.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d388/IOaegxFZL98.jpg',
#       'text': 'Саратов.<br>Фото: Министерство информации и печати Саратовской области',
#       'user_id': 100,
#       'width': 744},
#      'type': 'photo'},
#     {'photo': {'access_key': 'f976de537b3e985655',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 463,
#       'owner_id': -29534144,
#       'pid': 456376447,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d38e/DUB9aBlyXak.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d38f/dOKB78HMV4s.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d38d/LUqfyXC28BU.jpg',
#       'src_xbig': 'https://pp.userapi.com/c636826/v636826498/5d390/bU1nrhBQc5E.jpg',
#       'text': 'Екатеринбург.<br>Фото: kremlin.ру',
#       'user_id': 100,
#       'width': 750},
#      'type': 'photo'},
#     {'photo': {'access_key': 'ef7e35d721cc7d5921',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 350,
#       'owner_id': -29534144,
#       'pid': 456376448,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d396/YCT6VVf2Imc.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d397/81R4BMJSaYs.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d395/xYyIN49Slpw.jpg',
#       'text': 'Воронеж.<br>Фото: Елена Вострикова',
#       'user_id': 100,
#       'width': 600},
#      'type': 'photo'},
#     {'photo': {'access_key': '31e7671c8c377fa6ca',
#       'aid': -7,
#       'created': 1494346531,
#       'height': 350,
#       'owner_id': -29534144,
#       'pid': 456376449,
#       'src': 'https://pp.userapi.com/c636826/v636826498/5d39d/cq4c5hp2okA.jpg',
#       'src_big': 'https://pp.userapi.com/c636826/v636826498/5d39e/uftr7txTzZ4.jpg',
#       'src_small': 'https://pp.userapi.com/c636826/v636826498/5d39c/M_-2SnBK1dQ.jpg',
#       'text': 'Брянск',
#       'user_id': 100,
#       'width': 560},
#      'type': 'photo'},
#     {'photo': {'access_key': 'd44751c6d5309499a3',
#       'aid': -7,
#       'created': 1494346557,
#       'height': 1080,
#       'owner_id': -29534144,
#       'pid': 456376450,
#       'src': 'https://pp.userapi.com/c840128/v840128436/2484/10ldmss48bk.jpg',
#       'src_big': 'https://pp.userapi.com/c840128/v840128436/2485/YLU0y9b7SBA.jpg',
#       'src_small': 'https://pp.userapi.com/c840128/v840128436/2483/1Uw7BoQQxYo.jpg',
#       'src_xbig': 'https://pp.userapi.com/c840128/v840128436/2486/Keb-E9Jatmw.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c840128/v840128436/2487/8jghQEvISL0.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c840128/v840128436/2488/9QhmBfX8Aeg.jpg',
#       'text': 'Санкт-Петербург.<br>Фото: Сергей Николаев',
#       'user_id': 100,
#       'width': 1620},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 631},
#    'date': 1494346765,
#    'from_id': -29534144,
#    'id': 6263519,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 3841, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376450,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c840128/v840128436/2484/10ldmss48bk.jpg',
#     'type': 'photo'},
#    'online': 1,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'reply_count': 631,
#    'reposts': {'count': 57, 'user_reposted': 0},
#    'text': 'Сотни тысяч человек вышли сегодня на шествия «Бессмертного полка» по всей стране. Во многих городах установлен рекорд по числу участников акции. <br><br>Собрали фотографий с шествий',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': '30bbcd93c42a24b9bd',
#      'aid': -7,
#      'created': 1494341161,
#      'height': 600,
#      'owner_id': -29534144,
#      'pid': 456376352,
#      'post_id': 6262615,
#      'src': 'https://pp.userapi.com/c7002/v7002029/30d71/y9SFuTVUmJo.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002029/30d72/IT5ki2sxtrM.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002029/30d70/VVMfYlNKE5M.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002029/30d73/4xkdMg6Dd-M.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002029/30d74/ZOLxIPRkC5Q.jpg',
#      'text': 'Навальному в Барселоне сделали операцию по восстановлению зрения. Заживление займёт несколько месяцев.<br><br>Сам Алексей пытается отшучиваться',
#      'user_id': 100,
#      'width': 1000},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': '30bbcd93c42a24b9bd',
#       'aid': -7,
#       'created': 1494341161,
#       'height': 600,
#       'owner_id': -29534144,
#       'pid': 456376352,
#       'post_id': 6262615,
#       'src': 'https://pp.userapi.com/c7002/v7002029/30d71/y9SFuTVUmJo.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002029/30d72/IT5ki2sxtrM.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002029/30d70/VVMfYlNKE5M.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002029/30d73/4xkdMg6Dd-M.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002029/30d74/ZOLxIPRkC5Q.jpg',
#       'text': 'Навальному в Барселоне сделали операцию по восстановлению зрения. Заживление займёт несколько месяцев.<br><br>Сам Алексей пытается отшучиваться',
#       'user_id': 100,
#       'width': 1000},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 735},
#    'date': 1494341160,
#    'from_id': -29534144,
#    'id': 6262615,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 15490, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376352,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002029/30d71/y9SFuTVUmJo.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 735,
#    'reposts': {'count': 233, 'user_reposted': 0},
#    'text': 'Навальному в Барселоне сделали операцию по восстановлению зрения. Заживление займёт несколько месяцев.<br><br>Сам Алексей пытается отшучиваться',
#    'to_id': -29534144},
#   {'attachment': {'type': 'video',
#     'video': {'access_key': '333de10f53a85f99dc',
#      'date': 1494316402,
#      'description': 'Я не батюшка, я выше',
#      'duration': 136,
#      'image': 'https://cs7054.userapi.com/c636528/u162181074/video/l_05e48141.jpg',
#      'image_big': 'https://cs7054.userapi.com/c636528/u162181074/video/l_05e48141.jpg',
#      'image_small': 'https://cs7054.userapi.com/c636528/u162181074/video/s_b365cd69.jpg',
#      'image_xbig': 'https://cs7054.userapi.com/c636528/u162181074/video/y_7da67f10.jpg',
#      'owner_id': -132147085,
#      'platform': 'YouTube',
#      'title': 'Алтайский епископ',
#      'vid': 456240894,
#      'views': 131511}},
#    'attachments': [{'type': 'video',
#      'video': {'access_key': '333de10f53a85f99dc',
#       'date': 1494316402,
#       'description': 'Я не батюшка, я выше',
#       'duration': 136,
#       'image': 'https://cs7054.userapi.com/c636528/u162181074/video/l_05e48141.jpg',
#       'image_big': 'https://cs7054.userapi.com/c636528/u162181074/video/l_05e48141.jpg',
#       'image_small': 'https://cs7054.userapi.com/c636528/u162181074/video/s_b365cd69.jpg',
#       'image_xbig': 'https://cs7054.userapi.com/c636528/u162181074/video/y_7da67f10.jpg',
#       'owner_id': -132147085,
#       'platform': 'YouTube',
#       'title': 'Алтайский епископ',
#       'vid': 456240894,
#       'views': 131511}}],
#    'comments': {'can_post': 1, 'count': 190},
#    'copy_owner_id': -132147085,
#    'copy_post_date': 1494316414,
#    'copy_post_id': 48262,
#    'copy_post_type': 'post',
#    'date': 1494338547,
#    'from_id': -29534144,
#    'id': 6262303,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 3560, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456240894, 'owner_id': -132147085, 'type': 'video'},
#    'online': 0,
#    'post_source': {'type': 'vk'},
#    'post_type': 'copy',
#    'reply_count': 190,
#    'reposts': {'count': 209, 'user_reposted': 0},
#    'text': 'Он вам не батюшка!',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': 'ecbe8c8495d930e476',
#      'aid': -7,
#      'created': 1494333009,
#      'height': 1000,
#      'owner_id': -29534144,
#      'pid': 456376261,
#      'post_id': 6261509,
#      'src': 'https://pp.userapi.com/c7002/v7002261/30752/JAOuwBojAyY.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002261/30753/7ynL9NhQYSE.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002261/30751/-HVJCuZTy0w.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002261/30754/yp1iXA9ZbFM.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002261/30755/f2nioejt9lA.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c7002/v7002261/30756/mLUt157N4-4.jpg',
#      'text': '7 мая в Ростовской области похитили трёхлетнего ребёнка.<br><br>Вчера полиция поймала похитителей. Ими оказались 48-летние многодетные родители. Ребёнок жив и здоров.<br>http://news.lenta.ch/tDq6<br><br>А сегодня стали известны мотивы этой парочки:',
#      'user_id': 100,
#      'width': 1500},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'ecbe8c8495d930e476',
#       'aid': -7,
#       'created': 1494333009,
#       'height': 1000,
#       'owner_id': -29534144,
#       'pid': 456376261,
#       'post_id': 6261509,
#       'src': 'https://pp.userapi.com/c7002/v7002261/30752/JAOuwBojAyY.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002261/30753/7ynL9NhQYSE.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002261/30751/-HVJCuZTy0w.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002261/30754/yp1iXA9ZbFM.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002261/30755/f2nioejt9lA.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c7002/v7002261/30756/mLUt157N4-4.jpg',
#       'text': '7 мая в Ростовской области похитили трёхлетнего ребёнка.<br><br>Вчера полиция поймала похитителей. Ими оказались 48-летние многодетные родители. Ребёнок жив и здоров.<br>http://news.lenta.ch/tDq6<br><br>А сегодня стали известны мотивы этой парочки:',
#       'user_id': 100,
#       'width': 1500},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 207},
#    'date': 1494333009,
#    'from_id': -29534144,
#    'id': 6261509,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 4632, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376261,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002261/30752/JAOuwBojAyY.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 207,
#    'reposts': {'count': 115, 'user_reposted': 0},
#    'text': '7 мая в Ростовской области похитили трёхлетнего ребёнка.<br><br>Вчера полиция поймала похитителей. Ими оказались 48-летние многодетные родители. Ребёнок жив и здоров.<br>http://news.lenta.ch/tDq6<br><br>А сегодня стали известны мотивы этой парочки:',
#    'to_id': -29534144},
#   {'attachment': {'photo': {'access_key': 'e0e17e6d776008082c',
#      'aid': -7,
#      'created': 1494329135,
#      'height': 1238,
#      'owner_id': -29534144,
#      'pid': 456376152,
#      'post_id': 6260604,
#      'src': 'https://pp.userapi.com/c7002/v7002295/30c82/iSCg978YOZw.jpg',
#      'src_big': 'https://pp.userapi.com/c7002/v7002295/30c83/6WKaqujprbU.jpg',
#      'src_small': 'https://pp.userapi.com/c7002/v7002295/30c81/dmapRk2I1jA.jpg',
#      'src_xbig': 'https://pp.userapi.com/c7002/v7002295/30c84/UrJCKa0U5eA.jpg',
#      'src_xxbig': 'https://pp.userapi.com/c7002/v7002295/30c85/9sycbxkSlJQ.jpg',
#      'src_xxxbig': 'https://pp.userapi.com/c7002/v7002295/30c86/eaz4tboEITE.jpg',
#      'text': 'В Запорожье некоторые участники акции «Бессмертный полк» пришли с портретами героев Игры Престолов.<br><br>Ну що тут можна сказати?',
#      'user_id': 100,
#      'width': 869},
#     'type': 'photo'},
#    'attachments': [{'photo': {'access_key': 'e0e17e6d776008082c',
#       'aid': -7,
#       'created': 1494329135,
#       'height': 1238,
#       'owner_id': -29534144,
#       'pid': 456376152,
#       'post_id': 6260604,
#       'src': 'https://pp.userapi.com/c7002/v7002295/30c82/iSCg978YOZw.jpg',
#       'src_big': 'https://pp.userapi.com/c7002/v7002295/30c83/6WKaqujprbU.jpg',
#       'src_small': 'https://pp.userapi.com/c7002/v7002295/30c81/dmapRk2I1jA.jpg',
#       'src_xbig': 'https://pp.userapi.com/c7002/v7002295/30c84/UrJCKa0U5eA.jpg',
#       'src_xxbig': 'https://pp.userapi.com/c7002/v7002295/30c85/9sycbxkSlJQ.jpg',
#       'src_xxxbig': 'https://pp.userapi.com/c7002/v7002295/30c86/eaz4tboEITE.jpg',
#       'text': 'В Запорожье некоторые участники акции «Бессмертный полк» пришли с портретами героев Игры Престолов.<br><br>Ну що тут можна сказати?',
#       'user_id': 100,
#       'width': 869},
#      'type': 'photo'}],
#    'comments': {'can_post': 1, 'count': 748},
#    'date': 1494329135,
#    'from_id': -29534144,
#    'id': 6260604,
#    'likes': {'can_like': 1, 'can_publish': 1, 'count': 6909, 'user_likes': 0},
#    'marked_as_ads': 0,
#    'media': {'item_id': 456376152,
#     'owner_id': -29534144,
#     'thumb_src': 'https://pp.userapi.com/c7002/v7002295/30c82/iSCg978YOZw.jpg',
#     'type': 'photo'},
#    'online': 0,
#    'post_source': {'type': 'api'},
#    'post_type': 'post',
#    'reply_count': 748,
#    'reposts': {'count': 187, 'user_reposted': 0},
#    'text': 'В Запорожье некоторые участники акции «Бессмертный полк» пришли с портретами героев Игры Престолов.<br><br>Ну що тут можна сказати?',
#    'to_id': -29534144}]}

# %% [markdown]
# Запилим функцию для выкачивания лайков.

# %%
def Likes(wall):
    return([item['likes']['count'] for item in wall['response'][1:]])

# %%
len(Likes(wall))
# Out:
# 20

# %% [markdown]
# У нас уже есть 20 лайков. Хотелось бы получить побольше. Изучаем документацию. Выясняем, что существуют такие параметры как `count` - число записей для скачки (не может превышать 100) и `offset` - смещение, необходимое для выборки определённого подмножества записей.
#
# Модернизируем запрос.

# %%
print( Vk_downloader('wall.get','owner_id=-29534144&count=1'),
      Vk_downloader('wall.get','owner_id=-29534144&count=1&offset=1'),
      sep = '\n \n \n')
# Out:
# {'response': [20969, {'online': 0, 'from_id': -29534144, 'attachment': {'photo': {'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp', 'src_big': 'https://pp.userapi.com/c7002/v7002865/30e7c/qDpqL1dXNbY.jpg', 'src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg', 'aid': -7, 'src_small': 'https://pp.userapi.com/c7002/v7002865/30e7a/NDsL3t1RFpc.jpg', 'height': 359, 'created': 1494428411, 'pid': 456377343, 'owner_id': -29534144, 'post_id': 6271865, 'width': 502, 'user_id': 100, 'access_key': 'fc1f5d1e287f6c1122'}, 'type': 'photo'}, 'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp', 'comments': {'can_post': 1, 'count': 112}, 'to_id': -29534144, 'date': 1494428411, 'likes': {'user_likes': 0, 'can_publish': 1, 'count': 3391, 'can_like': 1}, 'post_source': {'type': 'api'}, 'marked_as_ads': 0, 'reposts': {'count': 119, 'user_reposted': 0}, 'media': {'type': 'photo', 'item_id': 456377343, 'owner_id': -29534144, 'thumb_src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg'}, 'id': 6271865, 'post_type': 'post', 'reply_count': 112, 'attachments': [{'photo': {'text': 'В Венесуэле оппозиция планирует провести «Марш дерьма» и закидать правительство говном. Прям буквально говном.<br><br>Протестующие подготавливают «коктейли Калотова» и намерены выступить против президента страны<br><br>http://news.lenta.ch/tuLp', 'src_big': 'https://pp.userapi.com/c7002/v7002865/30e7c/qDpqL1dXNbY.jpg', 'src': 'https://pp.userapi.com/c7002/v7002865/30e7b/OcX16cLJrfI.jpg', 'aid': -7, 'src_small': 'https://pp.userapi.com/c7002/v7002865/30e7a/NDsL3t1RFpc.jpg', 'height': 359, 'created': 1494428411, 'pid': 456377343, 'owner_id': -29534144, 'post_id': 6271865, 'width': 502, 'user_id': 100, 'access_key': 'fc1f5d1e287f6c1122'}, 'type': 'photo'}]}]}
#
#
# {'response': [20969, {'online': 0, 'from_id': -29534144, 'attachment': {'type': 'video', 'video': {'title': 'На Ямале дети застряли на льдине в луже посреди двора. Пришлось вызывать спасате...', 'access_key': 'c477ba800ed8242ddd', 'image_small': 'https://pp.userapi.com/c604627/u8821158/video/s_446a44ef.jpg', 'image_big': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg', 'views': 8930, 'image': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg', 'platform': 'YouTube', 'description': 'В Ноябрьске дети играли на льду на пустыре между двумя новостройками. Здесь посл...', 'owner_id': -132147085, 'vid': 456240919, 'duration': 46, 'date': 1494423746}}, 'text': 'В Ноябрьске дети застряли на льдине посреди огромной лужи во дворе. <br><br>Жителям пришлось вызывать спасателей, чтобы благополучно переправить ребят на берег', 'comments': {'can_post': 1, 'count': 47}, 'copy_post_date': 1494424270, 'copy_post_type': 'post', 'to_id': -29534144, 'date': 1494426457, 'copy_post_id': 48721, 'post_source': {'type': 'vk'}, 'likes': {'user_likes': 0, 'can_publish': 1, 'count': 620, 'can_like': 1}, 'copy_owner_id': -132147085, 'marked_as_ads': 0, 'reposts': {'count': 27, 'user_reposted': 0}, 'media': {'type': 'video', 'item_id': 456240919, 'owner_id': -132147085}, 'attachments': [{'type': 'video', 'video': {'title': 'На Ямале дети застряли на льдине в луже посреди двора. Пришлось вызывать спасате...', 'access_key': 'c477ba800ed8242ddd', 'image_small': 'https://pp.userapi.com/c604627/u8821158/video/s_446a44ef.jpg', 'image_big': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg', 'views': 8930, 'image': 'https://pp.userapi.com/c604627/u8821158/video/l_60018e98.jpg', 'platform': 'YouTube', 'description': 'В Ноябрьске дети играли на льду на пустыре между двумя новостройками. Здесь посл...', 'owner_id': -132147085, 'vid': 456240919, 'duration': 46, 'date': 1494423746}}], 'post_type': 'copy', 'reply_count': 47, 'id': 6271697}]}

# %% [markdown]
# Скачиваем 20 000 лоисов!
#
# ![картинка с лайками]()

# %%
list(range(0,20100,100))[:10]
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900]

# %%
likes = [ ]

for i in range(0,20100,100):
    wall =  Vk_downloader('wall.get','owner_id=-29534144&count=100&offset='+str(i))
    likes.extend(Likes(wall))
    if i%1000 == 0:
        print(i)

len(likes)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 20100

# %% [markdown]
# Итак, наконец-то 20 100 лайков в наших руках. Отбросим первые сто постов, под которыми лайки ещё продолжают ставится и исследуем 20 000 лайков!
#
# ### 3.2 Изучаем лайки

# %%
import scipy.stats as sts  # Пакет для статистики

# %%
import matplotlib.pyplot as plt # Пакет для визуализации
# Опция для отображения картинок
# %matplotlib inline 
# Размер картинок
plt.figure(figsize=(20,10))

# %% [markdown]
# Откинем первые сто постов, под которыми лайки всё ещё ставятся, превратим вектор в нумпаевский и посчитаем какие-нибудь описательные статистики.

# %%
likes = likes[100:]

# %%
likes[:10]
# Out:
# [1831, 6642, 5975, 8840, 2873, 1754, 5715, 4168, 6545, 5373]

# %% [markdown]
# Если вы до этого момента никогда не встречали нумпай, то выглядит он примерно уот так уот...

# %%
likes = np.array(likes)
likes[:10]
# Out:
# array([1831, 6642, 5975, 8840, 2873, 1754, 5715, 4168, 6545, 5373])

# %%
print('Среднее число лайков: ',np.mean(likes))
print('Минимальное число лайков: ',np.min(likes))
print('Максимальное число лайков: ',np.max(likes))
print('Медианное число лайков: ',np.median(likes))
print('Дисперсия числа лайков: ',np.var(likes))
print('Всего лайков: ',np.sum(likes))
# Out:
# Среднее число лайков:  3953.601
# Минимальное число лайков:  0
# Максимальное число лайков:  48630
# Медианное число лайков:  3448.0
# Дисперсия числа лайков:  7956684.1537
# Всего лайков:  79072020

# %%
plt.hist(likes,bins=300)
plt.ylabel('number of likes')
plt.xlabel('$likes$')

# %%
# Гипотеза о пуассоне...
x = np.random.poisson(10,1000)
y = np.random.poisson(9.9,1000)
sts.ks_2samp(x,y)
# Out:
# Ks_2sampResult(statistic=0.013999999999999957, pvalue=0.99996878255929322)

# %%
# Гипотеза не прошла :(
sravn = np.random.poisson(np.mean(likes),20000)
sts.ks_2samp(sravn,likes)
# Out:
# Ks_2sampResult(statistic=0.54949999999999999, pvalue=0.0)

# %%
# Да и фиг с ним! Построи бутстраповский доверительный интервал и забьём.

def get_bootstrap_samples(data, n_samples):
    indices = np.random.randint(0, len(data), (n_samples, len(data)))
    samples = data[indices]
    return samples

def stat_intervals(stat, alpha):
    boundaries = np.percentile(stat, [100 * alpha / 2., 100 * (1 - alpha / 2.)])
    return boundaries

stat_intervals(get_bootstrap_samples(likes, 1000),0.05)
# Out:
# array([   482.,  10792.])

# %% [markdown]
# Количество лайков под постом на лентаче с вероятностью 95% окажется в интервале между 482 и 10792. Интервал не очень впечатляет...
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/vk7.jpg" height="500" width="500">
#
# Идеи для дальнейшего развития:
# * Что-нибудь с АВ-тестированием. Лайки до развала и после развала.
# * В какое время чаще всего делаются посты на лентаче?
# * Пост, сделанный в какое время набирает наибольшее число лайков?
#
# ## 4. Реализация какой-нибудь идеи, но не первой

# %% [markdown]
# ## 5. Читерский способ скачивать контакт
#
# Сейчас мы скачивали из контакта данные напряму обращаясь к API. Стоит заметить, что для работы с конатктом в питоне существует специальный пакет. Установить его можно прописав `pip3 install vk`.
#
# Подробнее узнать про этот модуль можно в документации: https://pypi.python.org/pypi/vk/1.5
#
# Мы не будем использовать его в наших скриптах. Потому что мы жёсткие.
#
# <img align="center" src="https://vk.com/images/stickers/53/512.png" height="200" width="200">
