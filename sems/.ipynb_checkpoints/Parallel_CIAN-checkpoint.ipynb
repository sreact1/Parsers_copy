# %% [markdown]
# ## 1. Сложность по времени и сложность по памяти.
#
# Существует великая дилемма! Память или время?
#
# Многие алгоритмы предлагают выбор между объёмом памяти и скоростью. Задачу можно решить быстро, использую большой объём памяти, или медленнее, занимая меньший объём.

# %% [markdown]
# Не так давно мы с вами написали код, который позволяет нам скачивать ЦИАН. Мы амбициозные ребята и хотели бы скачать по максимуму наблюдений. Однако, это может занять довольно много времени. Выясним сколько!

# %%
# Подгружаем уже знакомые нам пакеты.
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Подгружаем пакет, который умеет считать время...
import time

# А также подгружаем модуль, необходимый нам для многопоточности
# Не забываем сначала установить его! 
from multiprocessing import Pool

# %% [markdown]
# Посмотрим сколько времени понадобится для работы той части кода, которая вытаскивает хрефы. Сделаем это для 10 страниц.

# %%
start_time = time.time() # время работы кода 

### Первая часть кода. Вытаскиваем список хрефов.

page_part_1 = "https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p="
page_part_2 = "&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1"

all_hrefs = [ ]  # Тут мы будем хранить наши хрефы!

for i in range(1,11): # Тут регулируем количество квартир (на одной странице их 28)
    # Делаем ссылку!
    page = page_part_1 + str(i) + page_part_2
    
    # Загружаем страницу
    response = requests.get(page)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Забираем себе хрефы и очищаем их
    hrefs = soup.findAll('div', attrs = {'class':"serp-item__content__bottom__left"})
    clean_hrefs = [item.a.attrs['href'] for item in hrefs]
    all_hrefs.extend(clean_hrefs)
    print('Качаю хреф номер ',i)

print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода
# Out:
# Качаю хреф номер  1
# Качаю хреф номер  2
# Качаю хреф номер  3
# Качаю хреф номер  4
# Качаю хреф номер  5
# Качаю хреф номер  6
# Качаю хреф номер  7
# Качаю хреф номер  8
# Качаю хреф номер  9
# Качаю хреф номер  10
# --- 14.110546588897705 seconds ---

# %% [markdown]
# На $10$ страниц ($280$ наблюдений, по $28$ квартир на каждой странице) уходит от $12$ до $15$ секунд. Чтобы скачать $150 000$ наблюдений (около $5358$ страниц) нам понадобится $15 \cdot 535.8 = 8036$ секунд. То есть около двух с половиной часов. Это не критично и можно подождать.
#
# Посмотрим как обстоит дело с основной частью кода, которая занимается прогрузкой информации о квартирах по каждому хрефу.

# %%
start_time = time.time() # время работы кода 

### Вторая часть кода. Функция, которая вытаскивает наблюдения по одной квартирке.        
def One_Flat_Downloader(href):
    """
    Функция производит выкачку по одной ЦИАНовской ссылке 
    всей существующей информации о квартире.
    Ввод: ссылка на описание квартиры
    Вывод: словарь с информацией о квартире    
    """
    
    data = { }  # Задали пустой словарь, в который мы будем сохранять данные
    
    # Подгружаем страничку с информацией по квартире
    response = requests.get(href)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Вытаскиваем цену на квартиру
    price = soup.findAll('div', attrs = {'class':"object_descr_price"})[0].text.strip()
    data['Цена'] = price
    
    # Вытаскиваем метро
    try:
        station = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0].a.text
        data['Метро'] = station
    except Exception:
        data['Метро'] = "NA"
    
    # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
    try:
        Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
        Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
        data['До метро'] = Do_metro
    except Exception:
        data['До метро'] = "NA"
    
    # Вытаскиваем координаты квартиры
    coordinates = soup.findAll('div',{'class':"object-descr__map-tabs__content js-object_descr__panorama"})[0]
    data['Координаты'] = coordinates.panorama.attrs['point']
    
        
    # Вытаскиваем количество комнат в квартире
    komnata = soup.findAll('div', attrs = {'class':"object_descr_title"})[0].text.strip()
    data['Комнаты'] = komnata
    
    # Вытаскиваем всё остальное
    table = soup.findAll('table',attrs = {'class':"object_descr_props flat sale"})[0]
    rows = table.find_all('tr')[1:]  # Вытащили все строки
    for row in rows:
        cols = [row.findAll('th')[0].text.strip(),row.findAll('td')[0].text.strip()] # очищаем каждую строку! 
        data[cols[0]] = cols[1] # запоминаем
    return(data) 


### Третья часть кода. Собираем данные по всем хрефам и объединяем их в огромную таблицу.

# В эту табличку будем собирать данные
df = pd.DataFrame( )
k = 0 # Это номера наблюдений
n = len(all_hrefs)
for item in all_hrefs:
    k = k + 1
    # грузим новое наблюдение
    df1 = pd.DataFrame.from_dict(One_Flat_Downloader(item),orient='index')
    # присваиваем этому наблюдению номер
    df1.columns =[k]
    # закидываем его в итоговую таблицу
    df = df.join(df1, how='outer')
    # Выдавать информацию о том, что сделана каждая десятая итерация! 
    if k%10 == 0:
        print('скачал ', k, ' квартир', n)

        
df = df.T  # Для удобства транспонируем таблицу        

# Добавим к итоговой таблице колонку из хрефов. Когда мы будем смотреть на данные,
# будет возникать довольно большое количество аномалий. Хотелось бы получше изучить
# их природу...

df['Хрефы'] = all_hrefs

print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода
# Out:
# скачал  10  квартир 280
# скачал  20  квартир 280
# скачал  30  квартир 280
# скачал  40  квартир 280
# скачал  50  квартир 280
# скачал  60  квартир 280
# скачал  70  квартир 280
# скачал  80  квартир 280
# скачал  90  квартир 280
# скачал  100  квартир 280
# скачал  110  квартир 280
# скачал  120  квартир 280
# скачал  130  квартир 280
# скачал  140  квартир 280
# скачал  150  квартир 280
# скачал  160  квартир 280
# скачал  170  квартир 280
# скачал  180  квартир 280
# скачал  190  квартир 280
# скачал  200  квартир 280
# скачал  210  квартир 280
# скачал  220  квартир 280
# скачал  230  квартир 280
# скачал  240  квартир 280
# скачал  250  квартир 280
# скачал  260  квартир 280
# скачал  270  квартир 280
# скачал  280  квартир 280
# --- 194.09195709228516 seconds ---

# %% [markdown]
# На выкачку $280$ наблюдений уходит около $200$ секунд. Значит для выкачки $150000$ наблюдений нам понадобится примерно $107142$ секунд ($30$ часов). Это довольна большая цифра. Такое количество времени ждать нам не очень хочется. Хотелось бы получить свои заслуженные наблюдения побыстрее.
#
# Вспомним, что у нашего компьютера есть несколько ядер и все вычисления, которые идут на нём можно распаралелить. Если бы у нас получилось качать данные в два потока, то код проработал бы $15$ часов. Если бы потоков было бы $10$, то код проработал бы $3$ часа. Если потоков было бы $30$, то код проработал бы всего один час.
#
# Обратите внимание, что мы при расчётах руководствуемся предпосылкой, от том что время работы нашего кода растёт линейно по объёму необходимой нам информации. Это довольно логично. Все циклы, прописанные нами выше, кроме самого главного никак не зависят от объема поступающей информации. Сложность нашего алгоритма по времени $O(n)$!
#
# Круто! Дело осталось за малым. Выбрать сколько потоков потянет наш компьютер и распаралелить код.

# %% [markdown]
# ## 2. Что такое Map - Reduce и кто такой Hadoop.
#
# ![Картинка со слоником]( )
#
#
# Эксперименты Google
#
# https://cloud.google.com/blog/big-data/2016/02/history-of-massive-scale-sorting-experiments-at-google

# %%
import numpy as np

# %%
from multiprocessing import Pool, cpu_count

# %% [markdown]
# Выясним сколько ядер на нашем компьютере.

# %%
cpu_count()
# Out:
# 4

# %% [markdown]
# В общем случае, распаралеливание кода делается по числу ядер. И обычно большее количество ядер означает большую скорость (если этот код вообще стоило паралелить).
#
# Мы будем использовать немного иную штуку, а именно многопоточную обработку. Разобьём имеющуюся у нас информацию на несколько частей и будем обрабатывать её в несколько потоков. Есть смысл поэкспериментировать с количеством потоков. Если их будет очень много, то код будет тратить лишнее время на переключение между ними.
#
# Итак, создаём 30 воркеров и пробуем прогнать наш алгоритм.

# %%
pool = ThreadPool(13)
results = pool.map(np.mean, parts)

# %%
tart_time = time.time() # время работы кода 


print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода

# %% [markdown]
# ## 3. Применяем концепцию Map - Reduce к нашему случаю.
#
# Итак, наш код состоит из двух частей. Первая - тащит хрефы и работает около 2-х часов. Её особо трогать не хочется. Распаралеливание может принести нам много головной боли. Нужно выбрать с какой страницы стартует какая часть кода и на какой странице какая часть кода свою работу заканчивает. Забьём на этот кусок и просто подождём пару часов. Два часа это не двое суток!

# %%
start_time = time.time() # время работы кода 

### Первая часть кода. Вытаскиваем список хрефов.

page_part_1 = "https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p="
page_part_2 = "&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1"

all_hrefs = [ ]  # Тут мы будем хранить наши хрефы!

for i in range(1,5361): # Тут регулируем количество квартир (на одной странице их 28)
    # Делаем ссылку!
    page = page_part_1 + str(i) + page_part_2
    
    # Загружаем страницу
    response = requests.get(page)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Забираем себе хрефы и очищаем их
    hrefs = soup.findAll('div', attrs = {'class':"serp-item__content__bottom__left"})
    clean_hrefs = [item.a.attrs['href'] for item in hrefs]
    all_hrefs.extend(clean_hrefs)
    print('Качаю хреф номер ',i)

print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода
# Out:
# Качаю хреф номер  1
# Качаю хреф номер  2
# Качаю хреф номер  3
# Качаю хреф номер  4
# Качаю хреф номер  5
# Качаю хреф номер  6
# Качаю хреф номер  7
# Качаю хреф номер  8
# Качаю хреф номер  9
# Качаю хреф номер  10
# Качаю хреф номер  11
# Качаю хреф номер  12
# Качаю хреф номер  13
# Качаю хреф номер  14
# Качаю хреф номер  15
# Качаю хреф номер  16
# Качаю хреф номер  17
# Качаю хреф номер  18
# Качаю хреф номер  19
# Качаю хреф номер  20
# Качаю хреф номер  21
# Качаю хреф номер  22
# Качаю хреф номер  23
# Качаю хреф номер  24
# Качаю хреф номер  25
# Качаю хреф номер  26
# Качаю хреф номер  27
# Качаю хреф номер  28
# Качаю хреф номер  29
# Качаю хреф номер  30
# Качаю хреф номер  31
# Качаю хреф номер  32
# Качаю хреф номер  33
# Качаю хреф номер  34
# Качаю хреф номер  35
# Качаю хреф номер  36
# Качаю хреф номер  37
# Качаю хреф номер  38
# Качаю хреф номер  39
# Качаю хреф номер  40
# Качаю хреф номер  41
# Качаю хреф номер  42
# Качаю хреф номер  43
# Качаю хреф номер  44
# Качаю хреф номер  45
# Качаю хреф номер  46
# Качаю хреф номер  47
# Качаю хреф номер  48
# Качаю хреф номер  49
# Качаю хреф номер  50
# Качаю хреф номер  51
# Качаю хреф номер  52
# Качаю хреф номер  53
# Качаю хреф номер  54
# Качаю хреф номер  55
# Качаю хреф номер  56
# Качаю хреф номер  57
# Качаю хреф номер  58
# Качаю хреф номер  59
# Качаю хреф номер  60
# Качаю хреф номер  61
# Качаю хреф номер  62
# Качаю хреф номер  63
# Качаю хреф номер  64
# Качаю хреф номер  65
# Качаю хреф номер  66
# Качаю хреф номер  67
# Качаю хреф номер  68
# Качаю хреф номер  69
# Качаю хреф номер  70
# Качаю хреф номер  71
# Качаю хреф номер  72
# Качаю хреф номер  73
# Качаю хреф номер  74
# Качаю хреф номер  75
# Качаю хреф номер  76
# Качаю хреф номер  77
# Качаю хреф номер  78
# Качаю хреф номер  79
# Качаю хреф номер  80
# Качаю хреф номер  81
# Качаю хреф номер  82
# Качаю хреф номер  83
# Качаю хреф номер  84
# Качаю хреф номер  85
# Качаю хреф номер  86
# Качаю хреф номер  87
# Качаю хреф номер  88
# Качаю хреф номер  89
# Качаю хреф номер  90
# Качаю хреф номер  91
# Качаю хреф номер  92
# Качаю хреф номер  93
# Качаю хреф номер  94
# Качаю хреф номер  95
# Качаю хреф номер  96
# Качаю хреф номер  97
# Качаю хреф номер  98
# Качаю хреф номер  99
# Качаю хреф номер  100
# Качаю хреф номер  101
# Качаю хреф номер  102
# Качаю хреф номер  103
# Качаю хреф номер  104
# Качаю хреф номер  105
# Качаю хреф номер  106
# Качаю хреф номер  107
# Качаю хреф номер  108
# Качаю хреф номер  109
# Качаю хреф номер  110
# Качаю хреф номер  111
# Качаю хреф номер  112
# Качаю хреф номер  113
# Качаю хреф номер  114
# Качаю хреф номер  115
# Качаю хреф номер  116
# Качаю хреф номер  117
# Качаю хреф номер  118
# Качаю хреф номер  119
# Качаю хреф номер  120
# Качаю хреф номер  121
# Качаю хреф номер  122
# Качаю хреф номер  123
# Качаю хреф номер  124
# Качаю хреф номер  125
# Качаю хреф номер  126
# Качаю хреф номер  127
# Качаю хреф номер  128
# Качаю хреф номер  129
# Качаю хреф номер  130
# Качаю хреф номер  131
# Качаю хреф номер  132
# Качаю хреф номер  133
# Качаю хреф номер  134
# Качаю хреф номер  135
# Качаю хреф номер  136
# Качаю хреф номер  137
# Качаю хреф номер  138
# Качаю хреф номер  139
# Качаю хреф номер  140
# Качаю хреф номер  141
# Качаю хреф номер  142
# Качаю хреф номер  143
# Качаю хреф номер  144
# Качаю хреф номер  145
# Качаю хреф номер  146
# Качаю хреф номер  147
# Качаю хреф номер  148
# Качаю хреф номер  149
# Качаю хреф номер  150
# Качаю хреф номер  151
# Качаю хреф номер  152
# Качаю хреф номер  153
# Качаю хреф номер  154
# Качаю хреф номер  155
# Качаю хреф номер  156
# Качаю хреф номер  157
# Качаю хреф номер  158
# Качаю хреф номер  159
# Качаю хреф номер  160
# Качаю хреф номер  161
# Качаю хреф номер  162
# Качаю хреф номер  163
# Качаю хреф номер  164
# Качаю хреф номер  165
# Качаю хреф номер  166
# Качаю хреф номер  167
# Качаю хреф номер  168
# Качаю хреф номер  169
# Качаю хреф номер  170
# Качаю хреф номер  171
# Качаю хреф номер  172
# Качаю хреф номер  173
# Качаю хреф номер  174
# Качаю хреф номер  175
# Качаю хреф номер  176
# Качаю хреф номер  177
# Качаю хреф номер  178
# Качаю хреф номер  179
# Качаю хреф номер  180
# Качаю хреф номер  181
# Качаю хреф номер  182
# Качаю хреф номер  183
# Качаю хреф номер  184
# Качаю хреф номер  185
# Качаю хреф номер  186
# Качаю хреф номер  187
# Качаю хреф номер  188
# Качаю хреф номер  189
# Качаю хреф номер  190
# Качаю хреф номер  191
# Качаю хреф номер  192
# Качаю хреф номер  193
# Качаю хреф номер  194
# Качаю хреф номер  195
# Качаю хреф номер  196
# Качаю хреф номер  197
# Качаю хреф номер  198
# Качаю хреф номер  199
# Качаю хреф номер  200
# Качаю хреф номер  201
# Качаю хреф номер  202
# Качаю хреф номер  203
# Качаю хреф номер  204
# Качаю хреф номер  205
# Качаю хреф номер  206
# Качаю хреф номер  207
# Качаю хреф номер  208
# Качаю хреф номер  209
# Качаю хреф номер  210
# Качаю хреф номер  211
# Качаю хреф номер  212
# Качаю хреф номер  213
# Качаю хреф номер  214
# Качаю хреф номер  215
# Качаю хреф номер  216
# Качаю хреф номер  217
# Качаю хреф номер  218
# Качаю хреф номер  219
# Качаю хреф номер  220
# Качаю хреф номер  221
# Качаю хреф номер  222
# Качаю хреф номер  223
# Качаю хреф номер  224
# Качаю хреф номер  225
# Качаю хреф номер  226
# Качаю хреф номер  227
# Качаю хреф номер  228
# Качаю хреф номер  229
# Качаю хреф номер  230
# Качаю хреф номер  231
# Качаю хреф номер  232
# Качаю хреф номер  233
# Качаю хреф номер  234
# Качаю хреф номер  235
# Качаю хреф номер  236
# Качаю хреф номер  237
# Качаю хреф номер  238
# Качаю хреф номер  239
# Качаю хреф номер  240
# Качаю хреф номер  241
# Качаю хреф номер  242
# Качаю хреф номер  243
# Качаю хреф номер  244
# Качаю хреф номер  245
# Качаю хреф номер  246
# Качаю хреф номер  247
# Качаю хреф номер  248
# Качаю хреф номер  249
# Качаю хреф номер  250
# Качаю хреф номер  251
# Качаю хреф номер  252
# Качаю хреф номер  253
# Качаю хреф номер  254
# Качаю хреф номер  255
# Качаю хреф номер  256
# Качаю хреф номер  257
# Качаю хреф номер  258
# Качаю хреф номер  259
# Качаю хреф номер  260
# Качаю хреф номер  261
# Качаю хреф номер  262
# Качаю хреф номер  263
# Качаю хреф номер  264
# Качаю хреф номер  265
# Качаю хреф номер  266
# Качаю хреф номер  267
# Качаю хреф номер  268
# Качаю хреф номер  269
# Качаю хреф номер  270
# Качаю хреф номер  271
# Качаю хреф номер  272
# Качаю хреф номер  273
# Качаю хреф номер  274
# Качаю хреф номер  275
# Качаю хреф номер  276
# Качаю хреф номер  277
# Качаю хреф номер  278
# Качаю хреф номер  279
# Качаю хреф номер  280
# Качаю хреф номер  281
# Качаю хреф номер  282
# Качаю хреф номер  283
# Качаю хреф номер  284
# Качаю хреф номер  285
# Качаю хреф номер  286
# Качаю хреф номер  287
# Качаю хреф номер  288
# Качаю хреф номер  289
# Качаю хреф номер  290
# Качаю хреф номер  291
# Качаю хреф номер  292
# Качаю хреф номер  293
# Качаю хреф номер  294
# Качаю хреф номер  295
# Качаю хреф номер  296
# Качаю хреф номер  297
# Качаю хреф номер  298
# Качаю хреф номер  299
# Качаю хреф номер  300
# Качаю хреф номер  301
# Качаю хреф номер  302
# Качаю хреф номер  303
# Качаю хреф номер  304
# Качаю хреф номер  305
# Качаю хреф номер  306
# Качаю хреф номер  307
# Качаю хреф номер  308
# Качаю хреф номер  309
# Качаю хреф номер  310
# Качаю хреф номер  311
# Качаю хреф номер  312
# Качаю хреф номер  313
# Качаю хреф номер  314
# Качаю хреф номер  315
# Качаю хреф номер  316
# Качаю хреф номер  317
# Качаю хреф номер  318
# Качаю хреф номер  319
# Качаю хреф номер  320
# Качаю хреф номер  321
# Качаю хреф номер  322
# Качаю хреф номер  323
# Качаю хреф номер  324
# Качаю хреф номер  325
# Качаю хреф номер  326
# Качаю хреф номер  327
# Качаю хреф номер  328
# Качаю хреф номер  329
# Качаю хреф номер  330
# Качаю хреф номер  331
# Качаю хреф номер  332
# Качаю хреф номер  333
# Качаю хреф номер  334
# Качаю хреф номер  335
# Качаю хреф номер  336
# Качаю хреф номер  337
# Качаю хреф номер  338
# Качаю хреф номер  339
# Качаю хреф номер  340
# Качаю хреф номер  341
# Качаю хреф номер  342
# Качаю хреф номер  343
# Качаю хреф номер  344
# Качаю хреф номер  345
# Качаю хреф номер  346
# Качаю хреф номер  347
# Качаю хреф номер  348
# Качаю хреф номер  349
# Качаю хреф номер  350
# Качаю хреф номер  351
# Качаю хреф номер  352
# Качаю хреф номер  353
# Качаю хреф номер  354
# Качаю хреф номер  355
# Качаю хреф номер  356
# Качаю хреф номер  357
# Качаю хреф номер  358
# Качаю хреф номер  359
# Качаю хреф номер  360
# Качаю хреф номер  361
# Качаю хреф номер  362
# Качаю хреф номер  363
# Качаю хреф номер  364
# Качаю хреф номер  365
# Качаю хреф номер  366
# Качаю хреф номер  367
# Качаю хреф номер  368
# Качаю хреф номер  369
# Качаю хреф номер  370
# Качаю хреф номер  371
# Качаю хреф номер  372
# Качаю хреф номер  373
# Качаю хреф номер  374
# Качаю хреф номер  375
# Качаю хреф номер  376
# Качаю хреф номер  377
# Качаю хреф номер  378
# Качаю хреф номер  379
# Качаю хреф номер  380
# Качаю хреф номер  381
# Качаю хреф номер  382
# Качаю хреф номер  383
# Качаю хреф номер  384
# Качаю хреф номер  385
# Качаю хреф номер  386
# Качаю хреф номер  387
# Качаю хреф номер  388
# Качаю хреф номер  389
# Качаю хреф номер  390
# Качаю хреф номер  391
# Качаю хреф номер  392
# Качаю хреф номер  393
# Качаю хреф номер  394
# Качаю хреф номер  395
# Качаю хреф номер  396
# Качаю хреф номер  397
# Качаю хреф номер  398
# Качаю хреф номер  399
# Качаю хреф номер  400
# Качаю хреф номер  401
# Качаю хреф номер  402
# Качаю хреф номер  403
# Качаю хреф номер  404
# Качаю хреф номер  405
# Качаю хреф номер  406
# Качаю хреф номер  407
# Качаю хреф номер  408
# Качаю хреф номер  409
# Качаю хреф номер  410
# Качаю хреф номер  411
# Качаю хреф номер  412
# Качаю хреф номер  413
# Качаю хреф номер  414
# Качаю хреф номер  415
# Качаю хреф номер  416
# Качаю хреф номер  417
# Качаю хреф номер  418
# Качаю хреф номер  419
# Качаю хреф номер  420
# Качаю хреф номер  421
# Качаю хреф номер  422
# Качаю хреф номер  423
# Качаю хреф номер  424
# Качаю хреф номер  425
# Качаю хреф номер  426
# Качаю хреф номер  427
# Качаю хреф номер  428
# Качаю хреф номер  429
# Качаю хреф номер  430
# Качаю хреф номер  431
# Качаю хреф номер  432
# Качаю хреф номер  433
# Качаю хреф номер  434
# Качаю хреф номер  435
# Качаю хреф номер  436
# Качаю хреф номер  437
# Качаю хреф номер  438
# Качаю хреф номер  439
# Качаю хреф номер  440
# Качаю хреф номер  441
# Качаю хреф номер  442
# Качаю хреф номер  443
# Качаю хреф номер  444
# Качаю хреф номер  445
# Качаю хреф номер  446
# Качаю хреф номер  447
# Качаю хреф номер  448
# Качаю хреф номер  449
# Качаю хреф номер  450
# Качаю хреф номер  451
# Качаю хреф номер  452
# Качаю хреф номер  453
# Качаю хреф номер  454
# Качаю хреф номер  455
# Качаю хреф номер  456
# Качаю хреф номер  457
# Качаю хреф номер  458
# Качаю хреф номер  459
# Качаю хреф номер  460
# Качаю хреф номер  461
# Качаю хреф номер  462
# Качаю хреф номер  463
# Качаю хреф номер  464
# Качаю хреф номер  465
# Качаю хреф номер  466
# Качаю хреф номер  467
# Качаю хреф номер  468
# Качаю хреф номер  469
# Качаю хреф номер  470
# Качаю хреф номер  471
# Качаю хреф номер  472
# Качаю хреф номер  473
# Качаю хреф номер  474
# Качаю хреф номер  475
# Качаю хреф номер  476
# Качаю хреф номер  477
# Качаю хреф номер  478
# Качаю хреф номер  479
# Качаю хреф номер  480
# Качаю хреф номер  481
# Качаю хреф номер  482
# Качаю хреф номер  483
# Качаю хреф номер  484
# Качаю хреф номер  485
# Качаю хреф номер  486
# Качаю хреф номер  487
# Качаю хреф номер  488
# Качаю хреф номер  489
# Качаю хреф номер  490
# Качаю хреф номер  491
# Качаю хреф номер  492
# Качаю хреф номер  493
# Качаю хреф номер  494
# Качаю хреф номер  495
# Качаю хреф номер  496
# Качаю хреф номер  497
# Качаю хреф номер  498
# Качаю хреф номер  499
# Качаю хреф номер  500
# Качаю хреф номер  501
# Качаю хреф номер  502
# Качаю хреф номер  503
# Качаю хреф номер  504
# Качаю хреф номер  505
# Качаю хреф номер  506
# Качаю хреф номер  507
# Качаю хреф номер  508
# Качаю хреф номер  509
# Качаю хреф номер  510
# Качаю хреф номер  511
# Качаю хреф номер  512
# Качаю хреф номер  513
# Качаю хреф номер  514
# Качаю хреф номер  515
# Качаю хреф номер  516
# Качаю хреф номер  517
# Качаю хреф номер  518
# Качаю хреф номер  519
# Качаю хреф номер  520
# Качаю хреф номер  521
# Качаю хреф номер  522
# Качаю хреф номер  523
# Качаю хреф номер  524
# Качаю хреф номер  525
# Качаю хреф номер  526
# Качаю хреф номер  527
# Качаю хреф номер  528
# Качаю хреф номер  529
# Качаю хреф номер  530
# Качаю хреф номер  531
# Качаю хреф номер  532
# Качаю хреф номер  533
# Качаю хреф номер  534
# Качаю хреф номер  535
# Качаю хреф номер  536
# Качаю хреф номер  537
# Качаю хреф номер  538
# Качаю хреф номер  539
# Качаю хреф номер  540
# Качаю хреф номер  541
# Качаю хреф номер  542
# Качаю хреф номер  543
# Качаю хреф номер  544
# Качаю хреф номер  545
# Качаю хреф номер  546
# Качаю хреф номер  547
# Качаю хреф номер  548
# Качаю хреф номер  549
# Качаю хреф номер  550
# Качаю хреф номер  551
# Качаю хреф номер  552
# Качаю хреф номер  553
# Качаю хреф номер  554
# Качаю хреф номер  555
# Качаю хреф номер  556
# Качаю хреф номер  557
# Качаю хреф номер  558
# Качаю хреф номер  559
# Качаю хреф номер  560
# Качаю хреф номер  561
# Качаю хреф номер  562
# Качаю хреф номер  563
# Качаю хреф номер  564
# Качаю хреф номер  565
# Качаю хреф номер  566
# Качаю хреф номер  567
# Качаю хреф номер  568
# Качаю хреф номер  569
# Качаю хреф номер  570
# Качаю хреф номер  571
# Качаю хреф номер  572
# Качаю хреф номер  573
# Качаю хреф номер  574
# Качаю хреф номер  575
# Качаю хреф номер  576
# Качаю хреф номер  577
# Качаю хреф номер  578
# Качаю хреф номер  579
# Качаю хреф номер  580
# Качаю хреф номер  581
# Качаю хреф номер  582
# Качаю хреф номер  583
# Качаю хреф номер  584
# Качаю хреф номер  585
# Качаю хреф номер  586
# Качаю хреф номер  587
# Качаю хреф номер  588
# Качаю хреф номер  589
# Качаю хреф номер  590
# Качаю хреф номер  591
# Качаю хреф номер  592
# Качаю хреф номер  593
# Качаю хреф номер  594
# Качаю хреф номер  595
# Качаю хреф номер  596
# Качаю хреф номер  597
# Качаю хреф номер  598
# Качаю хреф номер  599
# Качаю хреф номер  600
# Качаю хреф номер  601
# Качаю хреф номер  602
# Качаю хреф номер  603
# Качаю хреф номер  604
# Качаю хреф номер  605
# Качаю хреф номер  606
# Качаю хреф номер  607
# Качаю хреф номер  608
# Качаю хреф номер  609
# Качаю хреф номер  610
# Качаю хреф номер  611
# Качаю хреф номер  612
# Качаю хреф номер  613
# Качаю хреф номер  614
# Качаю хреф номер  615
# Качаю хреф номер  616
# Качаю хреф номер  617
# Качаю хреф номер  618
# Качаю хреф номер  619
# Качаю хреф номер  620
# Качаю хреф номер  621
# Качаю хреф номер  622
# Качаю хреф номер  623
# Качаю хреф номер  624
# Качаю хреф номер  625
# Качаю хреф номер  626
# Качаю хреф номер  627
# Качаю хреф номер  628
# Качаю хреф номер  629
# Качаю хреф номер  630
# Качаю хреф номер  631
# Качаю хреф номер  632
# Качаю хреф номер  633
# Качаю хреф номер  634
# Качаю хреф номер  635
# Качаю хреф номер  636
# Качаю хреф номер  637
# Качаю хреф номер  638
# Качаю хреф номер  639
# Качаю хреф номер  640
# Качаю хреф номер  641
# Качаю хреф номер  642
# Качаю хреф номер  643
# Качаю хреф номер  644
# Качаю хреф номер  645
# Качаю хреф номер  646
# Качаю хреф номер  647
# Качаю хреф номер  648
# Качаю хреф номер  649
# Качаю хреф номер  650
# Качаю хреф номер  651
# Качаю хреф номер  652
# Качаю хреф номер  653
# Качаю хреф номер  654
# Качаю хреф номер  655
# Качаю хреф номер  656
# Качаю хреф номер  657
# Качаю хреф номер  658
# Качаю хреф номер  659
# Качаю хреф номер  660
# Качаю хреф номер  661
# Качаю хреф номер  662
# Качаю хреф номер  663
# Качаю хреф номер  664
# Качаю хреф номер  665
# Качаю хреф номер  666
# Качаю хреф номер  667
# Качаю хреф номер  668
# Качаю хреф номер  669
# Качаю хреф номер  670
# Качаю хреф номер  671
# Качаю хреф номер  672
# Качаю хреф номер  673
# Качаю хреф номер  674
# Качаю хреф номер  675
# Качаю хреф номер  676
# Качаю хреф номер  677
# Качаю хреф номер  678
# Качаю хреф номер  679
# Качаю хреф номер  680
# Качаю хреф номер  681
# Качаю хреф номер  682
# Качаю хреф номер  683
# Качаю хреф номер  684
# Качаю хреф номер  685
# Качаю хреф номер  686
# Качаю хреф номер  687
# Качаю хреф номер  688
# Качаю хреф номер  689
# Качаю хреф номер  690
# Качаю хреф номер  691
# Качаю хреф номер  692
# Качаю хреф номер  693
# Качаю хреф номер  694
# Качаю хреф номер  695
# Качаю хреф номер  696
# Качаю хреф номер  697
# Качаю хреф номер  698
# Качаю хреф номер  699
# Качаю хреф номер  700
# Качаю хреф номер  701
# Качаю хреф номер  702
# Качаю хреф номер  703
# Качаю хреф номер  704
# Качаю хреф номер  705
# Качаю хреф номер  706
# Качаю хреф номер  707
# Качаю хреф номер  708
# Качаю хреф номер  709
# Качаю хреф номер  710
# Качаю хреф номер  711
# Качаю хреф номер  712
# Качаю хреф номер  713
# Качаю хреф номер  714
# Качаю хреф номер  715
# Качаю хреф номер  716
# Качаю хреф номер  717
# Качаю хреф номер  718
# Качаю хреф номер  719
# Качаю хреф номер  720
# Качаю хреф номер  721
# Качаю хреф номер  722
# Качаю хреф номер  723
# Качаю хреф номер  724
# Качаю хреф номер  725
# Качаю хреф номер  726
# Качаю хреф номер  727
# Качаю хреф номер  728
# Качаю хреф номер  729
# Качаю хреф номер  730
# Качаю хреф номер  731
# Качаю хреф номер  732
# Качаю хреф номер  733
# Качаю хреф номер  734
# Качаю хреф номер  735
# Качаю хреф номер  736
# Качаю хреф номер  737
# Качаю хреф номер  738
# Качаю хреф номер  739
# Качаю хреф номер  740
# Качаю хреф номер  741
# Качаю хреф номер  742
# Качаю хреф номер  743
# Качаю хреф номер  744
# Качаю хреф номер  745
# Качаю хреф номер  746
# Качаю хреф номер  747
# Качаю хреф номер  748
# Качаю хреф номер  749
# Качаю хреф номер  750
# Качаю хреф номер  751
# Качаю хреф номер  752
# Качаю хреф номер  753
# Качаю хреф номер  754
# Качаю хреф номер  755
# Качаю хреф номер  756
# Качаю хреф номер  757
# Качаю хреф номер  758
# Качаю хреф номер  759
# Качаю хреф номер  760
# Качаю хреф номер  761
# Качаю хреф номер  762
# Качаю хреф номер  763
# Качаю хреф номер  764
# Качаю хреф номер  765
# Качаю хреф номер  766
# Качаю хреф номер  767
# Качаю хреф номер  768
# Качаю хреф номер  769
# Качаю хреф номер  770
# Качаю хреф номер  771
# Качаю хреф номер  772
# Качаю хреф номер  773
# Качаю хреф номер  774
# Качаю хреф номер  775
# Качаю хреф номер  776
# Качаю хреф номер  777
# Качаю хреф номер  778
# Качаю хреф номер  779
# Качаю хреф номер  780
# Качаю хреф номер  781
# Качаю хреф номер  782
# Качаю хреф номер  783
# Качаю хреф номер  784
# Качаю хреф номер  785
# Качаю хреф номер  786
# Качаю хреф номер  787
# Качаю хреф номер  788
# Качаю хреф номер  789
# Качаю хреф номер  790
# Качаю хреф номер  791
# Качаю хреф номер  792
# Качаю хреф номер  793
# Качаю хреф номер  794
# Качаю хреф номер  795
# Качаю хреф номер  796
# Качаю хреф номер  797
# Качаю хреф номер  798
# Качаю хреф номер  799
# Качаю хреф номер  800
# Качаю хреф номер  801
# Качаю хреф номер  802
# Качаю хреф номер  803
# Качаю хреф номер  804
# Качаю хреф номер  805
# Качаю хреф номер  806
# Качаю хреф номер  807
# Качаю хреф номер  808
# Качаю хреф номер  809
# Качаю хреф номер  810
# Качаю хреф номер  811
# Качаю хреф номер  812
# Качаю хреф номер  813
# Качаю хреф номер  814
# Качаю хреф номер  815
# Качаю хреф номер  816
# Качаю хреф номер  817
# Качаю хреф номер  818
# Качаю хреф номер  819
# Качаю хреф номер  820
# Качаю хреф номер  821
# Качаю хреф номер  822
# Качаю хреф номер  823
# Качаю хреф номер  824
# Качаю хреф номер  825
# Качаю хреф номер  826
# Качаю хреф номер  827
# Качаю хреф номер  828
# Качаю хреф номер  829
# Качаю хреф номер  830
# Качаю хреф номер  831
# Качаю хреф номер  832
# Качаю хреф номер  833
# Качаю хреф номер  834
# Качаю хреф номер  835
# Качаю хреф номер  836
# Качаю хреф номер  837
# Качаю хреф номер  838
# Качаю хреф номер  839
# Качаю хреф номер  840
# Качаю хреф номер  841
# Качаю хреф номер  842
# Качаю хреф номер  843
# Качаю хреф номер  844
# Качаю хреф номер  845
# Качаю хреф номер  846
# Качаю хреф номер  847
# Качаю хреф номер  848
# Качаю хреф номер  849
# Качаю хреф номер  850
# Качаю хреф номер  851
# Качаю хреф номер  852
# Качаю хреф номер  853
# Качаю хреф номер  854
# Качаю хреф номер  855
# Качаю хреф номер  856
# Качаю хреф номер  857
# Качаю хреф номер  858
# Качаю хреф номер  859
# Качаю хреф номер  860
# Качаю хреф номер  861
# Качаю хреф номер  862
# Качаю хреф номер  863
# Качаю хреф номер  864
# Качаю хреф номер  865
# Качаю хреф номер  866
# Качаю хреф номер  867
# Качаю хреф номер  868
# Качаю хреф номер  869
# Качаю хреф номер  870
# Качаю хреф номер  871
# Качаю хреф номер  872
# Качаю хреф номер  873
# Качаю хреф номер  874
# Качаю хреф номер  875
# Качаю хреф номер  876
# Качаю хреф номер  877
# Качаю хреф номер  878
# Качаю хреф номер  879
# Качаю хреф номер  880
# Качаю хреф номер  881
# Качаю хреф номер  882
# Качаю хреф номер  883
# Качаю хреф номер  884
# Качаю хреф номер  885
# Качаю хреф номер  886
# Качаю хреф номер  887
# Качаю хреф номер  888
# Качаю хреф номер  889
# Качаю хреф номер  890
# Качаю хреф номер  891
# Качаю хреф номер  892
# Качаю хреф номер  893
# Качаю хреф номер  894
# Качаю хреф номер  895
# Качаю хреф номер  896
# Качаю хреф номер  897
# Качаю хреф номер  898
# Качаю хреф номер  899
# Качаю хреф номер  900
# Качаю хреф номер  901
# Качаю хреф номер  902
# Качаю хреф номер  903
# Качаю хреф номер  904
# Качаю хреф номер  905
# Качаю хреф номер  906
# Качаю хреф номер  907
# Качаю хреф номер  908
# Качаю хреф номер  909
# Качаю хреф номер  910
# Качаю хреф номер  911
# Качаю хреф номер  912
# Качаю хреф номер  913
# Качаю хреф номер  914
# Качаю хреф номер  915
# Качаю хреф номер  916
# Качаю хреф номер  917
# Качаю хреф номер  918
# Качаю хреф номер  919
# Качаю хреф номер  920
# Качаю хреф номер  921
# Качаю хреф номер  922
# Качаю хреф номер  923
# Качаю хреф номер  924
# Качаю хреф номер  925
# Качаю хреф номер  926
# Качаю хреф номер  927
# Качаю хреф номер  928
# Качаю хреф номер  929
# Качаю хреф номер  930
# Качаю хреф номер  931
# Качаю хреф номер  932
# Качаю хреф номер  933
# Качаю хреф номер  934
# Качаю хреф номер  935
# Качаю хреф номер  936
# Качаю хреф номер  937
# Качаю хреф номер  938
# Качаю хреф номер  939
# Качаю хреф номер  940
# Качаю хреф номер  941
# Качаю хреф номер  942
# Качаю хреф номер  943
# Качаю хреф номер  944
# Качаю хреф номер  945
# Качаю хреф номер  946
# Качаю хреф номер  947
# Качаю хреф номер  948
# Качаю хреф номер  949
# Качаю хреф номер  950
# Качаю хреф номер  951
# Качаю хреф номер  952
# Качаю хреф номер  953
# Качаю хреф номер  954
# Качаю хреф номер  955
# Качаю хреф номер  956
# Качаю хреф номер  957
# Качаю хреф номер  958
# Качаю хреф номер  959
# Качаю хреф номер  960
# Качаю хреф номер  961
# Качаю хреф номер  962
# Качаю хреф номер  963
# Качаю хреф номер  964
# Качаю хреф номер  965
# Качаю хреф номер  966
# Качаю хреф номер  967
# Качаю хреф номер  968
# Качаю хреф номер  969
# Качаю хреф номер  970
# Качаю хреф номер  971
# Качаю хреф номер  972
# Качаю хреф номер  973
# Качаю хреф номер  974
# Качаю хреф номер  975
# Качаю хреф номер  976
# Качаю хреф номер  977
# Качаю хреф номер  978
# Качаю хреф номер  979
# Качаю хреф номер  980
# Качаю хреф номер  981
# Качаю хреф номер  982
# Качаю хреф номер  983
# Качаю хреф номер  984
# Качаю хреф номер  985
# Качаю хреф номер  986
# Качаю хреф номер  987
# Качаю хреф номер  988
# Качаю хреф номер  989
# Качаю хреф номер  990
# Качаю хреф номер  991
# Качаю хреф номер  992
# Качаю хреф номер  993
# Качаю хреф номер  994
# Качаю хреф номер  995
# Качаю хреф номер  996
# Качаю хреф номер  997
# Качаю хреф номер  998
# Качаю хреф номер  999
# Качаю хреф номер  1000
# Качаю хреф номер  1001
# Качаю хреф номер  1002
# Качаю хреф номер  1003
# Качаю хреф номер  1004
# Качаю хреф номер  1005
# Качаю хреф номер  1006
# Качаю хреф номер  1007
# Качаю хреф номер  1008
# Качаю хреф номер  1009
# Качаю хреф номер  1010
# Качаю хреф номер  1011
# Качаю хреф номер  1012
# Качаю хреф номер  1013
# Качаю хреф номер  1014
# Качаю хреф номер  1015
# Качаю хреф номер  1016
# Качаю хреф номер  1017
# Качаю хреф номер  1018
# Качаю хреф номер  1019
# Качаю хреф номер  1020
# Качаю хреф номер  1021
# Качаю хреф номер  1022
# Качаю хреф номер  1023
# Качаю хреф номер  1024
# Качаю хреф номер  1025
# Качаю хреф номер  1026
# Качаю хреф номер  1027
# Качаю хреф номер  1028
# Качаю хреф номер  1029
# Качаю хреф номер  1030
# Качаю хреф номер  1031
# Качаю хреф номер  1032
# Качаю хреф номер  1033
# Качаю хреф номер  1034
# Качаю хреф номер  1035
# Качаю хреф номер  1036
# Качаю хреф номер  1037
# Качаю хреф номер  1038
# Качаю хреф номер  1039
# Качаю хреф номер  1040
# Качаю хреф номер  1041
# Качаю хреф номер  1042
# Качаю хреф номер  1043
# Качаю хреф номер  1044
# Качаю хреф номер  1045
# Качаю хреф номер  1046
# Качаю хреф номер  1047
# Качаю хреф номер  1048
# Качаю хреф номер  1049
# Качаю хреф номер  1050
# Качаю хреф номер  1051
# Качаю хреф номер  1052
# Качаю хреф номер  1053
# Качаю хреф номер  1054
# Качаю хреф номер  1055
# Качаю хреф номер  1056
# Качаю хреф номер  1057
# Качаю хреф номер  1058
# Качаю хреф номер  1059
# Качаю хреф номер  1060
# Качаю хреф номер  1061
# Качаю хреф номер  1062
# Качаю хреф номер  1063
# Качаю хреф номер  1064
# Качаю хреф номер  1065
# Качаю хреф номер  1066
# Качаю хреф номер  1067
# Качаю хреф номер  1068
# Качаю хреф номер  1069
# Качаю хреф номер  1070
# Качаю хреф номер  1071
# Качаю хреф номер  1072
# Качаю хреф номер  1073
# Качаю хреф номер  1074
# Качаю хреф номер  1075
# Качаю хреф номер  1076
# Качаю хреф номер  1077
# Качаю хреф номер  1078
# Качаю хреф номер  1079
# Качаю хреф номер  1080
# Качаю хреф номер  1081
# Качаю хреф номер  1082
# Качаю хреф номер  1083
# Качаю хреф номер  1084
# Качаю хреф номер  1085
# Качаю хреф номер  1086
# Качаю хреф номер  1087
# Качаю хреф номер  1088
# Качаю хреф номер  1089
# Качаю хреф номер  1090
# Качаю хреф номер  1091
# Качаю хреф номер  1092
# Качаю хреф номер  1093
# Качаю хреф номер  1094
# Качаю хреф номер  1095
# Качаю хреф номер  1096
# Качаю хреф номер  1097
# Качаю хреф номер  1098
# Качаю хреф номер  1099
# Качаю хреф номер  1100
# Качаю хреф номер  1101
# Качаю хреф номер  1102
# Качаю хреф номер  1103
# Качаю хреф номер  1104
# Качаю хреф номер  1105
# Качаю хреф номер  1106
# Качаю хреф номер  1107
# Качаю хреф номер  1108
# Качаю хреф номер  1109
# Качаю хреф номер  1110
# Качаю хреф номер  1111
# Качаю хреф номер  1112
# Качаю хреф номер  1113
# Качаю хреф номер  1114
# Качаю хреф номер  1115
# Качаю хреф номер  1116
# Качаю хреф номер  1117
# Качаю хреф номер  1118
# Качаю хреф номер  1119
# Качаю хреф номер  1120
# Качаю хреф номер  1121
# Качаю хреф номер  1122
# Качаю хреф номер  1123
# Качаю хреф номер  1124
# Качаю хреф номер  1125
# Качаю хреф номер  1126
# Качаю хреф номер  1127
# Качаю хреф номер  1128
# Качаю хреф номер  1129
# Качаю хреф номер  1130
# Качаю хреф номер  1131
# Качаю хреф номер  1132
# Качаю хреф номер  1133
# Качаю хреф номер  1134
# Качаю хреф номер  1135
# Качаю хреф номер  1136
# Качаю хреф номер  1137
# Качаю хреф номер  1138
# Качаю хреф номер  1139
# Качаю хреф номер  1140
# Качаю хреф номер  1141
# Качаю хреф номер  1142
# Качаю хреф номер  1143
# Качаю хреф номер  1144
# Качаю хреф номер  1145
# Качаю хреф номер  1146
# Качаю хреф номер  1147
# Качаю хреф номер  1148
# Качаю хреф номер  1149
# Качаю хреф номер  1150
# Качаю хреф номер  1151
# Качаю хреф номер  1152
# Качаю хреф номер  1153
# Качаю хреф номер  1154
# Качаю хреф номер  1155
# Качаю хреф номер  1156
# Качаю хреф номер  1157
# Качаю хреф номер  1158
# Качаю хреф номер  1159
# Качаю хреф номер  1160
# Качаю хреф номер  1161
# Качаю хреф номер  1162
# Качаю хреф номер  1163
# Качаю хреф номер  1164
# Качаю хреф номер  1165
# Качаю хреф номер  1166
# Качаю хреф номер  1167
# Качаю хреф номер  1168
# Качаю хреф номер  1169
# Качаю хреф номер  1170
# Качаю хреф номер  1171
# Качаю хреф номер  1172
# Качаю хреф номер  1173
# Качаю хреф номер  1174
# Качаю хреф номер  1175
# Качаю хреф номер  1176
# Качаю хреф номер  1177
# Качаю хреф номер  1178
# Качаю хреф номер  1179
# Качаю хреф номер  1180
# Качаю хреф номер  1181
# Качаю хреф номер  1182
# Качаю хреф номер  1183
# Качаю хреф номер  1184
# Качаю хреф номер  1185
# Качаю хреф номер  1186
# Качаю хреф номер  1187
# Качаю хреф номер  1188
# Качаю хреф номер  1189
# Качаю хреф номер  1190
# Качаю хреф номер  1191
# Качаю хреф номер  1192
# Качаю хреф номер  1193
# Качаю хреф номер  1194
# Качаю хреф номер  1195
# Качаю хреф номер  1196
# Качаю хреф номер  1197
# Качаю хреф номер  1198
# Качаю хреф номер  1199
# Качаю хреф номер  1200
# Качаю хреф номер  1201
# Качаю хреф номер  1202
# Качаю хреф номер  1203
# Качаю хреф номер  1204
# Качаю хреф номер  1205
# Качаю хреф номер  1206
# Качаю хреф номер  1207
# Качаю хреф номер  1208
# Качаю хреф номер  1209
# Качаю хреф номер  1210
# Качаю хреф номер  1211
# Качаю хреф номер  1212
# Качаю хреф номер  1213
# Качаю хреф номер  1214
# Качаю хреф номер  1215
# Качаю хреф номер  1216
# Качаю хреф номер  1217
# Качаю хреф номер  1218
# Качаю хреф номер  1219
# Качаю хреф номер  1220
# Качаю хреф номер  1221
# Качаю хреф номер  1222
# Качаю хреф номер  1223
# Качаю хреф номер  1224
# Качаю хреф номер  1225
# Качаю хреф номер  1226
# Качаю хреф номер  1227
# Качаю хреф номер  1228
# Качаю хреф номер  1229
# Качаю хреф номер  1230
# Качаю хреф номер  1231
# Качаю хреф номер  1232
# Качаю хреф номер  1233
# Качаю хреф номер  1234
# Качаю хреф номер  1235
# Качаю хреф номер  1236
# Качаю хреф номер  1237
# Качаю хреф номер  1238
# Качаю хреф номер  1239
# Качаю хреф номер  1240
# Качаю хреф номер  1241
# Качаю хреф номер  1242
# Качаю хреф номер  1243
# Качаю хреф номер  1244
# Качаю хреф номер  1245
# Качаю хреф номер  1246
# Качаю хреф номер  1247
# Качаю хреф номер  1248
# Качаю хреф номер  1249
# Качаю хреф номер  1250
# Качаю хреф номер  1251
# Качаю хреф номер  1252
# Качаю хреф номер  1253
# Качаю хреф номер  1254
# Качаю хреф номер  1255
# Качаю хреф номер  1256
# Качаю хреф номер  1257
# Качаю хреф номер  1258
# Качаю хреф номер  1259
# Качаю хреф номер  1260
# Качаю хреф номер  1261
# Качаю хреф номер  1262
# Качаю хреф номер  1263
# Качаю хреф номер  1264
# Качаю хреф номер  1265
# Качаю хреф номер  1266
# Качаю хреф номер  1267
# Качаю хреф номер  1268
# Качаю хреф номер  1269
# Качаю хреф номер  1270
# Качаю хреф номер  1271
# Качаю хреф номер  1272
# Качаю хреф номер  1273
# Качаю хреф номер  1274
# Качаю хреф номер  1275
# Качаю хреф номер  1276
# Качаю хреф номер  1277
# Качаю хреф номер  1278
# Качаю хреф номер  1279
# Качаю хреф номер  1280
# Качаю хреф номер  1281
# Качаю хреф номер  1282
# Качаю хреф номер  1283
# Качаю хреф номер  1284
# Качаю хреф номер  1285
# Качаю хреф номер  1286
# Качаю хреф номер  1287
# Качаю хреф номер  1288
# Качаю хреф номер  1289
# Качаю хреф номер  1290
# Качаю хреф номер  1291
# Качаю хреф номер  1292
# Качаю хреф номер  1293
# Качаю хреф номер  1294
# Качаю хреф номер  1295
# Качаю хреф номер  1296
# Качаю хреф номер  1297
# Качаю хреф номер  1298
# Качаю хреф номер  1299
# Качаю хреф номер  1300
# Качаю хреф номер  1301
# Качаю хреф номер  1302
# Качаю хреф номер  1303
# Качаю хреф номер  1304
# Качаю хреф номер  1305
# Качаю хреф номер  1306
# Качаю хреф номер  1307
# Качаю хреф номер  1308
# Качаю хреф номер  1309
# Качаю хреф номер  1310
# Качаю хреф номер  1311
# Качаю хреф номер  1312
# Качаю хреф номер  1313
# Качаю хреф номер  1314
# Качаю хреф номер  1315
# Качаю хреф номер  1316
# Качаю хреф номер  1317
# Качаю хреф номер  1318
# Качаю хреф номер  1319
# Качаю хреф номер  1320
# Качаю хреф номер  1321
# Качаю хреф номер  1322
# Качаю хреф номер  1323
# Качаю хреф номер  1324
# Качаю хреф номер  1325
# Качаю хреф номер  1326
# Качаю хреф номер  1327
# Качаю хреф номер  1328
# Качаю хреф номер  1329
# Качаю хреф номер  1330
# Качаю хреф номер  1331
# Качаю хреф номер  1332
# Качаю хреф номер  1333
# Качаю хреф номер  1334
# Качаю хреф номер  1335
# Качаю хреф номер  1336
# Качаю хреф номер  1337
# Качаю хреф номер  1338
# Качаю хреф номер  1339
# Качаю хреф номер  1340
# Качаю хреф номер  1341
# Качаю хреф номер  1342
# Качаю хреф номер  1343
# Качаю хреф номер  1344
# Качаю хреф номер  1345
# Качаю хреф номер  1346
# Качаю хреф номер  1347
# Качаю хреф номер  1348
# Качаю хреф номер  1349
# Качаю хреф номер  1350
# Качаю хреф номер  1351
# Качаю хреф номер  1352
# Качаю хреф номер  1353
# Качаю хреф номер  1354
# Качаю хреф номер  1355
# Качаю хреф номер  1356
# Качаю хреф номер  1357
# Качаю хреф номер  1358
# Качаю хреф номер  1359
# Качаю хреф номер  1360
# Качаю хреф номер  1361
# Качаю хреф номер  1362
# Качаю хреф номер  1363
# Качаю хреф номер  1364
# Качаю хреф номер  1365
# Качаю хреф номер  1366
# Качаю хреф номер  1367
# Качаю хреф номер  1368
# Качаю хреф номер  1369
# Качаю хреф номер  1370
# Качаю хреф номер  1371
# Качаю хреф номер  1372
# Качаю хреф номер  1373
# Качаю хреф номер  1374
# Качаю хреф номер  1375
# Качаю хреф номер  1376
# Качаю хреф номер  1377
# Качаю хреф номер  1378
# Качаю хреф номер  1379
# Качаю хреф номер  1380
# Качаю хреф номер  1381
# Качаю хреф номер  1382
# Качаю хреф номер  1383
# Качаю хреф номер  1384
# Качаю хреф номер  1385
# Качаю хреф номер  1386
# Качаю хреф номер  1387
# Качаю хреф номер  1388
# Качаю хреф номер  1389
# Качаю хреф номер  1390
# Качаю хреф номер  1391
# Качаю хреф номер  1392
# Качаю хреф номер  1393
# Качаю хреф номер  1394
# Качаю хреф номер  1395
# Качаю хреф номер  1396
# Качаю хреф номер  1397
# Качаю хреф номер  1398
# Качаю хреф номер  1399
# Качаю хреф номер  1400
# Качаю хреф номер  1401
# Качаю хреф номер  1402
# Качаю хреф номер  1403
# Качаю хреф номер  1404
# Качаю хреф номер  1405
# Качаю хреф номер  1406
# Качаю хреф номер  1407
# Качаю хреф номер  1408
# Качаю хреф номер  1409
# Качаю хреф номер  1410
# Качаю хреф номер  1411
# Качаю хреф номер  1412
# Качаю хреф номер  1413
# Качаю хреф номер  1414
# Качаю хреф номер  1415
# Качаю хреф номер  1416
# Качаю хреф номер  1417
# Качаю хреф номер  1418
# Качаю хреф номер  1419
# Качаю хреф номер  1420
# Качаю хреф номер  1421
# Качаю хреф номер  1422
# Качаю хреф номер  1423
# Качаю хреф номер  1424
# Качаю хреф номер  1425
# Качаю хреф номер  1426
# Качаю хреф номер  1427
# Качаю хреф номер  1428
# Качаю хреф номер  1429
# Качаю хреф номер  1430
# Качаю хреф номер  1431
# Качаю хреф номер  1432
# Качаю хреф номер  1433
# Качаю хреф номер  1434
# Качаю хреф номер  1435
# Качаю хреф номер  1436
# Качаю хреф номер  1437
# Качаю хреф номер  1438
# Качаю хреф номер  1439
# Качаю хреф номер  1440
# Качаю хреф номер  1441
# Качаю хреф номер  1442
# Качаю хреф номер  1443
# Качаю хреф номер  1444
# Качаю хреф номер  1445
# Качаю хреф номер  1446
# Качаю хреф номер  1447
# Качаю хреф номер  1448
# Качаю хреф номер  1449
# Качаю хреф номер  1450
# Качаю хреф номер  1451
# Качаю хреф номер  1452
# Качаю хреф номер  1453
# Качаю хреф номер  1454
# Качаю хреф номер  1455
# Качаю хреф номер  1456
# Качаю хреф номер  1457
# Качаю хреф номер  1458
# Качаю хреф номер  1459
# Качаю хреф номер  1460
# Качаю хреф номер  1461
# Качаю хреф номер  1462
# Качаю хреф номер  1463
# Качаю хреф номер  1464
# Качаю хреф номер  1465
# Качаю хреф номер  1466
# Качаю хреф номер  1467
# Качаю хреф номер  1468
# Качаю хреф номер  1469
# Качаю хреф номер  1470
# Качаю хреф номер  1471
# Качаю хреф номер  1472
# Качаю хреф номер  1473
# Качаю хреф номер  1474
# Качаю хреф номер  1475
# Качаю хреф номер  1476
# Качаю хреф номер  1477
# Качаю хреф номер  1478
# Качаю хреф номер  1479
# Качаю хреф номер  1480
# Качаю хреф номер  1481
# Качаю хреф номер  1482
# Качаю хреф номер  1483
# Качаю хреф номер  1484
# Качаю хреф номер  1485
# Качаю хреф номер  1486
# Качаю хреф номер  1487
# Качаю хреф номер  1488
# Качаю хреф номер  1489
# Качаю хреф номер  1490
# Качаю хреф номер  1491
# Качаю хреф номер  1492
# Качаю хреф номер  1493
# Качаю хреф номер  1494
# Качаю хреф номер  1495
# Качаю хреф номер  1496
# Качаю хреф номер  1497
# Качаю хреф номер  1498
# Качаю хреф номер  1499
# Качаю хреф номер  1500
# Качаю хреф номер  1501
# Качаю хреф номер  1502
# Качаю хреф номер  1503
# Качаю хреф номер  1504
# Качаю хреф номер  1505
# Качаю хреф номер  1506
# Качаю хреф номер  1507
# Качаю хреф номер  1508
# Качаю хреф номер  1509
# Качаю хреф номер  1510
# Качаю хреф номер  1511
# Качаю хреф номер  1512
# Качаю хреф номер  1513
# Качаю хреф номер  1514
# Качаю хреф номер  1515
# Качаю хреф номер  1516
# Качаю хреф номер  1517
# Качаю хреф номер  1518
# Качаю хреф номер  1519
# Качаю хреф номер  1520
# Качаю хреф номер  1521
# Качаю хреф номер  1522
# Качаю хреф номер  1523
# Качаю хреф номер  1524
# Качаю хреф номер  1525
# Качаю хреф номер  1526
# Качаю хреф номер  1527
# Качаю хреф номер  1528
# Качаю хреф номер  1529
# Качаю хреф номер  1530
# Качаю хреф номер  1531
# Качаю хреф номер  1532
# Качаю хреф номер  1533
# Качаю хреф номер  1534
# Качаю хреф номер  1535
# Качаю хреф номер  1536
# Качаю хреф номер  1537
# Качаю хреф номер  1538
# Качаю хреф номер  1539
# Качаю хреф номер  1540
# Качаю хреф номер  1541
# Качаю хреф номер  1542
# Качаю хреф номер  1543
# Качаю хреф номер  1544
# Качаю хреф номер  1545
# Качаю хреф номер  1546
# Качаю хреф номер  1547
# Качаю хреф номер  1548
# Качаю хреф номер  1549
# Качаю хреф номер  1550
# Качаю хреф номер  1551
# Качаю хреф номер  1552
# Качаю хреф номер  1553
# Качаю хреф номер  1554
# Качаю хреф номер  1555
# Качаю хреф номер  1556
# Качаю хреф номер  1557
# Качаю хреф номер  1558
# Качаю хреф номер  1559
# Качаю хреф номер  1560
# Качаю хреф номер  1561
# Качаю хреф номер  1562
# Качаю хреф номер  1563
# Качаю хреф номер  1564
# Качаю хреф номер  1565
# Качаю хреф номер  1566
# Качаю хреф номер  1567
# Качаю хреф номер  1568
# Качаю хреф номер  1569
# Качаю хреф номер  1570
# Качаю хреф номер  1571
# Качаю хреф номер  1572
# Качаю хреф номер  1573
# Качаю хреф номер  1574
# Качаю хреф номер  1575
# Качаю хреф номер  1576
# Качаю хреф номер  1577
# Качаю хреф номер  1578
# Качаю хреф номер  1579
# Качаю хреф номер  1580
# Качаю хреф номер  1581
# Качаю хреф номер  1582
# Качаю хреф номер  1583
# Качаю хреф номер  1584
# Качаю хреф номер  1585
# Качаю хреф номер  1586
# Качаю хреф номер  1587
# Качаю хреф номер  1588
# Качаю хреф номер  1589
# Качаю хреф номер  1590
# Качаю хреф номер  1591
# Качаю хреф номер  1592
# Качаю хреф номер  1593
# Качаю хреф номер  1594
# Качаю хреф номер  1595
# Качаю хреф номер  1596
# Качаю хреф номер  1597
# Качаю хреф номер  1598
# Качаю хреф номер  1599
# Качаю хреф номер  1600
# Качаю хреф номер  1601
# Качаю хреф номер  1602
# Качаю хреф номер  1603
# Качаю хреф номер  1604
# Качаю хреф номер  1605
# Качаю хреф номер  1606
# Качаю хреф номер  1607
# Качаю хреф номер  1608
# Качаю хреф номер  1609
# Качаю хреф номер  1610
# Качаю хреф номер  1611
# Качаю хреф номер  1612
# Качаю хреф номер  1613
# Качаю хреф номер  1614
# Качаю хреф номер  1615
# Качаю хреф номер  1616
# Качаю хреф номер  1617
# Качаю хреф номер  1618
# Качаю хреф номер  1619
# Качаю хреф номер  1620
# Качаю хреф номер  1621
# Качаю хреф номер  1622
# Качаю хреф номер  1623
# Качаю хреф номер  1624
# Качаю хреф номер  1625
# Качаю хреф номер  1626
# Качаю хреф номер  1627
# Качаю хреф номер  1628
# Качаю хреф номер  1629
# Качаю хреф номер  1630
# Качаю хреф номер  1631
# Качаю хреф номер  1632
# Качаю хреф номер  1633
# Качаю хреф номер  1634
# Качаю хреф номер  1635
# Качаю хреф номер  1636
# Качаю хреф номер  1637
# Качаю хреф номер  1638
# Качаю хреф номер  1639
# Качаю хреф номер  1640
# Качаю хреф номер  1641
# Качаю хреф номер  1642
# Качаю хреф номер  1643
# Качаю хреф номер  1644
# Качаю хреф номер  1645
# Качаю хреф номер  1646
# Качаю хреф номер  1647
# Качаю хреф номер  1648
# Качаю хреф номер  1649
# Качаю хреф номер  1650
# Качаю хреф номер  1651
# Качаю хреф номер  1652
# Качаю хреф номер  1653
# Качаю хреф номер  1654
# Качаю хреф номер  1655
# Качаю хреф номер  1656
# Качаю хреф номер  1657
# Качаю хреф номер  1658
# Качаю хреф номер  1659
# Качаю хреф номер  1660
# Качаю хреф номер  1661
# Качаю хреф номер  1662
# Качаю хреф номер  1663
# Качаю хреф номер  1664
# Качаю хреф номер  1665
# Качаю хреф номер  1666
# Качаю хреф номер  1667
# Качаю хреф номер  1668
# Качаю хреф номер  1669
# Качаю хреф номер  1670
# Качаю хреф номер  1671
# Качаю хреф номер  1672
# Качаю хреф номер  1673
# Качаю хреф номер  1674
# Качаю хреф номер  1675
# Качаю хреф номер  1676
# Качаю хреф номер  1677
# Качаю хреф номер  1678
# Качаю хреф номер  1679
# Качаю хреф номер  1680
# Качаю хреф номер  1681
# Качаю хреф номер  1682
# Качаю хреф номер  1683
# Качаю хреф номер  1684
# Качаю хреф номер  1685
# Качаю хреф номер  1686
# Качаю хреф номер  1687
# Качаю хреф номер  1688
# Качаю хреф номер  1689
# Качаю хреф номер  1690
# Качаю хреф номер  1691
# Качаю хреф номер  1692
# Качаю хреф номер  1693
# Качаю хреф номер  1694
# Качаю хреф номер  1695
# Качаю хреф номер  1696
# Качаю хреф номер  1697
# Качаю хреф номер  1698
# Качаю хреф номер  1699
# Качаю хреф номер  1700
# Качаю хреф номер  1701
# Качаю хреф номер  1702
# Качаю хреф номер  1703
# Качаю хреф номер  1704
# Качаю хреф номер  1705
# Качаю хреф номер  1706
# Качаю хреф номер  1707
# Качаю хреф номер  1708
# Качаю хреф номер  1709
# Качаю хреф номер  1710
# Качаю хреф номер  1711
# Качаю хреф номер  1712
# Качаю хреф номер  1713
# Качаю хреф номер  1714
# Качаю хреф номер  1715
# Качаю хреф номер  1716
# Качаю хреф номер  1717
# Качаю хреф номер  1718
# Качаю хреф номер  1719
# Качаю хреф номер  1720
# Качаю хреф номер  1721
# Качаю хреф номер  1722
# Качаю хреф номер  1723
# Качаю хреф номер  1724
# Качаю хреф номер  1725
# Качаю хреф номер  1726
# Качаю хреф номер  1727
# Качаю хреф номер  1728
# Качаю хреф номер  1729
# Качаю хреф номер  1730
# Качаю хреф номер  1731
# Качаю хреф номер  1732
# Качаю хреф номер  1733
# Качаю хреф номер  1734
# Качаю хреф номер  1735
# Качаю хреф номер  1736
# Качаю хреф номер  1737
# Качаю хреф номер  1738
# Качаю хреф номер  1739
# Качаю хреф номер  1740
# Качаю хреф номер  1741
# Качаю хреф номер  1742
# Качаю хреф номер  1743
# Качаю хреф номер  1744
# Качаю хреф номер  1745
# Качаю хреф номер  1746
# Качаю хреф номер  1747
# Качаю хреф номер  1748
# Качаю хреф номер  1749
# Качаю хреф номер  1750
# Качаю хреф номер  1751
# Качаю хреф номер  1752
# Качаю хреф номер  1753
# Качаю хреф номер  1754
# Качаю хреф номер  1755
# Качаю хреф номер  1756
# Качаю хреф номер  1757
# Качаю хреф номер  1758
# Качаю хреф номер  1759
# Качаю хреф номер  1760
# Качаю хреф номер  1761
# Качаю хреф номер  1762
# Качаю хреф номер  1763
# Качаю хреф номер  1764
# Качаю хреф номер  1765
# Качаю хреф номер  1766
# Качаю хреф номер  1767
# Качаю хреф номер  1768
# Качаю хреф номер  1769
# Качаю хреф номер  1770
# Качаю хреф номер  1771
# Качаю хреф номер  1772
# Качаю хреф номер  1773
# Качаю хреф номер  1774
# Качаю хреф номер  1775
# Качаю хреф номер  1776
# Качаю хреф номер  1777
# Качаю хреф номер  1778
# Качаю хреф номер  1779
# Качаю хреф номер  1780
# Качаю хреф номер  1781
# Качаю хреф номер  1782
# Качаю хреф номер  1783
# Качаю хреф номер  1784
# Качаю хреф номер  1785
# Качаю хреф номер  1786
# Качаю хреф номер  1787
# Качаю хреф номер  1788
# Качаю хреф номер  1789
# Качаю хреф номер  1790
# Качаю хреф номер  1791
# Качаю хреф номер  1792
# Качаю хреф номер  1793
# Качаю хреф номер  1794
# Качаю хреф номер  1795
# Качаю хреф номер  1796
# Качаю хреф номер  1797
# Качаю хреф номер  1798
# Качаю хреф номер  1799
# Качаю хреф номер  1800
# Качаю хреф номер  1801
# Качаю хреф номер  1802
# Качаю хреф номер  1803
# Качаю хреф номер  1804
# Качаю хреф номер  1805
# Качаю хреф номер  1806
# Качаю хреф номер  1807
# Качаю хреф номер  1808
# Качаю хреф номер  1809
# Качаю хреф номер  1810
# Качаю хреф номер  1811
# Качаю хреф номер  1812
# Качаю хреф номер  1813
# Качаю хреф номер  1814
# Качаю хреф номер  1815
# Качаю хреф номер  1816
# Качаю хреф номер  1817
# Качаю хреф номер  1818
# Качаю хреф номер  1819
# Качаю хреф номер  1820
# Качаю хреф номер  1821
# Качаю хреф номер  1822
# Качаю хреф номер  1823
# Качаю хреф номер  1824
# Качаю хреф номер  1825
# Качаю хреф номер  1826
# Качаю хреф номер  1827
# Качаю хреф номер  1828
# Качаю хреф номер  1829
# Качаю хреф номер  1830
# Качаю хреф номер  1831
# Качаю хреф номер  1832
# Качаю хреф номер  1833
# Качаю хреф номер  1834
# Качаю хреф номер  1835
# Качаю хреф номер  1836
# Качаю хреф номер  1837
# Качаю хреф номер  1838
# Качаю хреф номер  1839
# Качаю хреф номер  1840
# Качаю хреф номер  1841
# Качаю хреф номер  1842
# Качаю хреф номер  1843
# Качаю хреф номер  1844
# Качаю хреф номер  1845
# Качаю хреф номер  1846
# Качаю хреф номер  1847
# Качаю хреф номер  1848
# Качаю хреф номер  1849
# Качаю хреф номер  1850
# Качаю хреф номер  1851
# Качаю хреф номер  1852
# Качаю хреф номер  1853
# Качаю хреф номер  1854
# Качаю хреф номер  1855
# Качаю хреф номер  1856
# Качаю хреф номер  1857
# Качаю хреф номер  1858
# Качаю хреф номер  1859
# Качаю хреф номер  1860
# Качаю хреф номер  1861
# Качаю хреф номер  1862
# Качаю хреф номер  1863
# Качаю хреф номер  1864
# Качаю хреф номер  1865
# Качаю хреф номер  1866
# Качаю хреф номер  1867
# Качаю хреф номер  1868
# Качаю хреф номер  1869
# Качаю хреф номер  1870
# Качаю хреф номер  1871
# Качаю хреф номер  1872
# Качаю хреф номер  1873
# Качаю хреф номер  1874
# Качаю хреф номер  1875
# Качаю хреф номер  1876
# Качаю хреф номер  1877
# Качаю хреф номер  1878
# Качаю хреф номер  1879
# Качаю хреф номер  1880
# Качаю хреф номер  1881
# Качаю хреф номер  1882
# Качаю хреф номер  1883
# Качаю хреф номер  1884
# Качаю хреф номер  1885
# Качаю хреф номер  1886
# Качаю хреф номер  1887
# Качаю хреф номер  1888
# Качаю хреф номер  1889
# Качаю хреф номер  1890
# Качаю хреф номер  1891
# Качаю хреф номер  1892
# Качаю хреф номер  1893
# Качаю хреф номер  1894
# Качаю хреф номер  1895
# Качаю хреф номер  1896
# Качаю хреф номер  1897
# Качаю хреф номер  1898
# Качаю хреф номер  1899
# Качаю хреф номер  1900
# Качаю хреф номер  1901
# Качаю хреф номер  1902
# Качаю хреф номер  1903
# Качаю хреф номер  1904
# Качаю хреф номер  1905
# Качаю хреф номер  1906
# Качаю хреф номер  1907
# Качаю хреф номер  1908
# Качаю хреф номер  1909
# Качаю хреф номер  1910
# Качаю хреф номер  1911
# Качаю хреф номер  1912
# Качаю хреф номер  1913
# Качаю хреф номер  1914
# Качаю хреф номер  1915
# Качаю хреф номер  1916
# Качаю хреф номер  1917
# Качаю хреф номер  1918
# Качаю хреф номер  1919
# Качаю хреф номер  1920
# Качаю хреф номер  1921
# Качаю хреф номер  1922
# Качаю хреф номер  1923
# Качаю хреф номер  1924
# Качаю хреф номер  1925
# Качаю хреф номер  1926
# Качаю хреф номер  1927
# Качаю хреф номер  1928
# Качаю хреф номер  1929
# Качаю хреф номер  1930
# Качаю хреф номер  1931
# Качаю хреф номер  1932
# Качаю хреф номер  1933
# Качаю хреф номер  1934
# Качаю хреф номер  1935
# Качаю хреф номер  1936
# Качаю хреф номер  1937
# Качаю хреф номер  1938
# Качаю хреф номер  1939
# Качаю хреф номер  1940
# Качаю хреф номер  1941
# Качаю хреф номер  1942
# Качаю хреф номер  1943
# Качаю хреф номер  1944
# Качаю хреф номер  1945
# Качаю хреф номер  1946
# Качаю хреф номер  1947
# Качаю хреф номер  1948
# Качаю хреф номер  1949
# Качаю хреф номер  1950
# Качаю хреф номер  1951
# Качаю хреф номер  1952
# Качаю хреф номер  1953
# Качаю хреф номер  1954
# Качаю хреф номер  1955
# Качаю хреф номер  1956
# Качаю хреф номер  1957
# Качаю хреф номер  1958
# Качаю хреф номер  1959
# Качаю хреф номер  1960
# Качаю хреф номер  1961
# Качаю хреф номер  1962
# Качаю хреф номер  1963
# Качаю хреф номер  1964
# Качаю хреф номер  1965
# Качаю хреф номер  1966
# Качаю хреф номер  1967
# Качаю хреф номер  1968
# Качаю хреф номер  1969
# Качаю хреф номер  1970
# Качаю хреф номер  1971
# Качаю хреф номер  1972
# Качаю хреф номер  1973
# Качаю хреф номер  1974
# Качаю хреф номер  1975
# Качаю хреф номер  1976
# Качаю хреф номер  1977
# Качаю хреф номер  1978
# Качаю хреф номер  1979
# Качаю хреф номер  1980
# Качаю хреф номер  1981
# Качаю хреф номер  1982
# Качаю хреф номер  1983
# Качаю хреф номер  1984
# Качаю хреф номер  1985
# Качаю хреф номер  1986
# Качаю хреф номер  1987
# Качаю хреф номер  1988
# Качаю хреф номер  1989
# Качаю хреф номер  1990
# Качаю хреф номер  1991
# Качаю хреф номер  1992
# Качаю хреф номер  1993
# Качаю хреф номер  1994
# Качаю хреф номер  1995
# Качаю хреф номер  1996
# Качаю хреф номер  1997
# Качаю хреф номер  1998
# Качаю хреф номер  1999
# Качаю хреф номер  2000
# Качаю хреф номер  2001
# Качаю хреф номер  2002
# Качаю хреф номер  2003
# Качаю хреф номер  2004
# Качаю хреф номер  2005
# Качаю хреф номер  2006
# Качаю хреф номер  2007
# Качаю хреф номер  2008
# Качаю хреф номер  2009
# Качаю хреф номер  2010
# Качаю хреф номер  2011
# Качаю хреф номер  2012
# Качаю хреф номер  2013
# Качаю хреф номер  2014
# Качаю хреф номер  2015
# Качаю хреф номер  2016
# Качаю хреф номер  2017
# Качаю хреф номер  2018
# Качаю хреф номер  2019
# Качаю хреф номер  2020
# Качаю хреф номер  2021
# Качаю хреф номер  2022
# Качаю хреф номер  2023
# Качаю хреф номер  2024
# Качаю хреф номер  2025
# Качаю хреф номер  2026
# Качаю хреф номер  2027
# Качаю хреф номер  2028
# Качаю хреф номер  2029
# Качаю хреф номер  2030
# Качаю хреф номер  2031
# Качаю хреф номер  2032
# Качаю хреф номер  2033
# Качаю хреф номер  2034
# Качаю хреф номер  2035
# Качаю хреф номер  2036
# Качаю хреф номер  2037
# Качаю хреф номер  2038
# Качаю хреф номер  2039
# Качаю хреф номер  2040
# Качаю хреф номер  2041
# Качаю хреф номер  2042
# Качаю хреф номер  2043
# Качаю хреф номер  2044
# Качаю хреф номер  2045
# Качаю хреф номер  2046
# Качаю хреф номер  2047
# Качаю хреф номер  2048
# Качаю хреф номер  2049
# Качаю хреф номер  2050
# Качаю хреф номер  2051
# Качаю хреф номер  2052
# Качаю хреф номер  2053
# Качаю хреф номер  2054
# Качаю хреф номер  2055
# Качаю хреф номер  2056
# Качаю хреф номер  2057
# Качаю хреф номер  2058
# Качаю хреф номер  2059
# Качаю хреф номер  2060
# Качаю хреф номер  2061
# Качаю хреф номер  2062
# Качаю хреф номер  2063
# Качаю хреф номер  2064
# Качаю хреф номер  2065
# Качаю хреф номер  2066
# Качаю хреф номер  2067
# Качаю хреф номер  2068
# Качаю хреф номер  2069
# Качаю хреф номер  2070
# Качаю хреф номер  2071
# Качаю хреф номер  2072
# Качаю хреф номер  2073
# Качаю хреф номер  2074
# Качаю хреф номер  2075
# Качаю хреф номер  2076
# Качаю хреф номер  2077
# Качаю хреф номер  2078
# Качаю хреф номер  2079
# Качаю хреф номер  2080
# Качаю хреф номер  2081
# Качаю хреф номер  2082
# Качаю хреф номер  2083
# Качаю хреф номер  2084
# Качаю хреф номер  2085
# Качаю хреф номер  2086
# Качаю хреф номер  2087
# Качаю хреф номер  2088
# Качаю хреф номер  2089
# Качаю хреф номер  2090
# Качаю хреф номер  2091
# Качаю хреф номер  2092
# Качаю хреф номер  2093
# Качаю хреф номер  2094
# Качаю хреф номер  2095
# Качаю хреф номер  2096
# Качаю хреф номер  2097
# Качаю хреф номер  2098
# Качаю хреф номер  2099
# Качаю хреф номер  2100
# Качаю хреф номер  2101
# Качаю хреф номер  2102
# Качаю хреф номер  2103
# Качаю хреф номер  2104
# Качаю хреф номер  2105
# Качаю хреф номер  2106
# Качаю хреф номер  2107
# Качаю хреф номер  2108
# Качаю хреф номер  2109
# Качаю хреф номер  2110
# Качаю хреф номер  2111
# Качаю хреф номер  2112
# Качаю хреф номер  2113
# Качаю хреф номер  2114
# Качаю хреф номер  2115
# Качаю хреф номер  2116
# Качаю хреф номер  2117
# Качаю хреф номер  2118
# Качаю хреф номер  2119
# Качаю хреф номер  2120
# Качаю хреф номер  2121
# Качаю хреф номер  2122
# Качаю хреф номер  2123
# Качаю хреф номер  2124
# Качаю хреф номер  2125
# Качаю хреф номер  2126
# Качаю хреф номер  2127
# Качаю хреф номер  2128
# Качаю хреф номер  2129
# Качаю хреф номер  2130
# Качаю хреф номер  2131
# Качаю хреф номер  2132
# Качаю хреф номер  2133
# Качаю хреф номер  2134
# Качаю хреф номер  2135
# ...
# Качаю хреф номер  4667
# Качаю хреф номер  4668
# Качаю хреф номер  4669
# Качаю хреф номер  4670
# Качаю хреф номер  4671
# Качаю хреф номер  4672
# Качаю хреф номер  4673
# Качаю хреф номер  4674
# Качаю хреф номер  4675
# Качаю хреф номер  4676
# Качаю хреф номер  4677
# Качаю хреф номер  4678
# Качаю хреф номер  4679
# Качаю хреф номер  4680
# Качаю хреф номер  4681
# Качаю хреф номер  4682
# Качаю хреф номер  4683
# Качаю хреф номер  4684
# Качаю хреф номер  4685
# Качаю хреф номер  4686
# Качаю хреф номер  4687
# Качаю хреф номер  4688
# Качаю хреф номер  4689
# Качаю хреф номер  4690
# Качаю хреф номер  4691
# Качаю хреф номер  4692
# Качаю хреф номер  4693
# Качаю хреф номер  4694
# Качаю хреф номер  4695
# Качаю хреф номер  4696
# Качаю хреф номер  4697
# Качаю хреф номер  4698
# Качаю хреф номер  4699
# Качаю хреф номер  4700
# Качаю хреф номер  4701
# Качаю хреф номер  4702
# Качаю хреф номер  4703
# Качаю хреф номер  4704
# Качаю хреф номер  4705
# Качаю хреф номер  4706
# Качаю хреф номер  4707
# Качаю хреф номер  4708
# Качаю хреф номер  4709
# Качаю хреф номер  4710
# Качаю хреф номер  4711
# Качаю хреф номер  4712
# Качаю хреф номер  4713
# Качаю хреф номер  4714
# Качаю хреф номер  4715
# Качаю хреф номер  4716
# Качаю хреф номер  4717
# Качаю хреф номер  4718
# Качаю хреф номер  4719
# Качаю хреф номер  4720
# Качаю хреф номер  4721
# Качаю хреф номер  4722
# Качаю хреф номер  4723
# Качаю хреф номер  4724
# Качаю хреф номер  4725
# Качаю хреф номер  4726
# Качаю хреф номер  4727
# Качаю хреф номер  4728
# Качаю хреф номер  4729
# Качаю хреф номер  4730
# Качаю хреф номер  4731
# Качаю хреф номер  4732
# Качаю хреф номер  4733
# Качаю хреф номер  4734
# Качаю хреф номер  4735
# Качаю хреф номер  4736
# Качаю хреф номер  4737
# Качаю хреф номер  4738
# Качаю хреф номер  4739
# Качаю хреф номер  4740
# Качаю хреф номер  4741
# Качаю хреф номер  4742
# Качаю хреф номер  4743
# Качаю хреф номер  4744
# Качаю хреф номер  4745
# Качаю хреф номер  4746
# Качаю хреф номер  4747
# Качаю хреф номер  4748
# Качаю хреф номер  4749
# Качаю хреф номер  4750
# Качаю хреф номер  4751
# Качаю хреф номер  4752
# Качаю хреф номер  4753
# Качаю хреф номер  4754
# Качаю хреф номер  4755
# Качаю хреф номер  4756
# Качаю хреф номер  4757
# Качаю хреф номер  4758
# Качаю хреф номер  4759
# Качаю хреф номер  4760
# Качаю хреф номер  4761
# Качаю хреф номер  4762
# Качаю хреф номер  4763
# Качаю хреф номер  4764
# Качаю хреф номер  4765
# Качаю хреф номер  4766
# Качаю хреф номер  4767
# Качаю хреф номер  4768
# Качаю хреф номер  4769
# Качаю хреф номер  4770
# Качаю хреф номер  4771
# Качаю хреф номер  4772
# Качаю хреф номер  4773
# Качаю хреф номер  4774
# Качаю хреф номер  4775
# Качаю хреф номер  4776
# Качаю хреф номер  4777
# Качаю хреф номер  4778
# Качаю хреф номер  4779
# Качаю хреф номер  4780
# Качаю хреф номер  4781
# Качаю хреф номер  4782
# Качаю хреф номер  4783
# Качаю хреф номер  4784
# Качаю хреф номер  4785
# Качаю хреф номер  4786
# Качаю хреф номер  4787
# Качаю хреф номер  4788
# Качаю хреф номер  4789
# Качаю хреф номер  4790
# Качаю хреф номер  4791
# Качаю хреф номер  4792
# Качаю хреф номер  4793
# Качаю хреф номер  4794
# Качаю хреф номер  4795
# Качаю хреф номер  4796
# Качаю хреф номер  4797
# Качаю хреф номер  4798
# Качаю хреф номер  4799
# Качаю хреф номер  4800
# Качаю хреф номер  4801
# Качаю хреф номер  4802
# Качаю хреф номер  4803
# Качаю хреф номер  4804
# Качаю хреф номер  4805
# Качаю хреф номер  4806
# Качаю хреф номер  4807
# Качаю хреф номер  4808
# Качаю хреф номер  4809
# Качаю хреф номер  4810
# Качаю хреф номер  4811
# Качаю хреф номер  4812
# Качаю хреф номер  4813
# Качаю хреф номер  4814
# Качаю хреф номер  4815
# Качаю хреф номер  4816
# Качаю хреф номер  4817
# Качаю хреф номер  4818
# Качаю хреф номер  4819
# Качаю хреф номер  4820
# Качаю хреф номер  4821
# Качаю хреф номер  4822
# Качаю хреф номер  4823
# Качаю хреф номер  4824
# Качаю хреф номер  4825
# Качаю хреф номер  4826
# Качаю хреф номер  4827
# Качаю хреф номер  4828
# Качаю хреф номер  4829
# Качаю хреф номер  4830
# Качаю хреф номер  4831
# Качаю хреф номер  4832
# Качаю хреф номер  4833
# Качаю хреф номер  4834
# Качаю хреф номер  4835
# Качаю хреф номер  4836
# Качаю хреф номер  4837
# Качаю хреф номер  4838
# Качаю хреф номер  4839
# Качаю хреф номер  4840
# Качаю хреф номер  4841
# Качаю хреф номер  4842
# Качаю хреф номер  4843
# Качаю хреф номер  4844
# Качаю хреф номер  4845
# Качаю хреф номер  4846
# Качаю хреф номер  4847
# Качаю хреф номер  4848
# Качаю хреф номер  4849
# Качаю хреф номер  4850
# Качаю хреф номер  4851
# Качаю хреф номер  4852
# Качаю хреф номер  4853
# Качаю хреф номер  4854
# Качаю хреф номер  4855
# Качаю хреф номер  4856
# Качаю хреф номер  4857
# Качаю хреф номер  4858
# Качаю хреф номер  4859
# Качаю хреф номер  4860
# Качаю хреф номер  4861
# Качаю хреф номер  4862
# Качаю хреф номер  4863
# Качаю хреф номер  4864
# Качаю хреф номер  4865
# Качаю хреф номер  4866
# Качаю хреф номер  4867
# Качаю хреф номер  4868
# Качаю хреф номер  4869
# Качаю хреф номер  4870
# Качаю хреф номер  4871
# Качаю хреф номер  4872
# Качаю хреф номер  4873
# Качаю хреф номер  4874
# Качаю хреф номер  4875
# Качаю хреф номер  4876
# Качаю хреф номер  4877
# Качаю хреф номер  4878
# Качаю хреф номер  4879
# Качаю хреф номер  4880
# Качаю хреф номер  4881
# Качаю хреф номер  4882
# Качаю хреф номер  4883
# Качаю хреф номер  4884
# Качаю хреф номер  4885
# Качаю хреф номер  4886
# Качаю хреф номер  4887
# Качаю хреф номер  4888
# Качаю хреф номер  4889
# Качаю хреф номер  4890
# Качаю хреф номер  4891
# Качаю хреф номер  4892
# Качаю хреф номер  4893
# Качаю хреф номер  4894
# Качаю хреф номер  4895
# Качаю хреф номер  4896
# Качаю хреф номер  4897
# Качаю хреф номер  4898
# Качаю хреф номер  4899
# Качаю хреф номер  4900
# Качаю хреф номер  4901
# Качаю хреф номер  4902
# Качаю хреф номер  4903
# Качаю хреф номер  4904
# Качаю хреф номер  4905
# Качаю хреф номер  4906
# Качаю хреф номер  4907
# Качаю хреф номер  4908
# Качаю хреф номер  4909
# Качаю хреф номер  4910
# Качаю хреф номер  4911
# Качаю хреф номер  4912
# Качаю хреф номер  4913
# Качаю хреф номер  4914
# Качаю хреф номер  4915
# Качаю хреф номер  4916
# Качаю хреф номер  4917
# Качаю хреф номер  4918
# Качаю хреф номер  4919
# Качаю хреф номер  4920
# Качаю хреф номер  4921
# Качаю хреф номер  4922
# Качаю хреф номер  4923
# Качаю хреф номер  4924
# Качаю хреф номер  4925
# Качаю хреф номер  4926
# Качаю хреф номер  4927
# Качаю хреф номер  4928
# Качаю хреф номер  4929
# Качаю хреф номер  4930
# Качаю хреф номер  4931
# Качаю хреф номер  4932
# Качаю хреф номер  4933
# Качаю хреф номер  4934
# Качаю хреф номер  4935
# Качаю хреф номер  4936
# Качаю хреф номер  4937
# Качаю хреф номер  4938
# Качаю хреф номер  4939
# Качаю хреф номер  4940
# Качаю хреф номер  4941
# Качаю хреф номер  4942
# Качаю хреф номер  4943
# Качаю хреф номер  4944
# Качаю хреф номер  4945
# Качаю хреф номер  4946
# Качаю хреф номер  4947
# Качаю хреф номер  4948
# Качаю хреф номер  4949
# Качаю хреф номер  4950
# Качаю хреф номер  4951
# Качаю хреф номер  4952
# Качаю хреф номер  4953
# Качаю хреф номер  4954
# Качаю хреф номер  4955
# Качаю хреф номер  4956
# Качаю хреф номер  4957
# Качаю хреф номер  4958
# Качаю хреф номер  4959
# Качаю хреф номер  4960
# Качаю хреф номер  4961
# Качаю хреф номер  4962
# Качаю хреф номер  4963
# Качаю хреф номер  4964
# Качаю хреф номер  4965
# Качаю хреф номер  4966
# Качаю хреф номер  4967
# Качаю хреф номер  4968
# Качаю хреф номер  4969
# Качаю хреф номер  4970
# Качаю хреф номер  4971
# Качаю хреф номер  4972
# Качаю хреф номер  4973
# Качаю хреф номер  4974
# Качаю хреф номер  4975
# Качаю хреф номер  4976
# Качаю хреф номер  4977
# Качаю хреф номер  4978
# Качаю хреф номер  4979
# Качаю хреф номер  4980
# Качаю хреф номер  4981
# Качаю хреф номер  4982
# Качаю хреф номер  4983
# Качаю хреф номер  4984
# Качаю хреф номер  4985
# Качаю хреф номер  4986
# Качаю хреф номер  4987
# Качаю хреф номер  4988
# Качаю хреф номер  4989
# Качаю хреф номер  4990
# Качаю хреф номер  4991
# Качаю хреф номер  4992
# Качаю хреф номер  4993
# Качаю хреф номер  4994
# Качаю хреф номер  4995
# Качаю хреф номер  4996
# Качаю хреф номер  4997
# Качаю хреф номер  4998
# Качаю хреф номер  4999
# Качаю хреф номер  5000
# Качаю хреф номер  5001
# Качаю хреф номер  5002
# Качаю хреф номер  5003
# Качаю хреф номер  5004
# Качаю хреф номер  5005
# Качаю хреф номер  5006
# Качаю хреф номер  5007
# Качаю хреф номер  5008
# Качаю хреф номер  5009
# Качаю хреф номер  5010
# Качаю хреф номер  5011
# Качаю хреф номер  5012
# Качаю хреф номер  5013
# Качаю хреф номер  5014
# Качаю хреф номер  5015
# Качаю хреф номер  5016
# Качаю хреф номер  5017
# Качаю хреф номер  5018
# Качаю хреф номер  5019
# Качаю хреф номер  5020
# Качаю хреф номер  5021
# Качаю хреф номер  5022
# Качаю хреф номер  5023
# Качаю хреф номер  5024
# Качаю хреф номер  5025
# Качаю хреф номер  5026
# Качаю хреф номер  5027
# Качаю хреф номер  5028
# Качаю хреф номер  5029
# Качаю хреф номер  5030
# Качаю хреф номер  5031
# Качаю хреф номер  5032
# Качаю хреф номер  5033
# Качаю хреф номер  5034
# Качаю хреф номер  5035
# Качаю хреф номер  5036
# Качаю хреф номер  5037
# Качаю хреф номер  5038
# Качаю хреф номер  5039
# Качаю хреф номер  5040
# Качаю хреф номер  5041
# Качаю хреф номер  5042
# Качаю хреф номер  5043
# Качаю хреф номер  5044
# Качаю хреф номер  5045
# Качаю хреф номер  5046
# Качаю хреф номер  5047
# Качаю хреф номер  5048
# Качаю хреф номер  5049
# Качаю хреф номер  5050
# Качаю хреф номер  5051
# Качаю хреф номер  5052
# Качаю хреф номер  5053
# Качаю хреф номер  5054
# Качаю хреф номер  5055
# Качаю хреф номер  5056
# Качаю хреф номер  5057
# Качаю хреф номер  5058
# Качаю хреф номер  5059
# Качаю хреф номер  5060
# Качаю хреф номер  5061
# Качаю хреф номер  5062
# Качаю хреф номер  5063
# Качаю хреф номер  5064
# Качаю хреф номер  5065
# Качаю хреф номер  5066
# Качаю хреф номер  5067
# Качаю хреф номер  5068
# Качаю хреф номер  5069
# Качаю хреф номер  5070
# Качаю хреф номер  5071
# Качаю хреф номер  5072
# Качаю хреф номер  5073
# Качаю хреф номер  5074
# Качаю хреф номер  5075
# Качаю хреф номер  5076
# Качаю хреф номер  5077
# Качаю хреф номер  5078
# Качаю хреф номер  5079
# Качаю хреф номер  5080
# Качаю хреф номер  5081
# Качаю хреф номер  5082
# Качаю хреф номер  5083
# Качаю хреф номер  5084
# Качаю хреф номер  5085
# Качаю хреф номер  5086
# Качаю хреф номер  5087
# Качаю хреф номер  5088
# Качаю хреф номер  5089
# Качаю хреф номер  5090
# Качаю хреф номер  5091
# Качаю хреф номер  5092
# Качаю хреф номер  5093
# Качаю хреф номер  5094
# Качаю хреф номер  5095
# Качаю хреф номер  5096
# Качаю хреф номер  5097
# Качаю хреф номер  5098
# Качаю хреф номер  5099
# Качаю хреф номер  5100
# Качаю хреф номер  5101
# Качаю хреф номер  5102
# Качаю хреф номер  5103
# Качаю хреф номер  5104
# Качаю хреф номер  5105
# Качаю хреф номер  5106
# Качаю хреф номер  5107
# Качаю хреф номер  5108
# Качаю хреф номер  5109
# Качаю хреф номер  5110
# Качаю хреф номер  5111
# Качаю хреф номер  5112
# Качаю хреф номер  5113
# Качаю хреф номер  5114
# Качаю хреф номер  5115
# Качаю хреф номер  5116
# Качаю хреф номер  5117
# Качаю хреф номер  5118
# Качаю хреф номер  5119
# Качаю хреф номер  5120
# Качаю хреф номер  5121
# Качаю хреф номер  5122
# Качаю хреф номер  5123
# Качаю хреф номер  5124
# Качаю хреф номер  5125
# Качаю хреф номер  5126
# Качаю хреф номер  5127
# Качаю хреф номер  5128
# Качаю хреф номер  5129
# Качаю хреф номер  5130
# Качаю хреф номер  5131
# Качаю хреф номер  5132
# Качаю хреф номер  5133
# Качаю хреф номер  5134
# Качаю хреф номер  5135
# Качаю хреф номер  5136
# Качаю хреф номер  5137
# Качаю хреф номер  5138
# Качаю хреф номер  5139
# Качаю хреф номер  5140
# Качаю хреф номер  5141
# Качаю хреф номер  5142
# Качаю хреф номер  5143
# Качаю хреф номер  5144
# Качаю хреф номер  5145
# Качаю хреф номер  5146
# Качаю хреф номер  5147
# Качаю хреф номер  5148
# Качаю хреф номер  5149
# Качаю хреф номер  5150
# Качаю хреф номер  5151
# Качаю хреф номер  5152
# Качаю хреф номер  5153
# Качаю хреф номер  5154
# Качаю хреф номер  5155
# Качаю хреф номер  5156
# Качаю хреф номер  5157
# Качаю хреф номер  5158
# Качаю хреф номер  5159
# Качаю хреф номер  5160
# Качаю хреф номер  5161
# Качаю хреф номер  5162
# Качаю хреф номер  5163
# Качаю хреф номер  5164
# Качаю хреф номер  5165
# Качаю хреф номер  5166
# Качаю хреф номер  5167
# Качаю хреф номер  5168
# Качаю хреф номер  5169
# Качаю хреф номер  5170
# Качаю хреф номер  5171
# Качаю хреф номер  5172
# Качаю хреф номер  5173
# Качаю хреф номер  5174
# Качаю хреф номер  5175
# Качаю хреф номер  5176
# Качаю хреф номер  5177
# Качаю хреф номер  5178
# Качаю хреф номер  5179
# Качаю хреф номер  5180
# Качаю хреф номер  5181
# Качаю хреф номер  5182
# Качаю хреф номер  5183
# Качаю хреф номер  5184
# Качаю хреф номер  5185
# Качаю хреф номер  5186
# Качаю хреф номер  5187
# Качаю хреф номер  5188
# Качаю хреф номер  5189
# Качаю хреф номер  5190
# Качаю хреф номер  5191
# Качаю хреф номер  5192
# Качаю хреф номер  5193
# Качаю хреф номер  5194
# Качаю хреф номер  5195
# Качаю хреф номер  5196
# Качаю хреф номер  5197
# Качаю хреф номер  5198
# Качаю хреф номер  5199
# Качаю хреф номер  5200
# Качаю хреф номер  5201
# Качаю хреф номер  5202
# Качаю хреф номер  5203
# Качаю хреф номер  5204
# Качаю хреф номер  5205
# Качаю хреф номер  5206
# Качаю хреф номер  5207
# Качаю хреф номер  5208
# Качаю хреф номер  5209
# Качаю хреф номер  5210
# Качаю хреф номер  5211
# Качаю хреф номер  5212
# Качаю хреф номер  5213
# Качаю хреф номер  5214
# Качаю хреф номер  5215
# Качаю хреф номер  5216
# Качаю хреф номер  5217
# Качаю хреф номер  5218
# Качаю хреф номер  5219
# Качаю хреф номер  5220
# Качаю хреф номер  5221
# Качаю хреф номер  5222
# Качаю хреф номер  5223
# Качаю хреф номер  5224
# Качаю хреф номер  5225
# Качаю хреф номер  5226
# Качаю хреф номер  5227
# Качаю хреф номер  5228
# Качаю хреф номер  5229
# Качаю хреф номер  5230
# Качаю хреф номер  5231
# Качаю хреф номер  5232
# Качаю хреф номер  5233
# Качаю хреф номер  5234
# Качаю хреф номер  5235
# Качаю хреф номер  5236
# Качаю хреф номер  5237
# Качаю хреф номер  5238
# Качаю хреф номер  5239
# Качаю хреф номер  5240
# Качаю хреф номер  5241
# Качаю хреф номер  5242
# Качаю хреф номер  5243
# Качаю хреф номер  5244
# Качаю хреф номер  5245
# Качаю хреф номер  5246
# Качаю хреф номер  5247
# Качаю хреф номер  5248
# Качаю хреф номер  5249
# Качаю хреф номер  5250
# Качаю хреф номер  5251
# Качаю хреф номер  5252
# Качаю хреф номер  5253
# Качаю хреф номер  5254
# Качаю хреф номер  5255
# Качаю хреф номер  5256
# Качаю хреф номер  5257
# Качаю хреф номер  5258
# Качаю хреф номер  5259
# Качаю хреф номер  5260
# Качаю хреф номер  5261
# Качаю хреф номер  5262
# Качаю хреф номер  5263
# Качаю хреф номер  5264
# Качаю хреф номер  5265
# Качаю хреф номер  5266
# Качаю хреф номер  5267
# Качаю хреф номер  5268
# Качаю хреф номер  5269
# Качаю хреф номер  5270
# Качаю хреф номер  5271
# Качаю хреф номер  5272
# Качаю хреф номер  5273
# Качаю хреф номер  5274
# Качаю хреф номер  5275
# Качаю хреф номер  5276
# Качаю хреф номер  5277
# Качаю хреф номер  5278
# Качаю хреф номер  5279
# Качаю хреф номер  5280
# Качаю хреф номер  5281
# Качаю хреф номер  5282
# Качаю хреф номер  5283
# Качаю хреф номер  5284
# Качаю хреф номер  5285
# Качаю хреф номер  5286
# Качаю хреф номер  5287
# Качаю хреф номер  5288
# Качаю хреф номер  5289
# Качаю хреф номер  5290
# Качаю хреф номер  5291
# Качаю хреф номер  5292
# Качаю хреф номер  5293
# Качаю хреф номер  5294
# Качаю хреф номер  5295
# Качаю хреф номер  5296
# Качаю хреф номер  5297
# Качаю хреф номер  5298
# Качаю хреф номер  5299
# Качаю хреф номер  5300
# Качаю хреф номер  5301
# Качаю хреф номер  5302
# Качаю хреф номер  5303
# Качаю хреф номер  5304
# Качаю хреф номер  5305
# Качаю хреф номер  5306
# Качаю хреф номер  5307
# Качаю хреф номер  5308
# Качаю хреф номер  5309
# Качаю хреф номер  5310
# Качаю хреф номер  5311
# Качаю хреф номер  5312
# Качаю хреф номер  5313
# Качаю хреф номер  5314
# Качаю хреф номер  5315
# Качаю хреф номер  5316
# Качаю хреф номер  5317
# Качаю хреф номер  5318
# Качаю хреф номер  5319
# Качаю хреф номер  5320
# Качаю хреф номер  5321
# Качаю хреф номер  5322
# Качаю хреф номер  5323
# Качаю хреф номер  5324
# Качаю хреф номер  5325
# Качаю хреф номер  5326
# Качаю хреф номер  5327
# Качаю хреф номер  5328
# Качаю хреф номер  5329
# Качаю хреф номер  5330
# Качаю хреф номер  5331
# Качаю хреф номер  5332
# Качаю хреф номер  5333
# Качаю хреф номер  5334
# Качаю хреф номер  5335
# Качаю хреф номер  5336
# Качаю хреф номер  5337
# Качаю хреф номер  5338
# Качаю хреф номер  5339
# Качаю хреф номер  5340
# Качаю хреф номер  5341
# Качаю хреф номер  5342
# Качаю хреф номер  5343
# Качаю хреф номер  5344
# Качаю хреф номер  5345
# Качаю хреф номер  5346
# Качаю хреф номер  5347
# Качаю хреф номер  5348
# Качаю хреф номер  5349
# Качаю хреф номер  5350
# Качаю хреф номер  5351
# Качаю хреф номер  5352
# Качаю хреф номер  5353
# Качаю хреф номер  5354
# Качаю хреф номер  5355
# Качаю хреф номер  5356
# Качаю хреф номер  5357
# Качаю хреф номер  5358
# Качаю хреф номер  5359
# Качаю хреф номер  5360
# --- 8197.509937047958 seconds ---

# %% [markdown]
# На всякий случай сохраним вектор из ссылок. Чтобы не потерять структуру данных (вектор), запишем их в формате `pickle`.

# %%
len(all_hrefs)
# Out:
# 150080

# %%
import pickle

with open('all_refs.pickle', 'wb') as handle:
    pickle.dump(all_hrefs, handle)

# %%
import pickle

with open('all_refs.pickle', 'rb') as f:
     all_hrefs = pickle.load(f)

# %% [markdown]
# Как мы изначально и планировали, код проработал около 2,5 часов. Круто! Займёмся распаралеливанием второго куска кода. Функция `One_Flat_downloader` была написана нами довольно удачно. Она выкачивает только одно наблюдение и никак не повязана на циклы. Вообще не будем трогать её.

# %%
### Вторая часть кода. Функция, которая вытаскивает наблюдения по одной квартирке.    
    
def One_Flat_Downloader(href):
    """
    Функция производит выкачку по одной ЦИАНовской ссылке 
    всей существующей информации о квартире.
    Ввод: ссылка на описание квартиры
    Вывод: словарь с информацией о квартире    
    """
    
    data = { }  # Задали пустой словарь, в который мы будем сохранять данные
    
    # Подгружаем страничку с информацией по квартире
    response = requests.get(href)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Вытаскиваем цену на квартиру
    price = soup.findAll('div', attrs = {'class':"object_descr_price"})[0].text.strip()
    data['Цена'] = price
    
    # Вытаскиваем метро
    try:
        station = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0].a.text
        data['Метро'] = station
    except Exception:
        data['Метро'] = "NA"
    
    # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
    try:
        Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
        Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
        data['До метро'] = Do_metro
    except Exception:
        data['До метро'] = "NA"
    
    # Вытаскиваем количество комнат в квартире
    komnata = soup.findAll('div', attrs = {'class':"object_descr_title"})[0].text.strip()
    data['Комнаты'] = komnata
    
    # Вытаскиваем координаты квартиры
    coordinates = soup.findAll('div',{'class':"object-descr__map-tabs__content js-object_descr__panorama"})[0]
    data['Координаты'] = coordinates.panorama.attrs['point']
    
    # Вытаскиваем всё остальное
    table = soup.findAll('table',attrs = {'class':"object_descr_props flat sale"})[0]
    rows = table.find_all('tr')[1:]  # Вытащили все строки
    for row in rows:
        cols = [row.findAll('th')[0].text.strip(),row.findAll('td')[0].text.strip()] # очищаем каждую строку! 
        data[cols[0]] = cols[1] # запоминаем
    return(data)

# %% [markdown]
# Третья часть нашего кода - главный цикл, который и выкачивает информацию. Как раз в ней и происходит скачёк времени при росте объёма входа. Превратим этот цикл в функции `Map` и `Reduce`.
#
# Функция `Map` будет обращаться к вектору из ссылок `part_hrefs` и вытаскивать по ним всю информацию.

# %%
def Map(part_hrefs):
    # В эту табличку будем собирать данные
    df = pd.DataFrame( )
    k = 0 # Это номера наблюдений
    n = len(part_hrefs)
    for item in part_hrefs:
        k = k + 1
        # грузим новое наблюдение/
        df1 = pd.DataFrame.from_dict(One_Flat_Downloader(item),orient='index')
        # присваиваем этому наблюдению номер
        df1.columns =[k]
        # закидываем его в итоговую таблицу
        df = df.join(df1, how='outer')
        # Выдавать информацию о том, что сделана каждая десятая итерация! 
        if k%100 == 0:
            print('сделано ', k, ' итераций из', n)
    return(df)

# %% [markdown]
# ### Создаём потоки

# %% [markdown]
# Раздробим весь список из ссылок на какое-то количество частей. Например, на 30.

# %%
current_hrefs = all_hrefs[:60000]
len(current_hrefs)
# Out:
# 60000

# %%
# Делим весь список из имён на 30 частей
parts = [round(len(current_hrefs)/30)*i for i in range(30)]
parts.append(len(current_hrefs))
names = [current_hrefs[parts[i]:parts[i+1]] for i in range(30)]

# %% [markdown]
# Проверим, работает ли функция `Map`.

# %%
Map(names[0][:10])
# Out:
#                                                                       1   \
# Балкон:                                                              нет
# Вид из окна:                                                       улица
# Высота потолков:                                                     NaN
# Год постройки:                                                       NaN
# До метро               7\n                мин.\n                \n   ...
# Жилая площадь:                                                   30,8 м2
# Комнаты                                                      2-комн. кв.
# Координаты                                         [37.544467,55.860792]
# Лифт:                                                  2 пасс. + 1 груз.
# Метро                                             Петровско-Разумовская,
# Общая площадь:                                                   52,4 м2
# Парковка:                                                            NaN
# Площадь комнат:                                           12.76-18.05 м2
# Площадь кухни:                                                   12,9 м2
# Раздельных санузлов:                                                   1
# Ремонт:                                                              NaN
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             нет
# Тип дома:                    вторичка, \n            кирпично-монолитный
# Тип продажи:                                                   свободная
# Цена                                                      6 601 335 руб.
# Этаж:                                                              2 / 6
#
#                                                                       2   \
# Балкон:                                                              нет
# Вид из окна:                                                       улица
# Высота потолков:                                                  2,70 м
# Год постройки:                                                      1965
# До метро               11\n                мин.\n                \n  ...
# Жилая площадь:                                                     35 м2
# Комнаты                                                      2-комн. кв.
# Координаты                                         [37.638216,55.786151]
# Лифт:                                                  1 пасс. + 1 груз.
# Метро                                                     Проспект Мира,
# Общая площадь:                                                     47 м2
# Парковка:                                                            NaN
# Площадь комнат:                                                 18-17 м2
# Площадь кухни:                                                      9 м2
# Раздельных санузлов:                                                   2
# Ремонт:                                                      отсутствует
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             NaN
# Тип дома:                                вторичка, \n            блочный
# Тип продажи:                                                   свободная
# Цена                                                      9 700 000 руб.
# Этаж:                                                             1 / 12
#
#                                                                       3   \
# Балкон:                                                          2 лодж.
# Вид из окна:                                                двор и улица
# Высота потолков:                                                     NaN
# Год постройки:                                                       NaN
# До метро               15\n                мин.\n                \n  ...
# Жилая площадь:                                                     60 м2
# Комнаты                                                      3-комн. кв.
# Координаты                                         [37.479888,55.785422]
# Лифт:                                                  2 пасс. + 2 груз.
# Метро                                                  Октябрьское поле,
# Общая площадь:                                                     97 м2
# Парковка:                                                       наземная
# Площадь комнат:                                            23-16,9-18 м2
# Площадь кухни:                                                     11 м2
# Раздельных санузлов:                                                   2
# Ремонт:                                                      отсутствует
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             NaN
# Тип дома:                                                       вторичка
# Тип продажи:                                                   свободная
# Цена                                                     17 500 000 руб.
# Этаж:                                                            18 / 25
#
#                                                                       4   \
# Балкон:                                                                –
# Вид из окна:                                                           –
# Высота потолков:                                                     NaN
# Год постройки:                                                      2014
# До метро               15\n                мин.\n                \n  ...
# Жилая площадь:                                                         –
# Комнаты                                                           студия
# Координаты                                         [37.552543,55.491804]
# Лифт:                                                                  –
# Метро                                                   Бунинская аллея,
# Общая площадь:                                                   15,3 м2
# Парковка:                                                            NaN
# Площадь комнат:                                                        –
# Площадь кухни:                                                         –
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                    косметический
# Санузел:                                                             нет
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             NaN
# Тип дома:                                                       вторичка
# Тип продажи:                                                   свободная
# Цена                                                      1 290 000 руб.
# Этаж:                                                              3 / 3
#
#                                                                       5   \
# Балкон:                                                                –
# Вид из окна:                                                           –
# Высота потолков:                                                     NaN
# Год постройки:                                                       NaN
# До метро               25\n                мин.\n                \n  ...
# Жилая площадь:                                                     26 м2
# Комнаты                                                           студия
# Координаты                                         [37.322593,55.648382]
# Лифт:                                                                  –
# Метро                                                          Киевская,
# Общая площадь:                                                     29 м2
# Парковка:                                                       наземная
# Площадь комнат:                                                    26 м2
# Площадь кухни:                                                         –
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                      отсутствует
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                  1
# Телефон:                                                             NaN
# Тип дома:                                                       вторичка
# Тип продажи:                                                   свободная
# Цена                                                      1 440 000 руб.
# Этаж:                                                              3 / 3
#
#                                                                       6   \
# Балкон:                                                                –
# Вид из окна:                                                        двор
# Высота потолков:                                                  2,70 м
# Год постройки:                                                      2015
# До метро                                                              NA
# Жилая площадь:                                                     10 м2
# Комнаты                студия \n    \n\n                \n           ...
# Координаты                                         [37.554439,55.495098]
# Лифт:                                                  1 пасс. + 1 груз.
# Метро                                                   Бунинская аллея,
# Общая площадь:                                                     13 м2
# Парковка:                                                       наземная
# Площадь комнат:                                                    10 м2
# Площадь кухни:                                                      3 м2
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                      отсутствует
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                  1
# Телефон:                                                             NaN
# Тип дома:                             вторичка, \n            монолитный
# Тип продажи:                                                   свободная
# Цена                                                      1 590 000 руб.
# Этаж:                                                             2 / 21
#
#                                                                       7   \
# Балкон:                                                                –
# Вид из окна:                                                           –
# Высота потолков:                                                     NaN
# Год постройки:                                                       NaN
# До метро               30\n                мин.\n                \n  ...
# Жилая площадь:                                                     18 м2
# Комнаты                1-комн. кв. \n    \n\n                \n      ...
# Координаты                                         [36.917628,55.497660]
# Лифт:                                                                  –
# Метро                                                      Юго-Западная,
# Общая площадь:                                                     34 м2
# Парковка:                                                            NaN
# Площадь комнат:                                                    18 м2
# Площадь кухни:                                                     10 м2
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                              NaN
# Санузел:                                                             нет
# Сдача ГК:                                                1 кв. 2017 года
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             NaN
# Тип дома:                           новостройка, \n            кирпичный
# Тип продажи:                                                      214-ФЗ
# Цена                                                      1 730 000 руб.
# Этаж:                                                              1 / 3
#
#                                                                       8   \
# Балкон:                                                                –
# Вид из окна:                                                        двор
# Высота потолков:                                                  2,64 м
# Год постройки:                                                      1972
# До метро               16\n                мин.\n                \n  ...
# Жилая площадь:                                                      7 м2
# Комнаты                                                           студия
# Координаты                                         [37.617986,55.606690]
# Лифт:                                                                  –
# Метро                                                          Пражская,
# Общая площадь:                                                     12 м2
# Парковка:                                                            NaN
# Площадь комнат:                                                     7 м2
# Площадь кухни:                                                      3 м2
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                    косметический
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                  1
# Телефон:                                                             NaN
# Тип дома:                                                       вторичка
# Тип продажи:                                                   свободная
# Цена                                                      1 790 000 руб.
# Этаж:                                                              1 / 9
#
#                                                                       9   \
# Балкон:                                                                –
# Вид из окна:                                                           –
# Высота потолков:                                                     NaN
# Год постройки:                                                      1982
# До метро               8\n                мин.\n                \n   ...
# Жилая площадь:                                                         –
# Комнаты                                                      1-комн. кв.
# Координаты                                         [37.580310,55.563661]
# Лифт:                                                                  –
# Метро                                          Бульвар Дмитрия Донского,
# Общая площадь:                                                   11,4 м2
# Парковка:                                                       наземная
# Площадь комнат:                                                        –
# Площадь кухни:                                                         –
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                      отсутствует
# Санузел:                                                             NaN
# Сдача ГК:                                                            NaN
# Совмещенных санузлов:                                                  1
# Телефон:                                                             NaN
# Тип дома:                          вторичка, \n            панельный дом
# Тип продажи:                                                   свободная
# Цена                                                      1 790 000 руб.
# Этаж:                                                              1 / 9
#
#                                                                       10
# Балкон:                                                                –
# Вид из окна:                                                       улица
# Высота потолков:                                                     NaN
# Год постройки:                                                       NaN
# До метро               35\n                мин.\n                \n  ...
# Жилая площадь:                                                   18,1 м2
# Комнаты                1-комн. кв. \n    \n\n                \n      ...
# Координаты                                         [36.917628,55.497660]
# Лифт:                                                                  –
# Метро                                                         Саларьево,
# Общая площадь:                                                   34,8 м2
# Парковка:                                                            NaN
# Площадь комнат:                                                  18.1 м2
# Площадь кухни:                                                   10,8 м2
# Раздельных санузлов:                                                 NaN
# Ремонт:                                                              NaN
# Санузел:                                                             нет
# Сдача ГК:                                                2 кв. 2017 года
# Совмещенных санузлов:                                                NaN
# Телефон:                                                             NaN
# Тип дома:                       новостройка, \n            панельный дом
# Тип продажи:                                                 переуступка
# Цена                                                      1 800 000 руб.
# Этаж:                                                              1 / 3

# %% [markdown]
# Собираем по каждому из 30 векторов со ссылками информацию. Все потоки работаю независимо друг от друга и записывают информацию в свои таблички. После все таблички закидываются в вектор `l`.

# %%
start_time = time.time() # время работы кода 
    
if __name__ == '__main__':
    with Pool(30) as p:
        l = p.map(Map, names)

print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода
# Out:
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  100  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  200  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  300  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  400  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  500  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  600  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  700  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  800  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  900  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1000  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1100  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1200  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1300  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1400  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1500  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1600  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1700  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1800  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  1900  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# сделано  2000  итераций из 2000
# --- 8544.094778776169 seconds ---

# %% [markdown]
# Первые 60 000 наблюдений скачались за 8544 секунд (2 с лишним часа). Возможно, мы  переборщили с количеством потоков. Ожидалось, что алгоритм проработает около часа. При прямой работе алгоритм бы работал около 12 часов. Можно провести парочку экспериментов, но в любом случае получилось быстрее, чем 12 часов! Ну и господь с этой шайтан-машиной...

# %% [markdown]
# Остался последний шаг - `Reduce` - шаг. Функция `Reduce` будет брать таблички из списка `l` и объединять их все в один большой `dataframe`.

# %%
def Reduce(l):
    df = pd.DataFrame( )  # новый датафрейм, куда мы всё закинем! 
    k = 0
    for item in l:        # Этот цикл уже вам знаком...
        n = item.shape[1] + k
        item.columns = range(k,n)
        df = df.join(item, how = 'outer')
        k = n 
    return(df)

# %%
start_time = time.time() # время работы кода 

itog_data = Reduce(l) 
itog_data = itog_data.T             # Для удобства транспонируем таблицу        
itog_data['Хрефы'] = current_hrefs  # Добавим к итоговой таблице колонку из хрефов.

print("--- %s seconds ---" % (time.time() - start_time))  #время работы кода
# Out:
# --- 109.7799117565155 seconds ---

# %% [markdown]
# Смотрим на итоговые характеристики нашей таблицы и сохраняем результат на свой компьютер.

# %%
itog_data.shape
# Out:
# (60000, 27)

# %%
pd.DataFrame.to_csv(itog_data,'CIAN_data1.csv')
