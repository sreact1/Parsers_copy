# %% [markdown]
# <img src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/cian_main_theme.png" height="1000" width="1000">
#
# <img align="center" src="https://www.cian.ru/promo/adv/assets/images/logo.svg" height="300" width="300">
#
#
# # <center> Грабёж, разбой и другие незаконные деяния с помощью Python. <br> <br> Продолжаем ограбление. Задействуем союзника - Google!  </center>
# ---------

# %% [markdown]
# ## 1. Что такое API?
#
# API (Application Programming Interface) это уже готовый код, который можно всунуть в свой код!  Многие разработчики, в том числе Google и Вконтакте представляют свои уже готовые решения для вашей разработки.
#
# Обычно обращение к API происходит точно также как к обычной ссылке через пакет `requests`.

# %%
import pandas as pd
import numpy as np

import requests

# %% [markdown]
# Обратиться через этот пакет обычно нужно к простой банальной ссылке, в которую будет вшито то, что вы хотели бы для себя достать. Итак, заходим в [документацию по API для Google maps](https://developers.google.com/maps/documentation/webservices/), которая была заботливо для нас написана и начинаем её использовать.

# %% [markdown]
# Мы хотим получить расстояние, которое нужно пройти пешком или проехать на машине от каждой квартиры до ближайшего метро. Для этого мы будем использовать метод, который называется *distancematrix*.
#
# *Google Distance Matrix API* - это сервис, который предоставляет расстояние и время пути между указанными точками. Ссылка для запроса к API будет иметь следующую структуру
#
# > https://maps.googleapis.com/maps/api/distancematrix/json?units=imperial&origins=Washington,DC&destinations=New+York+City,NY&key=YOUR_API_KEY
#
# В первой строке указано название сервиса, к API которого мы обращаемся, метод который мы используем ,*distancematrix*, формат, в котором мы хотели бы получить ответ, *json*, и объекты, между которыми мы ищем расстояние, *Origins* - начало отсчета, *Destinations* - конец отсчета. Кроме того через амперсанды в ссылку можно добавить кучу других параметров. Например: *Mode* - способ перемещения, *Language* - язык, на котором мы хотели бы получить ответ на наш запрос.
#
# Пробуем!

# %%
mainpage = "http://maps.googleapis.com/maps/api/distancematrix/json?"

place_one = "м. Юго-Западная, Москва"
place_two = "ул. Академика Анохина 20, Москва"
sposob = "walking"
YOU_API_KEY = ''

parameters = 'origins='+place_one+'&destinations='+place_two+'&mode='+sposob+'&language=ru-Ru'

itog_url = mainpage + parameters
itog_url
# Out:
# 'http://maps.googleapis.com/maps/api/distancematrix/json?origins=м. Юго-Западная, Москва&destinations=ул. Академика Анохина 20, Москва&mode=walking&language=ru-Ru'

# %%
response = requests.get(itog_url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Ура! Благосоавенный 200-всё-очень-хорошо-ответ! Попробуем сделать как мы делали раньше и посмотреть html нашей странички.

# %%
content = response.content
content
# Out:
# b'{\n   "destination_addresses" : [\n      "\xd1\x83\xd0\xbb. \xd0\x90\xd0\xbd\xd0\xbe\xd1\x85\xd0\xb8\xd0\xbd\xd0\xb0 \xd0\x90\xd0\xba\xd0\xb0\xd0\xb4\xd0\xb5\xd0\xbc\xd0\xb8\xd0\xba\xd0\xb0, 20, \xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0, \xd0\xa0\xd0\xbe\xd1\x81\xd1\x81\xd0\xb8\xd1\x8f, 119602"\n   ],\n   "origin_addresses" : [ "\xd0\xae\xd0\xb3\xd0\xbe-\xd0\x97\xd0\xb0\xd0\xbf\xd0\xb0\xd0\xb4\xd0\xbd\xd0\xb0\xd1\x8f, \xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb0, \xd0\xa0\xd0\xbe\xd1\x81\xd1\x81\xd0\xb8\xd1\x8f, 119526" ],\n   "rows" : [\n      {\n         "elements" : [\n            {\n               "distance" : {\n                  "text" : "0,9 \xd0\xba\xd0\xbc",\n                  "value" : 897\n               },\n               "duration" : {\n                  "text" : "11 \xd0\xbc\xd0\xb8\xd0\xbd.",\n                  "value" : 687\n               },\n               "status" : "OK"\n            }\n         ]\n      }\n   ],\n   "status" : "OK"\n}\n'

# %% [markdown]
# Ух! Какая страшная штука. Но тем не менее она похожа именно на то, что нам нужно. Как я это понял? Интуиция... Но почему тогда она такая некрасивая? Всё дело в том, что мы пытаемся применить к нашему контенту те же самые методы, что мы использовали для html разметки. Тем не менее данные были скачены в формате json. Если бы мы указали в ссылке для скачки lxml-формат, то мы могли бы даже поработать с нашими данными красивым супом.
#
# Тем не менее, мы указали другой формат, потому что он более удобный. Смотрите!

# %%
content = response.json()
content
# Out:
# {'destination_addresses': ['ул. Анохина Академика, 20, Москва, Россия, 119602'],
#  'origin_addresses': ['Юго-Западная, Москва, Россия, 119526'],
#  'rows': [{'elements': [{'distance': {'text': '0,9 км', 'value': 897},
#      'duration': {'text': '11 мин.', 'value': 687},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %% [markdown]
# Секундочку... Это что? Словарь? Да! Это словарь!

# %%
type(content)
# Out:
# dict

# %% [markdown]
# Вытаскиваем из этого словаря всё, что нам необходимо.

# %%
content['destination_addresses']
# Out:
# ['ул. Анохина Академика, 20, Москва, Россия, 119602']

# %%
content['rows'][0]['elements'][0]['duration']['text']
# Out:
# '11 мин.'

# %% [markdown]
# Точно также можно качать расстояние между объектами по координатам! Подгружаем наш ЦИАНовский датасет!

# %%
df = pd.read_csv('clean_data_for_work.csv', header=0, sep=',' ,index_col=0)
longtitude = list(df['longitude'])
latitude = list(df['latitude'])
metro = list(df['metro_name'])

# %%
def infa_downloader(place_one,place_two,sposob):
    
    # создлали ссылку по входным параметрам
    mainpage = "http://maps.googleapis.com/maps/api/distancematrix/json?"
    parameters = 'origins='+place_one+'&destinations='+place_two+'&mode='+sposob+'&language=ru-Ru'+'&key='
    itog_url = mainpage + parameters
    
    # сделали запрос и вытащили инфу
    response = requests.get(itog_url)
    content = response.json()
    return(content)

# %%
str(longtitude[0])+','+str(latitude[0])
# Out:
# '37.544467,55.860792'

# %%
metro[0]
# Out:
# 'Петровско-Разумовская,'

# %%
infa_downloader(str(latitude[1001])+','+str(longtitude[1001]),metro[1001],"walking")
# Out:
# {'destination_addresses': ['Бунинская аллея, Москва, Россия, 117041'],
#  'origin_addresses': ['ул. 3-я Барышевская, Щербинка, Московская обл., Россия, 142171'],
#  'rows': [{'elements': [{'distance': {'text': '7,0 км', 'value': 7006},
#      'duration': {'text': '1 час. 26 мин.', 'value': 5140},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %%
infa_downloader(str(latitude[1001])+','+str(longtitude[1001]),metro[1001],"driving")
# Out:
# {'destination_addresses': ['Бунинская аллея, Москва, Россия, 117041'],
#  'origin_addresses': ['ул. 3-я Барышевская, Щербинка, Московская обл., Россия, 142171'],
#  'rows': [{'elements': [{'distance': {'text': '17,1 км', 'value': 17056},
#      'duration': {'text': '35 мин.', 'value': 2111},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %% [markdown]
# Вроде бы всё хорошо. Дело осталось за малым - написать цикл!
#
# # НЕТ!
#
# Ничего подобного. Сначала нужно изучить ограничения.
#
# <img src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/Workspace%201_180.png" height="700" width="700">
#
# Неожиданно выясняется, что мы можем делать в течение суток не более 2500 запросов. Чёрт возьми! Какая боль, какая обида и какие страдания... Ограничения выяснили, попробуем теперь написать цикл. Авось прокатит...

# %%
walk_dist  = [ ]
drive_dist = [ ]

for i in range(len(metro)):
    walk_dist.append( vremia_finder(str(latitude[i])+','+str(longtitude[i]),metro[i],"walking") )
    drive_dist.append( vremia_finder(str(latitude[i])+','+str(longtitude[i]),metro[i],"driving") )

# %% [markdown]
# Неожиданно вспоминаем, что такой цикл не заработает, потому что метро есть не везде... Переписываем цикл...

# %%
walk_dist  = [ ]
drive_dist = [ ]

for i in range(len(metro)):
    try:
        walk_dist.append( vremia_finder(str(latitude[i])+','+str(longtitude[i]),metro[i],"walking") )
    except Exception:
        walk_dist.append(np.nan)
    
    try:
        drive_dist.append( vremia_finder(str(latitude[i])+','+str(longtitude[i]),metro[i],"driving") )
    except Exception:
        drive_dist.append(np.nan)    
        
    # Мы хотим видеть где именно находится наш цикл!
    if i%10 == 0:
        print(i,drive_dist[i],walk_dist[i])
# Out:
# 0 10 мин. 51 мин.
# 10 32 мин. 7 ч. 45 мин.
# 20 30 мин. 42 мин.
# 30 6 мин. 12 мин.
# 40 31 мин. 4 ч. 47 мин.
# 50 31 мин. 4 ч. 47 мин.
# 60 7 мин. 10 мин.
# 70 17 мин. 1 час. 31 мин.
# 80 nan nan
# 90 9 мин. 28 мин.
# 100 30 мин. 3 ч. 48 мин.
# 110 24 мин. 3 ч. 15 мин.
# 120 5 мин. 12 мин.
# 130 31 мин. 3 ч. 51 мин.
# 140 19 мин. 1 час. 7 мин.
# 150 17 мин. 1 час. 31 мин.
# 160 33 мин. 5 ч. 13 мин.
# 170 7 мин. 9 мин.
# 180 23 мин. 1 час. 26 мин.
# 190 14 мин. 1 час. 6 мин.
# 200 14 мин. 1 час. 6 мин.
# 210 22 мин. 1 час. 36 мин.
# 220 nan nan
# 230 9 мин. 28 мин.
# 240 37 мин. 4 ч. 46 мин.
# 250 nan nan
# 260 14 мин. 1 час. 14 мин.
# 270 5 мин. 19 мин.
# 280 6 мин. 19 мин.
# 290 17 мин. 1 час. 29 мин.
# 300 23 мин. 1 час. 25 мин.
# 310 7 мин. 18 мин.
# 320 14 мин. 1 час. 14 мин.
# 330 19 ч. 31 мин. 11 дн. 13 ч.
# 340 25 мин. 3 ч. 40 мин.
# 350 17 мин. 1 час. 31 мин.
# 360 nan nan
# 370 22 мин. 2 ч. 52 мин.
# 380 10 мин. 57 мин.
# 390 16 мин. 1 час. 18 мин.
# 400 nan nan
# 410 19 мин. 1 час. 7 мин.
# 420 31 мин. 4 ч. 47 мин.
# 430 19 мин. 1 час. 7 мин.
# 440 2 мин. 7 мин.
# 450 13 мин. 1 час. 14 мин.
# 460 nan nan
# 470 14 мин. 1 час. 14 мин.
# 480 7 мин. 25 мин.
# 490 29 мин. 3 ч. 45 мин.
# 500 7 мин. 25 мин.
# 510 6 мин. 45 мин.
# 520 7 мин. 21 мин.
# 530 9 ч. 9 мин. 5 дн. 23 ч.
# 540 17 мин. 1 час. 31 мин.
# 550 nan nan
# 560 nan nan
# 570 9 мин. 28 мин.
# 580 19 мин. 1 час. 52 мин.
# 590 12 мин. 39 мин.
# 600 9 мин. 47 мин.
# 610 19 мин. 1 час. 52 мин.
# 620 16 мин. 1 час. 14 мин.
# 630 4 мин. 19 мин.
# 640 14 мин. 1 час. 57 мин.
# 650 8 мин. 32 мин.
# 660 nan nan
# 670 5 мин. 26 мин.
# 680 12 мин. 1 час. 54 мин.
# 690 9 мин. 50 мин.
# 700 31 мин. 4 ч. 47 мин.
# 710 19 мин. 1 час. 7 мин.
# 720 7 мин. 29 мин.
# 730 5 мин. 11 мин.
# 740 6 мин. 19 мин.
# 750 4 мин. 19 мин.
# 760 15 мин. 1 час. 11 мин.
# 770 4 мин. 19 мин.
# 780 17 мин. 1 час. 31 мин.
# 790 20 мин. 1 час. 33 мин.
# 800 nan nan
# 810 14 мин. 56 мин.
# 820 nan nan
# 830 40 мин. 5 ч. 46 мин.
# 840 nan nan
# 850 32 мин. 7 ч. 45 мин.
# 860 30 мин. 42 мин.
# 870 5 мин. 13 мин.
# 880 32 мин. 7 ч. 45 мин.
# 890 35 мин. 1 час. 26 мин.
# 900 36 мин. 1 час. 31 мин.
# 910 nan nan
# 920 5 мин. 14 мин.
# 930 35 мин. 1 час. 19 мин.
# 940 nan nan
# 950 nan nan
# 960 7 мин. 18 мин.
# 970 nan nan
# 980 17 мин. 1 час. 31 мин.
# 990 32 мин. 7 ч. 45 мин.
# 1000 30 мин. 42 мин.
# 1010 11 мин. 29 мин.
# 1020 32 мин. 7 ч. 45 мин.
# 1030 35 мин. 1 час. 26 мин.
# 1040 36 мин. 1 час. 31 мин.
# 1050 nan nan
# 1060 5 мин. 14 мин.
# 1070 35 мин. 1 час. 19 мин.
# 1080 nan nan
# 1090 nan nan
# 1100 7 мин. 18 мин.
# 1110 nan nan
# 1120 17 мин. 1 час. 31 мин.
# 1130 32 мин. 7 ч. 45 мин.
# 1140 30 мин. 42 мин.
# 1150 5 мин. 14 мин.
# 1160 32 мин. 7 ч. 45 мин.
# 1170 35 мин. 1 час. 26 мин.
# 1180 36 мин. 1 час. 31 мин.
# 1190 nan nan
# 1200 5 мин. 14 мин.
# 1210 35 мин. 1 час. 19 мин.
# 1220 nan nan
# 1230 nan nan
# 1240 7 мин. 18 мин.
# 1250 nan nan
# 1260 17 мин. 1 час. 31 мин.
# 1270 32 мин. 7 ч. 45 мин.
# 1280 30 мин. 42 мин.
# 1290 12 мин. 32 мин.
# 1300 32 мин. 7 ч. 45 мин.
# 1310 35 мин. 1 час. 26 мин.
# 1320 36 мин. 1 час. 31 мин.
# 1330 nan nan
# 1340 5 мин. 14 мин.
# 1350 35 мин. 1 час. 19 мин.
# 1360 nan nan
# 1370 nan nan
# 1380 7 мин. 18 мин.
# 1390 nan nan
# 1400 17 мин. 1 час. 31 мин.
# 1410 32 мин. 7 ч. 45 мин.
# 1420 30 мин. 42 мин.
# 1430 5 мин. 21 мин.
# 1440 32 мин. 7 ч. 45 мин.
# 1450 35 мин. 1 час. 26 мин.
# 1460 36 мин. 1 час. 31 мин.
# 1470 nan nan
# 1480 5 мин. 14 мин.
# 1490 35 мин. 1 час. 19 мин.
# 1500 nan nan
# 1510 nan nan
# 1520 7 мин. 18 мин.
# 1530 nan nan
# 1540 17 мин. 1 час. 31 мин.
# 1550 32 мин. 7 ч. 45 мин.
# 1560 30 мин. 42 мин.
# 1570 nan nan
# 1580 32 мин. 7 ч. 45 мин.
# 1590 35 мин. 1 час. 26 мин.
# 1600 36 мин. 1 час. 31 мин.
# 1610 nan nan
# 1620 5 мин. 14 мин.
# 1630 nan 1 час. 19 мин.
# 1640 nan nan
# 1650 nan nan
# 1660 nan nan
# 1670 nan nan
# 1680 nan nan
# 1690 nan nan
# 1700 nan nan
# 1710 nan nan
# 1720 nan nan
# 1730 nan nan
# 1740 36 мин. nan
# 1750 nan nan
# 1760 nan nan
# 1770 nan nan
# 1780 nan nan
# 1790 nan nan
# 1800 nan nan
# 1810 nan nan
# 1820 nan nan
# 1830 nan nan
# 1840 nan nan
# 1850 nan nan
# 1860 nan nan
# 1870 nan nan
# 1880 36 мин. nan
# 1890 nan nan
# 1900 nan nan
# 1910 nan nan
# 1920 nan nan
# 1930 nan nan
# 1940 nan nan
# 1950 nan nan
# 1960 nan nan
# 1970 nan nan
# 1980 nan nan
# 1990 nan nan
# 2000 nan nan
# 2010 nan nan
# 2020 nan 1 час. 31 мин.
# 2030 nan nan
# 2040 nan nan
# 2050 nan nan
# 2060 nan nan
# 2070 nan nan
# 2080 nan nan
# 2090 nan nan
# 2100 nan nan
# 2110 nan 7 ч. 45 мин.
# 2120 nan 42 мин.
# 2130 nan nan
# 2140 nan 7 ч. 45 мин.
# 2150 nan nan
# 2160 36 мин. nan
# 2170 nan nan
# 2180 nan nan
# 2190 nan nan
# 2200 nan nan
# 2210 nan nan
# 2220 nan nan
# 2230 nan nan
# 2240 nan nan
# 2250 nan 7 ч. 45 мин.
# 2260 nan nan
# 2270 nan nan
# 2280 nan 7 ч. 45 мин.
# 2290 nan nan
# 2300 36 мин. nan
# 2310 nan nan
# 2320 nan nan
# 2330 nan nan
# 2340 nan nan
# 2350 nan nan
# 2360 nan nan
# 2370 nan nan
# 2380 nan nan
# 2390 nan nan
# 2400 nan nan
# 2410 nan nan
# 2420 nan nan
# 2430 nan nan
# 2440 36 мин. nan
# 2450 nan nan
# 2460 nan nan
# 2470 nan nan
# 2480 nan nan
# 2490 nan nan
# 2500 nan nan
# 2510 nan nan
# 2520 nan nan
# 2530 nan nan
# 2540 nan nan
# 2550 nan nan
# 2560 nan nan
# 2570 nan nan
# 2580 36 мин. nan
# 2590 nan nan
# 2600 nan nan
# 2610 nan nan
# 2620 nan nan
# 2630 nan nan
# 2640 nan nan
# 2650 nan nan
# 2660 nan nan
# 2670 nan nan
# 2680 nan nan
# 2690 nan nan
# 2700 nan nan
# 2710 nan nan
# 2720 36 мин. nan
# 2730 nan nan
# 2740 nan nan
# 2750 nan nan
# 2760 nan nan
# 2770 nan nan
# 2780 nan nan
# 2790 nan nan
# 2800 nan nan
# 2810 nan nan
# 2820 nan nan
# 2830 nan nan
# 2840 nan 7 ч. 45 мин.
# 2850 nan nan
# 2860 nan 1 час. 31 мин.
# 2870 nan nan
# 2880 nan nan
# 2890 nan nan
# 2900 nan nan
# 2910 nan nan
# 2920 nan nan
# 2930 nan nan
# 2940 nan nan
# 2950 nan nan
# 2960 nan 42 мин.
# 2970 nan nan
# 2980 nan nan
# 2990 nan nan
# 3000 nan 1 час. 31 мин.
# 3010 nan nan
# 3020 nan nan
# 3030 nan nan
# 3040 nan nan
# 3050 nan nan
# 3060 nan nan
# 3070 nan nan
# 3080 nan nan
# 3090 nan 7 ч. 45 мин.
# 3100 nan nan
# 3110 nan nan
# 3120 nan 7 ч. 45 мин.
# 3130 nan nan
# 3140 36 мин. nan
# 3150 nan nan
# 3160 nan nan
# 3170 nan nan
# 3180 nan nan
# 3190 nan nan
# 3200 nan nan
# 3210 nan nan
# 3220 nan nan
# 3230 nan nan
# 3240 nan nan
# 3250 nan nan
# 3260 nan nan
# 3270 nan nan
# 3280 nan 1 час. 31 мин.
# 3290 nan nan
# 3300 nan nan
# 3310 nan nan
# 3320 nan nan
# 3330 nan nan
# 3340 nan nan
# 3350 nan nan
# 3360 nan nan
# 3370 nan 7 ч. 45 мин.
# 3380 nan 42 мин.
# 3390 nan nan
# 3400 nan 7 ч. 45 мин.
# 3410 nan nan
# 3420 36 мин. nan
# 3430 nan nan
# 3440 nan nan
# 3450 nan nan
# 3460 nan nan
# 3470 nan nan
# 3480 nan nan
# 3490 nan nan
# 3500 nan nan
# 3510 nan 7 ч. 45 мин.
# 3520 nan nan
# 3530 nan nan
# 3540 nan nan
# 3550 nan nan
# 3560 36 мин. nan
# 3570 nan nan
# 3580 nan nan
# 3590 nan nan
# 3600 nan nan
# 3610 nan nan
# 3620 nan nan
# 3630 nan nan
# 3640 nan nan
# 3650 nan nan
# 3660 nan nan
# 3670 nan nan
# 3680 nan nan
# 3690 nan nan
# 3700 36 мин. nan
# 3710 nan nan
# 3720 nan nan
# 3730 nan 1 час. 19 мин.
# 3740 nan nan
# 3750 nan nan
# 3760 7 мин. nan
# 3770 nan nan
# 3780 17 мин. nan
# 3790 32 мин. nan
# 3800 30 мин. nan
# 3810 nan nan
# 3820 32 мин. nan
# 3830 35 мин. nan
# 3840 36 мин. nan
# 3850 nan nan
# 3860 5 мин. nan
# 3870 35 мин. nan
# 3880 nan nan
# 3890 nan nan
# 3900 7 мин. nan
# 3910 nan nan
# 3920 17 мин. nan
# 3930 32 мин. nan
# 3940 30 мин. nan
# 3950 nan nan
# 3960 32 мин. nan
# 3970 35 мин. nan
# 3980 36 мин. nan
# 3990 nan nan
# 4000 5 мин. nan
# 4010 35 мин. nan
# 4020 nan nan
# 4030 nan nan
# 4040 7 мин. nan
# 4050 nan nan
# 4060 17 мин. nan
# 4070 32 мин. nan
# 4080 30 мин. nan
# 4090 nan nan
# 4100 32 мин. nan
# 4110 35 мин. nan
# 4120 36 мин. nan
# 4130 nan nan
# 4140 5 мин. nan
# 4150 35 мин. nan
# 4160 nan nan
# 4170 nan nan
# 4180 7 мин. nan
# 4190 nan nan
# 4200 17 мин. nan
# 4210 32 мин. nan
# 4220 30 мин. nan
# 4230 nan nan
# 4240 32 мин. nan
# 4250 35 мин. nan
# 4260 36 мин. nan
# 4270 nan nan
# 4280 5 мин. nan
# 4290 35 мин. nan
# 4300 nan nan
# 4310 nan nan
# 4320 nan 18 мин.
# 4330 nan nan
# 4340 nan nan
# 4350 nan 7 ч. 45 мин.
# 4360 30 мин. nan
# 4370 nan nan
# 4380 nan 7 ч. 45 мин.
# 4390 35 мин. nan
# 4400 36 мин. nan
# 4410 nan nan
# 4420 5 мин. 14 мин.
# 4430 35 мин. nan
# 4440 nan nan
# 4450 nan nan
# 4460 7 мин. nan
# 4470 nan nan
# 4480 nan 1 час. 31 мин.
# 4490 32 мин. nan
# 4500 nan nan
# 4510 nan nan
# 4520 32 мин. nan
# 4530 35 мин. nan
# 4540 nan 1 час. 31 мин.
# 4550 nan nan
# 4560 5 мин. nan
# 4570 nan 1 час. 19 мин.
# 4580 nan nan
# 4590 nan nan
# 4600 nan 18 мин.
# 4610 nan nan
# 4620 17 мин. nan
# 4630 nan 7 ч. 45 мин.
# 4640 nan 42 мин.
# 4650 nan nan
# 4660 nan 7 ч. 45 мин.
# 4670 nan 1 час. 26 мин.
# 4680 36 мин. nan
# 4690 nan nan
# 4700 nan 14 мин.
# 4710 35 мин. nan
# 4720 nan nan
# 4730 nan nan
# 4740 nan 18 мин.
# 4750 nan nan
# 4760 nan 1 час. 31 мин.
# 4770 32 мин. nan
# 4780 30 мин. nan
# 4790 nan nan
# 4800 32 мин. nan
# 4810 35 мин. nan
# 4820 nan 1 час. 31 мин.
# 4830 nan nan
# 4840 5 мин. nan
# 4850 nan 1 час. 19 мин.
# 4860 nan nan
# 4870 nan nan
# 4880 nan 18 мин.
# 4890 nan nan
# 4900 17 мин. nan
# 4910 nan 7 ч. 45 мин.
# 4920 nan 42 мин.
# 4930 nan nan
# 4940 nan 7 ч. 45 мин.
# 4950 nan 1 час. 26 мин.
# 4960 nan 1 час. 31 мин.
# 4970 nan nan
# 4980 nan 14 мин.
# 4990 nan 1 час. 19 мин.
# 5000 nan nan
# 5010 nan nan
# 5020 nan 18 мин.
# 5030 nan nan
# 5040 nan 1 час. 31 мин.
# 5050 nan 7 ч. 45 мин.
# 5060 nan 42 мин.
# 5070 nan nan
# 5080 nan 7 ч. 45 мин.
# 5090 nan 1 час. 26 мин.
# 5100 nan 1 час. 31 мин.
# 5110 nan nan
# 5120 5 мин. nan
# 5130 nan 1 час. 19 мин.
# 5140 nan nan
# 5150 nan nan
# 5160 7 мин. nan
# 5170 nan nan
# 5180 17 мин. nan
# 5190 32 мин. nan
# 5200 nan 42 мин.
# 5210 nan nan
# 5220 32 мин. nan
# 5230 nan 1 час. 26 мин.
# 5240 nan 1 час. 31 мин.
# 5250 nan nan
# 5260 nan 14 мин.
# 5270 nan 1 час. 19 мин.
# 5280 nan nan
# 5290 nan nan
# 5300 nan 18 мин.
# 5310 nan nan
# 5320 17 мин. 1 час. 31 мин.
# 5330 32 мин. nan
# 5340 nan 42 мин.
# 5350 nan nan
# 5360 32 мин. nan
# 5370 nan 1 час. 26 мин.
# 5380 nan 1 час. 31 мин.
# 5390 nan nan
# 5400 nan 14 мин.
# 5410 nan 1 час. 19 мин.
# 5420 nan nan
# 5430 nan nan
# 5440 nan 18 мин.
# 5450 nan nan
# 5460 17 мин. nan
# 5470 nan 7 ч. 45 мин.
# 5480 30 мин. 42 мин.
# 5490 nan nan
# 5500 nan 7 ч. 45 мин.
# 5510 35 мин. nan
# 5520 36 мин. nan
# 5530 nan nan
# 5540 5 мин. nan
# 5550 35 мин. nan
# 5560 nan nan
# 5570 nan nan
# 5580 7 мин. nan
# 5590 nan nan
# 5600 17 мин. 1 час. 31 мин.
# 5610 32 мин. 7 ч. 45 мин.
# 5620 30 мин. nan
# 5630 nan nan
# 5640 32 мин. 7 ч. 45 мин.
# 5650 35 мин. nan
# 5660 36 мин. nan
# 5670 nan nan
# 5680 5 мин. nan
# 5690 35 мин. nan
# 5700 nan nan
# 5710 nan nan
# 5720 7 мин. nan
# 5730 nan nan
# 5740 17 мин. 1 час. 31 мин.
# 5750 32 мин. 7 ч. 45 мин.
# 5760 30 мин. nan
# 5770 nan nan
# 5780 32 мин. 7 ч. 45 мин.
# 5790 35 мин. nan
# 5800 nan 1 час. 31 мин.
# 5810 nan nan
# 5820 5 мин. nan
# 5830 nan 1 час. 19 мин.
# 5840 nan nan
# 5850 nan nan
# 5860 nan 18 мин.
# 5870 nan nan
# 5880 nan 1 час. 31 мин.
# 5890 32 мин. 7 ч. 45 мин.
# 5900 nan 42 мин.
# 5910 nan nan
# 5920 32 мин. 7 ч. 45 мин.
# 5930 nan 1 час. 26 мин.
# 5940 nan 1 час. 31 мин.
# 5950 nan nan
# 5960 nan 14 мин.
# 5970 nan 1 час. 19 мин.
# 5980 nan nan
# 5990 nan nan
# 6000 nan 18 мин.
# 6010 nan nan
# 6020 nan 1 час. 31 мин.
# 6030 32 мин. 7 ч. 45 мин.
# 6040 nan 42 мин.
# 6050 nan nan
# 6060 32 мин. 7 ч. 45 мин.
# 6070 nan 1 час. 26 мин.
# 6080 36 мин. nan
# 6090 nan nan
# 6100 5 мин. nan
# 6110 nan 1 час. 19 мин.
# 6120 nan nan
# 6130 nan nan
# 6140 7 мин. nan
# 6150 nan nan
# 6160 17 мин. nan
# 6170 32 мин. nan
# 6180 30 мин. nan
# 6190 nan nan
# 6200 32 мин. nan
# 6210 35 мин. nan
# 6220 36 мин. nan
# 6230 nan nan
# 6240 5 мин. nan
# 6250 35 мин. nan
# 6260 nan nan
# 6270 nan nan
# 6280 7 мин. 18 мин.
# 6290 nan nan
# 6300 17 мин. 1 час. 31 мин.
# 6310 32 мин. 7 ч. 45 мин.
# 6320 nan 42 мин.
# 6330 nan nan
# 6340 32 мин. 7 ч. 45 мин.
# 6350 nan 1 час. 26 мин.
# 6360 nan 1 час. 31 мин.
# 6370 nan nan
# 6380 nan 14 мин.
# 6390 35 мин. 1 час. 19 мин.
# 6400 nan nan
# 6410 nan nan
# 6420 7 мин. 18 мин.
# 6430 nan nan
# 6440 17 мин. 1 час. 31 мин.
# 6450 32 мин. 7 ч. 45 мин.
# 6460 nan 42 мин.
# 6470 nan nan
# 6480 32 мин. 7 ч. 45 мин.
# 6490 nan 1 час. 26 мин.
# 6500 nan 1 час. 31 мин.
# 6510 nan nan
# 6520 nan 14 мин.
# 6530 35 мин. 1 час. 19 мин.
# 6540 nan nan
# 6550 nan nan
# 6560 7 мин. 18 мин.
# 6570 nan nan
# 6580 17 мин. 1 час. 31 мин.
# 6590 32 мин. 7 ч. 45 мин.
# 6600 nan 42 мин.
# 6610 nan nan
# 6620 32 мин. 7 ч. 45 мин.
# 6630 nan 1 час. 26 мин.
# 6640 nan 1 час. 31 мин.
# 6650 nan nan
# 6660 nan 14 мин.
# 6670 35 мин. 1 час. 19 мин.
# 6680 nan nan
# 6690 nan nan
# 6700 7 мин. nan
# 6710 nan nan
# 6720 17 мин. 1 час. 31 мин.
# 6730 32 мин. nan
# 6740 30 мин. nan
# 6750 nan nan
# 6760 32 мин. nan
# 6770 35 мин. nan
# 6780 36 мин. nan
# 6790 nan nan
# 6800 nan 14 мин.
# 6810 35 мин. nan
# 6820 nan nan
# 6830 nan nan
# 6840 nan 18 мин.
# 6850 nan nan
# 6860 nan 1 час. 31 мин.
# 6870 nan 7 ч. 45 мин.
# 6880 nan 42 мин.
# 6890 nan nan
# 6900 nan 7 ч. 45 мин.
# 6910 nan 1 час. 26 мин.
# 6920 nan 1 час. 31 мин.
# 6930 nan nan
# 6940 nan 14 мин.
# 6950 nan 1 час. 19 мин.
# 6960 nan nan
# 6970 nan nan
# 6980 nan 18 мин.
# 6990 nan nan
# 7000 nan 1 час. 31 мин.
# 7010 nan 7 ч. 45 мин.
# 7020 nan 42 мин.
# 7030 nan nan
# 7040 nan 7 ч. 45 мин.
# 7050 nan 1 час. 26 мин.
# 7060 nan 1 час. 31 мин.
# 7070 nan nan
# 7080 nan 14 мин.
# 7090 nan 1 час. 19 мин.
# 7100 nan nan
# 7110 nan nan
# 7120 nan 18 мин.
# 7130 nan nan
# 7140 nan 1 час. 31 мин.
# 7150 nan 7 ч. 45 мин.
# 7160 nan 42 мин.
# 7170 nan nan
# 7180 nan 7 ч. 45 мин.
# 7190 nan 1 час. 26 мин.
# 7200 nan 1 час. 31 мин.
# 7210 nan nan
# 7220 nan 14 мин.
# 7230 nan 1 час. 19 мин.
# 7240 nan nan
# 7250 nan nan
# 7260 nan 18 мин.
# 7270 nan nan
# 7280 nan 1 час. 31 мин.
# 7290 nan 7 ч. 45 мин.
# 7300 nan 42 мин.
# 7310 nan nan
# 7320 nan 7 ч. 45 мин.
# 7330 nan 1 час. 26 мин.
# 7340 nan 1 час. 31 мин.
# 7350 nan nan
# 7360 nan 14 мин.
# 7370 nan 1 час. 19 мин.
# 7380 nan nan
# 7390 nan nan
# 7400 nan 18 мин.
# 7410 nan nan
# 7420 nan 1 час. 31 мин.
# 7430 nan 7 ч. 45 мин.
# 7440 nan 42 мин.
# 7450 nan nan
# 7460 nan 7 ч. 45 мин.
# 7470 nan 1 час. 26 мин.
# 7480 nan 1 час. 31 мин.
# 7490 nan nan
# 7500 nan 14 мин.
# 7510 nan 1 час. 19 мин.
# 7520 nan nan
# 7530 nan nan
# 7540 nan 18 мин.
# 7550 nan nan
# 7560 nan 1 час. 31 мин.
# 7570 nan 7 ч. 45 мин.
# 7580 nan 42 мин.
# 7590 nan nan
# 7600 nan 7 ч. 45 мин.
# 7610 nan 1 час. 26 мин.
# 7620 nan 1 час. 31 мин.
# 7630 nan nan
# 7640 nan 14 мин.
# 7650 nan 1 час. 19 мин.
# 7660 nan nan
# 7670 nan nan
# 7680 nan 18 мин.
# 7690 nan nan
# 7700 nan 1 час. 31 мин.
# 7710 nan 7 ч. 45 мин.
# 7720 nan 42 мин.
# 7730 nan nan
# 7740 nan 7 ч. 45 мин.
# 7750 nan 1 час. 26 мин.
# 7760 nan 1 час. 31 мин.
# 7770 nan nan
# 7780 nan 14 мин.
# 7790 nan 1 час. 19 мин.
# 7800 nan nan
# 7810 nan nan
# 7820 nan 18 мин.
# 7830 nan nan
# 7840 17 мин. nan
# 7850 nan 7 ч. 45 мин.
# 7860 30 мин. nan
# 7870 nan nan
# 7880 nan 7 ч. 45 мин.
# 7890 35 мин. nan
# 7900 36 мин. nan
# 7910 nan nan
# 7920 5 мин. nan
# 7930 35 мин. nan
# 7940 nan nan
# 7950 nan nan
# 7960 7 мин. nan
# 7970 nan nan
# 7980 nan 1 час. 31 мин.
# 7990 32 мин. nan
# 8000 nan 42 мин.
# 8010 nan 1 час. 31 мин.
# 8020 32 мин. nan
# 8030 35 мин. nan
# 8040 nan 1 час. 31 мин.
# 8050 nan nan
# 8060 5 мин. nan
# 8070 nan 1 час. 19 мин.
# 8080 nan nan
# 8090 nan nan
# 8100 nan 18 мин.
# 8110 nan nan
# 8120 17 мин. nan
# 8130 nan 7 ч. 45 мин.
# 8140 nan 42 мин.
# 8150 nan nan
# 8160 nan 7 ч. 45 мин.
# 8170 nan 1 час. 26 мин.
# 8180 36 мин. nan
# 8190 nan nan
# 8200 nan 14 мин.
# 8210 35 мин. nan
# 8220 nan nan
# 8230 nan nan
# 8240 nan 18 мин.
# 8250 nan nan
# 8260 17 мин. 1 час. 31 мин.
# 8270 32 мин. nan
# 8280 30 мин. nan
# 8290 nan nan
# 8300 32 мин. nan
# 8310 35 мин. nan
# 8320 nan 1 час. 31 мин.
# 8330 nan nan
# 8340 5 мин. nan
# 8350 35 мин. nan
# 8360 nan nan
# 8370 nan nan
# 8380 nan 18 мин.
# 8390 nan nan
# 8400 17 мин. nan
# 8410 nan 7 ч. 45 мин.
# 8420 nan 42 мин.
# 8430 nan nan
# 8440 32 мин. nan
# 8450 nan 1 час. 26 мин.
# 8460 36 мин. nan
# 8470 nan nan
# 8480 nan 14 мин.
# 8490 35 мин. 1 час. 19 мин.
# 8500 nan nan
# 8510 nan nan
# 8520 nan 18 мин.
# 8530 nan nan
# 8540 nan 1 час. 31 мин.
# 8550 nan 7 ч. 45 мин.
# 8560 30 мин. nan
# 8570 nan nan
# 8580 32 мин. nan
# 8590 35 мин. nan
# 8600 nan 1 час. 31 мин.
# 8610 nan nan
# 8620 nan 14 мин.
# 8630 nan 1 час. 19 мин.
# 8640 nan nan
# 8650 nan nan
# 8660 7 мин. nan
# 8670 nan nan
# 8680 17 мин. nan
# 8690 32 мин. nan
# 8700 30 мин. nan
# 8710 nan nan
# 8720 nan 7 ч. 45 мин.
# 8730 nan 1 час. 26 мин.
# 8740 nan 1 час. 31 мин.
# 8750 nan nan
# 8760 nan 14 мин.
# 8770 nan 1 час. 19 мин.
# 8780 nan nan
# 8790 nan nan
# 8800 nan 18 мин.
# 8810 nan nan
# 8820 nan 1 час. 31 мин.
# 8830 nan 7 ч. 45 мин.
# 8840 nan 42 мин.
# 8850 nan nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-2ed4709c3a46> in <module>()
#       4 for i in range(len(metro)):
#       5     try:
# ----> 6         walk_dist.append( vremia_finder(str(latitude[i])+','+str(longtitude[i]),metro[i],"walking") )
#       7     except Exception:
#       8         walk_dist.append(np.nan)
#
# <ipython-input-50-40f6b5b5b9e3> in vremia_finder(place_one, place_two, sposob)
#       7
#       8     # сделали запрос и вытащили инфу
# ----> 9     response = requests.get(itog_url)
#      10     content = response.json()
#      11     return(content['rows'][0]['elements'][0]['duration']['text'])
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     374                     decode_content=False,
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#     378
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558             httplib_response = self._make_request(conn, method, url,
#     559                                                   timeout=timeout_obj,
# --> 560                                                   body=body, headers=headers)
#     561
#     562             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     352         # conn.request() calls httplib.*.request, not the method in
#     353         # urllib3.request. It also calls makefile (recv) on the socket.
# --> 354         conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# /usr/lib/python3.5/http/client.py in request(self, method, url, body, headers)
#    1104     def request(self, method, url, body=None, headers={}):
#    1105         """Send a complete request to the server."""
# -> 1106         self._send_request(method, url, body, headers)
#    1107
#    1108     def _set_content_length(self, body, method):
#
# /usr/lib/python3.5/http/client.py in _send_request(self, method, url, body, headers)
#    1149             # default charset of iso-8859-1.
#    1150             body = _encode(body, 'body')
# -> 1151         self.endheaders(body)
#    1152
#    1153     def getresponse(self):
#
# /usr/lib/python3.5/http/client.py in endheaders(self, message_body)
#    1100         else:
#    1101             raise CannotSendHeader()
# -> 1102         self._send_output(message_body)
#    1103
#    1104     def request(self, method, url, body=None, headers={}):
#
# /usr/lib/python3.5/http/client.py in _send_output(self, message_body)
#     932         del self._buffer[:]
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#     936             self.send(message_body)
#
# /usr/lib/python3.5/http/client.py in send(self, data)
#     875         if self.sock is None:
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#     879                 raise NotConnected()
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     160
#     161     def connect(self):
# --> 162         conn = self._new_conn()
#     163         self._prepare_conn(conn)
#     164
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     135         try:
#     136             conn = connection.create_connection(
# --> 137                 (self.host, self.port), self.timeout, **extra_kw)
#     138
#     139         except SocketTimeout as e:
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      65         host = host.strip('[]')
#      66     err = None
# ---> 67     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#      68         af, socktype, proto, canonname, sa = res
#      69         sock = None
#
# /usr/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     730     # and socket type values to enum constants.
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#     734         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %% [markdown]
# Цикл работает довольно быстро и обрубается как только число отведённых нам запросов заканчивается.
#
# ```
# {'destination_addresses': [],
#  'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_',
#  'origin_addresses': [],
#  'rows': [],
#  'status': 'OVER_QUERY_LIMIT'}
#
# ```
#
#
# Что нам с этим делать?
#
# * Выход первый: качать несколько дней, качать с разных компов
# * Выход второй: обмануть гугл, подключив кусок кода, который динамически меняет наш IP
#
# Но об этом чуть позже...  Когда мы станем совсем продвинутыми юзерами...
