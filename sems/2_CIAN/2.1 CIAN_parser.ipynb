# %% [markdown]
# <img src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/cian_main_theme.png" height="1000" width="1000">
#
# <img align="center" src="https://www.cian.ru/promo/adv/assets/images/logo.svg" height="300" width="300">
#
#
# # <center> Грабёж, разбой и другие незаконные деяния с помощью Python. <br> <br> Наше первое дело. Грабим ЦИАН.   </center>
# ---------

# %% [markdown]
# ## Что мы хотим получить?
#
# Итак, нам нужно распарсить [CIAN.ru](http://cian.ru) и получить из него как минимум следующий список переменных по каждой квартирке из каждого округа Москвы
#
# - **N** – номер квартиры по порядку
# - **Rooms** – число комнат
# - **Price** – цена
# - **Totsp** – общая площадь квартиры, кв. м.
# - **Livesp** – жилая площадь квартиры, кв. м.
# - **Kitsp** – площадь кухни, кв. м.
# - **Dist** – расстояние от центра в км. (можно по Пифагору)
# - **Metrdist** – расстояние до метро в минутах
# - **Walk** – 1 – если пешком от метро, 0 – если на транспорте
# - **Brick** – 1 – кирпичный/монолит/жб, 0 – другой
# - **Tel** – 1 – если есть, 0 – нет
# - **Bal** – 1 – есть балкон/лоджия, 0 – нет
# - **Floor** – номер этажа, на котором расположена квартира
# - **Nfloors** – всего этажей в доме
# - **New** – 1 – первичный рынок, 0 - вторичка
# - ** И другие**
# ---
#
#
# ## Для чего всё это нужно?
#
#
#
# **Во-первых**, написать свой первый (второй, третий...N+1) парсер, познакомиться получше с питоном и некоторыми его библиотеками.
#
# **Во-вторых**, получив такой датасетик можно будет заняться его обработкой, очисткой, визуализацией, и прочими радостями, которые обязательно сопровождают работу с данными
#
# **В-третьих**, на основании обработанных данных можно строить модели! Например, объясняющие цену квартирки, что поможет понять, кому и где на Руси жить хорошо, или по поиску аномалий и выбросов, чтобы узнать, где у нас есть недооцененное/переоцененное жильё.
#
# **В-четвёртых**, от того, что происходит ниже иногда хочется кричать.
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/2.png" height="600" width="600">
#
#
# ---

# %% [markdown]
# ## 1. Пара зубодробительных определений
#
# * **Парсер** – это скрипт, который грабит информацию с сайта
# * **Краулер** – это часть парсера, которая бродит по ссылкам
# * **Краулинг** – это переход по страницам и ссылкам
# * **Скрапинг** – это сбор данных со страниц
# * **Парсинг** – это сразу и то, и другое!
#
# ## 2. Что такое HTML?
#
# **HTML (HyperText Markup Language)**  — это такой же язык разметки как Markdown или LaTeX. Он является стандартным для написания различных сайтов. Команды в таком языке называются **тэгами**. Если быть совсем дотошным, то HTML является чпстным случаем некоего страшного стандарта SGML. Другим частным случаем является XML, с которым мы ещё встретимся.
#
# Если открыть абсолютно любой сайт, нажать на правую кнопку мышки, а после нажать `View page source`, то перед вами предстанет HTML скелет этого сайта.
#
# Можно увидеть, что HTML-страница это ни что иное как набор вложенных тегов. Можно заметить, например, следующие теги:
#
# - `<title>` – заголовок страницы
# - `<h1>…<h6>` – заголовки разных уровней
# - `<p>` – абзац (paragraph)
# - `<div>` – выделения фрагмента документа с целью изменения вида содержимого
# - `<table>` – прорисовка таблицы
# - `<tr>` – разделитель для строк в таблице
# - `<td>` – разделитель для столбцов в таблице
# - `<b>` – устанавливает жирное начертание шрифта
#
# Обычно команда `< ... >` открывает тег, а `</ ... >` закрывает его. Все, что находится между этими двумя командами подчиняется правилу, которое диктует тег. Например, все, что находится между `<p>` и `</p>` – это отдельный абзац.
#
# Теги образуют своеобразное дерево с корнем в теге `<html>` и разбивают страницу на разные логические кусочки. У каждого тега есть свои потомки (дети) - те теги, которые вложены в него и свои родители.
#
# Например, HTML-древо страницы может выглядеть вот так:
#
#     <html>
#     <head> Заголовок </head>
#     <body>
#         <div>
#             Первый кусок текста со своими свойствами
#         </div>
#         <div>
#             Второй кусок текста
#                 <b>
#                     Третий, жирный кусок
#                 </b>
#         </div>
#         Четвёртый кусок текста
#     </body>
#     </html>
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/tree.png" height="500" width="500">
#
# Можно работать с этим html как с тексом, а можно как с деревом. Обход этого дерева и есть парсинг веб-страницы. Мы всего лишь будем находить нужные нам узлы среди всего этого разнообразия и забирать из них информацию!
#
# Вручную обходить эти деревья не очень приятно, поэтому есть специальные языки для обхода деревьев.
#
# - CSS-селектор
# - XPath
# - Всякие разные библиотеки для всяких разных языков, например, BeautifulSoup для питона.

# %% [markdown]
# ## 3. Как работает интернет или сказ о Бобе и Алисе

# %% [markdown]
# Алиса --- это веб-сервер. Боб --- это обычный компьютер. Боб хочет подсоединиться к Алисе. Как это происходит:
#
# * Боб отправляет Алисе последовательности из нулей и единиц. 1 - высокое напряжение, 0 - низкое. Эти последовательности шифруют просьбу Боба подконектиться к Алисе.
#
# * Маршрутиризатор Боба собирает все эти последовательности в пакет и отправляет на IP-адрес Алисы.
#
# * Пакет Боба проходит несколько промежуточных серверов, которые направляют его к Алисе.
#
# * Сервер Алисы получает пакет Боба по своему IP
#
# * Сервер Алисы считывает порт назначения пакета. Грубо говоря, IP-адрес, это адрес дома. Порт - это квартира. Пакет передается в веб-сервер.
#
# * Веб-сервер получает запрос на какой-то файл и находит его. Файл связывается в новый пакет и через маршрутиризатор отправляется Бобу. Ура! У нас есть интернет.
#
# Обратите внимание, что в этой схема браузер использовался ... нигде. Браузер - это относительно недавнее изобретение в истории интернета. Браузер - это довольно полезное приложение для создания пакетов информации.

# %% [markdown]
# ## 4. Наш первый запрос
#
# Доступ к веб-станицам позволяет получать модуль `requests`. Подгрузим его. Если у вас не установлен этот модуль, то придётся напрячься и установить, прописав в терминале `pip3 install requests`.

# %%
import requests

# %% [markdown]
# Делаем запрос по ссылке `mainpage` и получаем ответ на свой запрос!

# %%
main_page = 'https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&region=1&room1=1&room2=1'
response = requests.get(main_page)
response
# Out:
# <Response [200]>

# %% [markdown]
# Благословенный 200 ответ - соединение установлено и данные получены, всё чудесно! Если попытаться перейти на несуществующую страницу, то можно получить, например, знаменитую ошибку 404, которая говорит о том, что клиент (Боб) был в состоянии общаться с сервером (Алисой), но не может найти данные согласно запросу.

# %%
requests.get('https://www.cian.ru/jhgrgoiogr')
# Out:
# <Response [404]>

# %% [markdown]
# Вернёмся к успешному запросу и посмотрим что же такого мы там получили...

# %%
html = response.content
html
# Out:
# b'\n\n<!DOCTYPE html>\n<html class="no-touch" >\n    <head>\n        \n\n<!-- Google Analytics Content Experiment code -->\n<script>function utmx_section(){}function utmx(){}(function(){var\nk=\'57940811-35\',d=document,l=d.location,c=d.cookie;\nif(l.search.indexOf(\'utm_expid=\'+k)>0)return;\nfunction f(n){if(c){var i=c.indexOf(n+\'=\');if(i>-1){var j=c.\nindexOf(\';\',i);return escape(c.substring(i+n.length+1,j<0?c.\nlength:j))}}}var x=f(\'__utmx\'),xx=f(\'__utmxx\'),h=l.hash;d.write(\n\'<sc\'+\'ript src="\'+\'http\'+(l.protocol==\'https:\'?\'s://ssl\':\n\'://www\')+\'.google-analytics.com/ga_exp.js?\'+\'utmxkey=\'+k+\n\'&utmx=\'+(x?x:\'\')+\'&utmxx=\'+(xx?xx:\'\')+\'&utmxtime=\'+new Date().\nvalueOf()+(h?\'&utmxhash=\'+escape(h.substr(1)):\'\')+\n\'" type="text/javascript" charset="utf-8"><\\/sc\'+\'ript>\')})();\n</script><script>utmx(\'url\',\'A/B\');</script>\n<!-- End of Google Analytics Content Experiment code -->\n\n\n        \n    \n            <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n            <meta name="google-site-verification" content="Eig23WXwvPZu3gp9EYVreR61rG4TX1bHQDEG0Di5ZSE"/>\n            <meta name="apple-mobile-web-app-title" content="\xd0\xa6\xd0\x98\xd0\x90\xd0\x9d">\n        \n    <meta name="apple-itunes-app" content="app-id=911804296, app-argument=https://www.cian.ru/cat.php?deal_type=sale&amp;engine_version=2&amp;offer_type=flat&amp;region=1&amp;room1=1&amp;room2=1">\n\n    <meta name="viewport" content="width=1024, initial-scale=1">\n\n\n        \n            <meta property="og:type" content="website"/>\n            <meta property="og:site_name" content="CIAN"/>\n            \n            \n            \n                <meta property="og:image" content="https://www.cian.ru/static/images/cian-logo-cyrillic-vertical.png" />\n            \n            \n        \n\n        \n            <title>\n                \xd0\x9a\xd1\x83\xd0\xbf\xd0\xb8\xd1\x82\xd1\x8c 1, 2-\xd0\xba\xd0\xbe\xd0\xbc\xd0\xbd\xd0\xb0\xd1\x82\xd0\xbd\xd1\x83\xd1\x8e \xd0\xba\xd0\xb2\xd0\xb0\xd1\x80\xd1\x82\xd0\xb8\xd1\x80\xd1\x83 \xd0\xb2 \xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb5 \xe2\x80\x94 93 400 \xd0\xbe\xd0\xb1\xd1\x8a\xd1\x8f\xd0\xb2\xd0\xbb\xd0\xb5\xd0\xbd\xd0\xb8\xd0\xb9\n            </title>\n            \n                \n                    <meta name="description" content="\xd0\x9f\xd1\x80\xd0\xbe\xd0\xb4\xd0\xb0\xd0\xb6\xd0\xb0 1, 2-\xd0\xba\xd0\xbe\xd0\xbc\xd0\xbd\xd0\xb0\xd1\x82\xd0\xbd\xd1\x8b\xd1\x85 \xd0\xba\xd0\xb2\xd0\xb0\xd1\x80\xd1\x82\xd0\xb8\xd1\x80 \xd0\xb2 \xd0\x9c\xd0\xbe\xd1\x81\xd0\xba\xd0\xb2\xd0\xb5 \xe2\x80\x94 93 400 \xd0\xbe\xd0\xb1\xd1\x8a\xd1\x8f\xd0\xb2\xd0\xbb\xd0\xb5\xd0\xbd\xd0\xb8\xd0\xb9" />\n                \n            \n            \n                \n            \n            \n            \n                <meta name="robots" content="noindex" />\n                <meta name="googlebot" content="noindex" />\n            \n            \n        \n\n        <link rel="icon" href="/static/images/favicon.ico" type="image/x-icon"/>\n\n        \n    <!--[if lte IE 10]>\n        <link rel="stylesheet" type="text/css" href="/static/fonts/webfont_ie.css" media="all"/>\n    <![endif]-->\n\n    <link rel="stylesheet" type="text/css" href="/static/newbuild/dist/serp.40208471dedc.css" media="all"/>\n\n\n        <script type="text/javascript" src="//sentry.cian.site/sentry.min.js"></script>\n        \n    \n\n\n\n    <script type="text/javascript" src="//wurfl.io/wurfl.js"></script>\n    <script src="/static/scripts/adfox.asyn.code.ver3.js"></script>\n    <script src="/static/scripts/adfox.asyn.code.scroll.js"></script>\n    <script src="/static/scripts/af.min.js"></script>\n    <script type="text/javascript">if (typeof window.cianConfig === "undefined") {window.cianConfig = {}}</script>\n    <script>\n        window.cianConfig.user = {\n            isAuthenticated: false\n        }\n         window.cianConfig.admitad = {\n            campaign_code: {\n       ...

# %% [markdown]
# Можно ли работать с этим ужасом? Ну... на самом деле да, но лучше не пробовать. Давайте сделаем всё красиво и используем для этого красивый суп!

# %% [markdown]
# ## 5. Красивый суп
#
# <img align="center" src="https://www.crummy.com/software/BeautifulSoup/10.1.jpg" height="200" width="200">
#
# Пакет **[`bs4`](https://www.crummy.com/software/BeautifulSoup/)**, a.k.a **BeautifulSoup** был назван в честь стишка про красивый суп из Алисы в стране чудес. В чём был смысл этого стишка, я не помню. Однако я помню зачем нужен этот пакет.
#
# Красивый суп. Эта совершенно волшебная библиотека, которая из сырого и необработанного HTML (или XML) кода страницы выдаст вам структурированный массив данных, по которому очень удобно искать необходимые теги, классы, атрибуты, тексты и прочие элементы веб страниц.
#
# > Пакет под названием `BeautifulSoup` — скорее всего, не то, что вам нужно. Это третья версия (*Beautiful Soup 3*), а мы будем использовать четвертую. Так что нам нужен пакет `beautifulsoup4`. Чтобы было совсем весело, при импорте нужно указывать другое название пакета — `bs4`, а импортировать функцию под названием `BeautifulSoup`. В общем, сначала легко запутаться, но эти трудности нужно преодолеть однажды, а потом будет проще.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Передадим функции `BeautifulSoup` текст веб-страницы, которую мы недавно получили.

# %%
soup = BeautifulSoup(html,'html.parser') # В опции также можно указать lxml, 
                                         # если предварительно установить одноименный пакет
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-touch">
# <head>
# <!-- Google Analytics Content Experiment code -->
# <script>function utmx_section(){}function utmx(){}(function(){var
# k='57940811-35',d=document,l=d.location,c=d.cookie;
# if(l.search.indexOf('utm_expid='+k)>0)return;
# function f(n){if(c){var i=c.indexOf(n+'=');if(i>-1){var j=c.
# indexOf(';',i);return escape(c.substring(i+n.length+1,j<0?c.
# length:j))}}}var x=f('__utmx'),xx=f('__utmxx'),h=l.hash;d.write(
# '<sc'+'ript src="'+'http'+(l.protocol=='https:'?'s://ssl':
# '://www')+'.google-analytics.com/ga_exp.js?'+'utmxkey='+k+
# '&utmx='+(x?x:'')+'&utmxx='+(xx?xx:'')+'&utmxtime='+new Date().
# valueOf()+(h?'&utmxhash='+escape(h.substr(1)):'')+
# '" type="text/javascript" charset="utf-8"><\/sc'+'ript>')})();
# </script><script>utmx('url','A/B');</script>
# <!-- End of Google Analytics Content Experiment code -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Eig23WXwvPZu3gp9EYVreR61rG4TX1bHQDEG0Di5ZSE" name="google-site-verification"/>
# <meta content="ЦИАН" name="apple-mobile-web-app-title">
# <meta content="app-id=911804296, app-argument=https://www.cian.ru/cat.php?deal_type=sale&amp;engine_version=2&amp;offer_type=flat&amp;region=1&amp;room1=1&amp;room2=1" name="apple-itunes-app">
# <meta content="width=1024, initial-scale=1" name="viewport">
# <meta content="website" property="og:type"/>
# <meta content="CIAN" property="og:site_name"/>
# <meta content="https://www.cian.ru/static/images/cian-logo-cyrillic-vertical.png" property="og:image"/>
# <title>
#                 Купить 1, 2-комнатную квартиру в Москве — 93 400 объявлений
#             </title>
# <meta content="Продажа 1, 2-комнатных квартир в Москве — 93 400 объявлений" name="description"/>
# <meta content="noindex" name="robots"/>
# <meta content="noindex" name="googlebot"/>
# <link href="/static/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <!--[if lte IE 10]>
#         <link rel="stylesheet" type="text/css" href="/static/fonts/webfont_ie.css" media="all"/>
#     <![endif]-->
# <link href="/static/newbuild/dist/serp.40208471dedc.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//sentry.cian.site/sentry.min.js" type="text/javascript"></script>
# <script src="//wurfl.io/wurfl.js" type="text/javascript"></script>
# <script src="/static/scripts/adfox.asyn.code.ver3.js"></script>
# <script src="/static/scripts/adfox.asyn.code.scroll.js"></script>
# <script src="/static/scripts/af.min.js"></script>
# <script type="text/javascript">if (typeof window.cianConfig === "undefined") {window.cianConfig = {}}</script>
# <script>
#         window.cianConfig.user = {
#             isAuthenticated: false
#         }
#          window.cianConfig.admitad = {
#             campaign_code: {
#               lead: '161a0791df',
#               subscription: 'f28743aabc'
#             },
#             client_id: '',
#             old_consumer: '0',
#             action_code: 1,
#             tariffcode: 1,
#         };
#     </script>
# <script src="/static/scripts/serp-scripts.min.js" type="text/javascript"></script>
# <script data-aload="/static/scripts/serp-scripts-async.min.js" type="text/javascript"></script>
# <!-- Требуется для расхлопа с телефонами застройщика для шапки ЖК -->
# <script src="/scripts-bundle/cian/common.js?v=11.2-41" type="text/javascript"></script>
# <script>
#         if (typeof window.cianConfig === "undefined") {
#             window.cianConfig = {};
#         }
#         window._userInfo = {
#
#         };
#         window.cianConfig.criteo = {
#             site_type: 'd',
#
#             new_customer: '1'
#         };
#         window.cianConfig['query'] = {"region": {"type": "terms", "value": [1]}, "_type": "flatsale", "engine_version": {"type": "term", "value": 2}, "room": {"type": "terms", "value": [1, 2]}};
#         window.cianConfig['countryCodes'] = [{"countryName": "\u0420\u043e\u0441\u0441\u0438\u044f", "countryId": 138, "countryPhoneCode": "+7"}, {"countryName": "\u0410\u0431\u0445\u0430\u0437\u0438\u044f", "countryId": 202, "countryPhoneCode": "+995"}, {"countryName": "\u0410\u0432\u0441\u0442\u0440\u0430\u043b\u0438\u044f", "countryId": 1, "countryPhoneCode": "+61"}, {"countryName": "\u0410\u0432\u0441\u0442\u0440\u0438\u044f", "countryId": 2, "countryPhoneCode": "+43"}, {"countryName": "\u0410\u0437\u0435\u0440\u0431\u0430\u0439\u0434\u0436\u0430\u043d", "countryId": 3, "countryPhoneCode": "+994"}, {"countryName": "\u0410\u043b\u0431\u0430\u043d\u0438\u044f", "countryId": 4, "countryPhoneCode": "+355"}, {"countryName": "\u0410\u043b\u0436\u0438\u0440", "countryId": 5, "countryPhoneCode": "+21"}, {"countryName": "\u0410\u043d\u0433\u043e\u043b\u0430", "countryId": 6, "countryPhoneCode": "+244"}, {"countryName": "\u0410\u043d\u0434\u043e\u0440\u0440\u0430", "countryId": 7, "countryPhoneCode": "+376"}, {"countryName": "\u0410\u043d\u0442\u0438\u0433\u0443\u0430 \u0438 \u0411\u0430\u0440\u0431\u0443\u0434\u0430", "countryId": 8, "countryPhoneCode": null}, {"countryName": "\u0410\u0440\u0433\u0435\u043d\u0442\u0438\u043d\u0430", "countryId": 9, "countryPhoneCode": "+54"}, {"countryName": "\u0410\u0440\u043c\u0435\u043d\u0438\u044f", "countryId": 10, "countryPhoneCode": "+374"}, {"countryName": "\u0410\u0444\u0433\u0430\u043d\u0438\u0441\u0442\u0430\u043d", "countryId": 11, "countryPhoneCode": "+93"}, {"countryName": "\u0411\u0430\u0433\u0430\u043c\u0441\u043a\u0438\u0435 \u043e\u0441\u0442\u0440\u043e\u0432\u0430", "countryId": 12, "countryPhoneCode": "+1242"}, {"countryName": "\u0411\u0430\u043d\u0433\u043b\u0430\u0434\u0435\u0448", "countryId": 13, "countryPhoneCode": "+880"}, {"countryName": "\u0411\u0430\u0440\u0431\u0430\u0434\u043e\u0441", "countryId": 14, "countryPhoneCode": "+1246"}, {"countryName": "\u0411\u0430\u0445\u0440\u0435\u0439\u043d", "countryId": 15, "countryPhoneCode": "+973"}, {"countryName": "\u0411\u0435\u043b\u0430\u0440\u0443\u0441\u044c", "countryId": 16, "countryPhoneCode": "+375"}, {"countryName": "\u0411\u0435\u043b\u0438\u0437", "countryId": 17, "countryPhoneCode": "+501"}, {"countryName": "\u0411\u0435\u043b\u044c\u0433\u0438\u044f", "countryId": 18, "countryPhoneCode": "+32"}, {"countryName": "\u0411\u0435\u043d\u0438\u043d", "countryId": 19, "countryPhoneCode": "+229"}, {"countryName": "\u0411\u043e\u043b\u0433\u0430\u0440\u0438\u044f", "countryId": 20, "countryPhoneCode": "+359"}, {"countryName": "\u0411\u043e\u043b\u0438\u0432\u0438\u044f", "countryId": 21, "countryPhoneCode": "+591"}, {"countryName": "\u0411\u043e\u0441\u043d\u0438\u044f \u0438 \u0413\u0435\u0440\u0446\u0435\u0433\u043e\u0432\u0438\u043d\u0430", "countryId": 22, "countryPhoneCode": "+387"}, {"countryName": "\u0411\u043e\u0442\u0441\u0432\u0430\u043d\u0430", "countryId": 23, "countryPhoneCode": "+267"}, {"countryName": "\u0411\u0440\u0430\u0437\u0438\u043b\u0438\u044f", "countryId": 24, "countryPhoneCode": "+55"}, {"countryName": "\u0411\u0440\u0443\u043d\u0435\u0439", "countryId": 25, "countryPhoneCode": "+673"}, {"countryName": "\u0411\u0443\u0440\u043a\u0438\u043d\u0430-\u0424\u0430\u0441\u043e", "countryId": 26, "countryPhoneCode": null}, {"countryName": "\u0411\u0443\u0440\u0443\u043d\u0434\u0438", "countryId": 27, "countryPhoneCode": "+257"}, {"countryName": "\u0411\u0443\u0442\u0430\u043d", "countryId": 28, "countryPhoneCode": "+975"}, {"countryName": "\u0412\u0430\u043d\u0443\u0430\u0442\u0443", "countryId": 29, "countryPhoneCode": null}, {"countryName": "\u0412\u0430\u0442\u0438\u043a\u0430\u043d", "countryId": 30, "countryPhoneCode": null}, {"countryName": "\u0412\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f", "countryId": 31, "countryPhoneCode": "+44"}, {"countryName": "\u0412\u0435\u043d\u0433\u0440\u0438\u044f", "countryId": 32, "countryPhoneCode": "+36"}, {"countryName": "\u0412\u ...
#
#         var tags = [];
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         tags = tags.concat([]);
#         window._existingSearchTags = tags;
#
#
#             window._specialties = null;
#
#
#         window._similarOffersCount = 0;
#         window._offersCount = 93400;
#         window._bsCenterListUrl = "";
#         window._h1 = "Купить 1, 2\u002Dкомнатную квартиру в Москве";
#         window._landingHeader = {
#
#
#
#         };
#
#         window._gaQuerystring = "deal_type\u003Dsale\u0026engine_version\u003D2\u0026offer_type\u003Dflat\u0026region\u003D1\u0026room1\u003D1\u0026room2\u003D1";
#         window._is_new_search = true;
#         window._offers = {"152578760": {"highways": [], "colorized": true, "show_recidivist_popup": false, "deal_type": "sale", "showCallbackButton": true, "bedrooms_count": null, "premium": {"state": true}, "top3": false, "phone": "+7 964 779-94-00", "link": "/sale/flat/152578760/", "phone_data_layer": {"category": "sale/flat_old", "brand": "12538172/realtor_not_commerce", "variant": "premium/color", "id": 152578760, "position": 22, "price": 2390000, "quantity": 1}, "complain": {"text": "", "api": "/ajax/complaints/add/"}, "client_fee": null, "ga_event_action": "/sale/flat/mo_id=0/obl_id=1/city_id=204543/object_type=1/ga_obj_type=1/spec=none/from_developer=0", "is_payed": false, "is_excluded_from_action": false, "floors_count": 3, "total_area": 26.0, "export": {"pdf": {"link": "/export/pdf/sale/flat/152578760/"}, "docx": {"link": "/export/docx/sale/flat/152578760/"}}, "basic_profi_score": 0, "id": 152578760, "default_photo_index": 0, "without_client_fee": true, "floor": 2, "realty_id": "152578760", "note": {"text": "", "api": ["/ajax/sale/flat/notes"]}, "is_new_multioffer": false, "underground": [{"line_color": "CF0000", "is_transport": false, "is_walking": true, "name": "\u0421\u0430\u043b\u0430\u0440\u044c\u0435\u0432\u043e", "time": 9}], "category": 111, "added": {"strict": "\u0432\u0447\u0435\u0440\u0430, 17:31", "humanized": "\u0432\u0447\u0435\u0440\u0430"}, "description": "\u0421\u0442\u0443\u0434\u0438\u044f \u0421 \u0420\u0415\u041c\u041e\u041d\u0422\u041e\u041c (\u043b\u0430\u043c\u0438\u043d\u0430\u0442, \u043e\u0431\u043e\u0438, \u0441\u0430\u043d\u0442\u0435\u0445\u043d\u0438\u043a\u0430, \u044d\u043b\u0435\u043a\u0442\u0440\u0438\u043a\u0430, \u0434\u0432\u0435\u0440\u0438)!!!                                                    \u042d\u0442\u043e \u043d\u043e\u0432\u044b\u0439 \u0444\u043e\u0440\u043c\u0430\u0442 \u0436\u0438\u043b\u044c\u044f  \u043a\u043e\u0442\u0442\u0435\u0434\u0436 \u043d\u0430 \u043d\u0435\u0441\u043a\u043e\u043b\u044c\u043a\u043e \u0432\u043b\u0430\u0434\u0435\u043b\u044c\u0446\u0435\u0432 - \u0437\u0430 \u044d\u0442\u0443 \u0446\u0435\u043d\u0443 \u0432\u044b \u043f\u043e\u043a\u0443\u043f\u0430\u0435\u0442\u0435 \u043d\u0435 \u0442\u043e\u043b\u044c\u043a\u043e \u0436\u0438\u043b\u044c\u0435, \u043d\u043e \u0438 \u043f\u0440\u0438\u0443\u0441\u0430\u0434\u0435\u0431\u043d\u044b\u0439 \u0443\u0447\u0430\u0441\u0442\u043e\u043a, \u0442\u043e \u0435\u0441\u0442\u044c 2 \u0432 1.                                                                                   C\u0442\u0443\u0434\u0438\u044f 19 \u043a\u0432. \u043c \u043f\u043e \u043f\u043e\u043b\u0443 + \u0432\u0442\u043e\u0440\u043e\u0439 \u0443\u0440\u043e\u0432\u0435\u043d\u044c 6,6 \u043a\u0432. \u043c (\u0441\u043f\u0430\u043b\u044c\u043d\u0430\u044f \u0437\u043e\u043d\u0430), \u0438\u0442\u043e\u0433\u043e 25,6 \u043a\u0432.\u043c. \u0424\u043e\u0442\u043e\u0433\u0440\u0430\u0444\u0438\u0438 \u0440\u0435\u0430\u043b\u044c\u043d\u044b\u0435!                                                                                                                                \u0420\u0430\u0439\u043e\u043d \u0421\u0430\u043b\u0430\u0440\u044c\u0435\u0432\u043e \u0430\u043a\u0442\u0438\u0432\u043d\u043e \u0440\u0430\u0437\u0432\u0438\u0432\u0430\u0435\u0442\u0441\u044f. \u0414\u043e\u043c \u043d\u0430\u0445\u043e\u0434\u0438\u0442\u0441\u044f \u0432 \u043e\u0433\u043e\u0440\u043e\u0436\u0435\u043d\u043d\u043e\u043c \u0448\u043b\u0430\u0433\u0431\u0430\u0443\u043c\u0430\u043c\u0438 \u043a\u043e\u0442\u0442\u0435\u0434\u0436\u043d\u043e\u043c \u043f\u043e\u0441\u0435\u043b\u043a\u0435. \u0412 \u0446\u0435\u043d\u0442\u0440\u0435 \u0434\u0435\u0442\u0441\u043a\u0430\u044f \u043f\u043b\u043e\u0449\u0430\u0434\u043a\u0430, \u0441\u043f\u043e\u0440\u0442\u0438\u0432\u043d\u044b\u0439 \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441.                                                                      \u041f\u043b\u044e\u0441\u044b, \u043a\u043e\u0442\u ...
#         window._regions = [{"bounded_by": {"upperCorner": {"lat": 56.958512, "lng": 40.205688}, "lowerCorner": {"lat": 54.255696, "lng": 35.148496}}, "mainTownId": null, "hasMetro": true, "parentId": null, "lat": 55.7557, "text": "\u041c\u043e\u0441\u043a\u0432\u0430", "lng": 37.6213, "hasHighway": false, "id": 1, "hasDistricts": true}, {"bounded_by": {"upperCorner": {"lat": 56.958512, "lng": 40.205688}, "lowerCorner": {"lat": 54.255696, "lng": 35.148496}}, "mainTownId": 1, "hasMetro": false, "parentId": null, "lat": 55.7557, "text": "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "lng": 37.6213, "hasHighway": true, "id": 4593, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 61.329293, "lng": 35.701312}, "lowerCorner": {"lat": 58.417336, "lng": 26.440169}}, "mainTownId": null, "hasMetro": true, "parentId": null, "lat": 59.9385, "text": "\u0421\u0430\u043d\u043a\u0442-\u041f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433", "lng": 30.3058, "hasHighway": false, "id": 2, "hasDistricts": true}, {"bounded_by": {"upperCorner": {"lat": 61.329293, "lng": 35.701312}, "lowerCorner": {"lat": 58.417336, "lng": 26.440169}}, "mainTownId": 2, "hasMetro": false, "parentId": null, "lat": 59.9385, "text": "\u041b\u0435\u043d\u0438\u043d\u0433\u0440\u0430\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "lng": 30.3058, "hasHighway": false, "id": 4588, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 45.217113, "lng": 40.777647}, "lowerCorner": {"lat": 43.760146, "lng": 38.684018}}, "mainTownId": 4855, "hasMetro": false, "parentId": null, "lat": 44.609139, "text": "\u0410\u0434\u044b\u0433\u0435\u044f", "lng": 40.113209, "hasHighway": false, "id": 4553, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 52.660268, "lng": 89.86565}, "lowerCorner": {"lat": 49.071318, "lng": 83.932803}}, "mainTownId": 4719, "hasMetro": false, "parentId": null, "lat": 51.958118, "text": "\u0410\u043b\u0442\u0430\u0439 (\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430)", "lng": 85.971291, "hasHighway": false, "id": 4554, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 54.45311, "lng": 87.168651}, "lowerCorner": {"lat": 50.639877, "lng": 77.888953}}, "mainTownId": 4668, "hasMetro": false, "parentId": null, "lat": 53.356338, "text": "\u0410\u043b\u0442\u0430\u0439\u0441\u043a\u0438\u0439 \u043a\u0440\u0430\u0439", "lng": 83.76165, "hasHighway": false, "id": 4555, "hasDistricts": true}, {"bounded_by": {"upperCorner": {"lat": 57.060508, "lng": 134.920913}, "lowerCorner": {"lat": 48.853458, "lng": 119.655391}}, "mainTownId": 4683, "hasMetro": false, "parentId": null, "lat": 50.27494, "text": "\u0410\u043c\u0443\u0440\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "lng": 127.534141, "hasHighway": false, "id": 4556, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 82.058623, "lng": 69.957225}, "lowerCorner": {"lat": 60.635816, "lng": 35.269598}}, "mainTownId": 4658, "hasMetro": false, "parentId": null, "lat": 64.536926, "text": "\u0410\u0440\u0445\u0430\u043d\u0433\u0435\u043b\u044c\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "lng": 40.565571, "hasHighway": false, "id": 4557, "hasDistricts": true}, {"bounded_by": {"upperCorner": {"lat": 48.863566, "lng": 49.886117}, "lowerCorner": {"lat": 45.262264, "lng": 44.960978}}, "mainTownId": 4660, "hasMetro": false, "parentId": null, "lat": 46.354889, "text": "\u0410\u0441\u0442\u0440\u0430\u0445\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "lng": 48.052719, "hasHighway": false, "id": 4558, "hasDistricts": false}, {"bounded_by": {"upperCorner": {"lat": 56.534644, "lng": 60.001809}, "lowerCorner": {"lat": 51.569554, "lng": 53.157542}}, "mainTownId": 176245, "hasMetro": false, "parentId": null, "lat": 54.7355, "text": "\u0411\u0430\u0448\u043a\u043e\u0440\u0442\u043e\u0441\u0442\u0430\u043d ...
#         window._region = {"bounded_by": {"upperCorner": {"lat": 56.958512, "lng": 40.205688}, "lowerCorner": {"lat": 54.255696, "lng": 35.148496}}, "mainTownId": null, "hasMetro": true, "parentId": null, "lat": 55.7557, "text": "\u041c\u043e\u0441\u043a\u0432\u0430", "lng": 37.6213, "hasHighway": false, "id": 1, "hasDistricts": true};
#         window._currentRegions = [{"bounded_by": {"upperCorner": {"lat": 56.958512, "lng": 40.205688}, "lowerCorner": {"lat": 54.255696, "lng": 35.148496}}, "mainTownId": null, "hasMetro": true, "parentId": null, "lat": 55.7557, "text": "\u041c\u043e\u0441\u043a\u0432\u0430", "lng": 37.6213, "hasHighway": false, "id": 1, "hasDistricts": true}];
#         window._currentRoots = [{"boundedBy": {"upperCorner": {"lat": 56.021224, "lng": 37.967428}, "lowerCorner": {"lat": 55.142175, "lng": 36.803101}}, "hasMetro": true, "displayName": "\u041c\u043e\u0441\u043a\u0432\u0430", "name": "\u041c\u043e\u0441\u043a\u0432\u0430", "hasHighway": false, "hasDistricts": true, "lng": 37.6213, "lat": 55.7557, "fullName": "\u041c\u043e\u0441\u043a\u0432\u0430", "id": 1}];
#         window._user = {"id": "112bebc6-2cd3-11e7-80ac-3ae581f9d5ab", "isAuthenticated": false};
#         window.subscriptionProposalOptions = {
#             offersCount: 750,
#             userIsWatchingHisOffers: false,
#             userHasSubscriptions: false,
#             searchURL: location.protocol + '//' + location.host + '/cat.php?' + 'deal_type\u003Dsale\u0026engine_version\u003D2\u0026offer_type\u003Dflat\u0026region\u003D1\u0026room1\u003D1\u0026room2\u003D1'
#         };
#
#         window.cianConfig.logToken = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....KMl7Q7ddA2zfukXJIzzQo5uXu2RgDgQ7Hbnmfs0EUi4";
#
#
#         window.highlightWordsList = '';
#         window._can_view_listing_sort = false;
#         window.newobject_allowed_location_ids = [4608, 4609, 2, 4612, 1, -2, 4618, 4623, 4560, 4561, 4630, 4567, 4580, 4584, 4585, 4588, 4593, 4596, 4606, 4598, 4603, -1];
#         window._serpViewMode = 'list'; // table / list
#         window._showModeSwitcher = true;
#     </script>
# <script data-aload="https://enterprise.api-maps.yandex.ru/2.1/?apikey=ad7bd5e9-cdc2-47b7-8455-8d4800185ea7&amp;lang=ru_RU&amp;load=&amp;onload=_onYandexMapLoaded&amp;coordorder=longlat" type="text/javascript"></script>
# <script async="" data-rum-host="www.cian.ru" defer="" src="//rum.ngenix.net/js/loader.js"></script>
# <!-- Cian Metrics -->
# <script async="" data-metrics-api="/ajax/metrics/" data-page-type="Listing" data-profile-session-key="112B850A-2CD3-11E7-B6C4-C5153B830C9C" data-website-type="Desktop" defer="" src="//metrics.cian.site/metrics.min.js"></script>
# <!-- /Cian Metrics -->
# </meta></meta></meta></head>
# <body>
# <script src="https://cdn.cian.site/media/adfox/ads.js" type="text/javascript"></script>
# <script>
#     (function() {
#         if (!window._cianCanRunAds) {
#             document.cookie = 'adb=1; path=/; domain=.cian.ru';
#         }
#     })();
# </script>
# <script>
# <!-- Cian Analytics -->
# !function(){"ca"in window||(window.ca=function(evt,param){
#   window.ca.q.push([evt,param])},window.ca.q=[]);
#   var n=document.createElement("script");
#   n.src="//analytics.cian.site/analytics.js?v=1",n.async=!0;
#   n.setAttribute('data-analytics-api-url', '//sopr-api.cian.ru/');
#   n.setAttribute('data-profile-session-key', '112B850A-2CD3-11E7-B6C4-C5153B830C9C');
#   var e=document.getElementsByTagName("script")[0];
#   e.parentNode.insertBefore(n,e)}();
# <!-- /Cian Analytics -->
# </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KC2KW5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KC2KW5');</script>
# <!-- End Google Tag Manager -->
# <svg display="none" height="0" version="1.1" width="0" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <!-- Москва -->
# <symbol id="metro_1" preserveaspectratio="xMidYMax" viewbox="0 0 16 11">
# <path d="M11.154 0L8 5.53 4.844 0 1.1 9.466H0v1.428h5.657V9.466H4.81l.824-2.36L8 11l2.365-3.893.824 2.36h-.848v1.427H16V9.466h-1.1" fill-rule="evenodd"></path>
# </symbol>
# <!-- Спб -->
# <symbol id="metro_2" preserveaspectratio="xMidYMax" viewbox="0 0 16 12">
# <path d="M8 8.667L10.5 0s5 1.556 5 6.89c0 3.777-1.818 5.11-1.818 5.11h-3.41s3.523-1.556 3.637-5.11c.113-3.557-2.615-5.334-2.615-5.334L8.227 11.778H8v-3.11zm0 0v3.11h-.227L4.705 1.558S1.977 3.332 2.09 6.888C2.206 10.443 5.728 12 5.728 12h-3.41S.5 10.667.5 6.89C.5 1.555 5.5 0 5.5 0L8 8.667z" fill-rule="evenodd"></path>
# </symbol>
# <!-- Самара -->
# <symbol id="metro_4608" preserveaspectratio="xMidYMax" viewbox="0 0 16 12">
# <path d="M11.75 0l3.75 10.983s-4.583.203-4.583-4.27C10.917 5.897 8 12 8 12V6.102L11.75 0zm-7.5 0L8 6.102V12S5.083 5.898 5.083 6.712c0 4.474-4.583 4.27-4.583 4.27L4.25 0z" fill-rule="evenodd"></path>
# </symbol>
# <!-- Екб -->
# <symbol id="metro_4612" preserveaspectratio="xMidYMax" viewbox="0 0 12 12">
# <path d="M0 0l5.895 6.316h.21L12 0v5.474L6.105 11.58h-.21L0 5.473V0zm0 6.737l4.21 4.42V12H0V6.737zm12 0V12H7.79v-.842L12 6.738z" fill-rule="evenodd"></path>
# </symbol>
# <!-- НН -->
# <symbol id="metro_4596" preserveaspectratio="xMidYMax" viewbox="0 0 14 15">
# <g fill-rule="evenodd">
# <path d="M7 12.387c-3.486 0-6.317-2.722-6.317-6.084C.683 2.94 3.513.22 7 .22c3.486 0 6.317 2.72 6.317 6.083 0 3.362-2.83 6.084-6.317 6.084zm0-.5c3.215 0 5.817-2.502 5.817-5.584C12.817 3.223 10.215.72 7 .72c-3.215 0-5.817 2.502-5.817 5.583 0 3.082 2.602 5.584 5.817 5.584z" fill-rule="nonzero"></path>
# <path d="M0 14.003l4.2-8.4 2.8 3.5v5.367l-1.4-2.567-1.4 2.1H0zm14 0H9.8l-1.4-2.1L7 14.47V9.103l2.8-3.5 4.2 8.4z"></path>
# </g>
# </symbol>
# <!-- Новосибирск -->
# <symbol id="metro_4598" preserveaspectratio="xMidYMax" viewbox="0 0 14 14">
# <path d="M7 6.808h-.114L3.92.54.5 13.076h2.737L4.605 7.97l2.28 5.57h.229l2.28-5.57 1.37 5.106H13.5L10.08.54 7.113 6.808H7z" fill-rule="evenodd"></path>
# </symbol>
# <!-- Казань -->
# <symbol id="metro_4618" preserveaspectratio="xMidYMax" viewbox="0 0 16 11">
# <path d="M5.3 0l2.2 3.463L4.5 11h-4L5.3 0zm5.4 0l4.8 11h-4l-3-7.537L10.7 0zM7.9 4.89h.2l1 2.647-1 .407h-.2l-1-.407 1-2.648z" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="top3" viewbox="0 0 15 15">
# <style>
# 				#top3 .st2{fill:#ff8400}
# 				#top3 .st3{fill:#FFF}
# 			</style>
# <circle class="st2" cx="7.5" cy="7.5" r="7"></circle>
# <path class="st3" d="M7.5 2.9l4 6.1h-8z"></path>
# <path class="st3" d="M6 8h3v4H6z"></path>
# </symbol>
# <symbol id="top3_inverted" viewbox="0 0 15 15">
# <style>
#                 #top3_inverted .st2{fill:#FFF}
#                 #top3_inverted .st3{fill:#ff8400}
#             </style>
# <circle class="st2" cx="7.5" cy="7.5" r="7"></circle>
# <path class="st3" d="M7.5 2.9l4 6.1h-8z"></path>
# <path class="st3" d="M6 8h3v4H6z"></path>
# </symbol>
# <symbol id="premium" viewbox="0 0 15 15">
# <style>
# 				#premium .st2{fill:#ff8400}
# 			</style>
# <path class="st2" d="M12.3 5.7l-4.6 4.6v3.2H6.4l-.7-1.1.3-.8-1.4-1.4.6.6-.6 1.7-.6-1.8-1.7-.6L4 9.6l-.9-.9-.8.3-1.1-.7V7h3.1L9 2.3s4.2-2.5 5-1.7c.8.9-1.7 5.1-1.7 5.1zm-.7-2.6c-.3-.3-1.3.2-1.8.6-.4.5-.6 1.1-.3 1.4.3.3.9.2 1.4-.3.5-.4 1-1.4.7-1.7zm-9.3 9.3l1.7.5-.6.6H1.2v-2.2l.6-.6.5 1.7z"></path>
# </symbol>
# <symbol id="brush" viewbox="0 0 15 15">
# <path class="st2" d="M11.3 9.5l-.5-.5 3.3-3.3c.1-.1.2-.3.1-.5h-1.1c-.1 0-.2-.1-.3-.2-.1-.1-.1-.2 0-.3l.1-.3-.3.1c-.1 0-.3 0-.3-.1-.2.1-.3 0-.3-.2l.1-.4-.4.1c-.1 0-.2 0-.3-.1-.1-.1-.1-.2-.1-.3l.1-.2-1.5.8c-.2.1-.4 0-.5-.1-.1-.1-.1-.3 0-.4l.9-1.3h-.2c-.1 0-.2 0-.3-.1-.1 0-.1-.1-.1-.2V.8c-.2 0-.4 0-.5.1L5.9 4.2l-.4-.5L8.8.4c.3-.4 1-.4 1.5 0 .1.1.1.2.1.2v.9l.6-.1c.1 0 .3 0 .4.1.1.1.1.3 0 .4l-.6.8.9-.5c.1-.1.3-.1.4 0 .1.1.2.2.1.4l-.1.4h.5c.1 0 .3 0 .3.1s.1.2.1.3l-.1.4.4-.1c.1 0 .3 0 .4.1.1.1.1.2.1.4l-.2.5h.8c.1 0 .2 0 .2.1.4.4.4 1.1 0 1.6l-3.3 3.1zM.5 14.5c.4.4.9.5 1.4.5 1.1-.2 2.3-1.4 3.1-3.2.2-.5.6-.8 1-.9.9-.2 2 .5 2.6 1.1.1.1.4.1.5 0l.7-.7-1-1c-.1-.1-.1-.3 0-.5.1-.1.3-.1.5 0l1 1 .3-.3c.1-.1.1-.4 0-.5L4.9 4.4c-.1-.1-.4-.1-.5 0L3 5.8c-.1.2-.1.4 0 .5.7.7 1.3 1.8 1.1 2.6-.1.4-.4.8-.9 1-1.8.8-3 2-3.2 3.1-.1.6.1 1.1.5 1.5zm.3-1.8c.4-.4 1-.4 1.4 0 .4.4.4 1 0 1.4-.4.4-1 .4-1.4 0s-.4-1 0-1.4z"></path>
# </symbol>
# <symbol id="paid" viewbox="0 0 15 15">
# <style>
# 				#paid .st0 {
# 					enable-background: new;
# 				}
# 			</style>
# <path class="st0 st2" d="M3.1 6.9h1.3V.5h3.1c1.5 0 2.5.2 3.2.8.9.6 1.5 1.6 1.5 3 0 1.1-.4 2.1-1.1 2.8-.9.9-1.9 1.3-3.7 1.3H6v1.1h5.6v1.4H6V13H4.3v-2.1H3.1V9.4h1.3V8.3H3.1V6.9zm6.5-4.5c-.6-.3-1.2-.5-2.2-.5H6v5h1.1c1.4 0 2.1-.2 2.7-.7.5-.5.7-1.1.7-1.9 0-.8-.3-1.5-.9-1.9z"></path>
# </symbol>
# <symbol id="call" viewbox="0 0 15 15">
# <path d="M4.55 4.8L1.2 1.45 2.5.15a.51.51 0 0 1 .72 0l2.61 2.61a.52.52 0 0 1 0 .73l-.57.57-.53.53a1.46 1.46 0 0 0-.18.21zm2.75 5.46c-.55-.47-1.07-1-1.58-1.48s-1-1-1.48-1.59A1.65 1.65 0 0 1 4 5.55L.54 2.11c-.8.82-.7 2.86.18 4.65A12.9 12.9 0 0 0 2.09 8.9a19.17 19.17 0 0 0 1.64 1.87 18.26 18.26 0 0 0 1.87 1.64 12.9 12.9 0 0 0 2.14 1.37c1.79.88 3.83 1 4.65.17l-3.44-3.43a1.66 1.66 0 0 1-1.64-.26zm7 1l-2.56-2.6a.52.52 0 0 0-.73 0l-.57.57-.53.53a1.6 1.6 0 0 1-.21.18l3.3 3.35 1.3-1.3a.51.51 0 0 0 .05-.72z"></path>
# </symbol>
# <symbol id="chat" viewbox="0 0 16 15">
# <path d="M15 3H6a1 1 0 0 0-1 1v7a1 1 0 0 0 1 1h5l3 3v-3h1a1 1 0 0 0 1-1V4a1 1 0 0 0-1-1z"></path>
# <path d="M9 0H1a1 1 0 0 0-1 1v6a1 1 0 0 0 1 1v2l2-2h1V3.5A1.5 1.5 0 0 1 5.5 2H10V1a1 1 0 0 0-1-1z"></path>
# </symbol>
# <symbol id="builder_mobile" viewbox="0 0 15 15">
# <path d="M7.5 12.2c-.9 0-1.7-.4-2-1.1-.1-.2 0-.4.1-.5.2-.1.4 0 .5.1.3.7 1.2.7 1.4.7s1.1-.1 1.4-.7c.1-.2.3-.2.5-.1s.2.3.1.5c-.3.7-1.1 1.1-2 1.1z"></path>
# <path d="M11.7 9c-.1 2.2-1.9 4-4.1 4-2.2 0-4.1-1.8-4.1-4h-1c.1 2.8 2.3 5 5.1 5s5.1-2.2 5.1-5h-1z"></path>
# <path d="M9.9 9.2c0-.3-.3-.6-.6-.6s-.6.3-.6.6.3.6.6.6.6-.2.6-.6zM5.8 9.9c.3 0 .6-.3.6-.6s-.3-.6-.6-.6-.6.2-.6.6.3.6.6.6zM12.4 6S12 2.7 10 1.7V4H9V0H6v4H5V1.7C3 2.7 2.6 6 2.6 6H2v2h11V6h-.6z"></path>
# </symbol>
# <symbol id="fairplay" viewbox="0 0 15 17">
# <path d="M12,11.18v5.2L7.48,13,3,16.38V11.16A7.51,7.51,0,0,1,1,6.5,6.5,6.5,0,1,1,12,11.18ZM8.53,4.91L7.46,2l-1,2.93-3.29.16L5.93,6.71,4.8,10.07,7.48,8l2.63,2.05L8.91,6.62l2.84-1.55Z"></path>
# </symbol>
# <symbol id="skype" viewbox="0 0 20 21">
# <path d="M 19.36 12.25 C 19.5 11.6 19.58 10.91 19.58 10.21 C 19.58 4.96 15.32 0.71 10.07 0.71 C 9.52 0.71 8.97 0.75 8.45 0.85 C 7.6 0.31 6.59 0 5.51 0 C 2.47 0 0 2.47 0 5.51 C 0 6.53 0.28 7.48 0.76 8.3 C 0.63 8.92 0.57 9.56 0.57 10.21 C 0.57 15.46 4.82 19.72 10.07 19.72 C 10.67 19.72 11.25 19.67 11.81 19.56 C 12.59 19.98 13.48 20.22 14.42 20.22 C 17.46 20.22 19.93 17.75 19.93 14.7 C 19.93 13.82 19.73 12.99 19.36 12.25" fill="#00adef" fill-rule="evenodd"></path>
# <path d="M 7.21 3.96 L 7.21 3.96 C 6.41 4.26 5.79 4.69 5.36 5.24 C 4.93 5.8 4.72 6.45 4.72 7.17 C 4.72 7.92 4.92 8.56 5.33 9.07 C 5.73 9.58 6.28 9.98 6.97 10.27 C 7.63 10.55 8.47 10.8 9.46 11.01 C 10.18 11.17 10.77 11.31 11.2 11.45 C 11.62 11.58 11.96 11.76 12.22 12.01 C 12.46 12.24 12.58 12.53 12.58 12.91 C 12.58 13.38 12.35 13.77 11.88 14.09 C 11.39 14.42 10.75 14.59 9.96 14.59 C 9.39 14.59 8.93 14.51 8.58 14.35 C 8.24 14.18 7.97 13.98 7.79 13.73 C 7.59 13.47 7.41 13.15 7.24 12.76 C 7.09 12.41 6.9 12.13 6.68 11.95 C 6.45 11.75 6.17 11.66 5.84 11.66 C 5.45 11.66 5.11 11.78 4.85 12.03 C 4.59 12.27 4.46 12.57 4.46 12.92 C 4.46 13.48 4.66 14.06 5.06 14.64 C 5.46 15.22 5.99 15.68 6.63 16.03 C 7.52 16.5 8.67 16.74 10.03 16.74 C 11.17 16.74 12.17 16.57 13 16.22 C 13.85 15.87 14.5 15.38 14.94 14.76 C 15.38 14.13 15.6 13.42 15.6 12.63 C 15.6 11.98 15.47 11.42 15.21 10.96 C 14.96 10.51 14.6 10.12 14.14 9.83 C 13.7 9.54 13.15 9.29 12.52 9.09 C 11.89 8.89 11.18 8.7 10.41 8.54 C 9.81 8.4 9.36 8.29 9.1 8.21 C 8.84 8.14 8.58 8.04 8.33 7.92 C 8.09 7.8 7.9 7.65 7.77 7.49 C 7.64 7.33 7.58 7.15 7.58 6.93 C 7.58 6.58 7.77 6.28 8.17 6.02 C 8.58 5.75 9.13 5.61 9.81 5.61 C 10.55 5.61 11.08 5.74 11.4 5.98 C 11.73 6.23 12.02 6.59 12.25 7.04 C 12.46 7.39 12.64 7.63 12.82 7.79 C 13.01 7.96 13.29 8.05 13.64 8.05 C 14.03 8.05 14.36 7.91 14.62 7.64 C 14.88 7.37 15.01 7.06 15.01 6.72 C 15.01 6.37 14.91 6 14.71 5.64 C 14.51 5.27 14.2 4.92 13.79 4.6 C 13.37 4.27 12.84 4.01 12.22 3.82 C 11.59 3.62 10.85 3.52 10 3.52 C 8.94 3.52 8 3.67 7.21 3.96" fill="#ffffff" fill-rule="evenodd"></path>
# </symbol>
# <symbol id="breadcrumbs_arrow" viewbox="0 0 6 11">
# <path d="M1 10.79a1 1 0 0 1-.77-1.63l3-3.66-3-3.66A1 1 0 0 1 1.77.57l3.53 4.3a1 1 0 0 1 0 1.27l-3.53 4.29a1 1 0 0 1-.77.36z"></path>
# </symbol>
# <symbol id="share_fb" viewbox="0 0 32 32">
# <style>
#           #share_fb .cls-1 { fill: #425497; }
#           #share_fb .cls-2 { fill: #fff;    }
#           </style>
# <rect class="cls-1" height="32" rx="16" ry="16" width="32"></rect>
# <path class="cls-2" d="M13 13.3h1.34V12a3.5 3.5 0 0 1 .43-2 2.39 2.39 0 0 1 2.09-1 8.5 8.5 0 0 1 2.41.24l-.34 2a4.54 4.54 0 0 0-1.08-.16.81.81 0 0 0-1 .71v1.51H19l-.15 1.94h-2V22h-2.51v-6.76H13V13.3z"></path>
# </symbol>
# <symbol id="share_ok" viewbox="0 0 32 32">
# <style>
#           #share_ok .cls-1 { fill: #ec7c21; }
#           #share_ok .cls-2 { fill: #fff;    }
#           </style>
# <rect class="cls-1" height="32" rx="16" ry="16" width="32"></rect>
# <path class="cls-2" d="M16 16.23a3.69 3.69 0 1 0-3.69-3.69A3.69 3.69 0 0 0 16 16.23zM16 11a1.53 1.53 0 1 1-1.53 1.53A1.53 1.53 0 0 1 16 11zM17.49 19.24a6.91 6.91 0 0 0 2.14-.89 1.08 1.08 0 0 0-1.15-1.83 4.69 4.69 0 0 1-5 0 1.08 1.08 0 0 0-1.15 1.83 6.92 6.92 0 0 0 2.14.89l-2.03 2.06A1.08 1.08 0 0 0 14 22.83l2-2 2 2a1.08 1.08 0 0 0 1.53-1.53z"></path>
# </symbol>
# <symbol id="share_vk" viewbox="0 0 32 32">
# <style>
#             .share_vk_base { fill: #526e8f; }
#             #share_vk .cls-2 { fill: #fff; fill-rule: evenodd; }
#           </style>
# <rect class="share_vk_base" height="32" rx="16" ry="16" width="32"></rect>
# <path class="cls-2" d="M17.26 9.46c1.72 0 3.19.84 3.19 2.55a2.59 2.59 0 0 1-1.58 2.61c.09.08.7.26.9.36a2.49 2.49 0 0 1 .74.54 2.6 2.6 0 0 1 .71 2.13C21.23 19.88 19.07 21 17 21h-4.8a.2.2 0 0 1-.2-.2V9.66a.2.2 0 0 1 .2-.2h5zm-2.39 3V14c1.35 0 2.62.18 2.62-1.29s-1.44-1.13-2.62-1.13v.92zm0 6.39c1.48 0 3.31.24 3.34-1.44S16.33 16 14.87 16v2.87z"></path>
# </symbol>
# <symbol id="share_twitter" viewbox="0 0 32 32">
# <style>
#             #share_twitter .cls-1 { fill: #55acee; }
#             #share_twitter .cls-2 { fill: #fff; }
#           </style>
# <rect class="cls-1" height="32" rx="16" ry="16" width="32"></rect>
# <path class="cls-2" d="M23.27 11.3a5.55 5.55 0 0 1-1.59.44 2.79 2.79 0 0 0 1.22-1.54 5.56 5.56 0 0 1-1.76.67 2.78 2.78 0 0 0-4.73 2.53 7.88 7.88 0 0 1-5.72-2.9 2.78 2.78 0 0 0 .86 3.71 2.77 2.77 0 0 1-1.26-.35 2.78 2.78 0 0 0 2.23 2.72 2.78 2.78 0 0 1-1.25 0 2.78 2.78 0 0 0 2.59 1.93 5.57 5.57 0 0 1-3.45 1.19 5.65 5.65 0 0 1-.66 0 7.9 7.9 0 0 0 12.14-6.6v-.36a5.64 5.64 0 0 0 1.38-1.44z"></path>
# </symbol>
# <symbol id="cross" viewbox="0 0 24 24">
# <rect height="31.7" transform="matrix(0.7071 -0.7071 0.7071 0.7071 -4.9875 12.0408)" width="2" x="11" y="-3.8"></rect>
# <rect height="31.7" transform="matrix(0.7071 0.7071 -0.7071 0.7071 12.0408 -4.9875)" width="2" x="11" y="-3.8"></rect>
# </symbol>
# <symbol id="pin" viewbox="21 235 12 18">
# <path d="M21.6600909,243.735945 L21.6600909,243.735945 L21.7320903,243.867944 L26.9640484,253.07187 L32.1960064,243.867944 L32.2680059,243.723945 L32.2680059,243.723945 L32.2680059,243.723945 C32.7276152,242.888072 32.978721,241.953629 33,240.999967 C32.9999019,238.514332 31.4671791,236.286125 29.1459599,235.397125 C26.8247407,234.508126 24.1957095,235.142432 22.5352459,236.992091 C20.8747823,238.841751 20.5267398,241.52373 21.6600909,243.735945 L21.6600909,243.735945 L21.6600909,243.735945 Z M27.0000481,238.359988 C28.0915646,238.360162 29.0745989,239.020382 29.4876771,240.030716 C29.9007553,241.04105 29.661848,242.200865 28.8831075,242.9657 C28.1043671,243.730534 26.9404361,243.948507 25.9377084,243.517293 C24.9349806,243.086079 24.2925783,242.091309 24.3120697,240.999967 C24.3382479,239.534216 25.5340634,238.359754 27.0000481,238.359988 L27.0000481,238.359988 Z"></path>
# </symbol>
# <symbol id="ic_archive" viewbox="0 0 16 12">
# <g fill="none" fill-rule="evenodd" opacity="0.669999957" stroke="none" stroke-width="1">
# <g fill="#0857D1" transform="translate(-1085.000000, -398.000000)">
# <g transform="translate(1085.000000, 395.000000)">
# <path d="M1.33333333,3 C0.620761905,3 0,3.6212381 0,4.33333333 L0,13.8571429 C0,14.4375048 0.371657143,14.8095238 0.952380952,14.8095238 L15.047619,14.8095238 C15.6283238,14.8095238 16,14.4375048 16,13.8571429 L16,7.76190476 C16,7.18154286 15.6283238,6.80952381 15.047619,6.80952381 L8.76190476,6.80952381 L7.80952381,4.14285714 C7.5556381,3.43197714 6.81624762,3 6.0952381,3 L1.33333333,3 L1.33333333,3 Z M8.75595238,4.52380952 L9.30357143,6.04761905 L15.047619,6.04761905 C15.3827718,6.04761905 15.7166396,6.13342952 16,6.30952381 L16,5.80952381 C16,5.0972381 15.4265714,4.52380952 14.7142857,4.52380952 L8.75595238,4.52380952 L8.75595238,4.52380952 Z"></path>
# </g>
# </g>
# </g>
# </symbol>
# <symbol id="checkmark" viewbox="0 0 14 9.5">
# <path d="M5.4,9.5L5.4,9.5c-0.3,0-0.5-0.1-0.7-0.3L0.3,4.7c-0.4-0.4-0.4-1.1,0-1.5c0.4-0.4,1.1-0.4,1.5,0L5.5,7l6.8-6.7 c0.4-0.4,1.1-0.4,1.5,0c0.4,0.4,0.4,1.1,0,1.5L6.2,9.2C6,9.4,5.7,9.5,5.4,9.5"></path>
# </symbol>
# <symbol id="icon-filters" viewbox="0 0 16 16">
# <g fill-rule="evenodd">
# <path d="M15.25 8.75H.75C.336 8.75 0 8.414 0 8s.336-.75.75-.75h14.5c.414 0 .75.336.75.75s-.336.75-.75.75M15.25 13.75H.75c-.414 0-.75-.336-.75-.75s.336-.75.75-.75h14.5c.414 0 .75.336.75.75s-.336.75-.75.75M15.25 3.75H.75C.336 3.75 0 3.414 0 3s.336-.75.75-.75h14.5c.414 0 .75.336.75.75s-.336.75-.75.75"></path>
# <path d="M4.78 5.25C3.54 5.25 2.53 4.24 2.53 3S3.54.75 4.78.75C6.023.75 7.03 1.76 7.03 3S6.023 5.25 4.78 5.25" fill="#FFF"></path>
# <path d="M4.78 0c-1.656 0-3 1.343-3 3s1.344 3 3 3c1.658 0 3-1.343 3-3s-1.342-3-3-3m0 1.5c.828 0 1.5.673 1.5 1.5s-.672 1.5-1.5 1.5c-.826 0-1.5-.673-1.5-1.5s.674-1.5 1.5-1.5"></path>
# <path d="M10.78 10.25c-1.24 0-2.25-1.01-2.25-2.25s1.01-2.25 2.25-2.25c1.242 0 2.25 1.01 2.25 2.25s-1.008 2.25-2.25 2.25" fill="#FFF"></path>
# <path d="M10.78 5c-1.656 0-3 1.343-3 3s1.344 3 3 3c1.658 0 3-1.343 3-3s-1.342-3-3-3m0 1.5c.828 0 1.5.673 1.5 1.5s-.672 1.5-1.5 1.5c-.826 0-1.5-.673-1.5-1.5s.674-1.5 1.5-1.5"></path>
# <path d="M4.78 15.25c-1.24 0-2.25-1.01-2.25-2.25s1.01-2.25 2.25-2.25c1.242 0 2.25 1.01 2.25 2.25s-1.008 2.25-2.25 2.25" fill="#FFF"></path>
# <path d="M4.78 10c-1.656 0-3 1.343-3 3s1.344 3 3 3c1.658 0 3-1.343 3-3s-1.342-3-3-3m0 1.5c.828 0 1.5.673 1.5 1.5s-.672 1.5-1.5 1.5c-.826 0-1.5-.673-1.5-1.5s.674-1.5 1.5-1.5"></path>
# </g>
# </symbol>
# <symbol id="my-offers" viewbox="0 0 14 14">
# <g fill="none" fill-rule="evenodd" opacity="0.669999957" stroke="none" stroke-width="1">
# <g fill="#0857D1" transform="translate(-1123.000000, -144.000000)">
# <g transform="translate(1123.000000, 142.000000)">
# <path d="M12.98151,8.50738916 L7.37277395,8.50738916 L6.76214543,7.82019704 C6.37767563,7.3546798 5.99320582,7 5.40519317,7 L1.04033007,7 C0.474933291,7 0,7.37684729 0,7.82019704 L0,9.32758621 L0,9.7044335 L0,15.179803 C0,15.6231527 0.474933291,16 1.04033007,16 L12.9588941,16 C13.5469067,16 13.9992242,15.6231527 13.9992242,15.179803 L13.9992242,9.30541872 C14.02184,8.86206897 13.5469067,8.50738916 12.98151,8.50738916 Z M5.09236948,5.56223176 C6.24096386,5.56223176 6.90361446,6.35622318 7.19076305,6.69957082 L7.45582329,7 L12.3373494,7 L13,5.26180258 L3.34738956,2 L2,5.56223176 L5.09236948,5.56223176 Z"></path>
# </g>
# </g>
# </g>
# </symbol>
# </defs>
# </svg>
# <div class="js-layout" id="layout">
# <link href="/static/cf/lib/index.4075bcf59d01.css" rel="stylesheet">
# <figure class="cf_app_banner" id="cf_app_banner">
# <div class="cg-container-fluid-xs">
# <div class="cg-row">
# <div class="cg-col-7">
# <i class="cf_app_banner-bg"></i>
# </div>
# <div class="cg-col-14">
# <div class="cf_app_banner-main">
# <p class="cf_app_banner-title">Установите мобильное приложение ЦИАН</p>
# <p class="cf_app_banner-sub_title">Свежие объявления всегда под рукой</p>
# <ul class="cf_app_banner-store_links">
# <li class="cf_app_banner-store_links_item">
# <a class="cf_app_banner-store_link" data-store-type="App_Store" href="//app.adjust.com/3m4ibr" rel="noopener nofollow" target="_blank">
# <svg height="30" viewbox="0 0 111 30" width="111" xmlns="http://www.w3.org/2000/svg"><path d="M17.54 13.61a5.74 5.74 0 0 1 2.74-4.82 5.88 5.88 0 0 0-4.63-2.5c-2-.21-3.84 1.17-4.83 1.17-.99 0-2.54-1.15-4.19-1.11a6.17 6.17 0 0 0-5.19 3.17c-2.24 3.89-.57 9.6 1.58 12.74 1.08 1.54 2.33 3.26 4 3.2 1.67-.06 2.21-1 4.15-1 1.94 0 2.49 1 4.17 1 1.68 0 2.82-1.54 3.85-3.1A12.7 12.7 0 0 0 21 18.77a5.55 5.55 0 0 1-3.46-5.16zm-3.17-9.39A5.65 5.65 0 0 0 15.66.17a5.76 5.76 0 0 0-3.72 1.93A5.38 5.38 0 0 0 10.61 6a4.76 4.76 0 0 0 3.76-1.78zM41.3 26h-2a.84.84 0 0 1-.54-.17 1 1 0 0 1-.31-.41l-1-2.8h-5.7l-1 2.8a.91.91 0 0 1-.29.4.82.82 0 0 1-.54.18h-2l5.38-13.74h2.6L41.3 26zm-4.51-5.19l-1.67-4.57a4.68 4.68 0 0 1-.26-.72 16.45 16.45 0 0 1-.27-.9c-.08.32-.17.63-.26.91s-.17.53-.26.74l-1.66 4.55h4.38v-.01zm7.77-3.23a5.1 5.1 0 0 1 1.36-1.09 3.65 3.65 0 0 1 1.79-.42 3.2 3.2 0 0 1 1.46.33c.453.24.843.582 1.14 1 .32.464.555.982.69 1.53a7.83 7.83 0 0 1 .26 2.07 6.68 6.68 0 0 1-.26 2 5 5 0 0 1-.84 1.62 3.9 3.9 0 0 1-1.32 1.07 3.84 3.84 0 0 1-1.73.38 3.49 3.49 0 0 1-1.4-.25 3.42 3.42 0 0 1-1-.7v4h-2.37V16.25h1.43a.58.58 0 0 1 .6.43l.19.9zm.12 5.89c.23.294.53.527.87.68.317.132.657.2 1 .2a2.25 2.25 0 0 0 1-.2 1.87 1.87 0 0 0 .73-.61 3 3 0 0 0 .46-1 5.9 5.9 0 0 0 .16-1.47 6.52 6.52 0 0 0-.14-1.45 2.8 2.8 0 0 0-.39-1 1.56 1.56 0 0 0-.62-.54 2 2 0 0 0-.83-.17 2.38 2.38 0 0 0-1.24.31 3.79 3.79 0 0 0-1 .87v4.38zm10.67-5.89a5.1 5.1 0 0 1 1.36-1.09 3.65 3.65 0 0 1 1.79-.42 3.2 3.2 0 0 1 1.5.33c.453.24.843.582 1.14 1a4.62 4.62 0 0 1 .7 1.6 7.83 7.83 0 0 1 .26 2.12 6.68 6.68 0 0 1-.29 2 5 5 0 0 1-.81 1.57 3.9 3.9 0 0 1-1.32 1.07 3.84 3.84 0 0 1-1.73.38 3.49 3.49 0 0 1-1.4-.25 3.42 3.42 0 0 1-1-.7v4h-2.42V16.25h1.43a.58.58 0 0 1 .6.43l.19.9zm.12 5.89c.23.294.53.527.87.68.317.132.657.2 1 .2a2.25 2.25 0 0 0 1-.2 1.87 1.87 0 0 0 .73-.61 3 3 0 0 0 .46-1 5.9 5.9 0 0 0 .16-1.47 6.52 6.52 0 0 0-.14-1.45 2.8 2.8 0 0 0-.39-1 1.56 1.56 0 0 0-.62-.54 2 2 0 0 0-.83-.17 2.38 2.38 0 0 0-1.24.31 3.79 3.79 0 0 0-1 .87v4.38zm19.6-8.71a.87.87 0 0 1-.24.29.54.54 0 0 1-.32.09.82.82 0 0 1-.44-.14l-.56-.33a4.62 4.62 0 0 0-.76-.33 3.16 3.16 0 0 0-1-.15 3.07 3.07 0 0 0-.93.13 2 2 0 0 0-.67.36 1.42 1.42 0 0 0-.4.55 1.79 1.79 0 0 0-.13.7 1.21 1.21 0 0 0 .27.81c.2.23.445.417.72.55.322.163.656.3 1 .41l1.17.38c.398.135.79.292 1.17.47a4 4 0 0 1 1 .68c.305.282.55.622.72 1 .215.46.328.962.33 1.47a4.73 4.73 0 0 1-.32 1.74 4 4 0 0 1-.93 1.42 4.38 4.38 0 0 1-1.5 1 5.52 5.52 0 0 1-2 .35 6.49 6.49 0 0 1-1.36-.21 6.77 6.77 0 0 1-1.22-.37 6.52 6.52 0 0 1-1.1-.57 5.28 5.28 0 0 1-.91-.74l.75-1.23a.81.81 0 0 1 .25-.22.62.62 0 0 1 .34-.06.91.91 0 0 1 .51.2l.66.43c.282.172.58.316.89.43a3.41 3.41 0 0 0 1.22.19 2.5 2.5 0 0 0 1.72-.52 1.86 1.86 0 0 0 .6-1.49 1.38 1.38 0 0 0-.27-.88 2.19 2.19 0 0 0-.72-.57 5.33 5.33 0 0 0-1-.39l-1.16-.35a9.94 9.94 0 0 1-1.16-.46 3.74 3.74 0 0 1-1-.69 3.16 3.16 0 0 1-.72-1.07 4.07 4.07 0 0 1-.27-1.58 3.8 3.8 0 0 1 1.17-2.73 4.26 4.26 0 0 1 1.41-.88 5.17 5.17 0 0 1 1.92-.33 6.39 6.39 0 0 1 2.2.38 5 5 0 0 1 1.75 1.06l-.68 1.2zm5.56 11.39a2.56 2.56 0 0 1-2-.72 2.76 2.76 0 0 1-.68-2V18H77a.45.45 0 0 1-.32-.12.48.48 0 0 1-.13-.37v-.92l1.57-.26.49-2.66a.52.52 0 0 1 .18-.29.54.54 0 0 1 .34-.1h1.22v3.07H83V18h-2.6v5.28a1 1 0 0 0 .22.71.77.77 0 0 0 .61.26c.122.02.248.02.37 0l.26-.11L82 24a.32.32 0 0 1 .17 0 .27.27 0 0 1 .17 0c.054.047.1.1.14.16l.7 1.14A3.55 3.55 0 0 1 82 26a4.39 4.39 0 0 1-1.37.15zm8.06-10.05a5.33 5.33 0 0 1 2 .35 4.38 4.38 0 0 1 2.52 2.58 6.53 6.53 0 0 1 0 4.17 4.48 4.48 0 0 1-1 1.59 4.27 4.27 0 0 1-1.52 1 5.31 5.31 0 0 1-2 .35 5.38 5.38 0 0 1-2-.35 4.25 4.25 0 0 1-1.52-1 4.53 4.53 0 0 1-1-1.59 6.44 6.44 0 0 1 0-4.17 4.43 4.43 0 0 1 1-1.58 4.31 4.31 0 0 1 1.52-1 5.4 5.4 0 0 1 2-.35zm0 8.24a2.06 2.06 0 0 0 1.8-.82 4.1 4.1 0 0 0 .58-2.39 4.15 4.15 0 0 0-.58-2.4 2.06 2.06 0 0 0-1.8-.83 2.1 2.1 0 0 0-1.83.83 4.1 4.1 0 0 0-.59 2.4 4.05 4.05 0 0 0 .59 2.39 2.11 2.11 0 0 0 1.83.82zm8.82-6.4a4.19 4.19 0 0 1 1.08-1.37 2.31 2.31 0 0 1 1.48-.5c.382-.02.76.082 1.08.29l-.15 1.76a.46.46 0 0 ...
# </a>
# </li>
# <li class="cf_app_banner-store_links_item">
# <a class="cf_app_banner-store_link" data-store-type="Google_Play" href="//m.onelink.me/58c278f4" rel="noopener nofollow" target="_blank">
# <svg height="29" viewbox="0 0 131 29" width="131" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M32.68 1.11a2.6 2.6 0 0 1 .85-.48 3.32 3.32 0 0 1 1.09-.17 3.17 3.17 0 0 1 .9.12c.245.067.476.18.68.33.18.135.327.31.43.51.1.202.153.424.15.65a1.57 1.57 0 0 1-.2.78 1.47 1.47 0 0 1-.6.57 2 2 0 0 1 .39.24c.114.09.215.194.3.31a1.23 1.23 0 0 1 .27.78 2 2 0 0 1-.16.78 1.8 1.8 0 0 1-.45.63 2.16 2.16 0 0 1-.72.42 2.88 2.88 0 0 1-1 .16 3.48 3.48 0 0 1-1.75-.47 2.5 2.5 0 0 1-.44-.33l.34-.55a.43.43 0 0 1 .11-.1.28.28 0 0 1 .15 0 .45.45 0 0 1 .24.09l.32.19c.14.077.288.14.44.19.2.064.41.094.62.09.316.02.63-.07.89-.25a.9.9 0 0 0 .31-.76.81.81 0 0 0-.33-.65 1.17 1.17 0 0 0-.35-.19 1.86 1.86 0 0 0-.5-.06h-.86V3h.79a1.42 1.42 0 0 0 .83-.21.7.7 0 0 0 .3-.61.67.67 0 0 0-.28-.56 1.35 1.35 0 0 0-.82-.21 1.85 1.85 0 0 0-.53.07 2.9 2.9 0 0 0-.39.15l-.28.15a.4.4 0 0 1-.2.07.23.23 0 0 1-.14 0 .4.4 0 0 1-.08-.2l-.32-.54zm4.97 1.81a2.59 2.59 0 0 1 1.81-.69 1.76 1.76 0 0 1 .68.13c.193.078.367.198.51.35a1.5 1.5 0 0 1 .32.53 2 2 0 0 1 .11.68v2.75h-.48a.47.47 0 0 1-.23 0 .31.31 0 0 1-.13-.18l-.09-.31-.32.26a2 2 0 0 1-.33.19 1.73 1.73 0 0 1-.36.12 2.06 2.06 0 0 1-.43 0 1.67 1.67 0 0 1-.51-.08 1 1 0 0 1-.66-.59 1.3 1.3 0 0 1-.09-.51 1 1 0 0 1 .24-.64 1.5 1.5 0 0 1 .31-.29 2.12 2.12 0 0 1 .49-.23 4.3 4.3 0 0 1 .68-.16 6.85 6.85 0 0 1 .88-.07v-.26a1 1 0 0 0-.19-.65.69.69 0 0 0-.54-.21 1.27 1.27 0 0 0-.42.06 1.67 1.67 0 0 0-.3.13l-.23.13a.46.46 0 0 1-.23.06.3.3 0 0 1-.14-.05.48.48 0 0 1-.12-.13l-.23-.34zm2.41 1.89a5.72 5.72 0 0 0-.76.08c-.172.03-.34.08-.5.15a.66.66 0 0 0-.27.21.52.52 0 0 0 .08.65.71.71 0 0 0 .39.1 1.24 1.24 0 0 0 .56-.12 1.67 1.67 0 0 0 .46-.35v-.71l.04-.01zM45 3.09h-1.9v3.58h-1V2.32h3v.78zm1.63-.18a2.26 2.26 0 0 1 .61-.49 1.63 1.63 0 0 1 .8-.19c.225-.002.448.05.65.15.2.102.375.25.51.43.153.21.265.448.33.7a3.5 3.5 0 0 1 .12 1 3 3 0 0 1-.13.91 2.2 2.2 0 0 1-.38.72 1.73 1.73 0 0 1-.59.48 1.71 1.71 0 0 1-.78.17 1.56 1.56 0 0 1-.62-.11 1.53 1.53 0 0 1-.46-.31V8.1h-1V2.32h.64a.26.26 0 0 1 .27.19l.03.4zm.06 2.63a1 1 0 0 0 .39.31c.146.06.302.092.46.09a1 1 0 0 0 .46-.09.84.84 0 0 0 .33-.27 1.35 1.35 0 0 0 .21-.46 2.62 2.62 0 0 0 .07-.66 2.92 2.92 0 0 0-.06-.65 1.26 1.26 0 0 0-.18-.43.7.7 0 0 0-.37-.24.87.87 0 0 0-.37-.08 1.06 1.06 0 0 0-.56.14 1.7 1.7 0 0 0-.43.39v2l.05-.05zm7.6-3.22l-2.38 5.56a.4.4 0 0 1-.12.17.37.37 0 0 1-.23.06h-.77l.82-1.75-1.76-4h.92a.29.29 0 0 1 .19.06.37.37 0 0 1 .1.14L52 4.77c.03.075.058.152.08.23l.06.23.06-.23.08-.23.88-2.26a.31.31 0 0 1 .11-.14.31.31 0 0 1 .18-.05h.84zm.23.47c.177-.168.384-.3.61-.39a2.29 2.29 0 0 1 .87-.15 2.48 2.48 0 0 1 .72.1c.19.054.37.142.53.26.136.098.248.224.33.37a.91.91 0 0 1 .11.44 1 1 0 0 1 0 .26 1 1 0 0 1-.34.5 1.25 1.25 0 0 1-.34.19c.225.08.425.218.58.4a1 1 0 0 1 .22.65c.003.2-.05.397-.15.57a1.36 1.36 0 0 1-.39.42 1.8 1.8 0 0 1-.55.26 2.33 2.33 0 0 1-.64.09 2.49 2.49 0 0 1-.4 0 2.13 2.13 0 0 1-.86-.34 1.75 1.75 0 0 1-.41-.42l.3-.38a.21.21 0 0 1 .19-.1.32.32 0 0 1 .19.06l.21.14c.088.056.182.103.28.14.13.044.264.064.4.06a.88.88 0 0 0 .6-.18.57.57 0 0 0 .2-.45.48.48 0 0 0-.21-.41 1.21 1.21 0 0 0-.68-.15h-.5v-.66h.49c.22.014.438-.034.63-.14a.44.44 0 0 0 .22-.38.43.43 0 0 0-.19-.36A1 1 0 0 0 56 3a1.35 1.35 0 0 0-.38 0l-.27.1-.19.1a.28.28 0 0 1-.14 0 .25.25 0 0 1-.12 0 .34.34 0 0 1-.11-.12l-.27-.29zm8-.47v4.36h-1v-3a2 2 0 0 1-.19.34l-.08.12-.2.28-.27.38-.31.44-.84 1.18a.9.9 0 0 1-.16.17.32.32 0 0 1-.22.08h-.65V2.32h1v3a2.27 2.27 0 0 1 .2-.32l.08-.12.2-.28.27-.38.31-.44.84-1.18a.78.78 0 0 1 .16-.18.33.33 0 0 1 .22-.08h.64v-.02zm4.78.77h-1.56v3.58h-1V3.09h-1.6v-.77h4.16v.78zm1.3 1.54c.012.198.052.393.12.58.056.15.14.285.25.4a1 1 0 0 0 .36.24c.15.055.31.082.47.08a1.43 1.43 0 0 0 .44-.06 1.94 1.94 0 0 0 .32-.13l.24-.13a.41.41 0 0 1 .2-.06.22.22 0 0 1 .2.1l.3.35a1.75 1.75 0 0 1-.39.34 2.18 2.18 0 0 1-.45.22 2.5 2.5 0 0 1-.48.12 3.32 3.32 0 0 1-.47 0 2.33 2.33 0 0 1-.85-.15 1.89 1.89 0 0 1-.68-.45 2.09 2.09 0 0 1-.45-.73 2.83 2.83 0 0 1-.17-1 2.42 2.42 0 0 1 .14-.84 2 2 0 0 1 .41-.6 ...
# </a>
# </li>
# </ul>
# <p class="cf_app_banner-disclaimer">Бесплатное приложение ЦИАН доступно для iOS, Android и Windows Phone.</p>
# </div>
# </div>
# <div class="cg-col-1 cg-skip-2">
# <div class="cf_app_banner-close">
# <button class="cf_app_banner-close_button" id="cf_app_banner-close_button" type="button">
# <svg height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M7 5.586L2.05.636.636 2.05 5.586 7l-4.95 4.95 1.414 1.414L7 8.414l4.95 4.95 1.414-1.414L8.414 7l4.95-4.95L11.95.636 7 5.586z" fill="currentColor" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# </div>
# </div>
# </div>
# </figure>
# <script>
#   (function(){
#     var COOKIE_NAME = 'app_banner_disabled';
#     var COOKIE_DOMAIN = 'cian.ru';
#     var SESSION = 0;
#     var MONTH = 30;
#     var YEAR = 365;
#
#     var setDisabledCookie = function setDisabledCookie(expirationDate) {
#       document.cookie = COOKIE_NAME+'=true; path=/; domain='+COOKIE_DOMAIN+(expirationDate?'; expires='+expirationDate.toUTCString():'');
#     }
#
#     var disableBannerFor = function disableBannerFor(days) {
#       if (!days) {
#         setDisabledCookie();
#         return;
#       }
#
#       var expirationDate = new Date();
#       expirationDate.setHours(0, 0, 0, 0);
#       expirationDate.setDate(expirationDate.getDate() + days);
#       setDisabledCookie(expirationDate);
#     }
#
#     var track = function track(options){
#       options.eventLabel = options.eventLabel || '';
#       window.ga && ga('send', 'event', 'mob_app', options.eventAction, options.eventLabel);
#       window.ca && ca('event', {name: 'oldevent', category: 'mob_app', action: options.eventAction, label: options.eventLabel});
#     }
#
#     document.addEventListener('DOMContentLoaded', function() {
#       disableBannerFor(SESSION);
#       track({ eventAction: 'open' });
#
#       document.getElementById('cf_app_banner-close_button').addEventListener('click', function() {
#         var banner = document.getElementById('cf_app_banner');
#         if (banner) {
#           banner.setAttribute('hidden', 'true');
#           banner = null;
#         }
#
#         disableBannerFor(MONTH);
#         track({ eventAction: 'close' });
#       });
#
#       [].forEach.call(document.getElementsByClassName('cf_app_banner-store_link'), function(link) {
#         link.addEventListener('click', function() {
#           disableBannerFor(YEAR);
#           track({ eventAction: 'click', eventLabel: link.getAttribute('data-store-type') })
#         });
#       });
#     });
#   })();
# </script>
# <div class="cf_header cf_header--embedded">
# <div class="cf_header-top">
# <div class="cg-container-fluid-xs">
# <div class="cg-row">
# <div class="cg-skip-3 cg-col-9 cg-col-s-8 cg-skip-s-0">
# <div class="cf_header-top_menu">
# ...
# </li>
# </ul>
# </div>
# <div class="js-footer-projects"></div>
# <script data-aload="/static/scripts/footer_links.js" type="text/javascript"></script>
# </div>
# <div class="footer-legal">
# <!--noindex-->ЦИАН — база данных о недвижимости. Использование сайта, в том числе размещение объявлений, означает согласие с <a href="/help/about/rules/">Пользовательским соглашением</a> и <a href="/help/about/privacy/">Политикой конфиденциальности ЦИАН</a>. Оплачивая лицензионный платеж, вы принимаете <a href="/help/about/oferta/">Лицензионное соглашение</a>.<!--/noindex-->
# </div>
# <div class="copyrights">
# <div class="center">
# <ul>
# <li>© 2017 ЦИАН ГРУПП</li>
# <li><a class="_toMobileVersion" href="">Мобильная версия сайта</a></li>
# </ul>
# <div class="footer-counters">
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-30374201-2' );
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
#
#
#
#   ga('set', 'dimension6', 'not_authorized');
#   ga('set', 'dimension7', 'not_authorized');
#   ga('set', 'dimension14', '96');
#
#
#     ga('set', 'dimension19', 'true');
#     <!-- В новой выдаче трекаем просмотр из js -->
#
#
# </script>
# <!-- /Google Analytics -->
# <!-- Retail Rocket -->
# <script>
#     var rrPartnerId = "550f12f91e99471c1446d760";
#     var rrApi = {};
#     var rrApiOnReady = rrApiOnReady || [];
#     rrApi.addToBasket = rrApi.order = rrApi.categoryView = rrApi.view = rrApi.recomMouseDown = rrApi.recomAddToCart = function() {};
#     $(function() {
#         var d = document
#         var ref = d.getElementsByTagName('script')[0];
#         var apiJs, apiJsId = 'rrApi-jssdk';
#         if (d.getElementById(apiJsId)) return;
#         apiJs = d.createElement('script');
#         apiJs.id = apiJsId;
#         apiJs.async = true;
#         apiJs.src = "//cdn.retailrocket.ru/content/javascript/tracking.js";
#         ref.parentNode.insertBefore(apiJs, ref);
#     });
# </script>
# <!-- / Retail Rocket -->
# </div>
# <div class="age">16+</div>
# <!-- -->
# <div class="artlebedev-link">
#                         Концепция дизайна — <a href="http://www.artlebedev.ru/" rel="nofollow" target="_blank">Студия Артемия Лебедева</a>
# </div>
# <!-- -->
# </div>
# </div>
# <div data-retailrocket-markup-block="564d96e365bf190cd0c72705"></div>
# <script src="/static/scripts/intersection.js"></script>
# <script src="/static/scripts/returned_users.js"></script>
# </div>
# <div class="popup_shadow" data-aload="">
# <div class="popup popup_login">
# <div class="popup_closer"></div>
# <div class="popup_content">
# <form action="" id="popup_login_form" method="post" onsubmit="return false">
# <table class="popup_login_form_table">
# <tr>
# <th></th>
# <td>
# <span class="pseudo popup_login_trigger_enter popup_login_trigger_active">Вход</span>
# <a href="/users.php?mode=reg" style="font-size: 18px;">Регистрация</a>
# </td>
# </tr>
# <tr>
# <th><span class="popup_login_id_text">ID или E-mail</span>:</th>
# <td><input class="popup_login_input_mail" name="login" type="text"/>
# <div class="popup_login_validator_tooltip">
# <div class="popup_login_validator_tooltip_arrow_left"></div>
# <div class="popup_login_validator_tooltip_content">Некорректный E-mail</div>
# </div>
# </td>
# </tr>
# <tr>
# <th>Пароль:</th>
# <td><input class="popup_login_input_pass" name="password" type="password"/><i class="popup_login_input_pass_trigger"></i>
# <div class="popup_login_validator_tooltip">
# <div class="popup_login_validator_tooltip_arrow_left"></div>
# <div class="popup_login_validator_tooltip_content">Не введен Пароль</div>
# </div>
# </td>
# </tr>
# <tr>
# <th></th>
# <td><label class="popup_login_remember"><input name="remember" type="checkbox">запомнить меня</input></label></td>
# </tr>
# <tr>
# <th></th>
# <td>
# <span class="submit_w"><button class="submit_login" disabled="disabled" type="submit"><span class="popup_spinner"></span>Войти</button></span>
# <a class="lost-" href="/users.php?mode=lostpassword">напомнить пароль</a>
# </td>
# </tr>
# </table>
# <input name="back_url" type="hidden" value="">
# <input name="csrf_token" type="hidden" value="a91280edefd5c5fffcb81877ca4b3e74ba25fc71">
# </input></input></form>
# </div>
# </div>
# </div>
# <div class="popup popup_comment">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <form action="/ajax/sale/flat/notes" id="popup_comment_form" onsubmit="return false">
#             Ваш комментарий:
#             <div><textarea class="popup_realtor_comment_text" cols="" name="text" rows=""></textarea></div>
# <div class="popup_plan_submit_row">
# <span class="submit_w"><button class="submit">Сохранить</button></span> или <span class="popup_cancel pseudo">отменить</span>
# </div>
# </form>
# </div>
# </div>
# <div class="popup popup_broken_address">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_broken_address_title">Адрес не распознан</div>
# <div class="popup_broken_address_body"><!--noindex-->Объявление нельзя найти по адресу.<br/>Проверьте правильность ввода адреса<!--/noindex--></div>
# <div class="popup_plan_submit_row">
# <span class="popup_broken_address_call_action"><span class="submit_w"><button class="popup_broken_address_submit">Редактировать объявление</button></span> или </span><span class="popup_cancel pseudo">отменить</span>
# </div>
# </div></div></link></div></body></html>
#
#
# <div class="popup popup_realtor_comment">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <form action="/ajax/sale/flat/realtor_notes" id="popup_realtor_comment_form" onsubmit="return false">
#             Ваш комментарий о риелторе:
#             <div><textarea class="popup_realtor_comment_text" cols="" name="text" rows=""></textarea></div>
# <div class="popup_plan_submit_row">
# <span class="submit_w"><button class="submit">Сохранить</button></span> или <span class="popup_cancel pseudo">отменить</span>
# </div>
# </form>
# </div>
# </div>
# <div class="popup_shadow" data-aload="">
# <div class="popup popup_stored_filter">
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_stored_filter_title">Сохранить поисковый фильтр</div>
# <!-- <div class="popup_stored_filter_info">Для сохранения поискового фильтра нужно придумать ему название.</div> -->
# <strong style="display: block; padding-bottom: 5px;">Название:</strong>
# <input class="c-input c-input_l popup_stored_filter_name" maxlength="255" name="name" type="text"/>
# <label class="popup_stored_filter_subscription_label">
# <input checked="" name="subscribe" type="checkbox">Получать новые уведомления на e-mail
#             </input></label>
# <div class="popup_stored_filter_subscription">
# <span class="popup_stored_filter_subscription_email_trigger pseudo"></span>
# <input class="popup_stored_filter_subscription_email_input c-input c-input_l" placeholder="E-mail" value=""/></div></div></div></div>
#
# <div class="popup_stored_filter_submit_row">
# <span class="submit_w"><button class="c-button c-button_white">Сохранить</button></span> или <span class="popup_cancel pseudo">отменить</span>
# </div>
#
#
#
# <div class="popup_shadow" data-aload="">
# <div class="popup popup_alert">
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_alert_box">
# <div class="popup_alert_box_title">Подтвердите</div>
# <div class="popup_alert_box_content"></div>
# <div class="popup_alert_submit_row"><span class="submit_w"><button class="submit">Да</button></span><span class="popup_alert_submit_row_cancel"> или
#                     <span class="popup_cancel pseudo">отменить</span></span></div>
# </div>
# </div>
# </div>
# </div>
# <div class="popup_shadow" data-aload="">
# <div class="popup popup_subscribe">
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_subscribe_title">
# <div class="popup_subscribe_title_image"></div>
# <div class="popup_subscribe_title_text">Подпишитесь<br/>на новые объявления бесплатно</div>
# </div>
# <div class="popup_subscribe_info">Мы будем отправлять все подходящие новые объявления вам на электронную почту</div>
# <div class="popup_subscribe_form">
# <input class="popup_subscribe_form_email" name="email" placeholder="E-mail" type="text" value=""/>
# <span class="popup_subscribe_form_submit_w submit_w">
# <button class="popup_subscribe_form_submit c-button c-button_white ">Отправить</button>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="popup popup_premium">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_premium_content">
# <div class="popup_premium_slides">
# <div class="popup_premium_slide">
# <div id="firstStepPremium">
# <div class="popup_premium_title">Премиум-статус</div>
# <div class="popup_premium_comment">Премиум-объявления размещаются на первых местах в поисковой
#                         выдаче и получают больше показов
#                     </div>
# <table class="popup_premium_tab">
# <tr>
# <th>Срок размещения</th>
# <td>
# <select class="popup_premium_days_select" name="period">
# <option selected="selected" value="0">бессрочно</option>
# <option value="14">14 дней</option>
# <option value="13">13 дней</option>
# <option value="12">12 дней</option>
# <option value="11">11 дней</option>
# <option value="10">10 дней</option>
# <option value="9">9 дней</option>
# <option value="8">8 дней</option>
# <option value="7">7 дней</option>
# <option value="6">6 дней</option>
# <option value="5">5 дней</option>
# <option value="4">4 дня</option>
# <option value="3">3 дня</option>
# <option value="2">2 дня</option>
# <option value="1">одни сутки</option>
# </select>
# </td>
# </tr>
# <tr>
# <th>Стоимость<br/>Премиум-объявления</th>
# <td>
# <strong>
# <span class="popup_premium_price"></span><span class="rur">р<span>уб.</span></span> в
#                                     сутки
#                                 </strong>
# <small>Всего на вашем счету <span id="popup_user_balance"></span><span class="rur">р<span>уб.</span></span>
# </small>
# </td>
# </tr>
# </table>
# <div class="popup_premium_submit_row" style="line-height: 20px">
# <span class="popup_submit_w">
# <button class="submit"><span class="popup_spinner"></span>Купить</button>
# </span>  или  <span class="popup_cancel pseudo">закрыть</span>
# <span class="popup_preloader">
# <img height="28" src="data:image/jpeg;base64,..." width="28"/>
# </span>
# </div>
# </div>
# </div>
# <div class="popup_premium_slide">
# <div class="popup_premium_title"><i></i>Покупка Премиум-статуса</div>
# <div class="popup_premium_comment" style="margin-bottom:5px">
#                     Для подтверждения своего права распоряжения счетом аккаунта
#                     введите код высланный Вам по sms
#                 </div>
# <table style="padding: 5px 0">
# <tbody>
# <tr>
# <th>Секретный код</th>
# <td><input class="popup_premium_secret_code_input" name="secret_code" type="text"/><span class="popup_premium_comment helpme"><span class="pseudo resend_code">Отправить еще раз</span></span></td>
# </tr>
# </tbody>
# </table>
# <div class="popup_submit_row">
# <span class="popup_submit_w">
# <button class="submit"><span class="popup_spinner"></span>Купить</button>
# </span>
#                      или
#                     <span class="popup_cancel pseudo">закрыть</span>
# <span class="popup_preloader">
# <img height="28" src="data:image/jpeg;base64,..." width="28"/>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="popup popup_premium_import">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <form onsubmit="return false">
# <div class="popup_premium_import_title">Премиум-статус</div>
# <div class="popup_premium_import_comment">Премиум-объявления размещаются на первых местах в поисковой
#                 выдаче и получают больше показов
#             </div>
# <div>
#                 Премиум-статус и импортируемого объявления можно установить только в XML-файле с помощью тега <span class="popup_premium_import_code">&lt;premium&gt;1&lt;/premium&gt;</span><br/>
#                 Подробнее с техническими требованиями можно ознакомиться по ссылке <a href="//www.cian.ru/nd/validator/help/index.php">www.cian.ru/nd/validator/help/index.php</a>
# </div>
# <div class="popup_premium_import_submit_row">
# <span class="popup_cancel pseudo">отменить</span>
# </div>
# </form>
# </div>
# </div>
# <div class="popup popup_export">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_export_box">
# <div><a href="#" name="pdf">Скачать в PDF</a></div>
# <div><a href="#" name="docx">Скачать в DOCX</a></div>
# </div>
# </div>
# </div>
# <div class="popup popup_printhelp">
# <div class="popup_tail"></div>
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_printhelp_title">Подготовка объявлений к печати</div>
# <div class="popup_printhelp_info">Вычеркните объявление, и оно не будет показываться при печати.<br/>Вы
#             сможете восстановить его, кликнув по ссылке «восстановить» на том же месте.
#         </div>
# <div class="popup_printhelp_submit_row">
# <span class="submit_w"><button>Понятно</button></span>
# </div>
# </div>
# </div>
# <div class="popup_shadow" data-aload="">
# <div class="popup popup_modal">
# <div class="popup_closer"></div>
# <div class="popup_content">
# <div class="popup_modal_title"></div>
# <div class="popup_modal_content"></div>
# <div class="popup_modal_submit_row">
# <span class="submit_w"><button class="submit">OK</button></span><span class="submit_cancel"> или <span class="popup_cancel pseudo">отменить</span></span>
# </div>
# </div>
# </div>
# </div>
# <div class="popup_shadow popup_shadow_fixed" data-aload="">
# <div class="popup popup_callback js__popup-callback">
# <div class="popup_closer"></div>
# <div class="c-callback c-callback_pop-up js__popup-callback">
# <div class="c-callback__media">
# <div class="c-callback__media__box">
# <div class="c-callback__icon"></div>
# </div>
# <div class="c-callback__media__content">
#                     Оставьте номер вашего телефона<br/>
#                     и мы оперативно перезвоним вам!
#                 </div>
# </div>
# <div class="c-callback__form js__c-callback__form">
# <div class="c-callback__form__field">
# <span class="c-callback__form__field__prefix">+7</span>
# <input class="c-input c-input_l c-callback__form__field__input js__c-callback__phone" maxlength="13" tabindex="1" type="phone"/>
# </div>
# <button class="c-button c-button_primary c-button_l js__c-callback__submit" type="submit">
#                     Перезвоните мне
#                 </button>
# </div>
# <div class="c-callback__time">
# <div class="js__c-callback__time__opener" style="display:none;">
# <a class="c-pseudo js__c-callback__time__choose" href="">Удобное время для звонка</a>
# </div>
# <div class="js__c-callback__time__box" style="display:none;">
#                     Удобное время: <input class="c-input c-input_l c-callback__time__input js__c-callback__time" maxlength="5" placeholder="10:00" tabindex="2" type="text"/>
# <a class="c-pseudo c-callback__time__right-now js__c-callback__time__right-now" href="">Позвоните прямо сейчас!</a>
# </div>
# </div>
# <div class="c-callback__error js__c-callback__error" style="display:none;"></div>
# <div class="c-callback__final js__c-callback__final" style="display:none;"></div>
# <div class="c-callback__footer">
# <p class="js__c-callback__time-note" style="display:none;">Укажите время в интервале с 10:00 до 18:00 по Московскому времени</p>
# <p>
#                     ЦИАН напрямую соединяет миллионы покупателей квартир в новостройках с отделами продаж застройщиков. Ваши контактные данные никогда не будут использованы в рекламных целях или переданы третьим лицам.
#                 </p>
# </div>
# </div>
# </div>
# </div>
# <div class="s-popup serp-item__popup__context js-serp-item-menu-popup">
# <div class="s-popup__tail"></div>
# <div class="s-popup__content">
# </div>
# </div>
# <div class="s-popup js-serp-item-comment-popup">
# <div class="s-popup__tail"></div>
# <div class="s-popup__content">
# </div>
# </div>
# <input id="deal_type" type="hidden" value="sale"/>
# <input id="offer_type" type="hidden" value="flat"/>

# %% [markdown]
# Что же лежит в переменной `soup`? Невнимательный пользователь, скорее всего, скажет,что ничего вообще не изменилось. Тем не менее это не так. Теперь мы можем свободно бродить по HTML-дереву страницы, искать детей, родителей и вытаскивать их!
#
# Например, можно бродить по вершинам, указывая путь из тегов.

# %%
soup.html.head.title
# Out:
# <title>
#                 Купить 1, 2-комнатную квартиру в Москве — 93 400 объявлений
#             </title>

# %% [markdown]
# Можно вытащить из того места, куда мы забрели, текст с помощью метода `text`.

# %%
soup.html.head.title.text
# Out:
# '\n                Купить 1, 2-комнатную квартиру в Москве — 93 400 объявлений\n            '

# %% [markdown]
# Более того, зная адрес элемента, мы сразу можем найти его!

# %%
obj = soup.find('div', attrs = {'class':"serp-item__price-col"})
obj
# Out:
# <div class="serp-item__price-col">
# <div class="serp-item__solid">
#         13,19 млн. руб.
#     </div>
# <div class="serp-item__prop">
#
#
#                 253 654 руб.
#
#             за м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#             свободная
#         </div>
# <div class="objects_item_ipo objects_item_ipo_serp3">
# <!--AdFox START-->
# <!--cian-->
# <!--Площадка: Cian.ru / Результаты поиска / Ипотека в поиске-->
# <!--Категория: <не задана>-->
# <!--Тип баннера: (cian) Ипотека в поиске-->
# <!-- ________________________AdFox Asynchronous code START__________________________ -->
# <div id="adfox_serp_item_mortgage_581258360"></div>
# <script type="text/javascript">
#   setTimeout(function() {
#     if (typeof(pr) == 'undefined') { var pr = Math.floor(Math.random() * 4294967295) + 1; }
#     if (typeof(document.referrer) != 'undefined') {
#       if (typeof(afReferrer) == 'undefined') {
#         afReferrer = encodeURIComponent(document.referrer);
#       }
#     } else {
#       afReferrer = '';
#     }
#     var addate = new Date();
#
#
#     var dl = encodeURIComponent(document.location);
#     var pr1 = Math.floor(Math.random() * 4294967295) + 1;
#     var ip = encodeURI(encodeURI('puid16=вторичка, кирпично-монолитный&amp;puid15=https://cdn.cian.site/2/020/132/kvartira-moskva-michurinskiy-prospekt-231020230-1.jpg&amp;puid14=Москва, район Раменки, Мичуринский просп., 13&amp;puid13=13190000.0&amp;puid12=156055236'));
#
#     (function(){
#     var elem = document.getElementById('adfox_serp_item_mortgage_581258360');
#     elem.setAttribute('id', 'adfox_serp_item_mortgage_581258360' + pr1);
#     elem.innerHTML = '<div id="AdFox_banner_'+pr1+'" style="height: 100%;"></div>';
#     elem.innerHTML += '<div style="visibility:hidden; position:absolute;"><iframe id="AdFox_iframe_'+pr1+'" width=1 height=1 marginwidth=0 marginheight=0 scrolling=no frameborder=0></iframe></div>';
#     })();
#
#     if (typeof AdFox_getCodeScript === 'function') {
#       AdFox_getCodeScript(1,pr1,'//ads.adfox.ru/202100/prepareCode?p1=bqajz&amp;p2=ezvd&amp;pct=a&amp;pfc=a&amp;pfb=a&amp;plp=a&amp;pli=a&amp;pop=a&amp;pr=' + pr +'&amp;pt=b&amp;pd=' + addate.getDate() + '&amp;pw=' + addate.getDay() + '&amp;pv=' + addate.getHours() + '&amp;prr=' + afReferrer + '&amp;puid19=not_video&amp;puid17=false&amp;puid16=false&amp;puid10=no_agent&amp;puid7=2323&amp;puid6=10001_15000&amp;puid5=obl_id_1&amp;puid4=offer_type_2&amp;puid3=sale_type_second&amp;puid2=offer_flat&amp;puid1=deal_type_sale&amp;puid9=140&amp;puid8=13190000&amp;'+ip+'&amp;dl='+dl+'&amp;pr1='+pr1);
#     }
#   }, 0);
# </script>
# <!-- _________________________AdFox Asynchronous code END___________________________ -->
# </div>
# </div>

# %% [markdown]
# Полученный после поиска объект также обладает структурой bs4. Поэтому можно продолжить искать нужные нам объекты уже в нём!

# %%
obj2 = obj.find('div', attrs = {'class':"serp-item__solid"})
obj2
# Out:
# <div class="serp-item__solid">
#         13,19 млн. руб.
#     </div>

# %%
obj2.text
# Out:
# '\n        13,19 млн. руб.\n    '

# %% [markdown]
# Эх! Удалить бы ещё значки `\n`, которые означают смену строки и лишние пробелы... Сказано - сделано! Лишние пробелы убирает метод `strip`!

# %%
obj2.text.strip()
# Out:
# '13,19 млн. руб.'

# %% [markdown]
# Обратите внимание, что после всех этих безумных преобразований у данных поменялся тип. Теперь они str.

# %%
type(obj2.text.strip())
# Out:
# str

# %% [markdown]
# Если несколько элементов на странице обладают указанным адресом, то метод `find` вернёт только самый первый.  Чтобы найти все элементы с таким адресом, нужно использовать метод `findAll`. На выход будет выдан список!

# %%
dirty_prices = soup.findAll('div', attrs = {'class':"serp-item__price-col"})
dirty_prices[0].findAll('div',{'class':"serp-item__solid"})[0]
# Out:
# <div class="serp-item__solid">
#         13,19 млн. руб.
#     </div>

# %% [markdown]
# Повторим поиск. Сделаем это для каждого элемента из нашего нового списка...

# %%
clean_prices = [item.find('div', attrs = {'class':"serp-item__solid"}).text.strip() for item in dirty_prices]
clean_prices[:10]
# Out:
# ['13,19 млн. руб.',
#  '19,5 млн. руб.',
#  '5,7 млн. руб.',
#  '1,73 млн. руб.',
#  '1,79 млн. руб.',
#  '1,8 млн. руб.',
#  '1,8 млн. руб.',
#  '1,85 млн. руб.',
#  '1,88 млн. руб.',
#  '1,9 млн. руб.']

# %% [markdown]
# Собственно говоря, это всё. Полученные нами данные оказались немного грязноватыми. Везде есть слово `руб`, где-то стоимости указаны в тысячах, а где-то в миллионах...  Пока что бросим их в таком виде. Мало ли среди большого массива, который мы намерены скачать, есть ещё какие-то неточности. Лучше произвести очистку после выкачивания.  Оформим всё это дело в виде функции, чтобы прям красиво было...

# %%
def FlatPriceFinder(soup):
    dirty_prices = soup.findAll('div', attrs = {'class':"serp-item__price-col"})
    clean_prices = [item.find('div', attrs = {'class':"serp-item__solid"}).text.strip() for item in dirty_prices]
    return(clean_prices)

print(FlatPriceFinder(soup))
# Out:
# ['13,19 млн. руб.', '19,5 млн. руб.', '5,7 млн. руб.', '1,73 млн. руб.', '1,79 млн. руб.', '1,8 млн. руб.', '1,8 млн. руб.', '1,85 млн. руб.', '1,88 млн. руб.', '1,9 млн. руб.', '1,9 млн. руб.', '1,95 млн. руб.', '1,99 млн. руб.', '1,99 млн. руб.', '1,99 млн. руб.', '2,2 млн. руб.', '2,2 млн. руб.', '2,21 млн. руб.', '2,24 млн. руб.', '2,24 млн. руб.', '2,3 млн. руб.', '2,39 млн. руб.', '2,4 млн. руб.', '2,44 млн. руб.', '2,44 млн. руб.', '2,5 млн. руб.', '2,5 млн. руб.', '2,51 млн. руб.']

# %% [markdown]
# Попробуем скачать ещё что-нибудь таким способом! Например, метраж!

# %%
obj1 = soup.findAll('div',{'class':"serp-item__area-col"})
print(obj1)
# Out:
# [<div class="serp-item__area-col">
# <div class="serp-item__solid">52 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 9 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 28 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">50 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 18,7 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 14 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">52 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 9 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 32 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">34 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">11 м<sup>2</sup></div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">34 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10,2 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18,1 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">35 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10,8 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18,1 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">34 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10,2 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18,1 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">27 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 4 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 20 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">35 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10,8 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18,1 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">42 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 12 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 15 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">34 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 8,3 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 17,5 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">38 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 10 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 19 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">27 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 2,5 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 22 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">32 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 25 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">17 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 14 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">42 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 11,5 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 18 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">21 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 12,5 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">22 м<sup>2</sup></div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">23 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 15,8 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">22 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 14,3 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">26 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 24 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">37 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 12,4 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 16,5 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">23 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 5 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 11,2 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">25 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 16,4 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">30 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 21,5 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">48 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         кухня 1 м<sup>2</sup>
# </div>
# <div class="serp-item__prop">
#         жилая 35 м<sup>2</sup>
# </div>
# </div>, <div class="serp-item__area-col">
# <div class="serp-item__solid">25 м<sup>2</sup></div>
# <div class="serp-item__prop">
#         жилая 16,4 м<sup>2</sup>
# </div>
# </div>]

# %%
obj2  = [item.findAll('div',{'class':"serp-item__solid"})[0].text for item in obj1]
print(obj2)
# Out:
# ['52\xa0м2', '50\xa0м2', '52\xa0м2', '34\xa0м2', '11\xa0м2', '34\xa0м2', '35\xa0м2', '34\xa0м2', '27\xa0м2', '35\xa0м2', '42\xa0м2', '34\xa0м2', '38\xa0м2', '27\xa0м2', '32\xa0м2', '17\xa0м2', '42\xa0м2', '21\xa0м2', '22\xa0м2', '23\xa0м2', '22\xa0м2', '26\xa0м2', '37\xa0м2', '23\xa0м2', '25\xa0м2', '30\xa0м2', '48\xa0м2', '25\xa0м2']

# %% [markdown]
# В принципе, по большей части, это всё. Все остальные кусочки с ЦИАН забираются аналогичным образом. Пишем ещё с десяток подобных функций! И всё хорошо. Однако, если нажать на кнопку "Подробнее", мы увидим чудо-чудное, диво-дивное! Дополнительную информацию!
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/3.png" height="700" width="700">

# %% [markdown]
# ## 6. Качаем всё, что плохо лежит!
#
# ### 6.1 Список из хрефов
#
# Для начала соберём все хрефы на квартиры! Уже, как обычно (как же быстро новое становится обычным!), с помощью красивого супа мы найдём ссылки на все хрефы.

# %%
hrefs = soup.findAll('div', attrs = {'class':"serp-item__content__bottom__left"})
# убедимся, что мы не насобирали лишнего
print(len(hrefs))
hrefs[0]
# Out:
# 28
# <div class="serp-item__content__bottom__left">
# <span class="serp-item__print-info">
# 					ID:234339, +7 968 829-33-01
# 				</span>
# <a class="serp-item__card-link link" href="https://www.cian.ru/sale/flat/156055236/" target="_blank">Подробнее</a>
# </div>

# %% [markdown]
# Перейдём по вытащенному кусочку с хрефом в часть с тэгом `<a>`, а после вытащим из неё атрибут `href`. Так мы ещё не делали, но так тоже можно...

# %%
hrefs[0].a.attrs['href']
# Out:
# 'https://www.cian.ru/sale/flat/156055236/'

# %% [markdown]
# Делаем по аналогии со всеми хрефами!

# %%
clean_hrefs = [item.a.attrs['href'] for item in hrefs]
print(clean_hrefs)
# Out:
# ['https://www.cian.ru/sale/flat/156055236/', 'https://www.cian.ru/sale/flat/156145585/', 'https://www.cian.ru/sale/flat/152918180/', 'https://www.cian.ru/sale/flat/156514613/', 'https://www.cian.ru/sale/flat/156690149/', 'https://www.cian.ru/sale/flat/156201561/', 'https://www.cian.ru/sale/flat/154412243/', 'https://www.cian.ru/sale/flat/154243990/', 'https://www.cian.ru/sale/flat/155993966/', 'https://www.cian.ru/sale/flat/156209514/', 'https://www.cian.ru/sale/flat/155634565/', 'https://www.cian.ru/sale/flat/153192250/', 'https://www.cian.ru/sale/flat/155818651/', 'https://www.cian.ru/sale/flat/156407537/', 'https://www.cian.ru/sale/flat/156403169/', 'https://www.cian.ru/sale/flat/156542727/', 'https://www.cian.ru/sale/flat/156759762/', 'https://www.cian.ru/sale/flat/151730037/', 'https://www.cian.ru/sale/flat/156725878/', 'https://www.cian.ru/sale/flat/151729500/', 'https://www.cian.ru/sale/flat/151729730/', 'https://www.cian.ru/sale/flat/152578760/', 'https://www.cian.ru/sale/flat/153182392/', 'https://www.cian.ru/sale/flat/156653312/', 'https://www.cian.ru/sale/flat/156654029/', 'https://www.cian.ru/sale/flat/155541376/', 'https://www.cian.ru/sale/flat/155190378/', 'https://www.cian.ru/sale/flat/151730016/']

# %% [markdown]
# Нам надо будет путешествовать по огромному длинному списку из квартир, который простирается очень далеко вглубь ЦИАН. Пробираться вглубь сайта можно тыкая на циферки внизу старницы
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/4.png" height="900" width="900">
#
# Как только мы нажимаем на одну из цифр, меняется ссылка.
#
#     `https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&
#     p=3&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1`
#
#     `https://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=8&engine_version=2&offer_type=flat&
#      p=10&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1`
#
# Обратите внимание на начало второй строки. Когда мы находились на третьей строке, там стояла цифра 3. Как толкьо мы переходим на десятую страницу, цифра меняется на 10. Сама по себе ссылка на квартиры формируется в заисимости от того какие огранчения мы накладываем на квартиры в поиске. Каждое новое ограничение вырождается в новый кусочек ссылки. Например, если наложить ограничения на районы Москвы, то ссылка будет выглядеть вот так:
#
#     `https://www.cian.ru/cat.php?deal_type=sale&district%5B0%5D=1&district%5B1%5D=4&
#     district%5B2%5D=5&district%5B3%5D=6&district%5B4%5D=7&district%5B5%5D=8&district%5B6%5D=9&
#     district%5B7%5D=10&district%5B8%5D=11&engine_version=2&offer_type=flat&
#     p=10&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1`
#
# Пройдёмся по всем существующим страницам ЦИАН и заберём себе все ссылки на квартиры!
#
# Каждую ссылку будем формировать следующим образом:

# %%
page_part_1 = "https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p="
page_part_2 = "&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1"

page = page_part_1 + str(42) + page_part_2  # Мы окжемся на 42 странице
page
# Out:
# 'https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p=42&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1'

# %% [markdown]
# Всего на каждой странице находится 28 ссылок. Вытаскиваем необходимое нам число квартир.

# %%
page_part_1 = "https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p="
page_part_2 = "&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1"

all_hrefs = [ ]  # Тут мы будем хранить наши хрефы!

for i in range(1,11): # Тут регулируем количество квартир
    # Делаем ссылку!
    page = page_part_1 + str(i) + page_part_2
    
    # Загружаем страницу
    response = requests.get(page)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Забираем себе хрефы и очищаем их
    hrefs = soup.findAll('div', attrs = {'class':"serp-item__content__bottom__left"})
    clean_hrefs = [item.a.attrs['href'] for item in hrefs]
    all_hrefs.extend(clean_hrefs)

# %%
len(all_hrefs)
# Out:
# 280

# %% [markdown]
# Ого сколько хрефов! Пора качать данные по каждому из них!
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/1.jpg" height="500" width="500">

# %% [markdown]
# ### 6.2 Качаем данные по конкретному хрефу
#
# Перейдём по какому-нибудь одному хрефу и заберём всю информацию о квартире! Вообще всю.

# %%
response = requests.get(clean_hrefs[0])
html = response.content
soup = BeautifulSoup(html,'html.parser')

# %% [markdown]
# Собираем информацию...

# %%
price = soup.findAll('div', attrs = {'class':"object_descr_price"})[0].text.strip()
price
# Out:
# '59 000 000 руб.'

# %%
soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0].a.text
# Out:
# 'Университет,'

# %%
metro_infa = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
metro_infa.find('span',{'class':'object_item_metro_comment'}).text.strip()
# Out:
# '11\n                мин.\n                \n                    на машине'

# %%
komnata = soup.findAll('div', attrs = {'class':"object_descr_title"})[0].text.strip()
komnata
# Out:
# '3-комн. кв.\xa0\n    \n\n                \n                    \n                        в\xa0ЖК «Золотые Ключи 2»'

# %% [markdown]
# Дело осталось за малым. Достать основную информацию о квартире... Посмотрим где она лежит на странице через inspect где она лежит и заметим, что она лежит в таблице!
#
# "Хммм...", - скажем мы и начнём эту таблицу разгребать. Будем делать это хардкорно, по тэгам. Как настоящие мужики!

# %%
table = soup.findAll('table',attrs = {'class':"object_descr_props flat sale"})[0]
table
# Out:
# <table class="object_descr_props flat sale" style="float:left">
# <tr>
# <th style="padding-top:5px;">Общая информация:</th>
# </tr>
# <tr>
# <th>Этаж:</th>
# <td>
#                 16 / 18
#
#             </td>
# </tr>
# <tr>
# <th>Тип дома:</th>
# <td>
#             вторичка
#
#         </td>
# </tr>
# <tr>
# <th>Тип продажи:</th>
# <td>свободная</td>
# </tr>
# <tr>
# <th>Общая площадь:</th>
# <td>
# <i class="object_descr_details_color"></i>138 м<sup>2</sup>
# </td>
# </tr>
# <tr>
# <th>Площадь комнат:</th>
# <td>
# <i class="object_descr_details_color"></i><!--
# -->–
#         </td>
# </tr>
# <tr>
# <th>Жилая площадь:</th>
# <td>
# <i class="object_descr_details_color" style="background-color:#90C090"></i>110 м<sup>2</sup>
# </td>
# </tr>
# <tr>
# <th>Площадь кухни:</th>
# <td>
# <i class="object_descr_details_color" style="background-color:#C09090"></i>–
#         </td>
# </tr>
# <tr>
# <th>Раздельных санузлов:</th>
# <td><i class="object_descr_details_color" style="background-color:#90C0C0"></i>1
#             </td>
# </tr>
# <tr>
# <th>Совмещенных санузлов:</th>
# <td><i class="object_descr_details_color" style="background-color:#90C0C0"></i>1
#             </td>
# </tr>
# <tr>
# <th>Балкон:</th>
# <td><i class="object_descr_details_color" style="background-color:#C0C0C0"></i>нет
#         </td>
# </tr>
# <tr>
# <th>Лифт:</th>
# <td>1 пасс. + 1 груз.</td>
# </tr>
# <tr>
# <th>Телефон:</th>
# <td>да</td>
# </tr>
# <tr>
# <th>Вид из окна:</th>
# <td>двор и улица</td>
# </tr>
# </table>

# %% [markdown]
# Вытаскиваем все строки

# %%
rows = table.findAll('tr')[1:]  # В нулевой строке идёт фраза "Общая информация:" Забьём на неё! 
rows[0]
# Out:
# <tr>
# <th>Этаж:</th>
# <td>
#                 16 / 18
#
#             </td>
# </tr>

# %% [markdown]
# Находим конкретные элементы!

# %%
rows[8].findAll('th')[0].text.strip()
# Out:
# 'Совмещенных санузлов:'

# %%
rows[8].findAll('td')[0].text.strip()
# Out:
# '1'

# %% [markdown]
# Такимии незатейливыми действиями вытащили отдельный объект из отдельной строки. А теперь всё сразу в виде двух циклов:

# %%
rows = table.find_all('tr')[1:]  # Вытащили все строки
data = [ ]  # Задали пустой список, в который мы будем сохранять строки 
for row in rows:
    cols = [row.findAll('th')[0].text.strip(),row.findAll('td')[0].text.strip()] # очищаем каждую строку! 
    data.append(cols) # запоминаем
data
# Out:
# [['Этаж:', '16\xa0/\xa018'],
#  ['Тип дома:', 'вторичка'],
#  ['Тип продажи:', 'свободная'],
#  ['Общая площадь:', '138\xa0м2'],
#  ['Площадь комнат:', '–'],
#  ['Жилая площадь:', '110\xa0м2'],
#  ['Площадь кухни:', '–'],
#  ['Раздельных санузлов:', '1'],
#  ['Совмещенных санузлов:', '1'],
#  ['Балкон:', 'нет'],
#  ['Лифт:', '1 пасс. + 1 груз.'],
#  ['Телефон:', 'да'],
#  ['Вид из окна:', 'двор и улица']]

# %% [markdown]
# Чуток всё это облагородим. Подгрузим пакет, который носит гордое название pandas! Подробнее про этот пакет мы поговорим немного позже. Если быть кратким, то pandas используется для работы с таблицами. Превратим наш список из списков в красивую удобную табличку.

# %%
import pandas as pd
data = pd.DataFrame(data)
data.head()
# Out:
#                  0          1
# 0            Этаж:    16 / 18
# 1        Тип дома:   вторичка
# 2     Тип продажи:  свободная
# 3   Общая площадь:     138 м2
# 4  Площадь комнат:          –

# %% [markdown]
# Отлично! Почти вся информация в сборе. Не хватает только одного: географических координат. Они понадобятся нам для вычисления различных расстояний. На рассматриваемой нами странице есть карта. Если мы можем открыть карту, на которую нанесён дом, значит где-то в HTML страницы спрятаны географические координаты! Попробуем отыскать их.
#
# Для этого откроем [Яндекс - карты](https://yandex.ru/maps) и вобьём адрес любой недвижимости с ЦИАН. Скопируем одну из координат объекта. Откроем код ЦИАНовской странички и воспользуемся поиском по ней. Опа! Мы нашли нужный нам тэг...

# %%
coordinates = soup.findAll('div',{'class':"object-descr__map-tabs__content js-object_descr__panorama"})[0]
coordinates
# Out:
# <div class="object-descr__map-tabs__content js-object_descr__panorama">
# <panorama ns="ymapspano" point="[37.500953,55.713040]"></panorama>
# </div>

# %%
coordinates.panorama.attrs['point']  # перешли по тэгу, после по атрубуту и координаты у нас в кармане.
# Out:
# '[37.500953,55.713040]'

# %% [markdown]
# Пришло время соеденить всё это в одно целое. Функция для выкачки данных по одной квартире будет выглядеть следующим образом:

# %%
def One_Flat_Downloader(href):
    """
    Функция производит выкачку по одной ЦИАНовской ссылке 
    всей существующей информации о квартире.
    Ввод: ссылка на описание квартиры
    Вывод: словарь с информацией о квартире    
    """
    
    data = { }  # Задали пустой словарь, в который мы будем сохранять данные
    
    # Подгружаем страничку с информацией по квартире
    response = requests.get(href)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Вытаскиваем цену на квартиру
    price = soup.findAll('div', attrs = {'class':"object_descr_price"})[0].text.strip()
    data['Цена'] = price
    
    # Вытаскиваем метро
    station = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0].a.text
    data['Метро'] = station
    
    # Вытаскиваем количество комнат в квартире
    komnata = soup.findAll('div', attrs = {'class':"object_descr_title"})[0].text.strip()
    data['Комнаты'] = komnata
    
    # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
    Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
    Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
    data['До метро'] = Do_metro
    
    # Вытаскиваем координаты квартиры
    coordinates = soup.findAll('div',{'class':"object-descr__map-tabs__content js-object_descr__panorama"})[0]
    data['Координаты'] = coordinates.panorama.attrs['point']
    
    # Вытаскиваем всё остальное
    table = soup.findAll('table',attrs = {'class':"object_descr_props flat sale"})[0]
    rows = table.find_all('tr')[1:]  # Вытащили все строки
    for row in rows:
        cols = [row.findAll('th')[0].text.strip(),row.findAll('td')[0].text.strip()] # очищаем каждую строку! 
        data[cols[0]] = cols[1] # запоминаем
    return(data)

# %% [markdown]
# Попробуем применить эту функцию к нескольким разным квартирам. Функция каждый раз будет возвращать нам табличку, которая относится к данной квартире. Каждый раз табличка будет содержать разное количество строк, потому что информация о каждой квартире в своём роде уникальна...

# %%
dic = One_Flat_Downloader(clean_hrefs[0])
pd.DataFrame.from_dict(dic,orient='index')
# Out:
#                                                                        0
# Площадь комнат:                                                        –
# Координаты                                         [37.500953,55.713040]
# Этаж:                                                            16 / 18
# Метро                                                       Университет,
# Вид из окна:                                                двор и улица
# Комнаты                3-комн. кв. \n    \n\n                \n      ...
# Общая площадь:                                                    138 м2
# Телефон:                                                              да
# Раздельных санузлов:                                                   1
# Тип продажи:                                                   свободная
# Лифт:                                                  1 пасс. + 1 груз.
# До метро               11\n                мин.\n                \n  ...
# Балкон:                                                              нет
# Жилая площадь:                                                    110 м2
# Тип дома:                                                       вторичка
# Цена                                                     59 000 000 руб.
# Совмещенных санузлов:                                                  1
# Площадь кухни:                                                         –

# %%
dic = One_Flat_Downloader(clean_hrefs[-1])
pd.DataFrame.from_dict(dic,orient='index')
# Out:
#                                                                        0
# Площадь комнат:                                                 17.21 м2
# Координаты                                         [37.774751,55.670397]
# Этаж:                                                            15 / 17
# Метро                                                           Люблино,
# Вид из окна:                                                        двор
# Комнаты                1-комн. кв. \n    \n\n                \n      ...
# Сдача ГК:                                                2 кв. 2019 года
# Общая площадь:                                                   24,1 м2
# Совмещенных санузлов:                                                  1
# Тип продажи:                                                   свободная
# Лифт:                                                  1 пасс. + 1 груз.
# До метро               4\n                мин.\n                \n   ...
# Балкон:                                                          1 лодж.
# Жилая площадь:                                                   17,2 м2
# Тип дома:                          новостройка, \n            монолитный
# Цена                                                      3 677 660 руб.
# Площадь кухни:                                                         –

# %% [markdown]
# ### 6.3 Агрегирование
#
# Итак, что у нас есть?
#
# * Огромный список из хрефов, которые надо пройти
# * Функция, которая по каждому хрефу собирает для нас нужные данные
#
# Что мы хотим?
# * Мы хотим, чтобы все эти данные оказались в одной большой таблице. Нужно написать функцию, которая будет соединять словари в единое целое. При этом, если в однои из словарей нет какого-нибудь ключа, в итоговом словаре он должен заполняться как NA.

# %%
df1 = pd.DataFrame.from_dict(One_Flat_Downloader(all_hrefs[0]),orient='index')
df2 = pd.DataFrame.from_dict(One_Flat_Downloader(all_hrefs[1]),orient='index')

# %%
print(df1.shape,df2.shape) # посмотрим размерности получившихся таблиц
# Out:
# (18, 1) (21, 1)

# %%
df1.head(3)
# Out:
#                            0
# Ремонт:          отсутствует
# Площадь комнат:   22.3-22 м2
# Санузел:                 нет

# %%
df2.head(3)
# Out:
#                                      0
# Ремонт:                   дизайнерский
# Площадь комнат:            28-27-21 м2
# Координаты       [37.786339,55.791618]

# %% [markdown]
# Обратим внимание, что у наблюдений одинаковые номера! Ноль и ... ноль. Надо как-то решить эту проблему. Переименуем у второй таблицы номер наблюдения с нулевого на первый, а после объединим таблички с помощью команды `join`. Если номер таблицы не заменить, то команда не сработает.

# %%
df2.columns =[1]
df = df1.join(df2, how='outer') # Если поставить вместо outer - inner, то останутся только общие строки
                                # Если поставить left, то тольо строки из левой таблицы
                                # Если только rigth, то только строки из правой таблицы. 
df.shape
# Out:
# (22, 2)

# %% [markdown]
# Попробуйте немного поэкспериментировать с кодом ниже!

# %%
# Пример на команду join: 
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']},
                    index=['K0', 'K1', 'K2'])

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                     'D': ['D0', 'D2', 'D3']},
                     index=['K0', 'K2', 'K3'])
left.join(right,how = 'right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
# Посмотрим на нашу таблицу! 
df.head()
# Out:
#                                                                   0  \
# Балкон:                                                         нет
# Вид из окна:                                                   двор
# Высота потолков:                                                NaN
# Год постройки:                                                  NaN
# До метро          15\n                мин.\n                \n  ...
#
#                                                                   1
# Балкон:                                                           –
# Вид из окна:                                                   двор
# Высота потолков:                                                3 м
# Год постройки:                                                 2011
# До метро          9\n                мин.\n                \n   ...

# %% [markdown]
# В принципе, всё готово. Можно объединять таблицы по всем хрефам. В атаку!

# %%
# В эту табличку будем собирать данные
df = pd.DataFrame( )
k = 0 # Это номера наблюдений
for item in all_hrefs:
    k = k + 1
    # грузим новое наблюдение
    df1 = pd.DataFrame.from_dict(One_Flat_Downloader(item),orient='index')
    # присваиваем этому наблюдению номер
    df1.columns =[k]
    # закидываем его в итоговую таблицу
    df = df.join(df1, how='outer')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-3a7eec68ceef> in <module>()
#       5     k = k + 1
#       6     # грузим новое наблюдение
# ----> 7     df1 = pd.DataFrame.from_dict(One_Flat_Downloader(item),orient='index')
#       8     # присваиваем этому наблюдению номер
#       9     df1.columns =[k]
#
# <ipython-input-38-408d1a0d0770> in One_Flat_Downloader(href)
#      28     # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
#      29     Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
# ---> 30     Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
#      31     data['До метро'] = Do_metro
#      32
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ОШИБКА?! Но я же вроде бы всё писал правильно...  А ещё я запускал код позавчера и он ... работал! А сейчас всё сломалось и не работает... Я в шоке! Что мне делать?! БЛИИИИИИИН
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/5.jpg" height="700" width="700">
#
#
# Попытаемся понять где именно произошёл сбой.

# %%
l = 0
for item in all_hrefs:
    One_Flat_Downloader(item)
    l = l + 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-6bec1b36d22f> in <module>()
#       1 l = 0
#       2 for item in all_hrefs:
# ----> 3     One_Flat_Downloader(item)
#       4     l = l + 1
#
# <ipython-input-38-408d1a0d0770> in One_Flat_Downloader(href)
#      28     # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
#      29     Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
# ---> 30     Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
#      31     data['До метро'] = Do_metro
#      32
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
l
# Out:
# 5

# %%
all_hrefs[l]
# Out:
# 'https://www.cian.ru/sale/flat/156514613/'

# %% [markdown]
# Сбой произошёл на ссылке номер $l$. Переходим по ней, смотрим что там происходит иииии... там Новая Москва, а в Новой Москве нет метро. Именно поэтому скрипт не может найти его и пишет нам, что `object has no attribute 'text'`.
#
# Что же нам делать? Конечно же прописывать исключения! В python существует специальная конструкция, которая называется try - except. Посмотрим на то как она работает:
#
# ```python
# try:
#     something
# except Name_of_some_error:
#     do_something_else
# ```
#
# > Конструкция позволяет в случае, если произошла ошибка типа Name_of_some_error не заканчивать программу со словами «Все пропало! Ошибка!», а тут же передать управление блоку do_something_else, который что-нибудь сделает.

# %%
from math import log
a = [1,2,3,4,-5,-7,9,10,0,12,2]
b = [ ]
for atem in a:
    b.append(log(atem))
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-cadb1b86fa2b> in <module>()
#       3 b = [ ]
#       4 for atem in a:
# ----> 5     b.append(log(atem))
#       6 print(b)
#
# ValueError: math domain error

# %% [markdown]
# Хотелось бы посчитать логарифм от каждого числа в векторе, но отрицательные числа нам мешают. Ну хорошо! Пропишем исключение...

# %%
b = [ ]
for atem in a:
    try:
        b.append(log(atem))
    except Exception:
        b.append('NA')
print(b)
# Out:
# [0.0, 0.6931471805599453, 1.0986122886681098, 1.3862943611198906, 'NA', 'NA', 2.1972245773362196, 2.302585092994046, 'NA', 2.4849066497880004, 0.6931471805599453]

# %% [markdown]
# Видите, что произошло? Когда логарифм не мог вычислиться, в вектор записывалось NA. Про исключения можно почитать [на просорах интернета](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html). В данном примере мы наложили очень сильное исключение, которое работает при возникновении абсолютно любой неадекватной ситуации в коде. Это исключение при необходимость можно ослабить, заменив на другое.
#
# Пропишем в функции, которая выкачивает страницы, в графе, которая отвечает за станцию метро, такое исключение. Итоговый код для скачки ЦИАН будет иметь следующий вид:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

### Первая часть кода. Вытаскиваем список хрефов.

page_part_1 = "https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&p="
page_part_2 = "&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1"

all_hrefs = [ ]  # Тут мы будем хранить наши хрефы!

for i in range(1,11): # Тут регулируем количество квартир (на одной странице их 28)
    # Делаем ссылку!
    page = page_part_1 + str(i) + page_part_2
    
    # Загружаем страницу
    response = requests.get(page)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Забираем себе хрефы и очищаем их
    hrefs = soup.findAll('div', attrs = {'class':"serp-item__content__bottom__left"})
    clean_hrefs = [item.a.attrs['href'] for item in hrefs]
    all_hrefs.extend(clean_hrefs)
    print('Качаю хреф номер ',i)
    

### Вторая часть кода. Функция, которая вытаскивает наблюдения по одной квартирке.    
    
def One_Flat_Downloader(href):
    """
    Функция производит выкачку по одной ЦИАНовской ссылке 
    всей существующей информации о квартире.
    Ввод: ссылка на описание квартиры
    Вывод: словарь с информацией о квартире    
    """
    
    data = { }  # Задали пустой словарь, в который мы будем сохранять данные
    
    # Подгружаем страничку с информацией по квартире
    response = requests.get(href)
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    
    # Вытаскиваем цену на квартиру
    price = soup.findAll('div', attrs = {'class':"object_descr_price"})[0].text.strip()
    data['Цена'] = price
    
    # Вытаскиваем метро
    try:
        station = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0].a.text
        data['Метро'] = station
    except Exception:
        data['Метро'] = "NA"
    
    # Вытаскиваем расстояние до метро то ли пешком то ли на машине...
    try:
        Do_metro = soup.findAll('p', attrs = {'class':"objects_item_metro_prg"})[0]
        Do_metro = Do_metro.find('span',{'class':'object_item_metro_comment'}).text.strip()
        data['До метро'] = Do_metro
    except Exception:
        data['До метро'] = "NA"
    
    # Вытаскиваем количество комнат в квартире
    komnata = soup.findAll('div', attrs = {'class':"object_descr_title"})[0].text.strip()
    data['Комнаты'] = komnata
    
    # Вытаскиваем координаты квартиры
    coordinates = soup.findAll('div',{'class':"object-descr__map-tabs__content js-object_descr__panorama"})[0]
    data['Координаты'] = coordinates.panorama.attrs['point']
    
    # Вытаскиваем всё остальное
    table = soup.findAll('table',attrs = {'class':"object_descr_props flat sale"})[0]
    rows = table.find_all('tr')[1:]  # Вытащили все строки
    for row in rows:
        cols = [row.findAll('th')[0].text.strip(),row.findAll('td')[0].text.strip()] # очищаем каждую строку! 
        data[cols[0]] = cols[1] # запоминаем
    return(data) 


### Третья часть кода. Собираем данные по всем хрефам и объединяем их в огромную таблицу.

# В эту табличку будем собирать данные
df = pd.DataFrame( )
k = 0 # Это номера наблюдений
n = len(all_hrefs)
for item in all_hrefs:
    k = k + 1
    # грузим новое наблюдение
    df1 = pd.DataFrame.from_dict(One_Flat_Downloader(item),orient='index')
    # присваиваем этому наблюдению номер
    df1.columns =[k]
    # закидываем его в итоговую таблицу
    df = df.join(df1, how='outer')
    # Выдавать информацию о том, что сделана каждая десятая итерация! 
    if k%10 == 0:
        print('скачал ', k, ' квартир', n)

        
df = df.T  # Для удобства транспонируем таблицу        

# Добавим к итоговой таблице колонку из хрефов. Когда мы будем смотреть на данные,
# будет возникать довольно большое количество аномалий. Хотелось бы получше изучить
# их природу...

df['Хрефы'] = all_hrefs
# Out:
# Качаю хреф номер  1
# Качаю хреф номер  2
# Качаю хреф номер  3
# Качаю хреф номер  4
# Качаю хреф номер  5
# Качаю хреф номер  6
# Качаю хреф номер  7
# Качаю хреф номер  8
# Качаю хреф номер  9
# Качаю хреф номер  10
# скачал  10  квартир 280
# скачал  20  квартир 280
# скачал  30  квартир 280
# скачал  40  квартир 280
# скачал  50  квартир 280
# скачал  60  квартир 280
# скачал  70  квартир 280
# скачал  80  квартир 280
# скачал  90  квартир 280
# скачал  100  квартир 280
# скачал  110  квартир 280
# скачал  120  квартир 280
# скачал  130  квартир 280
# скачал  140  квартир 280
# скачал  150  квартир 280
# скачал  160  квартир 280
# скачал  170  квартир 280
# скачал  180  квартир 280
# скачал  190  квартир 280
# скачал  200  квартир 280
# скачал  210  квартир 280
# скачал  220  квартир 280
# скачал  230  квартир 280
# скачал  240  квартир 280
# скачал  250  квартир 280
# скачал  260  квартир 280
# скачал  270  квартир 280
# скачал  280  квартир 280

# %%
# Посмотрим на получившуюся таблицу! 
df.head( )
# Out:
#    Балкон: Вид из окна: Высота потолков: Год постройки:  \
# 1      нет            –              NaN            NaN
# 2  1 балк.         двор           2,64 м           1996
# 3  1 балк.         двор              NaN            NaN
# 4        –            –              NaN           2014
# 5        –            –              NaN            NaN
#
#                                             До метро Жилая площадь:  \
# 1  45\n                мин.\n                \n  ...          64 м2
# 2  5\n                мин.\n                \n   ...          49 м2
# 3  12\n                мин.\n                \n  ...          42 м2
# 4  15\n                мин.\n                \n  ...              –
# 5  25\n                мин.\n                \n  ...          26 м2
#
#                                              Комнаты             Координаты  \
# 1  3-комн. кв. \n    \n\n                \n      ...  [37.186408,55.967809]
# 2                                        3-комн. кв.  [37.580921,55.537928]
# 3  2-комн. кв. \n    \n\n                \n      ...  [37.489518,55.703474]
# 4                                             студия  [37.552543,55.491804]
# 5                                             студия  [37.322593,55.648382]
#
#                Лифт:                      Метро  \
# 1  1 пасс. + 1 груз.           Пятницкое шоссе,
# 2            2 пасс.  Бульвар Дмитрия Донского,
# 3  1 пасс. + 1 груз.                  Киевская,
# 4                  –           Бунинская аллея,
# 5                  –                  Киевская,
#
#                      ...                    Санузел:        Сдача ГК:  \
# 1                    ...                         NaN  4 кв. 2014 года
# 2                    ...                         NaN              NaN
# 3                    ...                         нет              NaN
# 4                    ...                         нет              NaN
# 5                    ...                         NaN              NaN
#
#   Совмещенных санузлов: Статус помещения: Телефон:  \
# 1                   NaN               NaN      NaN
# 2                   NaN               NaN       да
# 3                   NaN               NaN      нет
# 4                   NaN               NaN      NaN
# 5                     1               NaN      NaN
#
#                                Тип дома: Тип продажи:             Цена  \
# 1  новостройка, \n            монолитный    свободная   6 335 910 руб.
# 2  вторичка, \n            панельный дом    свободная   7 700 000 руб.
# 3     вторичка, \n            монолитный    свободная  23 400 000 руб.
# 4                               вторичка    свободная   1 290 000 руб.
# 5                               вторичка    свободная   1 440 000 руб.
#
#      Этаж:                                     Хрефы
# 1   1 / 16  https://www.cian.ru/sale/flat/155887679/
# 2  13 / 14  https://www.cian.ru/sale/flat/156776650/
# 3   8 / 18  https://www.cian.ru/sale/flat/153398088/
# 4    3 / 3  https://www.cian.ru/sale/flat/156788999/
# 5    3 / 3  https://www.cian.ru/sale/flat/153866608/
#
# [5 rows x 27 columns]

# %%
# Посмотрим на размерность таблицы!
df.shape
# Out:
# (280, 27)

# %% [markdown]
# Сохраняем данные в формате csv...

# %%
pd.DataFrame.to_csv(df,'CIAN_data.csv')
